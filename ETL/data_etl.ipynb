# %%
#Dependencies
import pymongo
import pandas as pd
import csv
import os
from pymongo import MongoClient

from datetime import datetime as dt

# %%
# NASDAQ_stocks=os.path.join('Data','stock_name','NASDAQ.txt')
# NASDAQ_df = pd.read_csv(NASDAQ_stocks,sep='\t')
# NASDAQ_df

# %% [markdown]
# ## Data Extraction files

# %%
# Financial Data 2014-2018 C:\Users\sruth\LearnJS\Projects\Draft_Ideas\Data\Financial
# https://www.kaggle.com/cnic92/200-financial-indicators-of-us-stocks-20142018
    
data1= os.path.join('Data','Financial','2018_Financial_Data.csv')
finanace2018_df = pd.read_csv(data1)


data2= os.path.join('Data','Financial','2017_Financial_Data.csv')
finanace2017_df = pd.read_csv(data2)

data3= os.path.join('Data','Financial','2016_Financial_Data.csv')
finanace2016_df = pd.read_csv(data3)

data4= os.path.join('Data','Financial','2015_Financial_Data.csv')
finanace2015_df = pd.read_csv(data4)

data5= os.path.join('Data','Financial','2014_Financial_Data.csv')
finanace2014_df = pd.read_csv(data5)

# %%
# col_names = data_df.columns.tolist()
# col_names

# %%
# data_df['Sector'].value_counts()

# %%
# Selecting columns needed
finanace2018_df = finanace2018_df[['Unnamed: 0','Revenue','Revenue Growth','Gross Profit', 'Profit Margin',  'grossProfitMargin', 'netProfitMargin','Total assets','Total debt' ,'Total liabilities','EPS','Dividend per Share','Sector']]

# %% [markdown]
# Data Extracted from CSV to DataFrame

# %%
finanace2018_df=finanace2018_df.rename(columns={'Unnamed: 0': 'ticker'})
finanace2018_df
# Out:
#      ticker       Revenue  Revenue Growth  Gross Profit  Profit Margin  \
# 0     CMCSA  9.450700e+10          0.1115  9.450700e+10          0.124
# 1       KMI  1.414400e+10          0.0320  6.856000e+09          0.105
# 2      INTC  7.084800e+10          0.1289  4.373700e+10          0.297
# 3        MU  3.039100e+10          0.4955  1.789100e+10          0.465
# 4        GE  1.216150e+11          0.0285  2.615400e+10         -0.187
# ...     ...           ...             ...           ...            ...
# 4387   YRIV  0.000000e+00          0.0000  0.000000e+00         -1.231
# 4388   YTEN  5.560000e+05         -0.4110  5.560000e+05        -16.493
# 4389   ZKIN  5.488438e+07          0.2210  1.829059e+07          0.128
# 4390    ZOM  0.000000e+00          0.0000  0.000000e+00            NaN
# 4391   ZYME  5.301900e+07          0.0243  5.301900e+07         -0.689
#
#       grossProfitMargin  netProfitMargin  Total assets    Total debt  \
# 0              1.000000         0.124128  2.516840e+11  1.117430e+11
# 1              0.484729         0.113758  7.886600e+10  3.732400e+10
# 2              0.617336         0.297157  1.279630e+11  2.635900e+10
# 3              0.588694         0.465105  4.337600e+10  4.639000e+09
# 4              0.215056        -0.183818  3.110720e+11  1.036000e+11
# ...                 ...              ...           ...           ...
# 4387                NaN              NaN  3.860471e+08  1.174096e+08
# 4388           1.000000       -16.492806  1.296000e+07  6.465000e+06
# 4389           0.333257         0.127871  7.639856e+07  1.927053e+07
# 4390                NaN              NaN  6.033519e+06  0.000000e+00
# 4391           1.000000        -0.689489  2.443630e+08  0.000000e+00
#
#       Total liabilities    EPS  Dividend per Share             Sector
# 0          1.791820e+11   2.56               0.917  Consumer Cyclical
# 1          4.366900e+10   0.66               0.725             Energy
# 2          5.340000e+10   4.57               1.200         Technology
# 3          1.011200e+10  12.27               0.000         Technology
# 4          2.595910e+11  -2.62               0.370        Industrials
# ...                 ...    ...                 ...                ...
# 4387       2.146348e+08  -0.08               0.000        Real Estate
# 4388       7.262000e+06  -0.92               0.000    Basic Materials
# 4389       3.913097e+07   0.52               0.000    Basic Materials
# 4390       2.376519e+06  -0.18               0.000        Industrials
# 4391       6.387300e+07  -1.26               0.000         Healthcare
#
# [4392 rows x 13 columns]

# %%
finanace2017_df = finanace2017_df[['Unnamed: 0','Revenue','Revenue Growth','Gross Profit', 'Profit Margin',  'grossProfitMargin', 'netProfitMargin','Total assets','Total debt' ,'Total liabilities','EPS','Dividend per Share','Sector']]
finanace2017_df=finanace2017_df.rename(columns={'Unnamed: 0': 'ticker'})
finanace2017_df
# Out:
#      ticker       Revenue  Revenue Growth  Gross Profit  Profit Margin  \
# 0        PG  6.505800e+10         -0.0037  3.242000e+10       0.236000
# 1      VIPS  1.102060e+10          0.3525  2.462794e+09       0.004100
# 2        KR  1.153370e+11          0.0501  2.583500e+10       0.017000
# 3       RAD  2.292754e+10          0.1039  5.064707e+09       0.000000
# 4       GIS  1.561980e+10         -0.0570  5.567800e+09       0.106000
# ...     ...           ...             ...           ...            ...
# 4955   TSRI  6.257258e+07          0.0258  1.024606e+07       0.004000
# 4956   TZOO  1.065240e+08         -0.0677  9.361500e+07       0.033000
# 4957  USATP  1.040000e+08             NaN  2.700000e+07      -0.019231
# 4958   WSTG  1.605670e+08         -0.0246  2.707600e+07       0.032000
# 4959    WTT  4.607800e+07          0.4709  1.926100e+07      -0.098000
#
#       grossProfitMargin  netProfitMargin  Total assets    Total debt  \
# 0              0.498325         0.235574  1.204060e+11  3.159200e+10
# 1              0.223472         0.026740  5.741055e+09  8.709512e+08
# 2              0.223996         0.017124  3.650500e+10  1.407700e+10
# 3              0.220901         0.000177  1.159375e+10  3.290801e+09
# 4              0.356458         0.106115  2.181260e+10  9.481700e+09
# ...                 ...              ...           ...           ...
# 4955           0.163747         0.004286  1.453514e+07  0.000000e+00
# 4956           0.878816         0.033138  4.567200e+07  0.000000e+00
# 4957                NaN              NaN  9.800000e+07  1.000000e+06
# 4958           0.168627         0.031526  1.046900e+08  0.000000e+00
# 4959           0.418009        -0.097509  4.692100e+07  1.829000e+06
#
#       Total liabilities     EPS  Dividend per Share              Sector
# 0          6.462800e+10  5.8000               2.698  Consumer Defensive
# 1          3.587099e+09  0.5015               0.000  Consumer Defensive
# 2          2.979500e+10  2.0800               0.450  Consumer Defensive
# 3          1.097968e+10  0.0800               0.000  Consumer Defensive
# 4          1.621620e+10  2.8200               1.920  Consumer Defensive
# ...                 ...     ...                 ...                 ...
# 4955       6.775668e+06  0.1400               0.000          Technology
# 4956       3.259400e+07  0.2700               0.000          Technology
# 4957       3.200000e+07     NaN                 NaN          Technology
# 4958       6.597800e+07  1.1300               0.680          Technology
# 4959       1.181800e+07 -0.2200               0.000          Technology
#
# [4960 rows x 13 columns]

# %%
finanace2016_df = finanace2016_df[['Unnamed: 0','Revenue','Revenue Growth','Gross Profit', 'Profit Margin',  'grossProfitMargin', 'netProfitMargin','Total assets','Total debt' ,'Total liabilities','EPS','Dividend per Share','Sector']]
finanace2016_df=finanace2016_df.rename(columns={'Unnamed: 0': 'ticker'})
finanace2016_df
# Out:
#      ticker       Revenue  Revenue Growth  Gross Profit  Profit Margin  \
# 0        PG  6.529900e+10         -0.0770  3.239000e+10       0.161000
# 1      VIPS  8.148496e+09          0.3156  1.957756e+09       0.005200
# 2        KR  1.098300e+11          0.0126  2.433400e+10       0.019000
# 3       RAD  2.077024e+10         -0.2171  4.991979e+09       0.008000
# 4       GIS  1.656310e+10         -0.0605  5.829500e+09       0.102000
# ...     ...           ...             ...           ...            ...
# 4792   TSRI  6.099828e+07          0.0626  9.959402e+06       0.007000
# 4793   TZOO  1.142630e+08         -0.0782  1.004080e+08       0.058000
# 4794  USATP  7.700000e+07             NaN  2.200000e+07      -0.090909
# 4795   WSTG  1.646090e+08         -0.5692  2.733100e+07       0.036000
# 4796    WTT  3.132700e+07         -0.0538  1.316200e+07      -0.058000
#
#       grossProfitMargin  netProfitMargin  Total assets    Total debt  \
# 0              0.496026         0.160921  1.271360e+11  3.059800e+10
# 1              0.240260         0.035992  3.613312e+09  6.309140e+08
# 2              0.221561         0.018565  3.389700e+10  1.207900e+10
# 3              0.240343         0.007966  1.127701e+10  6.994136e+09
# 4              0.351957         0.102481  2.171230e+10  8.430900e+09
# ...                 ...              ...           ...           ...
# 4792           0.163273         0.006545  1.408968e+07  0.000000e+00
# 4793           0.878745         0.058033  5.353000e+07  0.000000e+00
# 4794                NaN              NaN  8.500000e+07  2.000000e+06
# 4795           0.166036         0.035849  1.136980e+08  0.000000e+00
# 4796           0.420149        -0.058480  3.543500e+07  0.000000e+00
#
#       Total liabilities    EPS  Dividend per Share              Sector
# 0          6.915300e+10  3.800               2.658  Consumer Defensive
# 1          2.780799e+09  0.506               0.000  Consumer Defensive
# 2          2.709900e+10  2.090               0.500  Consumer Defensive
# 3          1.069558e+10  3.200               0.000  Consumer Defensive
# 4          1.555960e+10  2.830               1.780  Consumer Defensive
# ...                 ...    ...                 ...                 ...
# 4792       4.618188e+06  0.200               0.000          Technology
# 4793       3.546600e+07  0.470               0.000          Technology
# 4794       3.000000e+07    NaN                 NaN          Technology
# 4795       7.608700e+07  1.250               0.680          Technology
# 4796       3.729000e+06 -0.100               0.000          Technology
#
# [4797 rows x 13 columns]

# %%
finanace2015_df = finanace2015_df[['Unnamed: 0','Revenue','Revenue Growth','Gross Profit', 'Profit Margin',  'grossProfitMargin', 'netProfitMargin','Total assets','Total debt' ,'Total liabilities','EPS','Dividend per Share','Sector']]
finanace2015_df=finanace2015_df.rename(columns={'Unnamed: 0': 'ticker'})
finanace2015_df
# Out:
#      ticker       Revenue  Revenue Growth  Gross Profit  Profit Margin  \
# 0        PG  7.074900e+10         -0.0491  3.369300e+10       0.099000
# 1      VIPS  6.193685e+09          0.6587  1.524648e+09       0.006200
# 2        KR  1.084650e+11          0.1026  2.295300e+10       0.016000
# 3       RAD  2.652838e+10          0.0393  7.576732e+09       0.080000
# 4       GIS  1.763030e+10         -0.0156  5.949200e+09       0.069000
# ...     ...           ...             ...           ...            ...
# 4115   TSRI  5.740290e+07          0.1590  9.315468e+06       0.003000
# 4116   TZOO  1.239610e+08         -0.1911  1.058130e+08       0.088000
# 4117  USATP  5.800000e+07             NaN  1.700000e+07      -0.017241
# 4118   WSTG  3.820900e+08          0.1213  2.657300e+07       0.015000
# 4119    WTT  3.310911e+07         -0.1792  1.482787e+07       0.011000
#
#       grossProfitMargin  netProfitMargin  Total assets    Total debt  \
# 0              0.476233         0.099450  1.294950e+11  3.034500e+10
# 1              0.246162         0.039541  3.086662e+09  6.398369e+08
# 2              0.211617         0.015931  3.049700e+10  1.159700e+10
# 3              0.285609         0.079506  8.777425e+09  5.559116e+09
# 4              0.337442         0.069273  2.183200e+10  9.191500e+09
# ...                 ...              ...           ...           ...
# 4115           0.162282         0.003357  1.405128e+07  0.000000e+00
# 4116           0.853599         0.087640  6.857900e+07  5.658000e+06
# 4117                NaN              NaN  7.400000e+07  2.000000e+06
# 4118           0.069546         0.015258  9.408200e+07  0.000000e+00
# 4119           0.447849         0.011377  3.470632e+07  7.376000e+04
#
#       Total liabilities      EPS  Dividend per Share              Sector
# 0          6.644500e+10   2.5000               2.595  Consumer Defensive
# 1          2.530004e+09   0.4234               0.000  Consumer Defensive
# 2          2.505500e+10   1.7400               0.340  Consumer Defensive
# 3          8.720369e+09  43.4000               0.000  Consumer Defensive
# 4          1.566040e+10   2.0200               1.670  Consumer Defensive
# ...                 ...      ...                 ...                 ...
# 4115       4.948346e+06   0.1000               0.000          Technology
# 4116       4.719200e+07   0.7400               0.000          Technology
# 4117       2.100000e+07      NaN                 NaN          Technology
# 4118       5.542300e+07   1.2200               0.680          Technology
# 4119       1.801873e+06   0.0200               0.000          Technology
#
# [4120 rows x 13 columns]

# %%
finanace2014_df = finanace2014_df[['Unnamed: 0','Revenue','Revenue Growth','Gross Profit', 'Profit Margin',  'grossProfitMargin', 'netProfitMargin','Total assets','Total debt' ,'Total liabilities','EPS','Dividend per Share','Sector']]
finanace2014_df=finanace2014_df.rename(columns={'Unnamed: 0': 'ticker'})
finanace2014_df
# Out:
#      ticker       Revenue  Revenue Growth  Gross Profit  Profit Margin  \
# 0        PG  7.440100e+10         -0.0713  3.537100e+10       0.156000
# 1      VIPS  3.734148e+09          1.1737  9.285226e+08       0.005800
# 2        KR  9.837500e+10          0.0182  2.023700e+10       0.015000
# 3       RAD  2.552641e+10          0.0053  7.323734e+09       0.008000
# 4       GIS  1.790960e+10          0.0076  6.369800e+09       0.102000
# ...     ...           ...             ...           ...            ...
# 3803   TSRI  4.952987e+07          0.1028  8.278229e+06      -0.002000
# 3804   TZOO  1.532400e+08         -0.1019  1.340660e+08       0.085000
# 3805  USATP  4.200000e+07             NaN  1.500000e+07       0.666667
# 3806   WSTG  3.407580e+08          0.1344  2.481000e+07       0.017000
# 3807    WTT  4.033737e+07          0.1925  1.904369e+07       0.060000
#
#       grossProfitMargin  netProfitMargin  Total assets    Total debt  \
# 0              0.475410         0.156490  1.442660e+11  3.541700e+10
# 1              0.248657         0.036373  2.736687e+09  6.223741e+08
# 2              0.205713         0.015441  2.928100e+10  1.131000e+10
# 3              0.286908         0.009771  6.944871e+09  5.757143e+09
# 4              0.355664         0.101867  2.314570e+10  8.785800e+09
# ...                 ...              ...           ...           ...
# 3803           0.167136        -0.001735  1.356259e+07  0.000000e+00
# 3804           0.874876         0.085239  9.330700e+07  1.000000e+06
# 3805                NaN              NaN  7.100000e+07  0.000000e+00
# 3806           0.072808         0.016903  9.498100e+07  0.000000e+00
# 3807           0.472110         0.060097  3.628892e+07  3.205400e+04
#
#       Total liabilities     EPS  Dividend per Share              Sector
# 0          7.429000e+10  4.1900               2.448  Consumer Defensive
# 1          2.301093e+09  0.2396               0.000  Consumer Defensive
# 2          2.388600e+10  1.4700               0.307  Consumer Defensive
# 3          9.058573e+09  4.6000               0.000  Consumer Defensive
# 4          1.515620e+10  2.9000               1.550  Consumer Defensive
# ...                 ...     ...                 ...                 ...
# 3803       4.642508e+06 -0.0400               0.000          Technology
# 3804       5.748000e+07  0.8800               0.000          Technology
# 3805       1.700000e+07     NaN                 NaN          Technology
# 3806       5.541400e+07  1.2400               0.680          Technology
# 3807       2.658557e+06  0.1200               0.000          Technology
#
# [3808 rows x 13 columns]

# %% [markdown]
# Top 500 stock tickers based on S&P 2019

# %%
# https://datahub.io/core/s-and-p-500-companies#resource-s-and-p-500-companies_zip
# Top 500 companies as listed by S& P 500 in 2019
top500= os.path.join('Data','S&P500','S&P500.csv')
top500_df = pd.read_csv(top500)
top500_df
# Out:
#     Symbol                    Name                  Sector
# 0      MMM              3M Company             Industrials
# 1      AOS         A.O. Smith Corp             Industrials
# 2      ABT     Abbott Laboratories             Health Care
# 3     ABBV             AbbVie Inc.             Health Care
# 4      ACN           Accenture plc  Information Technology
# ..     ...                     ...                     ...
# 500    XYL              Xylem Inc.             Industrials
# 501    YUM         Yum! Brands Inc  Consumer Discretionary
# 502    ZBH  Zimmer Biomet Holdings             Health Care
# 503   ZION           Zions Bancorp              Financials
# 504    ZTS                  Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
# # Top 500 Stock tickers to list
list_topstocks=top500_df['Symbol'].tolist()

# %% [markdown]
# ## Transform the data extracted

# %%
#2018 Financial indicator of top 500 stocks 
top500_2018 =finanace2018_df.loc[finanace2018_df['ticker'].isin(list_topstocks)]
top500_2018
# Out:
#      ticker       Revenue  Revenue Growth  Gross Profit  Profit Margin  \
# 0     CMCSA  9.450700e+10          0.1115  9.450700e+10          0.124
# 1       KMI  1.414400e+10          0.0320  6.856000e+09          0.105
# 2      INTC  7.084800e+10          0.1289  4.373700e+10          0.297
# 3        MU  3.039100e+10          0.4955  1.789100e+10          0.465
# 4        GE  1.216150e+11          0.0285  2.615400e+10         -0.187
# ...     ...           ...             ...           ...            ...
# 2052    AZO  1.122108e+10          0.0305  5.973746e+09          0.119
# 2079   ANSS  1.293636e+09          0.1811  1.137751e+09          0.324
# 2173    AMG  2.378400e+09          0.0318  2.378400e+09          0.102
# 2228   SNPS  3.121058e+09          0.1454  2.385160e+09          0.139
# 2558   IPGP  1.459874e+09          0.0362  8.002680e+08          0.277
#
#       grossProfitMargin  netProfitMargin  Total assets    Total debt  \
# 0              1.000000         0.124128  2.516840e+11  1.117430e+11
# 1              0.484729         0.113758  7.886600e+10  3.732400e+10
# 2              0.617336         0.297157  1.279630e+11  2.635900e+10
# 3              0.588694         0.465105  4.337600e+10  4.639000e+09
# 4              0.215056        -0.183818  3.110720e+11  1.036000e+11
# ...                 ...              ...           ...           ...
# 2052           0.532368         0.119199  9.346980e+09  5.005930e+09
# 2079           0.879499         0.324183  3.265964e+09  0.000000e+00
# 2173           1.000000         0.102422  8.219100e+09  1.829600e+09
# 2228           0.764215         0.138581  6.145974e+09  4.693040e+08
# 2558           0.548176         0.276755  2.574450e+09  4.537800e+07
#
#       Total liabilities    EPS  Dividend per Share              Sector
# 0          1.791820e+11   2.56               0.917   Consumer Cyclical
# 1          4.366900e+10   0.66               0.725              Energy
# 2          5.340000e+10   4.57               1.200          Technology
# 3          1.011200e+10  12.27               0.000          Technology
# 4          2.595910e+11  -2.62               0.370         Industrials
# ...                 ...    ...                 ...                 ...
# 2052       1.086734e+10  49.59               0.000   Consumer Cyclical
# 2079       6.164170e+08   4.99               0.000          Technology
# 2173       3.250500e+09   4.55               1.200  Financial Services
# 2228       2.660959e+09   2.90               0.000          Technology
# 2558       3.682150e+08   7.55               0.000          Technology
#
# [476 rows x 13 columns]

# %%
#2017 Financial indicator of top 500 stocks 
top500_2017 =finanace2017_df.loc[finanace2017_df['ticker'].isin(list_topstocks)]
top500_2017
# Out:
#      ticker       Revenue  Revenue Growth  Gross Profit  Profit Margin  \
# 0        PG  6.505800e+10         -0.0037  3.242000e+10          0.236
# 2        KR  1.153370e+11          0.0501  2.583500e+10          0.017
# 4       GIS  1.561980e+10         -0.0570  5.567800e+09          0.106
# 5        PM  7.809800e+10          0.0420  1.831600e+10          0.077
# 6        KO  3.541000e+10         -0.1541  2.215500e+10          0.035
# ...     ...           ...             ...           ...            ...
# 4590   GRMN  3.121560e+09          0.0249  1.797941e+09          0.227
# 4610    AME  4.300170e+09          0.1198  1.438800e+09          0.158
# 4636   ANSS  1.095250e+09          0.1080  9.450860e+08          0.237
# 4661   SNPS  2.724880e+09          0.1248  2.070696e+09          0.050
# 4718   IPGP  1.408889e+09          0.4002  7.969110e+08          0.247
#
#       grossProfitMargin  netProfitMargin  Total assets    Total debt  \
# 0              0.498325         0.235574  1.204060e+11  3.159200e+10
# 2              0.223996         0.017124  3.650500e+10  1.407700e+10
# 4              0.356458         0.106115  2.181260e+10  9.481700e+09
# 5              0.234526         0.077275  4.296800e+10  3.433900e+10
# 6              0.625671         0.035244  8.789600e+10  4.768500e+10
# ...                 ...              ...           ...           ...
# 4590           0.575975         0.227132  4.948289e+09  0.000000e+00
# 4610           0.334591         0.158475  7.796064e+09  2.174289e+09
# 4636           0.862895         0.236705  2.941623e+09  0.000000e+00
# 4661           0.759922         0.050117  5.396414e+09  1.439870e+08
# 4718           0.565631         0.246729  2.367255e+09  4.898200e+07
#
#       Total liabilities    EPS  Dividend per Share              Sector
# 0          6.462800e+10  5.800               2.698  Consumer Defensive
# 2          2.979500e+10  2.080               0.450  Consumer Defensive
# 4          1.621620e+10  2.820               1.920  Consumer Defensive
# 5          5.319800e+10  3.880               4.220  Consumer Defensive
# 6          6.891900e+10  0.293               1.480  Consumer Defensive
# ...                 ...    ...                 ...                 ...
# 4590       1.095870e+09  3.770               2.550          Technology
# 4610       3.768431e+09  2.960               0.360          Technology
# 4636       6.957920e+08  3.050               0.000          Technology
# 4661       2.116690e+09  0.910               0.000          Technology
# 4718       3.449330e+08  6.500               0.000          Technology
#
# [478 rows x 13 columns]

# %%
#2016 Financial indicator of top 500 stocks 
top500_2016 =finanace2016_df.loc[finanace2016_df['ticker'].isin(list_topstocks)]
top500_2016
# Out:
#      ticker       Revenue  Revenue Growth  Gross Profit  Profit Margin  \
# 0        PG  6.529900e+10         -0.0770  3.239000e+10          0.161
# 2        KR  1.098300e+11          0.0126  2.433400e+10          0.019
# 4       GIS  1.656310e+10         -0.0605  5.829500e+09          0.102
# 5        PM  7.495300e+10          0.0141  1.729400e+10          0.093
# 6        KO  4.186300e+10         -0.0549  2.539800e+10          0.156
# ...     ...           ...             ...           ...            ...
# 4443   GRMN  3.045797e+09          0.0800  1.688525e+09          0.170
# 4462    AME  3.840087e+09         -0.0338  1.254588e+09          0.133
# 4487   ANSS  9.884650e+08          0.0485  8.416050e+08          0.269
# 4511   SNPS  2.422532e+09          0.0804  1.879570e+09          0.110
# 4565   IPGP  1.006173e+09          0.1164  5.522400e+08          0.259
#
#       grossProfitMargin  netProfitMargin  Total assets    Total debt  \
# 0              0.496026         0.160921  1.271360e+11  3.059800e+10
# 2              0.221561         0.018565  3.389700e+10  1.207900e+10
# 4              0.351957         0.102481  2.171230e+10  8.430900e+09
# 5              0.230731         0.092952  3.685100e+10  2.906700e+10
# 6              0.606693         0.155913  8.727000e+10  4.570900e+10
# ...                 ...              ...           ...           ...
# 4443           0.554379         0.169980  4.525133e+09  0.000000e+00
# 4462           0.326708         0.133371  7.100674e+09  2.341565e+09
# 4487           0.851426         0.268736  2.800526e+09  0.000000e+00
# 4511           0.775870         0.110143  5.240365e+09  2.050000e+08
# 4565           0.548852         0.259152  1.789999e+09  4.082300e+07
#
#       Total liabilities   EPS  Dividend per Share              Sector
# 0          6.915300e+10  3.80               2.658  Consumer Defensive
# 2          2.709900e+10  2.09               0.500  Consumer Defensive
# 4          1.555960e+10  2.83               1.780  Consumer Defensive
# 5          4.775100e+10  4.48               4.120  Consumer Defensive
# 6          6.405000e+10  1.51               1.400  Consumer Defensive
# ...                 ...   ...                 ...                 ...
# 4443       1.107130e+09  2.74               2.550          Technology
# 4462       3.844161e+09  2.20               0.360          Technology
# 4487       5.921210e+08  3.05               0.000          Technology
# 4511       2.045219e+09  1.76               0.000          Technology
# 4565       2.322750e+08  4.91               0.000          Technology
#
# [475 rows x 13 columns]

# %%
#2015 Financial indicator of top 500 stocks 
top500_2015 =finanace2015_df.loc[finanace2015_df['ticker'].isin(list_topstocks)]
top500_2015
# Out:
#      ticker       Revenue  Revenue Growth  Gross Profit  Profit Margin  \
# 0        PG  7.074900e+10         -0.0491  3.369300e+10          0.099
# 2        KR  1.084650e+11          0.1026  2.295300e+10          0.016
# 4       GIS  1.763030e+10         -0.0156  5.949200e+09          0.069
# 5        PM  7.390800e+10         -0.0774  1.742900e+10          0.093
# 6        KO  4.429400e+10         -0.0370  2.681200e+10          0.166
# ...     ...           ...             ...           ...            ...
# 3782   GRMN  2.820270e+09         -0.0176  1.538704e+09          0.162
# 3799    AME  3.974295e+09         -0.0119  1.356308e+09          0.149
# 3823   ANSS  9.427530e+08          0.0072  7.955070e+08          0.268
# 3847   SNPS  2.242211e+09          0.0898  1.723291e+09          0.101
# 3900   IPGP  9.012650e+08          0.1707  4.918770e+08          0.269
#
#       grossProfitMargin  netProfitMargin  Total assets    Total debt  \
# 0              0.476233         0.099450  1.294950e+11  3.034500e+10
# 2              0.211617         0.015931  3.049700e+10  1.159700e+10
# 4              0.337442         0.069273  2.183200e+10  9.191500e+09
# 5              0.235820         0.092994  3.395600e+10  2.848000e+10
# 6              0.605319         0.165959  8.999600e+10  4.411600e+10
# ...                 ...              ...           ...           ...
# 3782           0.545587         0.161767  4.499391e+09  0.000000e+00
# 3799           0.341270         0.148670  6.660450e+09  1.938040e+09
# 3823           0.843813         0.267855  2.729904e+09  0.000000e+00
# 3847           0.768568         0.100764  5.045739e+09  2.050000e+08
# 3900           0.545763         0.268682  1.453429e+09  1.966700e+07
#
#       Total liabilities   EPS  Dividend per Share              Sector
# 0          6.644500e+10  2.50               2.595  Consumer Defensive
# 2          2.505500e+10  1.74               0.340  Consumer Defensive
# 4          1.566040e+10  2.02               1.670  Consumer Defensive
# 5          4.543200e+10  4.42               4.040  Consumer Defensive
# 6          6.423200e+10  1.69               1.320  Consumer Defensive
# ...                 ...   ...                 ...                 ...
# 3782       1.154265e+09  2.39               2.010          Technology
# 3799       3.405824e+09  2.46               0.360          Technology
# 3823       5.354770e+08  2.82               0.000          Technology
# 3847       1.911750e+09  1.46               0.000          Technology
# 3900       1.927640e+08  4.60               0.000          Technology
#
# [469 rows x 13 columns]

# %% [markdown]
# ## Read individual stock data from CSV (filter them to top 500) and append them toa single DataFrame and filter for dates 2014-18

# %%
#2014 Financial indicator of top 500 stocks 
top500_2014 =finanace2014_df.loc[finanace2014_df['ticker'].isin(list_topstocks)]
top500_2014
# Out:
#      ticker       Revenue  Revenue Growth  Gross Profit  Profit Margin  \
# 0        PG  7.440100e+10         -0.0713  3.537100e+10          0.156
# 2        KR  9.837500e+10          0.0182  2.023700e+10          0.015
# 4       GIS  1.790960e+10          0.0076  6.369800e+09          0.102
# 5        PM  8.010600e+10          0.0010  1.933100e+10          0.094
# 6        KO  4.599800e+10         -0.0183  2.810900e+10          0.154
# ...     ...           ...             ...           ...            ...
# 3490   GRMN  2.870658e+09          0.0907  1.604412e+09          0.127
# 3506    AME  4.021964e+09          0.1190  1.361223e+09          0.145
# 3529   ANSS  9.360210e+08          0.0868  7.826350e+08          0.272
# 3550   SNPS  2.057472e+09          0.0485  1.600587e+09          0.126
# 3598   IPGP  7.698320e+08          0.1880  4.165180e+08          0.260
#
#       grossProfitMargin  netProfitMargin  Total assets    Total debt  \
# 0              0.475410         0.156490  1.442660e+11  3.541700e+10
# 2              0.205713         0.015441  2.928100e+10  1.131000e+10
# 4              0.355664         0.101867  2.314570e+10  8.785800e+09
# 5              0.241318         0.093539  3.518700e+10  2.945500e+10
# 6              0.611092         0.154311  9.202300e+10  4.174500e+10
# ...                 ...              ...           ...           ...
# 3490           0.558900         0.126874  4.693303e+09  0.000000e+00
# 3506           0.338447         0.145317  6.420963e+09  1.714026e+09
# 3529           0.836130         0.272099  2.752879e+09  0.000000e+00
# 3550           0.777939         0.125943  4.775499e+09  7.500000e+07
# 3598           0.541051         0.260375  1.210887e+09  3.563100e+07
#
#       Total liabilities   EPS  Dividend per Share              Sector
# 0          7.429000e+10  4.19               2.448  Consumer Defensive
# 2          2.388600e+10  1.47               0.307  Consumer Defensive
# 4          1.515620e+10  2.90               1.550  Consumer Defensive
# 5          4.639000e+10  4.76               3.880  Consumer Defensive
# 6          6.146200e+10  1.62               1.220  Consumer Defensive
# ...                 ...   ...                 ...                 ...
# 3490       1.289936e+09  1.89               1.890          Technology
# 3506       3.181402e+09  2.39               0.330          Technology
# 3529       5.353780e+08  2.77               0.000          Technology
# 3550       1.719329e+09  1.67               0.000          Technology
# 3598       1.643260e+08  3.85               0.000          Technology
#
# [463 rows x 13 columns]

# %%
stocklist_2018= top500_2018['ticker'].tolist()
# stocklist_2018

# %%
stock_df = pd.DataFrame()
for i in range(len(stocklist_2018)):
    data= f'Data/Individual_stocks/{stocklist_2018[i]}.csv'
    try:
        df = pd.read_csv(data)
        df["Year"]=pd.DatetimeIndex(df['date']).year
        df["ticker"]= stocklist_2018[i]
        df1=df.loc[df['Year']> 2013 ]
        stock_df=stock_df.append(df1)
    except:
        print(f"Individual stock {stocklist_2018[i] }file not found!")
        pass
# Out:
# Individual stock CAfile not found!
# Individual stock COLfile not found!

# %%
stock_df.head()
# Out:
#          date    volume       open      close       high        low  \
# 0  2019-04-18  13959300  42.740002  42.430000  42.830002  42.040001
# 1  2019-04-17  15338700  42.139999  42.570000  42.639999  41.889999
# 2  2019-04-16  10053600  41.840000  41.970001  42.180000  41.509998
# 3  2019-04-15  12729100  41.320000  41.779999  41.799999  41.259998
# 4  2019-04-12  11536400  41.070000  41.299999  41.330002  40.950001
#
#     adjclose  Year ticker
# 0  42.430000  2019  CMCSA
# 1  42.570000  2019  CMCSA
# 2  41.970001  2019  CMCSA
# 3  41.779999  2019  CMCSA
# 4  41.299999  2019  CMCSA

# %%
# stock_df_amzn=stock_df.loc[stock_df['ticker']== 'PG']
# stock_df_amzn

# %%
# stock_df_amzn.info()

# %%
# type(stock_df_amzn['date'][0])

# %%
#  stock_df_amzn['date']  = pd.to_datetime(stock_df_amzn['date'], format='%Y-%m-%d', errors='coerce')
# Out:
# C:\Users\sruth\Anaconda3\envs\PandasLearn\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#  stock_df_amzn['date']

# %%
#  pd.DataFrame(stock_df_amzn['date']).info()

# %%
# resample_df = amzn_df.resample('M',on ='date').mean()
# stock_df_amzn_mean=stock_df_amzn.resample('M', on = 'date').mean()
# stock_df_amzn_mean

# %%
# stock_df_amzn_mean.info()

# %%
# stock_df_amzn_mean_dict= stock_df_amzn_mean.to_dict('records')
# stock_df_amzn_mean_dict

# %%
# print(jsonify(stock_df_amzn_mean_dict))

# %%
# type(stock_df_amzn['date'][0])

# %%
# stock_df_amzn['date']  =  pd.to_datetime(stock_df_amzn['date'],unit='s')

# %%
# pd.date_range(start='1/1/2018', periods=5, freq='M')
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30',
#                '2018-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
# filtered= stock_df_amzn.resample('D', level = 0).mean()

# %% [markdown]
# Writing the dataframe to a CSV

# %%
path1= os.path.join('Data', 'output', 'stock.csv')
stock_df.to_csv(path1)

# %%
#TEST 
# data= f'Data/Individual_stocks/{stocklist_2018[1]}.csv'
# #   stock_df.append(pd.read_csv(data))
# df = pd.read_csv(data)
# df["Year"]=pd.DatetimeIndex(df['date']).year
# df["ticker"]= stocklist_2018[1]
# df1=df.loc[df['Year']> 2013 ]
# df1

# %% [markdown]
# Convert the DataFrame of 500 stock to a dictionary

# %%
stock_dict = stock_df.to_dict('records')

# %%
stock_dict
# Out:
# [{'date': '2019-04-18',
#   'volume': 13959300,
#   'open': 42.7400016784668,
#   'close': 42.43000030517578,
#   'high': 42.83000183105469,
#   'low': 42.040000915527344,
#   'adjclose': 42.43000030517578,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-17',
#   'volume': 15338700,
#   'open': 42.13999938964844,
#   'close': 42.56999969482422,
#   'high': 42.63999938964844,
#   'low': 41.88999938964844,
#   'adjclose': 42.56999969482422,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-16',
#   'volume': 10053600,
#   'open': 41.84000015258789,
#   'close': 41.97000122070313,
#   'high': 42.18000030517578,
#   'low': 41.5099983215332,
#   'adjclose': 41.97000122070313,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-15',
#   'volume': 12729100,
#   'open': 41.31999969482422,
#   'close': 41.77999877929688,
#   'high': 41.79999923706055,
#   'low': 41.2599983215332,
#   'adjclose': 41.77999877929688,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-12',
#   'volume': 11536400,
#   'open': 41.06999969482422,
#   'close': 41.29999923706055,
#   'high': 41.33000183105469,
#   'low': 40.95000076293945,
#   'adjclose': 41.29999923706055,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-11',
#   'volume': 9249400,
#   'open': 41.11999893188477,
#   'close': 41.040000915527344,
#   'high': 41.13999938964844,
#   'low': 40.849998474121094,
#   'adjclose': 41.040000915527344,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-10',
#   'volume': 13375200,
#   'open': 41.18000030517578,
#   'close': 41.08000183105469,
#   'high': 41.290000915527344,
#   'low': 40.77999877929688,
#   'adjclose': 41.08000183105469,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-09',
#   'volume': 14949600,
#   'open': 40.70000076293945,
#   'close': 41.040000915527344,
#   'high': 41.13999938964844,
#   'low': 40.56999969482422,
#   'adjclose': 41.040000915527344,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-08',
#   'volume': 12467200,
#   'open': 40.349998474121094,
#   'close': 40.709999084472656,
#   'high': 40.75,
#   'low': 40.16999816894531,
#   'adjclose': 40.709999084472656,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-05',
#   'volume': 21141000,
#   'open': 40.43000030517578,
#   'close': 40.41999816894531,
#   'high': 40.54999923706055,
#   'low': 40.310001373291016,
#   'adjclose': 40.41999816894531,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-04',
#   'volume': 12294800,
#   'open': 40.31999969482422,
#   'close': 40.40999984741211,
#   'high': 40.61999893188477,
#   'low': 40.11999893188477,
#   'adjclose': 40.40999984741211,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-03',
#   'volume': 21040200,
#   'open': 40.29999923706055,
#   'close': 40.27000045776367,
#   'high': 40.58000183105469,
#   'low': 39.97000122070313,
#   'adjclose': 40.27000045776367,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-02',
#   'volume': 14237200,
#   'open': 40.16999816894531,
#   'close': 40.02000045776367,
#   'high': 40.38999938964844,
#   'low': 39.810001373291016,
#   'adjclose': 40.02000045776367,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-04-01',
#   'volume': 14326000,
#   'open': 40.34000015258789,
#   'close': 40.310001373291016,
#   'high': 40.38999938964844,
#   'low': 39.97000122070313,
#   'adjclose': 40.10000228881836,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-29',
#   'volume': 21135700,
#   'open': 40.20000076293945,
#   'close': 39.97999954223633,
#   'high': 40.34000015258789,
#   'low': 39.59000015258789,
#   'adjclose': 39.7717170715332,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-28',
#   'volume': 10454400,
#   'open': 40.209999084472656,
#   'close': 40.41999816894531,
#   'high': 40.5,
#   'low': 40.11999893188477,
#   'adjclose': 40.20942687988281,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-27',
#   'volume': 18266600,
#   'open': 39.68000030517578,
#   'close': 40.209999084472656,
#   'high': 40.38999938964844,
#   'low': 39.68000030517578,
#   'adjclose': 40.00051879882813,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-26',
#   'volume': 11188300,
#   'open': 39.400001525878906,
#   'close': 39.63000106811523,
#   'high': 39.72000122070313,
#   'low': 39.209999084472656,
#   'adjclose': 39.42354202270508,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-25',
#   'volume': 15844100,
#   'open': 39.47999954223633,
#   'close': 39.18000030517578,
#   'high': 39.52000045776367,
#   'low': 38.93999862670898,
#   'adjclose': 38.975887298583984,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-22',
#   'volume': 17030100,
#   'open': 39.93999862670898,
#   'close': 39.459999084472656,
#   'high': 39.97000122070313,
#   'low': 39.349998474121094,
#   'adjclose': 39.25442886352539,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-21',
#   'volume': 17684000,
#   'open': 39.45000076293945,
#   'close': 40.04999923706055,
#   'high': 40.16999816894531,
#   'low': 39.25,
#   'adjclose': 39.84135437011719,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-20',
#   'volume': 23337900,
#   'open': 39.7599983215332,
#   'close': 39.47000122070313,
#   'high': 39.79999923706055,
#   'low': 38.900001525878906,
#   'adjclose': 39.26437759399414,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-19',
#   'volume': 16787000,
#   'open': 39.97999954223633,
#   'close': 39.77999877929688,
#   'high': 40.349998474121094,
#   'low': 39.70000076293945,
#   'adjclose': 39.57276153564453,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-18',
#   'volume': 21799700,
#   'open': 40.22999954223633,
#   'close': 39.91999816894531,
#   'high': 40.45000076293945,
#   'low': 39.88000106811523,
#   'adjclose': 39.71202850341797,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-15',
#   'volume': 66922700,
#   'open': 39.90999984741211,
#   'close': 40.47000122070313,
#   'high': 40.52000045776367,
#   'low': 39.540000915527344,
#   'adjclose': 40.2591667175293,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-14',
#   'volume': 16567600,
#   'open': 39.47000122070313,
#   'close': 39.86999893188477,
#   'high': 39.95000076293945,
#   'low': 39.36999893188477,
#   'adjclose': 39.66229248046875,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-13',
#   'volume': 21550400,
#   'open': 39.68999862670898,
#   'close': 39.560001373291016,
#   'high': 39.86000061035156,
#   'low': 39.36999893188477,
#   'adjclose': 39.35390853881836,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-12',
#   'volume': 21376100,
#   'open': 39.15999984741211,
#   'close': 39.4900016784668,
#   'high': 39.72999954223633,
#   'low': 38.97000122070313,
#   'adjclose': 39.28427505493164,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-11',
#   'volume': 25653900,
#   'open': 38.25,
#   'close': 39.16999816894531,
#   'high': 39.2400016784668,
#   'low': 38.099998474121094,
#   'adjclose': 38.96593856811523,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-08',
#   'volume': 13652900,
#   'open': 38.22000122070313,
#   'close': 38.18999862670898,
#   'high': 38.47999954223633,
#   'low': 37.88999938964844,
#   'adjclose': 37.99104309082031,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-07',
#   'volume': 14113100,
#   'open': 38.56999969482422,
#   'close': 38.38000106811523,
#   'high': 38.65999984741211,
#   'low': 38.13999938964844,
#   'adjclose': 38.18005752563477,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-06',
#   'volume': 11051900,
#   'open': 38.88000106811523,
#   'close': 38.61000061035156,
#   'high': 38.95000076293945,
#   'low': 38.45000076293945,
#   'adjclose': 38.40885543823242,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-05',
#   'volume': 14946000,
#   'open': 38.790000915527344,
#   'close': 38.72000122070313,
#   'high': 38.9900016784668,
#   'low': 38.54999923706055,
#   'adjclose': 38.51828384399414,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-04',
#   'volume': 15970400,
#   'open': 39.25,
#   'close': 38.72999954223633,
#   'high': 39.650001525878906,
#   'low': 38.38000106811523,
#   'adjclose': 38.52823257446289,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-03-01',
#   'volume': 24117200,
#   'open': 38.849998474121094,
#   'close': 39.099998474121094,
#   'high': 39.5099983215332,
#   'low': 38.81999969482422,
#   'adjclose': 38.89630126953125,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-28',
#   'volume': 18315300,
#   'open': 38.54999923706055,
#   'close': 38.66999816894531,
#   'high': 38.900001525878906,
#   'low': 38.52000045776367,
#   'adjclose': 38.46854019165039,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-27',
#   'volume': 17534900,
#   'open': 38.63999938964844,
#   'close': 38.52999877929688,
#   'high': 38.72000122070313,
#   'low': 38.38999938964844,
#   'adjclose': 38.32927322387695,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-26',
#   'volume': 18127700,
#   'open': 38.63000106811523,
#   'close': 38.79999923706055,
#   'high': 38.86000061035156,
#   'low': 38.40999984741211,
#   'adjclose': 38.59786605834961,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-25',
#   'volume': 16212000,
#   'open': 38.65999984741211,
#   'close': 38.56999969482422,
#   'high': 38.79999923706055,
#   'low': 38.310001373291016,
#   'adjclose': 38.36906433105469,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-22',
#   'volume': 20376900,
#   'open': 38.47999954223633,
#   'close': 38.61000061035156,
#   'high': 38.7400016784668,
#   'low': 38.40999984741211,
#   'adjclose': 38.40885543823242,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-21',
#   'volume': 22082200,
#   'open': 37.61000061035156,
#   'close': 38.47000122070313,
#   'high': 38.47000122070313,
#   'low': 37.43999862670898,
#   'adjclose': 38.26958847045898,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-20',
#   'volume': 14970400,
#   'open': 37.70000076293945,
#   'close': 37.790000915527344,
#   'high': 37.91999816894531,
#   'low': 37.52999877929688,
#   'adjclose': 37.5931282043457,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-19',
#   'volume': 12853500,
#   'open': 37.75,
#   'close': 37.54999923706055,
#   'high': 37.93999862670898,
#   'low': 37.47999954223633,
#   'adjclose': 37.35437774658203,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-15',
#   'volume': 15877100,
#   'open': 37.599998474121094,
#   'close': 37.77000045776367,
#   'high': 37.77999877929688,
#   'low': 37.150001525878906,
#   'adjclose': 37.57323455810547,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-14',
#   'volume': 16008400,
#   'open': 36.959999084472656,
#   'close': 37.2599983215332,
#   'high': 37.459999084472656,
#   'low': 36.75,
#   'adjclose': 37.06588745117188,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-13',
#   'volume': 14326400,
#   'open': 37.2400016784668,
#   'close': 37.02999877929688,
#   'high': 37.45000076293945,
#   'low': 36.790000915527344,
#   'adjclose': 36.83708572387695,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-12',
#   'volume': 14626400,
#   'open': 37.310001373291016,
#   'close': 37.2400016784668,
#   'high': 37.45000076293945,
#   'low': 37.040000915527344,
#   'adjclose': 37.04599380493164,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-11',
#   'volume': 14761400,
#   'open': 37.70000076293945,
#   'close': 37.0,
#   'high': 37.7400016784668,
#   'low': 36.900001525878906,
#   'adjclose': 36.80724334716797,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-08',
#   'volume': 18071000,
#   'open': 37.5,
#   'close': 37.599998474121094,
#   'high': 37.7599983215332,
#   'low': 36.9900016784668,
#   'adjclose': 37.40411758422852,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-07',
#   'volume': 22902300,
#   'open': 37.15999984741211,
#   'close': 37.68000030517578,
#   'high': 37.709999084472656,
#   'low': 37.09000015258789,
#   'adjclose': 37.483699798583984,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-06',
#   'volume': 20357300,
#   'open': 37.13999938964844,
#   'close': 37.16999816894531,
#   'high': 37.290000915527344,
#   'low': 36.790000915527344,
#   'adjclose': 36.976356506347656,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-05',
#   'volume': 24378500,
#   'open': 36.86999893188477,
#   'close': 37.150001525878906,
#   'high': 37.27000045776367,
#   'low': 36.56999969482422,
#   'adjclose': 36.95646286010742,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-04',
#   'volume': 22890300,
#   'open': 36.7400016784668,
#   'close': 36.77000045776367,
#   'high': 36.86999893188477,
#   'low': 36.27000045776367,
#   'adjclose': 36.57844161987305,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-02-01',
#   'volume': 18712300,
#   'open': 36.709999084472656,
#   'close': 36.790000915527344,
#   'high': 36.88000106811523,
#   'low': 36.47999954223633,
#   'adjclose': 36.59833908081055,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-31',
#   'volume': 31274500,
#   'open': 35.880001068115234,
#   'close': 36.56999969482422,
#   'high': 36.810001373291016,
#   'low': 35.77000045776367,
#   'adjclose': 36.37948226928711,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-30',
#   'volume': 22674000,
#   'open': 36.02999877929688,
#   'close': 35.43000030517578,
#   'high': 36.02999877929688,
#   'low': 35.25,
#   'adjclose': 35.24542236328125,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-29',
#   'volume': 19312300,
#   'open': 35.380001068115234,
#   'close': 36.08000183105469,
#   'high': 36.33000183105469,
#   'low': 35.380001068115234,
#   'adjclose': 35.89204025268555,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-28',
#   'volume': 26457000,
#   'open': 35.47999954223633,
#   'close': 35.36999893188477,
#   'high': 35.529998779296875,
#   'low': 34.669998168945305,
#   'adjclose': 35.185733795166016,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-25',
#   'volume': 25199500,
#   'open': 36.63000106811523,
#   'close': 35.779998779296875,
#   'high': 36.83000183105469,
#   'low': 35.560001373291016,
#   'adjclose': 35.59359741210937,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-24',
#   'volume': 40436900,
#   'open': 36.849998474121094,
#   'close': 36.2400016784668,
#   'high': 36.88000106811523,
#   'low': 35.439998626708984,
#   'adjclose': 36.05120468139648,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-23',
#   'volume': 36648300,
#   'open': 36.09000015258789,
#   'close': 36.88999938964844,
#   'high': 37.41999816894531,
#   'low': 35.959999084472656,
#   'adjclose': 36.69781494140625,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-22',
#   'volume': 32850900,
#   'open': 36.04999923706055,
#   'close': 34.970001220703125,
#   'high': 36.09000015258789,
#   'low': 34.830001831054695,
#   'adjclose': 34.78781890869141,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-18',
#   'volume': 22670000,
#   'open': 36.13000106811523,
#   'close': 36.209999084472656,
#   'high': 36.27999877929688,
#   'low': 35.529998779296875,
#   'adjclose': 36.021358489990234,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-17',
#   'volume': 25457200,
#   'open': 35.79999923706055,
#   'close': 35.90999984741211,
#   'high': 36.20000076293945,
#   'low': 35.7400016784668,
#   'adjclose': 35.722923278808594,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-16',
#   'volume': 20838500,
#   'open': 36.0099983215332,
#   'close': 35.900001525878906,
#   'high': 36.31999969482422,
#   'low': 35.880001068115234,
#   'adjclose': 35.712974548339844,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-15',
#   'volume': 13450000,
#   'open': 35.720001220703125,
#   'close': 35.83000183105469,
#   'high': 36.0,
#   'low': 35.56999969482422,
#   'adjclose': 35.643341064453125,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-14',
#   'volume': 16609400,
#   'open': 35.40999984741211,
#   'close': 35.77000045776367,
#   'high': 35.9900016784668,
#   'low': 35.349998474121094,
#   'adjclose': 35.58365249633789,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-11',
#   'volume': 19161600,
#   'open': 35.61000061035156,
#   'close': 35.630001068115234,
#   'high': 35.7400016784668,
#   'low': 35.310001373291016,
#   'adjclose': 35.44438171386719,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-10',
#   'volume': 16669600,
#   'open': 35.90999984741211,
#   'close': 35.81999969482422,
#   'high': 36.0,
#   'low': 35.5,
#   'adjclose': 35.63339233398437,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-09',
#   'volume': 16045100,
#   'open': 35.86999893188477,
#   'close': 36.060001373291016,
#   'high': 36.11999893188477,
#   'low': 35.5099983215332,
#   'adjclose': 35.87214279174805,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-08',
#   'volume': 20440700,
#   'open': 35.65999984741211,
#   'close': 35.720001220703125,
#   'high': 35.88999938964844,
#   'low': 35.36000061035156,
#   'adjclose': 35.533912658691406,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-07',
#   'volume': 26180800,
#   'open': 35.630001068115234,
#   'close': 35.43000030517578,
#   'high': 35.90999984741211,
#   'low': 35.27000045776367,
#   'adjclose': 35.24542236328125,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-04',
#   'volume': 22843800,
#   'open': 35.029998779296875,
#   'close': 35.810001373291016,
#   'high': 35.84000015258789,
#   'low': 34.860000610351555,
#   'adjclose': 35.623443603515625,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-03',
#   'volume': 28750400,
#   'open': 34.330001831054695,
#   'close': 34.639999389648445,
#   'high': 35.33000183105469,
#   'low': 34.130001068115234,
#   'adjclose': 34.45953750610352,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2019-01-02',
#   'volume': 16970400,
#   'open': 33.490001678466804,
#   'close': 34.36999893188477,
#   'high': 34.450000762939446,
#   'low': 33.419998168945305,
#   'adjclose': 34.19094467163086,
#   'Year': 2019,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-31',
#   'volume': 21613200,
#   'open': 34.290000915527344,
#   'close': 34.049999237060554,
#   'high': 34.59999847412109,
#   'low': 33.299999237060554,
#   'adjclose': 33.87261199951172,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-28',
#   'volume': 16231300,
#   'open': 34.860000610351555,
#   'close': 34.34999847412109,
#   'high': 35.36000061035156,
#   'low': 34.18000030517578,
#   'adjclose': 33.98203659057617,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-27',
#   'volume': 17456600,
#   'open': 33.799999237060554,
#   'close': 34.470001220703125,
#   'high': 34.5,
#   'low': 33.110000610351555,
#   'adjclose': 34.100753784179695,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-26',
#   'volume': 22917200,
#   'open': 33.259998321533196,
#   'close': 34.139999389648445,
#   'high': 34.169998168945305,
#   'low': 32.610000610351555,
#   'adjclose': 33.774288177490234,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-24',
#   'volume': 13391400,
#   'open': 33.720001220703125,
#   'close': 33.06999969482422,
#   'high': 33.970001220703125,
#   'low': 33.029998779296875,
#   'adjclose': 32.715747833251946,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-21',
#   'volume': 40280400,
#   'open': 34.669998168945305,
#   'close': 33.75,
#   'high': 36.0,
#   'low': 33.669998168945305,
#   'adjclose': 33.388465881347656,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-20',
#   'volume': 27230400,
#   'open': 35.220001220703125,
#   'close': 34.61999893188477,
#   'high': 35.43000030517578,
#   'low': 34.22999954223633,
#   'adjclose': 34.2491455078125,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-19',
#   'volume': 32338800,
#   'open': 35.81999969482422,
#   'close': 35.189998626708984,
#   'high': 36.560001373291016,
#   'low': 34.950000762939446,
#   'adjclose': 34.813037872314446,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-18',
#   'volume': 23690300,
#   'open': 36.459999084472656,
#   'close': 35.650001525878906,
#   'high': 36.459999084472656,
#   'low': 35.22999954223633,
#   'adjclose': 35.26811599731445,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-17',
#   'volume': 20725300,
#   'open': 36.38999938964844,
#   'close': 36.209999084472656,
#   'high': 36.86000061035156,
#   'low': 36.0,
#   'adjclose': 35.82211303710937,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-14',
#   'volume': 18146900,
#   'open': 36.38999938964844,
#   'close': 36.34000015258789,
#   'high': 36.849998474121094,
#   'low': 36.18000030517578,
#   'adjclose': 35.950721740722656,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-13',
#   'volume': 18407300,
#   'open': 37.02999877929688,
#   'close': 36.7599983215332,
#   'high': 37.29999923706055,
#   'low': 36.38999938964844,
#   'adjclose': 36.3662223815918,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-12',
#   'volume': 23589100,
#   'open': 37.310001373291016,
#   'close': 36.97999954223633,
#   'high': 37.4900016784668,
#   'low': 36.83000183105469,
#   'adjclose': 36.5838623046875,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-11',
#   'volume': 24295000,
#   'open': 37.790000915527344,
#   'close': 36.84000015258789,
#   'high': 37.93000030517578,
#   'low': 36.7400016784668,
#   'adjclose': 36.44536590576172,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-10',
#   'volume': 16235400,
#   'open': 37.540000915527344,
#   'close': 37.349998474121094,
#   'high': 37.599998474121094,
#   'low': 36.709999084472656,
#   'adjclose': 36.94990158081055,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-07',
#   'volume': 20605200,
#   'open': 37.65999984741211,
#   'close': 37.40999984741211,
#   'high': 38.02000045776367,
#   'low': 37.08000183105469,
#   'adjclose': 37.00925827026367,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-06',
#   'volume': 27455100,
#   'open': 37.310001373291016,
#   'close': 37.88000106811523,
#   'high': 37.91999816894531,
#   'low': 36.97999954223633,
#   'adjclose': 37.47422409057617,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-04',
#   'volume': 30198200,
#   'open': 39.20000076293945,
#   'close': 37.68999862670898,
#   'high': 39.290000915527344,
#   'low': 37.36000061035156,
#   'adjclose': 37.28625869750977,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-12-03',
#   'volume': 23382700,
#   'open': 39.09000015258789,
#   'close': 39.150001525878906,
#   'high': 39.22999954223633,
#   'low': 38.68000030517578,
#   'adjclose': 38.73062133789063,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-30',
#   'volume': 38075200,
#   'open': 39.45000076293945,
#   'close': 39.0099983215332,
#   'high': 39.599998474121094,
#   'low': 38.72000122070313,
#   'adjclose': 38.59211730957031,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-29',
#   'volume': 16362200,
#   'open': 38.70000076293945,
#   'close': 39.41999816894531,
#   'high': 39.65999984741211,
#   'low': 38.63999938964844,
#   'adjclose': 38.99772644042969,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-28',
#   'volume': 17816000,
#   'open': 38.22999954223633,
#   'close': 39.060001373291016,
#   'high': 39.06999969482422,
#   'low': 38.18999862670898,
#   'adjclose': 38.64158630371094,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-27',
#   'volume': 13718500,
#   'open': 37.61999893188477,
#   'close': 38.36000061035156,
#   'high': 38.45000076293945,
#   'low': 37.61999893188477,
#   'adjclose': 37.9490852355957,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-26',
#   'volume': 13283800,
#   'open': 37.77999877929688,
#   'close': 37.77000045776367,
#   'high': 37.9900016784668,
#   'low': 37.43999862670898,
#   'adjclose': 37.36540603637695,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-23',
#   'volume': 5743900,
#   'open': 37.2599983215332,
#   'close': 37.38999938964844,
#   'high': 37.709999084472656,
#   'low': 37.20000076293945,
#   'adjclose': 36.98947525024414,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-21',
#   'volume': 16525400,
#   'open': 36.70000076293945,
#   'close': 37.5099983215332,
#   'high': 37.72999954223633,
#   'low': 36.65999984741211,
#   'adjclose': 37.10818862915039,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-20',
#   'volume': 29276600,
#   'open': 38.15999984741211,
#   'close': 36.7599983215332,
#   'high': 38.47999954223633,
#   'low': 36.61000061035156,
#   'adjclose': 36.3662223815918,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-19',
#   'volume': 19265800,
#   'open': 38.59000015258789,
#   'close': 38.18000030517578,
#   'high': 38.90999984741211,
#   'low': 37.9900016784668,
#   'adjclose': 37.77101135253906,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-16',
#   'volume': 21542400,
#   'open': 38.709999084472656,
#   'close': 38.59000015258789,
#   'high': 38.91999816894531,
#   'low': 38.310001373291016,
#   'adjclose': 38.17662048339844,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-15',
#   'volume': 20772100,
#   'open': 38.11000061035156,
#   'close': 38.4900016784668,
#   'high': 38.4900016784668,
#   'low': 37.81999969482422,
#   'adjclose': 38.07769012451172,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-14',
#   'volume': 23447600,
#   'open': 38.0099983215332,
#   'close': 38.290000915527344,
#   'high': 38.68000030517578,
#   'low': 37.77000045776367,
#   'adjclose': 37.87983322143555,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-13',
#   'volume': 17569500,
#   'open': 38.25,
#   'close': 37.72000122070313,
#   'high': 38.4900016784668,
#   'low': 37.5099983215332,
#   'adjclose': 37.3159408569336,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-12',
#   'volume': 17042200,
#   'open': 38.25,
#   'close': 38.0,
#   'high': 38.58000183105469,
#   'low': 37.56999969482422,
#   'adjclose': 37.59293746948242,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-09',
#   'volume': 17819200,
#   'open': 38.15999984741211,
#   'close': 38.34000015258789,
#   'high': 38.709999084472656,
#   'low': 37.95000076293945,
#   'adjclose': 37.929298400878906,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-08',
#   'volume': 14327200,
#   'open': 38.4900016784668,
#   'close': 38.29999923706055,
#   'high': 38.58000183105469,
#   'low': 37.90999984741211,
#   'adjclose': 37.88972473144531,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-07',
#   'volume': 21551900,
#   'open': 37.97000122070313,
#   'close': 38.29999923706055,
#   'high': 38.34000015258789,
#   'low': 37.63999938964844,
#   'adjclose': 37.88972473144531,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-06',
#   'volume': 19682900,
#   'open': 38.11000061035156,
#   'close': 37.72999954223633,
#   'high': 38.18999862670898,
#   'low': 37.52999877929688,
#   'adjclose': 37.32583236694336,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-05',
#   'volume': 18780000,
#   'open': 37.93999862670898,
#   'close': 38.02000045776367,
#   'high': 38.349998474121094,
#   'low': 37.849998474121094,
#   'adjclose': 37.61272430419922,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-02',
#   'volume': 24593400,
#   'open': 38.09000015258789,
#   'close': 37.65999984741211,
#   'high': 38.22999954223633,
#   'low': 37.0099983215332,
#   'adjclose': 37.2565803527832,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-11-01',
#   'volume': 23797500,
#   'open': 38.099998474121094,
#   'close': 37.95000076293945,
#   'high': 38.16999816894531,
#   'low': 37.65999984741211,
#   'adjclose': 37.54347610473633,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-31',
#   'volume': 28182000,
#   'open': 37.959999084472656,
#   'close': 38.13999938964844,
#   'high': 38.650001525878906,
#   'low': 37.31999969482422,
#   'adjclose': 37.73143768310547,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-30',
#   'volume': 36610600,
#   'open': 36.4900016784668,
#   'close': 37.709999084472656,
#   'high': 37.77000045776367,
#   'low': 36.11999893188477,
#   'adjclose': 37.30604553222656,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-29',
#   'volume': 32373500,
#   'open': 35.91999816894531,
#   'close': 35.9900016784668,
#   'high': 36.52000045776367,
#   'low': 35.41999816894531,
#   'adjclose': 35.604469299316406,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-26',
#   'volume': 42435100,
#   'open': 35.63999938964844,
#   'close': 35.2400016784668,
#   'high': 36.41999816894531,
#   'low': 34.919998168945305,
#   'adjclose': 34.86250686645508,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-25',
#   'volume': 33839600,
#   'open': 35.880001068115234,
#   'close': 35.84000015258789,
#   'high': 36.27999877929688,
#   'low': 35.049999237060554,
#   'adjclose': 35.456077575683594,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-24',
#   'volume': 29974900,
#   'open': 35.97999954223633,
#   'close': 34.11999893188477,
#   'high': 36.2599983215332,
#   'low': 34.049999237060554,
#   'adjclose': 33.754501342773445,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-23',
#   'volume': 20100200,
#   'open': 35.40999984741211,
#   'close': 35.650001525878906,
#   'high': 35.790000915527344,
#   'low': 35.049999237060554,
#   'adjclose': 35.26811599731445,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-22',
#   'volume': 24301900,
#   'open': 36.099998474121094,
#   'close': 35.75,
#   'high': 36.25,
#   'low': 35.59000015258789,
#   'adjclose': 35.367042541503906,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-19',
#   'volume': 24405300,
#   'open': 36.11999893188477,
#   'close': 35.97999954223633,
#   'high': 36.5099983215332,
#   'low': 35.779998779296875,
#   'adjclose': 35.59457778930664,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-18',
#   'volume': 27905800,
#   'open': 36.27999877929688,
#   'close': 35.939998626708984,
#   'high': 36.63999938964844,
#   'low': 35.81999969482422,
#   'adjclose': 35.55500411987305,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-17',
#   'volume': 20386600,
#   'open': 36.11999893188477,
#   'close': 36.400001525878906,
#   'high': 36.66999816894531,
#   'low': 35.790000915527344,
#   'adjclose': 36.01008224487305,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-16',
#   'volume': 26282200,
#   'open': 35.220001220703125,
#   'close': 36.0,
#   'high': 36.099998474121094,
#   'low': 35.20000076293945,
#   'adjclose': 35.61436462402344,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-15',
#   'volume': 22877300,
#   'open': 34.610000610351555,
#   'close': 35.09000015258789,
#   'high': 35.66999816894531,
#   'low': 34.509998321533196,
#   'adjclose': 34.714115142822266,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-12',
#   'volume': 31439300,
#   'open': 34.049999237060554,
#   'close': 34.61999893188477,
#   'high': 34.790000915527344,
#   'low': 33.889999389648445,
#   'adjclose': 34.2491455078125,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-11',
#   'volume': 36284000,
#   'open': 34.59999847412109,
#   'close': 33.669998168945305,
#   'high': 34.689998626708984,
#   'low': 33.509998321533196,
#   'adjclose': 33.30932235717773,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-10',
#   'volume': 25754000,
#   'open': 35.36999893188477,
#   'close': 34.279998779296875,
#   'high': 35.650001525878906,
#   'low': 34.22999954223633,
#   'adjclose': 33.91278839111328,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-09',
#   'volume': 17407000,
#   'open': 35.279998779296875,
#   'close': 35.439998626708984,
#   'high': 35.83000183105469,
#   'low': 34.990001678466804,
#   'adjclose': 35.06036376953125,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-08',
#   'volume': 18925400,
#   'open': 34.5,
#   'close': 35.18000030517578,
#   'high': 35.22999954223633,
#   'low': 34.450000762939446,
#   'adjclose': 34.803150177001946,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-05',
#   'volume': 20433800,
#   'open': 35.189998626708984,
#   'close': 34.560001373291016,
#   'high': 35.22999954223633,
#   'low': 34.40999984741211,
#   'adjclose': 34.18978881835937,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-04',
#   'volume': 23118400,
#   'open': 35.049999237060554,
#   'close': 35.209999084472656,
#   'high': 35.279998779296875,
#   'low': 34.84000015258789,
#   'adjclose': 34.83282470703125,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-03',
#   'volume': 28967700,
#   'open': 35.779998779296875,
#   'close': 35.189998626708984,
#   'high': 35.880001068115234,
#   'low': 35.009998321533196,
#   'adjclose': 34.813037872314446,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-02',
#   'volume': 25036400,
#   'open': 35.279998779296875,
#   'close': 35.70000076293945,
#   'high': 35.88999938964844,
#   'low': 35.0,
#   'adjclose': 35.31758117675781,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-10-01',
#   'volume': 20430700,
#   'open': 35.529998779296875,
#   'close': 35.52000045776367,
#   'high': 35.63999938964844,
#   'low': 34.990001678466804,
#   'adjclose': 34.9515380859375,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-28',
#   'volume': 17306300,
#   'open': 35.25,
#   'close': 35.40999984741211,
#   'high': 35.65999984741211,
#   'low': 35.150001525878906,
#   'adjclose': 34.84330368041992,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-27',
#   'volume': 17055300,
#   'open': 35.5,
#   'close': 35.220001220703125,
#   'high': 35.720001220703125,
#   'low': 35.18000030517578,
#   'adjclose': 34.65634155273437,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-26',
#   'volume': 19777000,
#   'open': 35.599998474121094,
#   'close': 35.36999893188477,
#   'high': 35.90999984741211,
#   'low': 35.29999923706055,
#   'adjclose': 34.803939819335945,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-25',
#   'volume': 25533500,
#   'open': 35.86000061035156,
#   'close': 35.400001525878906,
#   'high': 35.97999954223633,
#   'low': 35.290000915527344,
#   'adjclose': 34.83346176147461,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-24',
#   'volume': 67853400,
#   'open': 35.95000076293945,
#   'close': 35.630001068115234,
#   'high': 36.27000045776367,
#   'low': 34.75,
#   'adjclose': 35.059783935546875,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-21',
#   'volume': 57634200,
#   'open': 37.95000076293945,
#   'close': 37.900001525878906,
#   'high': 38.060001373291016,
#   'low': 37.47999954223633,
#   'adjclose': 37.293453216552734,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-20',
#   'volume': 20489900,
#   'open': 37.61000061035156,
#   'close': 37.810001373291016,
#   'high': 37.9900016784668,
#   'low': 37.11999893188477,
#   'adjclose': 37.204891204833984,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-19',
#   'volume': 17452200,
#   'open': 37.650001525878906,
#   'close': 37.31999969482422,
#   'high': 37.93999862670898,
#   'low': 37.290000915527344,
#   'adjclose': 36.72273254394531,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-18',
#   'volume': 23443900,
#   'open': 37.11000061035156,
#   'close': 37.7400016784668,
#   'high': 37.88000106811523,
#   'low': 36.97999954223633,
#   'adjclose': 37.13601684570313,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-17',
#   'volume': 13318500,
#   'open': 37.02999877929688,
#   'close': 36.959999084472656,
#   'high': 37.209999084472656,
#   'low': 36.72000122070313,
#   'adjclose': 36.36849594116211,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-14',
#   'volume': 15004700,
#   'open': 37.150001525878906,
#   'close': 36.959999084472656,
#   'high': 37.209999084472656,
#   'low': 36.72000122070313,
#   'adjclose': 36.36849594116211,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-13',
#   'volume': 22993900,
#   'open': 36.150001525878906,
#   'close': 37.040000915527344,
#   'high': 37.22999954223633,
#   'low': 36.08000183105469,
#   'adjclose': 36.44721984863281,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-12',
#   'volume': 20877400,
#   'open': 36.209999084472656,
#   'close': 36.09000015258789,
#   'high': 36.29999923706055,
#   'low': 35.66999816894531,
#   'adjclose': 35.51241683959961,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-11',
#   'volume': 20600900,
#   'open': 36.43999862670898,
#   'close': 36.29999923706055,
#   'high': 36.5,
#   'low': 36.22000122070313,
#   'adjclose': 35.71905517578125,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-10',
#   'volume': 14292300,
#   'open': 36.400001525878906,
#   'close': 36.36000061035156,
#   'high': 36.5099983215332,
#   'low': 36.27999877929688,
#   'adjclose': 35.778099060058594,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-07',
#   'volume': 18156300,
#   'open': 35.900001525878906,
#   'close': 36.16999816894531,
#   'high': 36.36999893188477,
#   'low': 35.75,
#   'adjclose': 35.59113693237305,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-06',
#   'volume': 18329000,
#   'open': 36.52999877929688,
#   'close': 35.91999816894531,
#   'high': 36.52999877929688,
#   'low': 35.720001220703125,
#   'adjclose': 35.34513473510742,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-05',
#   'volume': 16801100,
#   'open': 36.290000915527344,
#   'close': 36.27999877929688,
#   'high': 36.47999954223633,
#   'low': 36.150001525878906,
#   'adjclose': 35.69937515258789,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-09-04',
#   'volume': 19158800,
#   'open': 36.75,
#   'close': 36.38000106811523,
#   'high': 36.849998474121094,
#   'low': 36.209999084472656,
#   'adjclose': 35.79777908325195,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-31',
#   'volume': 20414900,
#   'open': 36.599998474121094,
#   'close': 36.9900016784668,
#   'high': 37.06999969482422,
#   'low': 36.58000183105469,
#   'adjclose': 36.39801788330078,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-30',
#   'volume': 10563600,
#   'open': 36.54999923706055,
#   'close': 36.68000030517578,
#   'high': 36.70000076293945,
#   'low': 36.40999984741211,
#   'adjclose': 36.09297561645508,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-29',
#   'volume': 13419100,
#   'open': 36.27000045776367,
#   'close': 36.75,
#   'high': 36.900001525878906,
#   'low': 36.22000122070313,
#   'adjclose': 36.16185760498047,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-28',
#   'volume': 10815200,
#   'open': 36.65999984741211,
#   'close': 36.349998474121094,
#   'high': 36.70000076293945,
#   'low': 36.20000076293945,
#   'adjclose': 35.76825714111328,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-27',
#   'volume': 11958300,
#   'open': 36.63999938964844,
#   'close': 36.43000030517578,
#   'high': 36.70000076293945,
#   'low': 36.400001525878906,
#   'adjclose': 35.846981048583984,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-24',
#   'volume': 24501900,
#   'open': 35.36999893188477,
#   'close': 36.5,
#   'high': 36.790000915527344,
#   'low': 35.31999969482422,
#   'adjclose': 35.91585922241211,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-23',
#   'volume': 11487500,
#   'open': 35.380001068115234,
#   'close': 35.310001373291016,
#   'high': 35.47999954223633,
#   'low': 35.2599983215332,
#   'adjclose': 34.74489974975586,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-22',
#   'volume': 7951800,
#   'open': 35.70000076293945,
#   'close': 35.47999954223633,
#   'high': 35.7400016784668,
#   'low': 35.45000076293945,
#   'adjclose': 34.912181854248054,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-21',
#   'volume': 11407000,
#   'open': 35.45000076293945,
#   'close': 35.7400016784668,
#   'high': 36.0099983215332,
#   'low': 35.43000030517578,
#   'adjclose': 35.16802215576172,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-20',
#   'volume': 9957900,
#   'open': 35.70000076293945,
#   'close': 35.43000030517578,
#   'high': 35.72999954223633,
#   'low': 35.29999923706055,
#   'adjclose': 34.862979888916016,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-17',
#   'volume': 12079500,
#   'open': 35.560001373291016,
#   'close': 35.599998474121094,
#   'high': 35.849998474121094,
#   'low': 35.349998474121094,
#   'adjclose': 35.030258178710945,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-16',
#   'volume': 16394500,
#   'open': 35.049999237060554,
#   'close': 35.65999984741211,
#   'high': 35.849998474121094,
#   'low': 35.009998321533196,
#   'adjclose': 35.089298248291016,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-15',
#   'volume': 15367600,
#   'open': 35.20000076293945,
#   'close': 34.970001220703125,
#   'high': 35.27000045776367,
#   'low': 34.669998168945305,
#   'adjclose': 34.410343170166016,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-14',
#   'volume': 10478900,
#   'open': 35.09999847412109,
#   'close': 35.38999938964844,
#   'high': 35.4900016784668,
#   'low': 35.040000915527344,
#   'adjclose': 34.823623657226555,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-13',
#   'volume': 15910600,
#   'open': 35.11999893188477,
#   'close': 35.040000915527344,
#   'high': 35.189998626708984,
#   'low': 34.779998779296875,
#   'adjclose': 34.47922515869141,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-10',
#   'volume': 11873700,
#   'open': 35.2599983215332,
#   'close': 35.080001831054695,
#   'high': 35.34000015258789,
#   'low': 34.950000762939446,
#   'adjclose': 34.518585205078125,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-09',
#   'volume': 17122800,
#   'open': 35.09999847412109,
#   'close': 35.4900016784668,
#   'high': 35.810001373291016,
#   'low': 35.049999237060554,
#   'adjclose': 34.92202377319336,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-08',
#   'volume': 12297700,
#   'open': 35.470001220703125,
#   'close': 35.049999237060554,
#   'high': 35.4900016784668,
#   'low': 34.889999389648445,
#   'adjclose': 34.489059448242195,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-07',
#   'volume': 10952200,
#   'open': 35.45000076293945,
#   'close': 35.400001525878906,
#   'high': 35.52000045776367,
#   'low': 35.189998626708984,
#   'adjclose': 34.83346176147461,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-06',
#   'volume': 12087200,
#   'open': 35.59000015258789,
#   'close': 35.31999969482422,
#   'high': 35.7599983215332,
#   'low': 35.290000915527344,
#   'adjclose': 34.75474166870117,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-03',
#   'volume': 16485800,
#   'open': 34.939998626708984,
#   'close': 35.40999984741211,
#   'high': 35.43000030517578,
#   'low': 34.72999954223633,
#   'adjclose': 34.84330368041992,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-02',
#   'volume': 19240300,
#   'open': 35.169998168945305,
#   'close': 34.639999389648445,
#   'high': 35.20000076293945,
#   'low': 34.61999893188477,
#   'adjclose': 34.08562469482422,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-08-01',
#   'volume': 20155600,
#   'open': 35.900001525878906,
#   'close': 35.400001525878906,
#   'high': 35.900001525878906,
#   'low': 35.31999969482422,
#   'adjclose': 34.83346176147461,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-31',
#   'volume': 21644300,
#   'open': 35.650001525878906,
#   'close': 35.779998779296875,
#   'high': 36.09000015258789,
#   'low': 35.540000915527344,
#   'adjclose': 35.20737838745117,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-30',
#   'volume': 21883100,
#   'open': 35.060001373291016,
#   'close': 35.459999084472656,
#   'high': 35.70000076293945,
#   'low': 35.02000045776367,
#   'adjclose': 34.89249801635742,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-27',
#   'volume': 22686900,
#   'open': 34.84000015258789,
#   'close': 35.080001831054695,
#   'high': 35.61000061035156,
#   'low': 34.759998321533196,
#   'adjclose': 34.518585205078125,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-26',
#   'volume': 40293000,
#   'open': 34.84000015258789,
#   'close': 34.75,
#   'high': 35.09999847412109,
#   'low': 33.77000045776367,
#   'adjclose': 34.193862915039055,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-25',
#   'volume': 22055800,
#   'open': 33.389999389648445,
#   'close': 33.419998168945305,
#   'high': 33.52000045776367,
#   'low': 32.810001373291016,
#   'adjclose': 32.885143280029304,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-24',
#   'volume': 21795000,
#   'open': 34.169998168945305,
#   'close': 33.389999389648445,
#   'high': 34.290000915527344,
#   'low': 33.34999847412109,
#   'adjclose': 32.85562896728516,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-23',
#   'volume': 22336100,
#   'open': 34.15999984741211,
#   'close': 34.169998168945305,
#   'high': 34.299999237060554,
#   'low': 33.81999969482422,
#   'adjclose': 33.623146057128906,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-20',
#   'volume': 24577000,
#   'open': 34.77000045776367,
#   'close': 34.299999237060554,
#   'high': 34.950000762939446,
#   'low': 34.290000915527344,
#   'adjclose': 33.75106430053711,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-19',
#   'volume': 41627300,
#   'open': 35.139999389648445,
#   'close': 34.90999984741211,
#   'high': 35.290000915527344,
#   'low': 34.740001678466804,
#   'adjclose': 34.35129928588867,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-18',
#   'volume': 16172600,
#   'open': 34.11999893188477,
#   'close': 34.040000915527344,
#   'high': 34.450000762939446,
#   'low': 33.97999954223633,
#   'adjclose': 33.495227813720696,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-17',
#   'volume': 21119900,
#   'open': 34.709999084472656,
#   'close': 34.27000045776367,
#   'high': 34.919998168945305,
#   'low': 34.209999084472656,
#   'adjclose': 33.721542358398445,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-16',
#   'volume': 22937600,
#   'open': 34.740001678466804,
#   'close': 34.970001220703125,
#   'high': 35.27000045776367,
#   'low': 34.650001525878906,
#   'adjclose': 34.410343170166016,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-13',
#   'volume': 25167300,
#   'open': 34.400001525878906,
#   'close': 34.700000762939446,
#   'high': 35.150001525878906,
#   'low': 34.400001525878906,
#   'adjclose': 34.144664764404304,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-12',
#   'volume': 22374100,
#   'open': 33.68000030517578,
#   'close': 34.549999237060554,
#   'high': 34.56999969482422,
#   'low': 33.59999847412109,
#   'adjclose': 33.99706268310547,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-11',
#   'volume': 33639100,
#   'open': 33.09000015258789,
#   'close': 33.77000045776367,
#   'high': 34.18000030517578,
#   'low': 33.029998779296875,
#   'adjclose': 33.229549407958984,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-10',
#   'volume': 12363300,
#   'open': 33.709999084472656,
#   'close': 33.34000015258789,
#   'high': 33.720001220703125,
#   'low': 33.189998626708984,
#   'adjclose': 32.806427001953125,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-09',
#   'volume': 13664900,
#   'open': 33.779998779296875,
#   'close': 33.560001373291016,
#   'high': 33.799999237060554,
#   'low': 33.25,
#   'adjclose': 33.022911071777344,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-06',
#   'volume': 11541300,
#   'open': 33.27000045776367,
#   'close': 33.580001831054695,
#   'high': 33.610000610351555,
#   'low': 33.0,
#   'adjclose': 33.042591094970696,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-05',
#   'volume': 11330300,
#   'open': 33.380001068115234,
#   'close': 33.11999893188477,
#   'high': 33.400001525878906,
#   'low': 32.90999984741211,
#   'adjclose': 32.58994674682617,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-03',
#   'volume': 12660800,
#   'open': 33.200000762939446,
#   'close': 33.09000015258789,
#   'high': 33.610000610351555,
#   'low': 32.990001678466804,
#   'adjclose': 32.56042861938477,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-07-02',
#   'volume': 17165000,
#   'open': 32.439998626708984,
#   'close': 33.169998168945305,
#   'high': 33.220001220703125,
#   'low': 32.419998168945305,
#   'adjclose': 32.639148712158196,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-06-29',
#   'volume': 37956600,
#   'open': 32.509998321533196,
#   'close': 32.810001373291016,
#   'high': 33.59999847412109,
#   'low': 32.5,
#   'adjclose': 32.09795379638672,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-06-28',
#   'volume': 25199400,
#   'open': 32.439998626708984,
#   'close': 32.630001068115234,
#   'high': 32.700000762939446,
#   'low': 32.080001831054695,
#   'adjclose': 31.921859741210934,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-06-27',
#   'volume': 28842400,
#   'open': 32.560001373291016,
#   'close': 32.290000915527344,
#   'high': 32.900001525878906,
#   'low': 32.290000915527344,
#   'adjclose': 31.58923721313477,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-06-26',
#   'volume': 31471300,
#   'open': 33.310001373291016,
#   'close': 32.779998779296875,
#   'high': 33.310001373291016,
#   'low': 32.669998168945305,
#   'adjclose': 32.068603515625,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-06-25',
#   'volume': 33063300,
#   'open': 33.799999237060554,
#   'close': 33.11999893188477,
#   'high': 34.110000610351555,
#   'low': 32.90999984741211,
#   'adjclose': 32.401222229003906,
#   'Year': 2018,
#   'ticker': 'CMCSA'},
#  {'date': '2018-06-22',
#   'volume': 105512100,
#   'open': 33.0,
#   'close': 33.810001373291016,
#   'high': 34.150001525878906,
#   'low': 32.90999984741211,
#   'adjclose': 33.07625198364258,
# ...
#   'open': 29.9950008392334,
#   'close': 29.3799991607666,
#   'high': 30.104999542236328,
#   'low': 28.584999084472656,
#   'adjclose': 26.71635437011719,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-08-05',
#   'volume': 57180200,
#   'open': 31.395000457763672,
#   'close': 29.90500068664551,
#   'high': 31.479999542236328,
#   'low': 29.809999465942386,
#   'adjclose': 27.19375991821289,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-08-04',
#   'volume': 15488000,
#   'open': 31.434999465942386,
#   'close': 31.3700008392334,
#   'high': 31.684999465942386,
#   'low': 31.28000068664551,
#   'adjclose': 28.52593994140625,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-08-03',
#   'volume': 19139200,
#   'open': 31.3799991607666,
#   'close': 31.604999542236328,
#   'high': 31.65999984741211,
#   'low': 31.315000534057614,
#   'adjclose': 28.739633560180664,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-31',
#   'volume': 19432600,
#   'open': 31.395000457763672,
#   'close': 31.20499992370605,
#   'high': 31.4950008392334,
#   'low': 31.06999969482422,
#   'adjclose': 28.37589836120605,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-30',
#   'volume': 19701200,
#   'open': 31.20000076293945,
#   'close': 31.18000030517578,
#   'high': 31.32500076293945,
#   'low': 31.01499938964844,
#   'adjclose': 28.353166580200195,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-29',
#   'volume': 17613200,
#   'open': 31.10000038146973,
#   'close': 31.239999771118164,
#   'high': 31.34000015258789,
#   'low': 31.0,
#   'adjclose': 28.4077262878418,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-28',
#   'volume': 23735400,
#   'open': 30.7549991607666,
#   'close': 31.20499992370605,
#   'high': 31.22500038146973,
#   'low': 30.565000534057614,
#   'adjclose': 28.37589836120605,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-27',
#   'volume': 24069000,
#   'open': 31.1299991607666,
#   'close': 30.55500030517578,
#   'high': 31.165000915527344,
#   'low': 30.42499923706055,
#   'adjclose': 27.78483390808105,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-24',
#   'volume': 20589400,
#   'open': 31.20000076293945,
#   'close': 31.084999084472656,
#   'high': 31.44499969482422,
#   'low': 30.98500061035156,
#   'adjclose': 28.266775131225586,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-23',
#   'volume': 41968000,
#   'open': 32.450000762939446,
#   'close': 31.23500061035156,
#   'high': 32.450000762939446,
#   'low': 31.1200008392334,
#   'adjclose': 28.40317726135254,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-22',
#   'volume': 22448600,
#   'open': 32.375,
#   'close': 32.25,
#   'high': 32.49499893188477,
#   'low': 32.06999969482422,
#   'adjclose': 29.32615852355957,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-21',
#   'volume': 18958200,
#   'open': 32.060001373291016,
#   'close': 32.134998321533196,
#   'high': 32.200000762939446,
#   'low': 31.920000076293945,
#   'adjclose': 29.22158241271973,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-20',
#   'volume': 13905400,
#   'open': 32.134998321533196,
#   'close': 32.15999984741211,
#   'high': 32.209999084472656,
#   'low': 31.9950008392334,
#   'adjclose': 29.244314193725586,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-17',
#   'volume': 21380400,
#   'open': 32.040000915527344,
#   'close': 32.134998321533196,
#   'high': 32.150001525878906,
#   'low': 31.79999923706055,
#   'adjclose': 29.22158241271973,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-16',
#   'volume': 21375600,
#   'open': 32.075000762939446,
#   'close': 32.15999984741211,
#   'high': 32.325000762939446,
#   'low': 32.005001068115234,
#   'adjclose': 29.244314193725586,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-15',
#   'volume': 18517000,
#   'open': 31.540000915527344,
#   'close': 31.875,
#   'high': 31.895000457763672,
#   'low': 31.520000457763672,
#   'adjclose': 28.98515892028809,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-14',
#   'volume': 20730400,
#   'open': 31.92499923706055,
#   'close': 31.6200008392334,
#   'high': 31.95499992370605,
#   'low': 31.44499969482422,
#   'adjclose': 28.75327491760254,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-13',
#   'volume': 21389400,
#   'open': 31.864999771118164,
#   'close': 31.86000061035156,
#   'high': 32.130001068115234,
#   'low': 31.82999992370605,
#   'adjclose': 28.97151756286621,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-10',
#   'volume': 24538200,
#   'open': 31.295000076293945,
#   'close': 31.59499931335449,
#   'high': 31.70499992370605,
#   'low': 31.170000076293945,
#   'adjclose': 28.73053932189941,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-09',
#   'volume': 22309000,
#   'open': 31.26000022888184,
#   'close': 31.0049991607666,
#   'high': 31.35000038146973,
#   'low': 30.95499992370605,
#   'adjclose': 28.19403076171875,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-08',
#   'volume': 30773800,
#   'open': 31.09499931335449,
#   'close': 30.84499931335449,
#   'high': 31.395000457763672,
#   'low': 30.815000534057614,
#   'adjclose': 28.04853630065918,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-07',
#   'volume': 27454400,
#   'open': 31.190000534057614,
#   'close': 31.2549991607666,
#   'high': 31.354999542236328,
#   'low': 30.65500068664551,
#   'adjclose': 28.42136383056641,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-06',
#   'volume': 26754600,
#   'open': 30.899999618530273,
#   'close': 31.05500030517578,
#   'high': 31.29999923706055,
#   'low': 30.864999771118164,
#   'adjclose': 28.23949813842773,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-02',
#   'volume': 39168200,
#   'open': 31.13500022888184,
#   'close': 31.170000076293945,
#   'high': 31.774999618530273,
#   'low': 31.05500030517578,
#   'adjclose': 28.34407043457031,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-07-01',
#   'volume': 43338400,
#   'open': 30.190000534057614,
#   'close': 31.125,
#   'high': 31.15500068664551,
#   'low': 30.190000534057614,
#   'adjclose': 28.30315589904785,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-30',
#   'volume': 25268800,
#   'open': 30.28499984741211,
#   'close': 30.06999969482422,
#   'high': 30.28499984741211,
#   'low': 29.82500076293945,
#   'adjclose': 27.34380149841309,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-29',
#   'volume': 22983000,
#   'open': 30.315000534057614,
#   'close': 29.989999771118164,
#   'high': 30.520000457763672,
#   'low': 29.940000534057614,
#   'adjclose': 27.271055221557614,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-26',
#   'volume': 61609400,
#   'open': 30.6200008392334,
#   'close': 30.63500022888184,
#   'high': 30.81999969482422,
#   'low': 30.40500068664551,
#   'adjclose': 27.6302433013916,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-25',
#   'volume': 24223400,
#   'open': 30.32999992370605,
#   'close': 30.440000534057614,
#   'high': 30.729999542236328,
#   'low': 30.229999542236328,
#   'adjclose': 27.45436668395996,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-24',
#   'volume': 15829000,
#   'open': 30.395000457763672,
#   'close': 30.18000030517578,
#   'high': 30.4950008392334,
#   'low': 30.125,
#   'adjclose': 27.21986961364746,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-23',
#   'volume': 17667000,
#   'open': 30.46999931335449,
#   'close': 30.3799991607666,
#   'high': 30.540000915527344,
#   'low': 30.22500038146973,
#   'adjclose': 27.400251388549805,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-22',
#   'volume': 33535600,
#   'open': 30.34000015258789,
#   'close': 30.48500061035156,
#   'high': 30.6200008392334,
#   'low': 30.25,
#   'adjclose': 27.494956970214844,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-19',
#   'volume': 46073600,
#   'open': 30.145000457763672,
#   'close': 30.2549991607666,
#   'high': 30.44499969482422,
#   'low': 30.05500030517578,
#   'adjclose': 27.287511825561523,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-18',
#   'volume': 28950200,
#   'open': 29.95499992370605,
#   'close': 30.239999771118164,
#   'high': 30.42499923706055,
#   'low': 29.92499923706055,
#   'adjclose': 27.273984909057614,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-17',
#   'volume': 26062200,
#   'open': 29.434999465942386,
#   'close': 29.809999465942386,
#   'high': 29.82999992370605,
#   'low': 29.434999465942386,
#   'adjclose': 26.88616371154785,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-16',
#   'volume': 19883600,
#   'open': 29.165000915527344,
#   'close': 29.440000534057614,
#   'high': 29.51499938964844,
#   'low': 28.979999542236328,
#   'adjclose': 26.55245018005371,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-15',
#   'volume': 18597600,
#   'open': 28.934999465942386,
#   'close': 29.170000076293945,
#   'high': 29.26000022888184,
#   'low': 28.7549991607666,
#   'adjclose': 26.30893325805664,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-12',
#   'volume': 19971000,
#   'open': 29.19499969482422,
#   'close': 29.1299991607666,
#   'high': 29.295000076293945,
#   'low': 29.01499938964844,
#   'adjclose': 26.27285575866699,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-11',
#   'volume': 22679600,
#   'open': 29.13999938964844,
#   'close': 29.3799991607666,
#   'high': 29.399999618530273,
#   'low': 29.04999923706055,
#   'adjclose': 26.498332977294922,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-10',
#   'volume': 20626400,
#   'open': 29.0,
#   'close': 29.114999771118164,
#   'high': 29.25,
#   'low': 28.93000030517578,
#   'adjclose': 26.25932884216309,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-09',
#   'volume': 22674200,
#   'open': 28.84499931335449,
#   'close': 28.92499923706055,
#   'high': 29.024999618530273,
#   'low': 28.540000915527344,
#   'adjclose': 26.08796501159668,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-08',
#   'volume': 35215000,
#   'open': 29.34000015258789,
#   'close': 28.934999465942386,
#   'high': 29.40500068664551,
#   'low': 28.86000061035156,
#   'adjclose': 26.096982955932614,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-05',
#   'volume': 22300800,
#   'open': 29.395000457763672,
#   'close': 29.34499931335449,
#   'high': 29.459999084472656,
#   'low': 29.020000457763672,
#   'adjclose': 26.466766357421875,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-04',
#   'volume': 26743200,
#   'open': 29.5049991607666,
#   'close': 29.47500038146973,
#   'high': 29.84000015258789,
#   'low': 29.38500022888184,
#   'adjclose': 26.58401870727539,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-03',
#   'volume': 27546400,
#   'open': 29.540000915527344,
#   'close': 29.65999984741211,
#   'high': 29.729999542236328,
#   'low': 29.47500038146973,
#   'adjclose': 26.750871658325195,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-02',
#   'volume': 22714400,
#   'open': 29.18000030517578,
#   'close': 29.40999984741211,
#   'high': 29.59000015258789,
#   'low': 29.165000915527344,
#   'adjclose': 26.525392532348636,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-06-01',
#   'volume': 25654400,
#   'open': 29.354999542236328,
#   'close': 29.38999938964844,
#   'high': 29.5,
#   'low': 29.209999084472656,
#   'adjclose': 26.50735664367676,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-29',
#   'volume': 26310000,
#   'open': 29.545000076293945,
#   'close': 29.229999542236328,
#   'high': 29.63500022888184,
#   'low': 29.15500068664551,
#   'adjclose': 26.363046646118164,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-28',
#   'volume': 23096000,
#   'open': 29.559999465942386,
#   'close': 29.51499938964844,
#   'high': 29.645000457763672,
#   'low': 29.34499931335449,
#   'adjclose': 26.62009239196777,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-27',
#   'volume': 29069200,
#   'open': 29.29999923706055,
#   'close': 29.670000076293945,
#   'high': 29.790000915527344,
#   'low': 29.21999931335449,
#   'adjclose': 26.75988578796387,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-26',
#   'volume': 52480000,
#   'open': 28.959999084472656,
#   'close': 29.295000076293945,
#   'high': 29.61000061035156,
#   'low': 28.920000076293945,
#   'adjclose': 26.421672821044922,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-22',
#   'volume': 24085600,
#   'open': 28.770000457763672,
#   'close': 28.934999465942386,
#   'high': 29.059999465942386,
#   'low': 28.70499992370605,
#   'adjclose': 26.096982955932614,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-21',
#   'volume': 37799200,
#   'open': 28.78000068664551,
#   'close': 28.770000457763672,
#   'high': 29.10000038146973,
#   'low': 28.71999931335449,
#   'adjclose': 25.94816589355469,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-20',
#   'volume': 30610000,
#   'open': 28.84499931335449,
#   'close': 28.78499984741211,
#   'high': 29.07500076293945,
#   'low': 28.649999618530273,
#   'adjclose': 25.96169471740723,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-19',
#   'volume': 24279800,
#   'open': 28.5049991607666,
#   'close': 28.614999771118164,
#   'high': 28.709999084472656,
#   'low': 28.440000534057614,
#   'adjclose': 25.80836677551269,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-18',
#   'volume': 27916800,
#   'open': 28.34499931335449,
#   'close': 28.48500061035156,
#   'high': 28.59000015258789,
#   'low': 28.32500076293945,
#   'adjclose': 25.69112205505371,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-15',
#   'volume': 34599200,
#   'open': 28.38500022888184,
#   'close': 28.31999969482422,
#   'high': 28.440000534057614,
#   'low': 28.15500068664551,
#   'adjclose': 25.54230117797852,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-14',
#   'volume': 27971000,
#   'open': 28.354999542236328,
#   'close': 28.270000457763672,
#   'high': 28.520000457763672,
#   'low': 28.13999938964844,
#   'adjclose': 25.49720764160156,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-13',
#   'volume': 51302600,
#   'open': 28.72500038146973,
#   'close': 28.13999938964844,
#   'high': 28.795000076293945,
#   'low': 28.10000038146973,
#   'adjclose': 25.37995719909668,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-12',
#   'volume': 25538000,
#   'open': 28.7450008392334,
#   'close': 28.665000915527344,
#   'high': 28.854999542236328,
#   'low': 28.61000061035156,
#   'adjclose': 25.853464126586914,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-11',
#   'volume': 24247400,
#   'open': 29.315000534057614,
#   'close': 28.88500022888184,
#   'high': 29.395000457763672,
#   'low': 28.8700008392334,
#   'adjclose': 26.05188369750977,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-08',
#   'volume': 29829000,
#   'open': 29.25,
#   'close': 29.20499992370605,
#   'high': 29.375,
#   'low': 29.07500076293945,
#   'adjclose': 26.34049797058105,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-07',
#   'volume': 26825400,
#   'open': 28.75,
#   'close': 28.959999084472656,
#   'high': 29.114999771118164,
#   'low': 28.67499923706055,
#   'adjclose': 26.11952781677246,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-06',
#   'volume': 33526400,
#   'open': 29.045000076293945,
#   'close': 28.82999992370605,
#   'high': 29.149999618530273,
#   'low': 28.65999984741211,
#   'adjclose': 26.002277374267575,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-05',
#   'volume': 32248000,
#   'open': 29.40500068664551,
#   'close': 28.989999771118164,
#   'high': 29.520000457763672,
#   'low': 28.95499992370605,
#   'adjclose': 26.14658546447754,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-04',
#   'volume': 42781000,
#   'open': 30.024999618530273,
#   'close': 29.38999938964844,
#   'high': 30.04999923706055,
#   'low': 29.315000534057614,
#   'adjclose': 26.50735664367676,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-05-01',
#   'volume': 31156400,
#   'open': 28.899999618530273,
#   'close': 29.20499992370605,
#   'high': 29.2450008392334,
#   'low': 28.65999984741211,
#   'adjclose': 26.34049797058105,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  {'date': '2015-04-30',
#   'volume': 46140200,
#   'open': 29.18000030517578,
#   'close': 28.8799991607666,
#   'high': 29.47500038146973,
#   'low': 28.65500068664551,
#   'adjclose': 26.04737663269043,
#   'Year': 2015,
#   'ticker': 'CMCSA'},
#  ...]

# %%
financial2018_dict=top500_2018.to_dict('records')
financial2018_dict
# Out:
# [{'ticker': 'CMCSA',
#   'Revenue': 94507000000.0,
#   'Revenue Growth': 0.1115,
#   'Gross Profit': 94507000000.0,
#   'Profit Margin': 0.124,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.12412837144339,
#   'Total assets': 251684000000.0,
#   'Total debt': 111743000000.0,
#   'Total liabilities': 179182000000.0,
#   'EPS': 2.56,
#   'Dividend per Share': 0.917,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'KMI',
#   'Revenue': 14144000000.0,
#   'Revenue Growth': 0.032,
#   'Gross Profit': 6856000000.0,
#   'Profit Margin': 0.105,
#   'grossProfitMargin': 0.48472850678733,
#   'netProfitMargin': 0.1137584841629,
#   'Total assets': 78866000000.0,
#   'Total debt': 37324000000.0,
#   'Total liabilities': 43669000000.0,
#   'EPS': 0.66,
#   'Dividend per Share': 0.725,
#   'Sector': 'Energy'},
#  {'ticker': 'INTC',
#   'Revenue': 70848000000.0,
#   'Revenue Growth': 0.1289,
#   'Gross Profit': 43737000000.0,
#   'Profit Margin': 0.297,
#   'grossProfitMargin': 0.61733570460705,
#   'netProfitMargin': 0.29715729448961,
#   'Total assets': 127963000000.0,
#   'Total debt': 26359000000.0,
#   'Total liabilities': 53400000000.0,
#   'EPS': 4.57,
#   'Dividend per Share': 1.2,
#   'Sector': 'Technology'},
#  {'ticker': 'MU',
#   'Revenue': 30391000000.0,
#   'Revenue Growth': 0.4955,
#   'Gross Profit': 17891000000.0,
#   'Profit Margin': 0.465,
#   'grossProfitMargin': 0.58869402125629,
#   'netProfitMargin': 0.46510480076338,
#   'Total assets': 43376000000.0,
#   'Total debt': 4639000000.0,
#   'Total liabilities': 10112000000.0,
#   'EPS': 12.27,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'GE',
#   'Revenue': 121615000000.0,
#   'Revenue Growth': 0.0285,
#   'Gross Profit': 26154000000.0,
#   'Profit Margin': -0.187,
#   'grossProfitMargin': 0.21505570858858,
#   'netProfitMargin': -0.183817785635,
#   'Total assets': 311072000000.0,
#   'Total debt': 103600000000.0,
#   'Total liabilities': 259591000000.0,
#   'EPS': -2.62,
#   'Dividend per Share': 0.37,
#   'Sector': 'Industrials'},
#  {'ticker': 'BAC',
#   'Revenue': 91247000000.0,
#   'Revenue Growth': 0.0446,
#   'Gross Profit': 91247000000.0,
#   'Profit Margin': 0.293,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.30847041546571,
#   'Total assets': 2354507000000.0,
#   'Total debt': 436569000000.0,
#   'Total liabilities': 2089182000000.0,
#   'EPS': 2.64,
#   'Dividend per Share': 0.54,
#   'Sector': 'Financial Services'},
#  {'ticker': 'AAPL',
#   'Revenue': 265595000000.0,
#   'Revenue Growth': 0.1586,
#   'Gross Profit': 101839000000.0,
#   'Profit Margin': 0.224,
#   'grossProfitMargin': 0.3834371882000801,
#   'netProfitMargin': 0.22414202074587,
#   'Total assets': 365725000000.0,
#   'Total debt': 114483000000.0,
#   'Total liabilities': 258578000000.0,
#   'EPS': 12.01,
#   'Dividend per Share': 2.72,
#   'Sector': 'Technology'},
#  {'ticker': 'MSFT',
#   'Revenue': 110360000000.0,
#   'Revenue Growth': 0.1428,
#   'Gross Profit': 72007000000.0,
#   'Profit Margin': 0.15,
#   'grossProfitMargin': 0.65247372236318,
#   'netProfitMargin': 0.15015404131932,
#   'Total assets': 258848000000.0,
#   'Total debt': 81808000000.0,
#   'Total liabilities': 176130000000.0,
#   'EPS': 2.15,
#   'Dividend per Share': 1.65,
#   'Sector': 'Technology'},
#  {'ticker': 'HPQ',
#   'Revenue': 58472000000.0,
#   'Revenue Growth': 0.1233,
#   'Gross Profit': 10669000000.0,
#   'Profit Margin': 0.091,
#   'grossProfitMargin': 0.18246340128609,
#   'netProfitMargin': 0.091103434122315,
#   'Total assets': 34622000000.0,
#   'Total debt': 5987000000.0,
#   'Total liabilities': 35261000000.0,
#   'EPS': 3.3,
#   'Dividend per Share': 0.557,
#   'Sector': 'Technology'},
#  {'ticker': 'F',
#   'Revenue': 160338000000.0,
#   'Revenue Growth': 0.0227,
#   'Gross Profit': 14606000000.0,
#   'Profit Margin': 0.023,
#   'grossProfitMargin': 0.091095061682196,
#   'netProfitMargin': 0.022932804450598,
#   'Total assets': 256540000000.0,
#   'Total debt': 154213000000.0,
#   'Total liabilities': 220474000000.0,
#   'EPS': 0.93,
#   'Dividend per Share': 0.6,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'AMD',
#   'Revenue': 6475000000.0,
#   'Revenue Growth': 0.2326,
#   'Gross Profit': 2447000000.0,
#   'Profit Margin': 0.052000000000000005,
#   'grossProfitMargin': 0.37791505791506,
#   'netProfitMargin': 0.052046332046332,
#   'Total assets': 4556000000.0,
#   'Total debt': 1250000000.0,
#   'Total liabilities': 3290000000.0,
#   'EPS': 0.34,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'FB',
#   'Revenue': 55838000000.0,
#   'Revenue Growth': 0.3735,
#   'Gross Profit': 46483000000.0,
#   'Profit Margin': 0.396,
#   'grossProfitMargin': 0.8324617643898399,
#   'netProfitMargin': 0.39600272216054,
#   'Total assets': 97334000000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 13207000000.0,
#   'EPS': 7.65,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'WFC',
#   'Revenue': 84664000000.0,
#   'Revenue Growth': -0.0139,
#   'Gross Profit': 84664000000.0,
#   'Profit Margin': 0.244,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.26449258244354,
#   'Total assets': 1895883000000.0,
#   'Total debt': 334831000000.0,
#   'Total liabilities': 1698817000000.0,
#   'EPS': 4.31,
#   'Dividend per Share': 1.64,
#   'Sector': 'Financial Services'},
#  {'ticker': 'AIG',
#   'Revenue': 47389000000.0,
#   'Revenue Growth': -0.043,
#   'Gross Profit': 16223000000.0,
#   'Profit Margin': 0.0,
#   'grossProfitMargin': 0.34233682922197,
#   'netProfitMargin': -0.00012661166093396999,
#   'Total assets': 491984000000.0,
#   'Total debt': 34540000000.0,
#   'Total liabilities': 434675000000.0,
#   'EPS': -0.01,
#   'Dividend per Share': 1.28,
#   'Sector': 'Financial Services'},
#  {'ticker': 'T',
#   'Revenue': 170756000000.0,
#   'Revenue Growth': 0.0636,
#   'Gross Profit': 91337000000.0,
#   'Profit Margin': 0.113,
#   'grossProfitMargin': 0.5348977488345901,
#   'netProfitMargin': 0.11343671671859,
#   'Total assets': 531864000000.0,
#   'Total debt': 176505000000.0,
#   'Total liabilities': 337980000000.0,
#   'EPS': 2.85,
#   'Dividend per Share': 2.0,
#   'Sector': 'Communication Services'},
#  {'ticker': 'C',
#   'Revenue': 72854000000.0,
#   'Revenue Growth': 0.0057,
#   'Gross Profit': 65286000000.0,
#   'Profit Margin': 0.248,
#   'grossProfitMargin': 0.8961210091415699,
#   'netProfitMargin': 0.24768715513218,
#   'Total assets': 1917383000000.0,
#   'Total debt': 442113000000.0,
#   'Total liabilities': 1720309000000.0,
#   'EPS': 6.69,
#   'Dividend per Share': 1.54,
#   'Sector': 'Financial Services'},
#  {'ticker': 'MS',
#   'Revenue': 40107000000.0,
#   'Revenue Growth': 0.057,
#   'Gross Profit': 40107000000.0,
#   'Profit Margin': 0.205,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.21811653826015,
#   'Total assets': 853531000000.0,
#   'Total debt': 199128000000.0,
#   'Total liabilities': 772125000000.0,
#   'EPS': 4.81,
#   'Dividend per Share': 1.1,
#   'Sector': 'Financial Services'},
#  {'ticker': 'JPM',
#   'Revenue': 109029000000.0,
#   'Revenue Growth': 0.0827,
#   'Gross Profit': 109029000000.0,
#   'Profit Margin': 0.282,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.28165900815379,
#   'Total assets': 2622532000000.0,
#   'Total debt': 533627000000.0,
#   'Total liabilities': 2366017000000.0,
#   'EPS': 9.04,
#   'Dividend per Share': 2.48,
#   'Sector': 'Financial Services'},
#  {'ticker': 'ORCL',
#   'Revenue': 39383000000.0,
#   'Revenue Growth': 0.0421,
#   'Gross Profit': 31323000000.0,
#   'Profit Margin': 0.091,
#   'grossProfitMargin': 0.79534316837214,
#   'netProfitMargin': 0.091079907574334,
#   'Total assets': 137851000000.0,
#   'Total debt': 60619000000.0,
#   'Total liabilities': 90978000000.0,
#   'EPS': 0.87,
#   'Dividend per Share': 0.76,
#   'Sector': 'Technology'},
#  {'ticker': 'NKE',
#   'Revenue': 36397000000.0,
#   'Revenue Growth': 0.0596,
#   'Gross Profit': 15956000000.0,
#   'Profit Margin': 0.053,
#   'grossProfitMargin': 0.4383877792125701,
#   'netProfitMargin': 0.053108772701047004,
#   'Total assets': 22536000000.0,
#   'Total debt': 3810000000.0,
#   'Total liabilities': 12724000000.0,
#   'EPS': 1.19,
#   'Dividend per Share': 0.76,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'PG',
#   'Revenue': 66832000000.0,
#   'Revenue Growth': 0.0273,
#   'Gross Profit': 32400000000.0,
#   'Profit Margin': 0.146,
#   'grossProfitMargin': 0.48479770169978,
#   'netProfitMargin': 0.14588819727077,
#   'Total assets': 118310000000.0,
#   'Total debt': 31286000000.0,
#   'Total liabilities': 65427000000.0,
#   'EPS': 3.75,
#   'Dividend per Share': 2.787,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'PFE',
#   'Revenue': 53647000000.0,
#   'Revenue Growth': 0.021,
#   'Gross Profit': 42399000000.0,
#   'Profit Margin': 0.208,
#   'grossProfitMargin': 0.7903331034354201,
#   'netProfitMargin': 0.20789606128954,
#   'Total assets': 159422000000.0,
#   'Total debt': 41740000000.0,
#   'Total liabilities': 95664000000.0,
#   'EPS': 1.9,
#   'Dividend per Share': 1.36,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AVGO',
#   'Revenue': 20848000000.0,
#   'Revenue Growth': 0.1821,
#   'Gross Profit': 10733000000.0,
#   'Profit Margin': 0.588,
#   'grossProfitMargin': 0.51482156561781,
#   'netProfitMargin': 0.58801803530315,
#   'Total assets': 50124000000.0,
#   'Total debt': 17493000000.0,
#   'Total liabilities': 23467000000.0,
#   'EPS': 29.33,
#   'Dividend per Share': 7.0,
#   'Sector': 'Technology'},
#  {'ticker': 'AMAT',
#   'Revenue': 17253000000.0,
#   'Revenue Growth': 0.1868,
#   'Gross Profit': 7817000000.0,
#   'Profit Margin': 0.192,
#   'grossProfitMargin': 0.45308062365965,
#   'netProfitMargin': 0.19202457543616,
#   'Total assets': 17633000000.0,
#   'Total debt': 5309000000.0,
#   'Total liabilities': 10788000000.0,
#   'EPS': 3.27,
#   'Dividend per Share': 0.6,
#   'Sector': 'Technology'},
#  {'ticker': 'XOM',
#   'Revenue': 290212000000.0,
#   'Revenue Growth': 0.1876,
#   'Gross Profit': 101377000000.0,
#   'Profit Margin': 0.07200000000000001,
#   'grossProfitMargin': 0.34932049674031,
#   'netProfitMargin': 0.071809573690957,
#   'Total assets': 346196000000.0,
#   'Total debt': 37796000000.0,
#   'Total liabilities': 147668000000.0,
#   'EPS': 4.88,
#   'Dividend per Share': 3.23,
#   'Sector': 'Energy'},
#  {'ticker': 'QCOM',
#   'Revenue': 22611000000.0,
#   'Revenue Growth': 0.0159,
#   'Gross Profit': 12367000000.0,
#   'Profit Margin': -0.22,
#   'grossProfitMargin': 0.54694617663969,
#   'netProfitMargin': -0.21953916235461,
#   'Total assets': 32718000000.0,
#   'Total debt': 16370000000.0,
#   'Total liabilities': 31911000000.0,
#   'EPS': -3.39,
#   'Dividend per Share': 2.38,
#   'Sector': 'Technology'},
#  {'ticker': 'CSCO',
#   'Revenue': 49330000000.0,
#   'Revenue Growth': 0.0276,
#   'Gross Profit': 30606000000.0,
#   'Profit Margin': 0.002,
#   'grossProfitMargin': 0.62043381309548,
#   'netProfitMargin': 0.0022298803973241,
#   'Total assets': 108784000000.0,
#   'Total debt': 25569000000.0,
#   'Total liabilities': 65580000000.0,
#   'EPS': 0.02,
#   'Dividend per Share': 1.24,
#   'Sector': 'Technology'},
#  {'ticker': 'AXP',
#   'Revenue': 36986000000.0,
#   'Revenue Growth': 0.0841,
#   'Gross Profit': 36986000000.0,
#   'Profit Margin': 0.187,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.1871248580544,
#   'Total assets': 188602000000.0,
#   'Total debt': 61523000000.0,
#   'Total liabilities': 166312000000.0,
#   'EPS': 7.93,
#   'Dividend per Share': 1.44,
#   'Sector': 'Financial Services'},
#  {'ticker': 'BMY',
#   'Revenue': 22561000000.0,
#   'Revenue Growth': 0.0859,
#   'Gross Profit': 16014000000.0,
#   'Profit Margin': 0.218,
#   'grossProfitMargin': 0.70980896236869,
#   'netProfitMargin': 0.21807543991844,
#   'Total assets': 34986000000.0,
#   'Total debt': 7349000000.0,
#   'Total liabilities': 20859000000.0,
#   'EPS': 3.01,
#   'Dividend per Share': 1.6,
#   'Sector': 'Healthcare'},
#  {'ticker': 'V',
#   'Revenue': 20609000000.0,
#   'Revenue Growth': 0.1226,
#   'Gross Profit': 17439000000.0,
#   'Profit Margin': 0.5,
#   'grossProfitMargin': 0.8461837061478001,
#   'netProfitMargin': 0.49983017128439,
#   'Total assets': 69225000000.0,
#   'Total debt': 16630000000.0,
#   'Total liabilities': 35219000000.0,
#   'EPS': 4.43,
#   'Dividend per Share': 0.825,
#   'Sector': 'Financial Services'},
#  {'ticker': 'KEY',
#   'Revenue': 6178000000.0,
#   'Revenue Growth': 0.0252,
#   'Gross Profit': 6178000000.0,
#   'Profit Margin': 0.29100000000000004,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.30203949498219,
#   'Total assets': 139613000000.0,
#   'Total debt': 14595000000.0,
#   'Total liabilities': 124017000000.0,
#   'EPS': 1.73,
#   'Dividend per Share': 0.565,
#   'Sector': 'Financial Services'},
#  {'ticker': 'RF',
#   'Revenue': 5525000000.0,
#   'Revenue Growth': 0.0325,
#   'Gross Profit': 5525000000.0,
#   'Profit Margin': 0.307,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.30678733031674,
#   'Total assets': 125688000000.0,
#   'Total debt': 14024000000.0,
#   'Total liabilities': 110598000000.0,
#   'EPS': 1.55,
#   'Dividend per Share': 0.46,
#   'Sector': 'Financial Services'},
#  {'ticker': 'KR',
#   'Revenue': 122662000000.0,
#   'Revenue Growth': 0.0635,
#   'Gross Profit': 27000000000.0,
#   'Profit Margin': 0.016,
#   'grossProfitMargin': 0.22011706967113,
#   'netProfitMargin': 0.015546787106031,
#   'Total assets': 37197000000.0,
#   'Total debt': 15589000000.0,
#   'Total liabilities': 30292000000.0,
#   'EPS': 2.11,
#   'Dividend per Share': 0.49,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'HAL',
#   'Revenue': 23995000000.0,
#   'Revenue Growth': 0.1637,
#   'Gross Profit': 2986000000.0,
#   'Profit Margin': 0.069,
#   'grossProfitMargin': 0.12444259220671,
#   'netProfitMargin': 0.069014377995416,
#   'Total assets': 25982000000.0,
#   'Total debt': 10312000000.0,
#   'Total liabilities': 16438000000.0,
#   'EPS': 1.89,
#   'Dividend per Share': 0.72,
#   'Sector': 'Energy'},
#  {'ticker': 'MRO',
#   'Revenue': 6582000000.0,
#   'Revenue Growth': 0.3813,
#   'Gross Profit': 5165000000.0,
#   'Profit Margin': 0.16699999999999998,
#   'grossProfitMargin': 0.78471589182619,
#   'netProfitMargin': 0.16651473716196,
#   'Total assets': 21321000000.0,
#   'Total debt': 5499000000.0,
#   'Total liabilities': 9193000000.0,
#   'EPS': 1.3,
#   'Dividend per Share': 0.2,
#   'Sector': 'Energy'},
#  {'ticker': 'GILD',
#   'Revenue': 22127000000.0,
#   'Revenue Growth': -0.1524,
#   'Gross Profit': 17274000000.0,
#   'Profit Margin': 0.247,
#   'grossProfitMargin': 0.78067519320287,
#   'netProfitMargin': 0.24653138699327,
#   'Total assets': 63675000000.0,
#   'Total debt': 27322000000.0,
#   'Total liabilities': 42141000000.0,
#   'EPS': 4.2,
#   'Dividend per Share': 2.28,
#   'Sector': 'Healthcare'},
#  {'ticker': 'GM',
#   'Revenue': 147049000000.0,
#   'Revenue Growth': 0.01,
#   'Gross Profit': 14095000000.0,
#   'Profit Margin': 0.054000000000000006,
#   'grossProfitMargin': 0.095852402940516,
#   'netProfitMargin': 0.054498840522547,
#   'Total assets': 227339000000.0,
#   'Total debt': 104951000000.0,
#   'Total liabilities': 184562000000.0,
#   'EPS': 5.61,
#   'Dividend per Share': 1.52,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'FCX',
#   'Revenue': 18628000000.0,
#   'Revenue Growth': 0.1356,
#   'Gross Profit': 5183000000.0,
#   'Profit Margin': 0.14,
#   'grossProfitMargin': 0.27823706248658003,
#   'netProfitMargin': 0.13968219884046,
#   'Total assets': 42216000000.0,
#   'Total debt': 11141000000.0,
#   'Total liabilities': 24324000000.0,
#   'EPS': 1.79,
#   'Dividend per Share': 0.15,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'CRM',
#   'Revenue': 10540000000.0,
#   'Revenue Growth': 0.2493,
#   'Gross Profit': 7767000000.0,
#   'Profit Margin': 0.034,
#   'grossProfitMargin': 0.73690702087287,
#   'netProfitMargin': 0.03415559772296,
#   'Total assets': 21984000000.0,
#   'Total debt': 1720000000.0,
#   'Total liabilities': 11608000000.0,
#   'EPS': 0.5,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'ATVI',
#   'Revenue': 7500000000.0,
#   'Revenue Growth': 0.0688,
#   'Gross Profit': 4983000000.0,
#   'Profit Margin': 0.242,
#   'grossProfitMargin': 0.6644,
#   'netProfitMargin': 0.24173333333333,
#   'Total assets': 17890000000.0,
#   'Total debt': 2671000000.0,
#   'Total liabilities': 6498000000.0,
#   'EPS': 2.38,
#   'Dividend per Share': 0.34,
#   'Sector': 'Technology'},
#  {'ticker': 'NUE',
#   'Revenue': 25067279000.0,
#   'Revenue Growth': 0.2377,
#   'Gross Profit': 4295408000.0,
#   'Profit Margin': 0.094,
#   'grossProfitMargin': 0.17135517580507995,
#   'netProfitMargin': 0.094177233994962,
#   'Total assets': 17920588000.0,
#   'Total debt': 4291146000.0,
#   'Total liabilities': 7718620000.0,
#   'EPS': 7.44,
#   'Dividend per Share': 1.54,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'LOW',
#   'Revenue': 68619000000.0,
#   'Revenue Growth': 0.0554,
#   'Gross Profit': 22434000000.0,
#   'Profit Margin': 0.05,
#   'grossProfitMargin': 0.3269356883662,
#   'netProfitMargin': 0.050233900231714014,
#   'Total assets': 35291000000.0,
#   'Total debt': 16995000000.0,
#   'Total liabilities': 29418000000.0,
#   'EPS': 4.09,
#   'Dividend per Share': 1.58,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'SLB',
#   'Revenue': 32815000000.0,
#   'Revenue Growth': 0.078,
#   'Gross Profit': 4337000000.0,
#   'Profit Margin': 0.065,
#   'grossProfitMargin': 0.13216516836811998,
#   'netProfitMargin': 0.065153131190005,
#   'Total assets': 70507000000.0,
#   'Total debt': 16051000000.0,
#   'Total liabilities': 33921000000.0,
#   'EPS': 1.54,
#   'Dividend per Share': 2.0,
#   'Sector': 'Energy'},
#  {'ticker': 'FOXA',
#   'Revenue': 10153000000.0,
#   'Revenue Growth': 0.0234,
#   'Gross Profit': 3648000000.0,
#   'Profit Margin': 0.215,
#   'grossProfitMargin': 0.35930266916182,
#   'netProfitMargin': 0.21540431399586,
#   'Total assets': 13121000000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 3527000000.0,
#   'EPS': 3.52,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'ABBV',
#   'Revenue': 32753000000.0,
#   'Revenue Growth': 0.1608,
#   'Gross Profit': 25035000000.0,
#   'Profit Margin': 0.174,
#   'grossProfitMargin': 0.7643574634384599,
#   'netProfitMargin': 0.17363294965346998,
#   'Total assets': 59352000000.0,
#   'Total debt': 40310000000.0,
#   'Total liabilities': 67798000000.0,
#   'EPS': 3.67,
#   'Dividend per Share': 3.59,
#   'Sector': 'Healthcare'},
#  {'ticker': 'GIS',
#   'Revenue': 15740400000.0,
#   'Revenue Growth': 0.0077,
#   'Gross Profit': 5435600000.0,
#   'Profit Margin': 0.135,
#   'grossProfitMargin': 0.34532794592259003,
#   'netProfitMargin': 0.13538410713832,
#   'Total assets': 30624000000.0,
#   'Total debt': 15818600000.0,
#   'Total liabilities': 23355400000.0,
#   'EPS': 3.69,
#   'Dividend per Share': 1.96,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'VZ',
#   'Revenue': 130863000000.0,
#   'Revenue Growth': 0.0383,
#   'Gross Profit': 75355000000.0,
#   'Profit Margin': 0.119,
#   'grossProfitMargin': 0.57583121279506,
#   'netProfitMargin': 0.11865844432727,
#   'Total assets': 264829000000.0,
#   'Total debt': 113063000000.0,
#   'Total liabilities': 210119000000.0,
#   'EPS': 3.76,
#   'Dividend per Share': 2.372,
#   'Sector': 'Communication Services'},
#  {'ticker': 'XRX',
#   'Revenue': 9830000000.0,
#   'Revenue Growth': -0.0424,
#   'Gross Profit': 3927000000.0,
#   'Profit Margin': 0.037000000000000005,
#   'grossProfitMargin': 0.39949135300102,
#   'netProfitMargin': 0.036724313326551,
#   'Total assets': 14874000000.0,
#   'Total debt': 5230000000.0,
#   'Total liabilities': 9621000000.0,
#   'EPS': 1.4,
#   'Dividend per Share': 1.0,
#   'Sector': 'Technology'},
#  {'ticker': 'MAT',
#   'Revenue': 4514810000.0,
#   'Revenue Growth': -0.0751,
#   'Gross Profit': 1798683000.0,
#   'Profit Margin': -0.118,
#   'grossProfitMargin': 0.39839616728057,
#   'netProfitMargin': -0.11812213581524003,
#   'Total assets': 5238225000.0,
#   'Total debt': 2855899000.0,
#   'Total liabilities': 4581422000.0,
#   'EPS': -1.55,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'CTL',
#   'Revenue': 23443000000.0,
#   'Revenue Growth': 0.3278,
#   'Gross Profit': 12581000000.0,
#   'Profit Margin': -0.07400000000000001,
#   'grossProfitMargin': 0.536663396323,
#   'netProfitMargin': -0.07392398583799001,
#   'Total assets': 70256000000.0,
#   'Total debt': 36061000000.0,
#   'Total liabilities': 50428000000.0,
#   'EPS': -1.63,
#   'Dividend per Share': 2.16,
#   'Sector': 'Communication Services'},
#  {'ticker': 'DVN',
#   'Revenue': 10734000000.0,
#   'Revenue Growth': 0.2091,
#   'Gross Profit': 4146000000.0,
#   'Profit Margin': 0.285,
#   'grossProfitMargin': 0.38624930128563,
#   'netProfitMargin': 0.28544810881312,
#   'Total assets': 19566000000.0,
#   'Total debt': 4454000000.0,
#   'Total liabilities': 10380000000.0,
#   'EPS': 6.14,
#   'Dividend per Share': 0.3,
#   'Sector': 'Energy'},
#  {'ticker': 'MPC',
#   'Revenue': 97102000000.0,
#   'Revenue Growth': 0.2884,
#   'Gross Profit': 11036000000.0,
#   'Profit Margin': 0.029,
#   'grossProfitMargin': 0.11365368375523,
#   'netProfitMargin': 0.028629688368932007,
#   'Total assets': 92940000000.0,
#   'Total debt': 27524000000.0,
#   'Total liabilities': 47887000000.0,
#   'EPS': 5.36,
#   'Dividend per Share': 1.84,
#   'Sector': 'Energy'},
#  {'ticker': 'PM',
#   'Revenue': 79823000000.0,
#   'Revenue Growth': 0.0221,
#   'Gross Profit': 18867000000.0,
#   'Profit Margin': 0.099,
#   'grossProfitMargin': 0.23636044749007,
#   'netProfitMargin': 0.099106773736893,
#   'Total assets': 39801000000.0,
#   'Total debt': 31759000000.0,
#   'Total liabilities': 50540000000.0,
#   'EPS': 5.08,
#   'Dividend per Share': 4.49,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KO',
#   'Revenue': 31856000000.0,
#   'Revenue Growth': -0.1004,
#   'Gross Profit': 20086000000.0,
#   'Profit Margin': 0.202,
#   'grossProfitMargin': 0.6305248618784499,
#   'netProfitMargin': 0.20197137117027,
#   'Total assets': 83216000000.0,
#   'Total debt': 44214000000.0,
#   'Total liabilities': 64158000000.0,
#   'EPS': 1.51,
#   'Dividend per Share': 1.56,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'COP',
#   'Revenue': 38727000000.0,
#   'Revenue Growth': 0.1885,
#   'Gross Profit': 18172000000.0,
#   'Profit Margin': 0.162,
#   'grossProfitMargin': 0.46923335140858,
#   'netProfitMargin': 0.16156686549436,
#   'Total assets': 69980000000.0,
#   'Total debt': 14968000000.0,
#   'Total liabilities': 37916000000.0,
#   'EPS': 5.36,
#   'Dividend per Share': 1.16,
#   'Sector': 'Energy'},
#  {'ticker': 'DIS',
#   'Revenue': 59434000000.0,
#   'Revenue Growth': 0.0779,
#   'Gross Profit': 26708000000.0,
#   'Profit Margin': 0.212,
#   'grossProfitMargin': 0.44937241309688,
#   'netProfitMargin': 0.21196621462463,
#   'Total assets': 98598000000.0,
#   'Total debt': 20874000000.0,
#   'Total liabilities': 45766000000.0,
#   'EPS': 8.4,
#   'Dividend per Share': 1.68,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'LEN',
#   'Revenue': 20571631000.0,
#   'Revenue Growth': 0.6267,
#   'Gross Profit': 2334185000.0,
#   'Profit Margin': 0.08199999999999999,
#   'grossProfitMargin': 0.11346620984987,
#   'netProfitMargin': 0.08243541797925501,
#   'Total assets': 28566181000.0,
#   'Total debt': 8543868000.0,
#   'Total liabilities': 13883224000.0,
#   'EPS': 5.46,
#   'Dividend per Share': 0.16,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'CVX',
#   'Revenue': 166339000000.0,
#   'Revenue Growth': 0.1737,
#   'Gross Profit': 46350000000.0,
#   'Profit Margin': 0.08900000000000001,
#   'grossProfitMargin': 0.2786478216173,
#   'netProfitMargin': 0.08911920836364301,
#   'Total assets': 253863000000.0,
#   'Total debt': 34459000000.0,
#   'Total liabilities': 98221000000.0,
#   'EPS': 7.81,
#   'Dividend per Share': 4.48,
#   'Sector': 'Energy'},
#  {'ticker': 'PYPL',
#   'Revenue': 15451000000.0,
#   'Revenue Growth': 0.18,
#   'Gross Profit': 7114000000.0,
#   'Profit Margin': 0.133,
#   'grossProfitMargin': 0.4604232735745301,
#   'netProfitMargin': 0.13313054171251,
#   'Total assets': 43332000000.0,
#   'Total debt': 1998000000.0,
#   'Total liabilities': 27946000000.0,
#   'EPS': 1.74,
#   'Dividend per Share': 0.0,
#   'Sector': 'Financial Services'},
#  {'ticker': 'WMT',
#   'Revenue': 500343000000.0,
#   'Revenue Growth': 0.0298,
#   'Gross Profit': 126947000000.0,
#   'Profit Margin': 0.02,
#   'grossProfitMargin': 0.25371994811559,
#   'netProfitMargin': 0.019710478611672,
#   'Total assets': 204522000000.0,
#   'Total debt': 46487000000.0,
#   'Total liabilities': 123700000000.0,
#   'EPS': 3.29,
#   'Dividend per Share': 2.04,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MRK',
#   'Revenue': 42294000000.0,
#   'Revenue Growth': 0.0541,
#   'Gross Profit': 28785000000.0,
#   'Profit Margin': 0.147,
#   'grossProfitMargin': 0.68059299191375,
#   'netProfitMargin': 0.14706577765168,
#   'Total assets': 82637000000.0,
#   'Total debt': 25114000000.0,
#   'Total liabilities': 55755000000.0,
#   'EPS': 2.34,
#   'Dividend per Share': 1.99,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MDLZ',
#   'Revenue': 25938000000.0,
#   'Revenue Growth': 0.0016,
#   'Gross Profit': 10352000000.0,
#   'Profit Margin': 0.13,
#   'grossProfitMargin': 0.3991055594109,
#   'netProfitMargin': 0.13034929447142998,
#   'Total assets': 62729000000.0,
#   'Total debt': 18372000000.0,
#   'Total liabilities': 37016000000.0,
#   'EPS': 2.3,
#   'Dividend per Share': 0.96,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MGM',
#   'Revenue': 11763096000.0,
#   'Revenue Growth': 0.0894,
#   'Gross Profit': 4844221000.0,
#   'Profit Margin': 0.04,
#   'grossProfitMargin': 0.41181513778345,
#   'netProfitMargin': 0.039681049954876,
#   'Total assets': 30210706000.0,
#   'Total debt': 15271462000.0,
#   'Total liabilities': 19740915000.0,
#   'EPS': 0.82,
#   'Dividend per Share': 0.48,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'SCHW',
#   'Revenue': 10132000000.0,
#   'Revenue Growth': 0.1757,
#   'Gross Profit': 10132000000.0,
#   'Profit Margin': 0.329,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.34613106987762,
#   'Total assets': 296482000000.0,
#   'Total debt': 6878000000.0,
#   'Total liabilities': 275812000000.0,
#   'EPS': 2.47,
#   'Dividend per Share': 0.46,
#   'Sector': 'Financial Services'},
#  {'ticker': 'NVDA',
#   'Revenue': 9714000000.0,
#   'Revenue Growth': 0.4058,
#   'Gross Profit': 5822000000.0,
#   'Profit Margin': 0.314,
#   'grossProfitMargin': 0.59934115709286,
#   'netProfitMargin': 0.31367099032324,
#   'Total assets': 11241000000.0,
#   'Total debt': 2000000000.0,
#   'Total liabilities': 3770000000.0,
#   'EPS': 5.09,
#   'Dividend per Share': 0.57,
#   'Sector': 'Technology'},
#  {'ticker': 'JNJ',
#   'Revenue': 81581000000.0,
#   'Revenue Growth': 0.0,
#   'Gross Profit': 54595000000.0,
#   'Profit Margin': 0.188,
#   'grossProfitMargin': 0.6692121940157599,
#   'netProfitMargin': 0.1875068949878,
#   'Total assets': 145314000000.0,
#   'Total debt': 30480000000.0,
#   'Total liabilities': 85562000000.0,
#   'EPS': 5.7,
#   'Dividend per Share': 3.54,
#   'Sector': 'Healthcare'},
#  {'ticker': 'WDC',
#   'Revenue': 20647000000.0,
#   'Revenue Growth': 0.0814,
#   'Gross Profit': 7705000000.0,
#   'Profit Margin': 0.033,
#   'grossProfitMargin': 0.37317770136097,
#   'netProfitMargin': 0.032692400833051014,
#   'Total assets': 29235000000.0,
#   'Total debt': 11172000000.0,
#   'Total liabilities': 17704000000.0,
#   'EPS': 2.27,
#   'Dividend per Share': 2.0,
#   'Sector': 'Technology'},
#  {'ticker': 'BSX',
#   'Revenue': 9823000000.0,
#   'Revenue Growth': 0.0857,
#   'Gross Profit': 7010000000.0,
#   'Profit Margin': 0.17,
#   'grossProfitMargin': 0.71363127354169,
#   'netProfitMargin': 0.17011096406393,
#   'Total assets': 20999000000.0,
#   'Total debt': 7056000000.0,
#   'Total liabilities': 12273000000.0,
#   'EPS': 1.21,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'STI',
#   'Revenue': 9005000000.0,
#   'Revenue Growth': 0.0498,
#   'Gross Profit': 9005000000.0,
#   'Profit Margin': 0.29600000000000004,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.30816213214881,
#   'Total assets': 215543000000.0,
#   'Total debt': 23844000000.0,
#   'Total liabilities': 191263000000.0,
#   'EPS': 5.79,
#   'Dividend per Share': 1.8,
#   'Sector': 'Financial Services'},
#  {'ticker': 'BK',
#   'Revenue': 16392000000.0,
#   'Revenue Growth': 0.0546,
#   'Gross Profit': 16392000000.0,
#   'Profit Margin': 0.25,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.26024890190337,
#   'Total assets': 362873000000.0,
#   'Total debt': 48572000000.0,
#   'Total liabilities': 322005000000.0,
#   'EPS': 4.06,
#   'Dividend per Share': 1.04,
#   'Sector': 'Financial Services'},
#  {'ticker': 'APA',
#   'Revenue': 7348000000.0,
#   'Revenue Growth': 0.2482,
#   'Gross Profit': 2438000000.0,
#   'Profit Margin': 0.005,
#   'grossProfitMargin': 0.33179096352749,
#   'netProfitMargin': 0.0054436581382689,
#   'Total assets': 21582000000.0,
#   'Total debt': 8244000000.0,
#   'Total liabilities': 12770000000.0,
#   'EPS': 0.11,
#   'Dividend per Share': 1.0,
#   'Sector': 'Energy'},
#  {'ticker': 'DAL',
#   'Revenue': 44438000000.0,
#   'Revenue Growth': 0.0802,
#   'Gross Profit': 26493000000.0,
#   'Profit Margin': 0.08900000000000001,
#   'grossProfitMargin': 0.59617894594716,
#   'netProfitMargin': 0.088550339799271,
#   'Total assets': 60266000000.0,
#   'Total debt': 16527000000.0,
#   'Total liabilities': 46579000000.0,
#   'EPS': 5.69,
#   'Dividend per Share': 1.31,
#   'Sector': 'Industrials'},
#  {'ticker': 'CCL',
#   'Revenue': 18881000000.0,
#   'Revenue Growth': 0.0783,
#   'Gross Profit': 7792000000.0,
#   'Profit Margin': 0.16699999999999998,
#   'grossProfitMargin': 0.4126900058259601,
#   'netProfitMargin': 0.16694031036492002,
#   'Total assets': 42401000000.0,
#   'Total debt': 10323000000.0,
#   'Total liabilities': 17958000000.0,
#   'EPS': 4.45,
#   'Dividend per Share': 1.95,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'DISCA',
#   'Revenue': 10553000000.0,
#   'Revenue Growth': 0.5354,
#   'Gross Profit': 6618000000.0,
#   'Profit Margin': 0.056,
#   'grossProfitMargin': 0.62712025016583,
#   'netProfitMargin': 0.056287311664929,
#   'Total assets': 32550000000.0,
#   'Total debt': 16793000000.0,
#   'Total liabilities': 22033000000.0,
#   'EPS': 0.86,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'ABT',
#   'Revenue': 30578000000.0,
#   'Revenue Growth': 0.1164,
#   'Gross Profit': 17872000000.0,
#   'Profit Margin': 0.077,
#   'grossProfitMargin': 0.5844724965661601,
#   'netProfitMargin': 0.07744129766498799,
#   'Total assets': 67173000000.0,
#   'Total debt': 19566000000.0,
#   'Total liabilities': 36451000000.0,
#   'EPS': 1.34,
#   'Dividend per Share': 1.12,
#   'Sector': 'Healthcare'},
#  {'ticker': 'FITB',
#   'Revenue': 6693000000.0,
#   'Revenue Growth': -0.0101,
#   'Gross Profit': 6693000000.0,
#   'Profit Margin': 0.316,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.32765575974899,
#   'Total assets': 146069000000.0,
#   'Total debt': 16924000000.0,
#   'Total liabilities': 129819000000.0,
#   'EPS': 3.11,
#   'Dividend per Share': 0.74,
#   'Sector': 'Financial Services'},
#  {'ticker': 'USB',
#   'Revenue': 21142000000.0,
#   'Revenue Growth': 0.0411,
#   'Gross Profit': 21142000000.0,
#   'Profit Margin': 0.321,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.33563522845521004,
#   'Total assets': 467374000000.0,
#   'Total debt': 55479000000.0,
#   'Total liabilities': 415717000000.0,
#   'EPS': 4.15,
#   'Dividend per Share': 1.34,
#   'Sector': 'Financial Services'},
#  {'ticker': 'BA',
#   'Revenue': 101127000000.0,
#   'Revenue Growth': 0.0758,
#   'Gross Profit': 19637000000.0,
#   'Profit Margin': 0.103,
#   'grossProfitMargin': 0.1941815736648,
#   'netProfitMargin': 0.10343429548983,
#   'Total assets': 117359000000.0,
#   'Total debt': 13847000000.0,
#   'Total liabilities': 116949000000.0,
#   'EPS': 18.05,
#   'Dividend per Share': 6.84,
#   'Sector': 'Industrials'},
#  {'ticker': 'EBAY',
#   'Revenue': 10746000000.0,
#   'Revenue Growth': 0.0825,
#   'Gross Profit': 8364000000.0,
#   'Profit Margin': 0.235,
#   'grossProfitMargin': 0.77833612506979,
#   'netProfitMargin': 0.23543644146659,
#   'Total assets': 22819000000.0,
#   'Total debt': 9231000000.0,
#   'Total liabilities': 16538000000.0,
#   'EPS': 2.58,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'HBAN',
#   'Revenue': 4275000000.0,
#   'Revenue Growth': 0.0407,
#   'Gross Profit': 4275000000.0,
#   'Profit Margin': 0.309,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.32584795321637,
#   'Total assets': 108781000000.0,
#   'Total debt': 10642000000.0,
#   'Total liabilities': 97679000000.0,
#   'EPS': 1.22,
#   'Dividend per Share': 0.5,
#   'Sector': 'Financial Services'},
#  {'ticker': 'WBA',
#   'Revenue': 131537000000.0,
#   'Revenue Growth': 0.1127,
#   'Gross Profit': 30792000000.0,
#   'Profit Margin': 0.038,
#   'grossProfitMargin': 0.23409382911272,
#   'netProfitMargin': 0.038194576430966,
#   'Total assets': 68124000000.0,
#   'Total debt': 14397000000.0,
#   'Total liabilities': 41435000000.0,
#   'EPS': 5.07,
#   'Dividend per Share': 1.64,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DISCK',
#   'Revenue': 10553000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 6618000000.0,
#   'Profit Margin': 0.058182507343882986,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 32550000000.0,
#   'Total debt': 15185000000.0,
#   'Total liabilities': 24164000000.0,
#   'EPS': 0.86,
#   'Dividend per Share': nan,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'PGR',
#   'Revenue': 31979000000.0,
#   'Revenue Growth': 0.1915,
#   'Gross Profit': 10258000000.0,
#   'Profit Margin': 0.081,
#   'grossProfitMargin': 0.32077300728603003,
#   'netProfitMargin': 0.08178179430251101,
#   'Total assets': 46575000000.0,
#   'Total debt': 4404900000.0,
#   'Total liabilities': 35538700000.0,
#   'EPS': 4.45,
#   'Dividend per Share': 1.125,
#   'Sector': 'Financial Services'},
#  {'ticker': 'MO',
#   'Revenue': 25364000000.0,
#   'Revenue Growth': -0.0083,
#   'Gross Profit': 12254000000.0,
#   'Profit Margin': 0.275,
#   'grossProfitMargin': 0.4831256899542701,
#   'netProfitMargin': 0.27452294590759,
#   'Total assets': 55638000000.0,
#   'Total debt': 25746000000.0,
#   'Total liabilities': 40810000000.0,
#   'EPS': 3.69,
#   'Dividend per Share': 3.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MDT',
#   'Revenue': 29953000000.0,
#   'Revenue Growth': 0.0082,
#   'Gross Profit': 20886000000.0,
#   'Profit Margin': 0.104,
#   'grossProfitMargin': 0.69729242479885,
#   'netProfitMargin': 0.10362901879611,
#   'Total assets': 91393000000.0,
#   'Total debt': 25757000000.0,
#   'Total liabilities': 40571000000.0,
#   'EPS': 2.29,
#   'Dividend per Share': 1.84,
#   'Sector': 'Healthcare'},
#  {'ticker': 'EOG',
#   'Revenue': 17275399000.0,
#   'Revenue Growth': 0.5413,
#   'Gross Profit': 9600224000.0,
#   'Profit Margin': 0.198,
#   'grossProfitMargin': 0.55571648446441,
#   'netProfitMargin': 0.19791380795315,
#   'Total assets': 33934474000.0,
#   'Total debt': 6083262000.0,
#   'Total liabilities': 14570286000.0,
#   'EPS': 5.93,
#   'Dividend per Share': 0.758,
#   'Sector': 'Energy'},
#  {'ticker': 'HPE',
#   'Revenue': 30852000000.0,
#   'Revenue Growth': 0.0686,
#   'Gross Profit': 9570000000.0,
#   'Profit Margin': 0.062,
#   'grossProfitMargin': 0.31019058732011,
#   'netProfitMargin': 0.061843640606768,
#   'Total assets': 55493000000.0,
#   'Total debt': 12141000000.0,
#   'Total liabilities': 34219000000.0,
#   'EPS': 1.25,
#   'Dividend per Share': 0.375,
#   'Sector': 'Technology'},
#  {'ticker': 'TXN',
#   'Revenue': 15784000000.0,
#   'Revenue Growth': 0.055,
#   'Gross Profit': 10277000000.0,
#   'Profit Margin': 0.354,
#   'grossProfitMargin': 0.6511023821591501,
#   'netProfitMargin': 0.35352255448555,
#   'Total assets': 17137000000.0,
#   'Total debt': 5068000000.0,
#   'Total liabilities': 8143000000.0,
#   'EPS': 5.71,
#   'Dividend per Share': 2.63,
#   'Sector': 'Technology'},
#  {'ticker': 'OKE',
#   'Revenue': 12593196000.0,
#   'Revenue Growth': 0.0344,
#   'Gross Profit': 3066566000.0,
#   'Profit Margin': 0.091,
#   'grossProfitMargin': 0.24350974923284,
#   'netProfitMargin': 0.091454385368099,
#   'Total assets': 18231671000.0,
#   'Total debt': 9408993000.0,
#   'Total liabilities': 11652128000.0,
#   'EPS': 2.8,
#   'Dividend per Share': 3.245,
#   'Sector': 'Energy'},
#  {'ticker': 'CVS',
#   'Revenue': 194579000000.0,
#   'Revenue Growth': 0.053,
#   'Gross Profit': 31538000000.0,
#   'Profit Margin': -0.003,
#   'grossProfitMargin': 0.1620832669507,
#   'netProfitMargin': -0.0030527446435638,
#   'Total assets': 196456000000.0,
#   'Total debt': 73429000000.0,
#   'Total liabilities': 137913000000.0,
#   'EPS': -0.57,
#   'Dividend per Share': 2.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HES',
#   'Revenue': 6466000000.0,
#   'Revenue Growth': 0.1994,
#   'Gross Profit': 3390000000.0,
#   'Profit Margin': -0.051,
#   'grossProfitMargin': 0.52428085369626,
#   'netProfitMargin': -0.043612743581813,
#   'Total assets': 21433000000.0,
#   'Total debt': 6672000000.0,
#   'Total liabilities': 10545000000.0,
#   'EPS': -1.1,
#   'Dividend per Share': 1.0,
#   'Sector': 'Energy'},
#  {'ticker': 'NLSN',
#   'Revenue': 6515000000.0,
#   'Revenue Growth': -0.0087,
#   'Gross Profit': 3710000000.0,
#   'Profit Margin': -0.109,
#   'grossProfitMargin': 0.5694551036070601,
#   'netProfitMargin': -0.10928626247122,
#   'Total assets': 15179000000.0,
#   'Total debt': 8387000000.0,
#   'Total liabilities': 12136000000.0,
#   'EPS': -2.0,
#   'Dividend per Share': 1.39,
#   'Sector': 'Industrials'},
#  {'ticker': 'OXY',
#   'Revenue': 18934000000.0,
#   'Revenue Growth': 0.4264,
#   'Gross Profit': 7950000000.0,
#   'Profit Margin': 0.218,
#   'grossProfitMargin': 0.41987958170487,
#   'netProfitMargin': 0.21817893736136,
#   'Total assets': 43854000000.0,
#   'Total debt': 10317000000.0,
#   'Total liabilities': 22524000000.0,
#   'EPS': 5.4,
#   'Dividend per Share': 3.1,
#   'Sector': 'Energy'},
#  {'ticker': 'SYF',
#   'Revenue': 7739000000.0,
#   'Revenue Growth': 0.0945,
#   'Gross Profit': 7739000000.0,
#   'Profit Margin': 0.361,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.36051169401731,
#   'Total assets': 106792000000.0,
#   'Total debt': 23996000000.0,
#   'Total liabilities': 92114000000.0,
#   'EPS': 3.76,
#   'Dividend per Share': 0.72,
#   'Sector': 'Financial Services'},
#  {'ticker': 'LUV',
#   'Revenue': 21965000000.0,
#   'Revenue Growth': 0.0387,
#   'Gross Profit': 14908000000.0,
#   'Profit Margin': 0.112,
#   'grossProfitMargin': 0.67871613931254,
#   'netProfitMargin': 0.11222399271567997,
#   'Total assets': 26243000000.0,
#   'Total debt': 3377000000.0,
#   'Total liabilities': 16390000000.0,
#   'EPS': 4.3,
#   'Dividend per Share': 0.605,
#   'Sector': 'Industrials'},
#  {'ticker': 'FTI',
#   'Revenue': 12552900000.0,
#   'Revenue Growth': -0.1663,
#   'Gross Profit': 2279900000.0,
#   'Profit Margin': -0.153,
#   'grossProfitMargin': 0.18162336989859,
#   'netProfitMargin': -0.15308016474281,
#   'Total assets': 24784500000.0,
#   'Total debt': 4191700000.0,
#   'Total liabilities': 14357100000.0,
#   'EPS': -4.2,
#   'Dividend per Share': 0.52,
#   'Sector': 'Energy'},
#  {'ticker': 'EQR',
#   'Revenue': 2578434000.0,
#   'Revenue Growth': 0.0433,
#   'Gross Profit': 1698800000.0,
#   'Profit Margin': 0.254,
#   'grossProfitMargin': 0.65884951873889,
#   'netProfitMargin': 0.25501331428301005,
#   'Total assets': 20394209000.0,
#   'Total debt': 8817939000.0,
#   'Total liabilities': 9615454000.0,
#   'EPS': 1.78,
#   'Dividend per Share': 2.16,
#   'Sector': 'Real Estate'},
#  {'ticker': 'UNH',
#   'Revenue': 226247000000.0,
#   'Revenue Growth': 0.1247,
#   'Gross Profit': 53846000000.0,
#   'Profit Margin': 0.053,
#   'grossProfitMargin': 0.23799652592079,
#   'netProfitMargin': 0.052977498044173,
#   'Total assets': 152221000000.0,
#   'Total debt': 36554000000.0,
#   'Total liabilities': 95994000000.0,
#   'EPS': 12.45,
#   'Dividend per Share': 3.45,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AMZN',
#   'Revenue': 232887000000.0,
#   'Revenue Growth': 0.3093,
#   'Gross Profit': 93731000000.0,
#   'Profit Margin': 0.043,
#   'grossProfitMargin': 0.40247416128852,
#   'netProfitMargin': 0.04325273630558999,
#   'Total assets': 162648000000.0,
#   'Total debt': 33145000000.0,
#   'Total liabilities': 119099000000.0,
#   'EPS': 20.68,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'NFLX',
#   'Revenue': 15794341000.0,
#   'Revenue Growth': 0.3508,
#   'Gross Profit': 5826803000.0,
#   'Profit Margin': 0.077,
#   'grossProfitMargin': 0.36891713304151,
#   'netProfitMargin': 0.076688353125971,
#   'Total assets': 25974400000.0,
#   'Total debt': 10360058000.0,
#   'Total liabilities': 20735635000.0,
#   'EPS': 2.78,
#   'Dividend per Share': 0.0,
#   'Sector': 'Communication Services'},
#  {'ticker': 'CSX',
#   'Revenue': 12250000000.0,
#   'Revenue Growth': 0.0738,
#   'Gross Profit': 4773000000.0,
#   'Profit Margin': 0.27,
#   'grossProfitMargin': 0.38963265306122,
#   'netProfitMargin': 0.27012244897959004,
#   'Total assets': 36729000000.0,
#   'Total debt': 14757000000.0,
#   'Total liabilities': 24149000000.0,
#   'EPS': 3.86,
#   'Dividend per Share': 0.88,
#   'Sector': 'Industrials'},
#  {'ticker': 'WYNN',
#   'Revenue': 6717660000.0,
#   'Revenue Growth': 0.1067,
#   'Gross Profit': 2631385000.0,
#   'Profit Margin': 0.085,
#   'grossProfitMargin': 0.39171154836654,
#   'netProfitMargin': 0.085212707996535,
#   'Total assets': 13216269000.0,
#   'Total debt': 9423100000.0,
#   'Total liabilities': 11401480000.0,
#   'EPS': 5.37,
#   'Dividend per Share': 2.75,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'FOX',
#   'Revenue': nan,
#   'Revenue Growth': nan,
#   'Gross Profit': 3648000000.0,
#   'Profit Margin': 0.147,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 13121000000.0,
#   'Total debt': 19523000000.0,
#   'Total liabilities': 3252000000.0,
#   'EPS': nan,
#   'Dividend per Share': 0.36,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'CNC',
#   'Revenue': 60116000000.0,
#   'Revenue Growth': 0.2425,
#   'Gross Profit': 8421000000.0,
#   'Profit Margin': 0.015,
#   'grossProfitMargin': 0.14007918025151,
#   'netProfitMargin': 0.01497105595848,
#   'Total assets': 30901000000.0,
#   'Total debt': 6686000000.0,
#   'Total liabilities': 19878000000.0,
#   'EPS': 2.31,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ZION',
#   'Revenue': 2821000000.0,
#   'Revenue Growth': 0.0913,
#   'Gross Profit': 2821000000.0,
#   'Profit Margin': 0.301,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.31336405529954,
#   'Total assets': 68746000000.0,
#   'Total debt': 6377000000.0,
#   'Total liabilities': 61168000000.0,
#   'EPS': 4.36,
#   'Dividend per Share': 1.04,
#   'Sector': 'Financial Services'},
#  {'ticker': 'CI',
#   'Revenue': 48650000000.0,
#   'Revenue Growth': 0.1637,
#   'Gross Profit': 16329000000.0,
#   'Profit Margin': 0.054000000000000006,
#   'grossProfitMargin': 0.33564234326824,
#   'netProfitMargin': 0.054203494347379005,
#   'Total assets': 153226000000.0,
#   'Total debt': 42478000000.0,
#   'Total liabilities': 112154000000.0,
#   'EPS': 10.69,
#   'Dividend per Share': 0.04,
#   'Sector': 'Healthcare'},
#  {'ticker': 'WMB',
#   'Revenue': 8686000000.0,
#   'Revenue Growth': 0.0816,
#   'Gross Profit': 4335000000.0,
#   'Profit Margin': -0.018000000000000002,
#   'grossProfitMargin': 0.49907897766521,
#   'netProfitMargin': -0.017844807736588003,
#   'Total assets': 45302000000.0,
#   'Total debt': 22414000000.0,
#   'Total liabilities': 29305000000.0,
#   'EPS': -0.16,
#   'Dividend per Share': 1.36,
#   'Sector': 'Energy'},
#  {'ticker': 'HBI',
#   'Revenue': 6803955000.0,
#   'Revenue Growth': 0.0514,
#   'Gross Profit': 2656519000.0,
#   'Profit Margin': 0.081,
#   'grossProfitMargin': 0.39043747349887,
#   'netProfitMargin': 0.08128860346666,
#   'Total assets': 7255958000.0,
#   'Total debt': 3980591000.0,
#   'Total liabilities': 6285675000.0,
#   'EPS': 1.52,
#   'Dividend per Share': 0.6,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'BBT',
#   'Revenue': 10992000000.0,
#   'Revenue Growth': 0.0206,
#   'Gross Profit': 10992000000.0,
#   'Profit Margin': 0.279,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.29448689956332,
#   'Total assets': 225697000000.0,
#   'Total debt': 28887000000.0,
#   'Total liabilities': 195519000000.0,
#   'EPS': 3.96,
#   'Dividend per Share': 1.56,
#   'Sector': 'Financial Services'},
#  {'ticker': 'PAYX',
#   'Revenue': 3377700000.0,
#   'Revenue Growth': 0.0713,
#   'Gross Profit': 2359500000.0,
#   'Profit Margin': 0.294,
#   'grossProfitMargin': 0.69855226929567,
#   'netProfitMargin': 0.29431269798976,
#   'Total assets': 7915400000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 5558600000.0,
#   'EPS': 2.77,
#   'Dividend per Share': 2.06,
#   'Sector': 'Industrials'},
#  {'ticker': 'CELG',
#   'Revenue': 15281000000.0,
#   'Revenue Growth': 0.1752,
#   'Gross Profit': 14694000000.0,
#   'Profit Margin': 0.265,
#   'grossProfitMargin': 0.96158628362018,
#   'netProfitMargin': 0.2647732478241,
#   'Total assets': 35480000000.0,
#   'Total debt': 20270000000.0,
#   'Total liabilities': 29319000000.0,
#   'EPS': 5.65,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'D',
#   'Revenue': 13366000000.0,
#   'Revenue Growth': 0.062,
#   'Gross Profit': 5624000000.0,
#   'Profit Margin': 0.183,
#   'grossProfitMargin': 0.42076911566662,
#   'netProfitMargin': 0.18307646266647,
#   'Total assets': 77914000000.0,
#   'Total debt': 35175000000.0,
#   'Total liabilities': 55866000000.0,
#   'EPS': 3.74,
#   'Dividend per Share': 3.34,
#   'Sector': 'Utilities'},
#  {'ticker': 'CFG',
#   'Revenue': 5802000000.0,
#   'Revenue Growth': 0.0772,
#   'Gross Profit': 5802000000.0,
#   'Profit Margin': 0.292,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.29162357807653,
#   'Total assets': 160518000000.0,
#   'Total debt': 17242000000.0,
#   'Total liabilities': 139701000000.0,
#   'EPS': 3.54,
#   'Dividend per Share': 0.98,
#   'Sector': 'Financial Services'},
#  {'ticker': 'MMM',
#   'Revenue': 32765000000.0,
#   'Revenue Growth': 0.035,
#   'Gross Profit': 16083000000.0,
#   'Profit Margin': 0.163,
#   'grossProfitMargin': 0.49085914848161,
#   'netProfitMargin': 0.16325347169235,
#   'Total assets': 36500000000.0,
#   'Total debt': 14622000000.0,
#   'Total liabilities': 26652000000.0,
#   'EPS': 9.09,
#   'Dividend per Share': 5.44,
#   'Sector': 'Industrials'},
#  {'ticker': 'BIIB',
#   'Revenue': 13452900000.0,
#   'Revenue Growth': 0.0961,
#   'Gross Profit': 11636600000.0,
#   'Profit Margin': 0.329,
#   'grossProfitMargin': 0.86498821815371,
#   'netProfitMargin': 0.32934906228397,
#   'Total assets': 25288900000.0,
#   'Total debt': 5936500000.0,
#   'Total liabilities': 12257300000.0,
#   'EPS': 21.63,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ACN',
#   'Revenue': 40992534000.0,
#   'Revenue Growth': 0.1331,
#   'Gross Profit': 12493364000.0,
#   'Profit Margin': 0.099,
#   'grossProfitMargin': 0.30477169330396003,
#   'netProfitMargin': 0.09904015692223403,
#   'Total assets': 24449083000.0,
#   'Total debt': 25013000.0,
#   'Total liabilities': 13724495000.0,
#   'EPS': 6.46,
#   'Dividend per Share': 2.66,
#   'Sector': 'Technology'},
#  {'ticker': 'SBUX',
#   'Revenue': 24719500000.0,
#   'Revenue Growth': 0.1042,
#   'Gross Profit': 16788800000.0,
#   'Profit Margin': 0.183,
#   'grossProfitMargin': 0.6791723133558499,
#   'netProfitMargin': 0.18278282327717,
#   'Total assets': 24156400000.0,
#   'Total debt': 9440100000.0,
#   'Total liabilities': 22980600000.0,
#   'EPS': 3.27,
#   'Dividend per Share': 1.26,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'VLO',
#   'Revenue': 117033000000.0,
#   'Revenue Growth': 0.2453,
#   'Gross Profit': 5594000000.0,
#   'Profit Margin': 0.027000000000000003,
#   'grossProfitMargin': 0.04779848418822,
#   'netProfitMargin': 0.026676236617023,
#   'Total assets': 50155000000.0,
#   'Total debt': 9109000000.0,
#   'Total liabilities': 27424000000.0,
#   'EPS': 7.3,
#   'Dividend per Share': 3.2,
#   'Sector': 'Energy'},
#  {'ticker': 'ADSK',
#   'Revenue': 2056600000.0,
#   'Revenue Growth': 0.0126,
#   'Gross Profit': 1753200000.0,
#   'Profit Margin': -0.276,
#   'grossProfitMargin': 0.85247495866965,
#   'netProfitMargin': -0.27564912963143,
#   'Total assets': 4113600000.0,
#   'Total debt': 1586000000.0,
#   'Total liabilities': 4369600000.0,
#   'EPS': -2.58,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'HD',
#   'Revenue': 100904000000.0,
#   'Revenue Growth': 0.0667,
#   'Gross Profit': 34356000000.0,
#   'Profit Margin': 0.086,
#   'grossProfitMargin': 0.34048204233727003,
#   'netProfitMargin': 0.085526837389994,
#   'Total assets': 44529000000.0,
#   'Total debt': 27028000000.0,
#   'Total liabilities': 43075000000.0,
#   'EPS': 7.33,
#   'Dividend per Share': 3.56,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'ARNC',
#   'Revenue': 14014000000.0,
#   'Revenue Growth': 0.0813,
#   'Gross Profit': 2617000000.0,
#   'Profit Margin': 0.046,
#   'grossProfitMargin': 0.18674182959897,
#   'netProfitMargin': 0.04581133152561701,
#   'Total assets': 18693000000.0,
#   'Total debt': 6330000000.0,
#   'Total liabilities': 13108000000.0,
#   'EPS': 1.33,
#   'Dividend per Share': 0.24,
#   'Sector': 'Industrials'},
#  {'ticker': 'NTRS',
#   'Revenue': 5974700000.0,
#   'Revenue Growth': 0.1058,
#   'Gross Profit': 5974700000.0,
#   'Profit Margin': 0.253,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.26049843506787,
#   'Total assets': 132212500000.0,
#   'Total debt': 14065500000.0,
#   'Total liabilities': 121704200000.0,
#   'EPS': 6.68,
#   'Dividend per Share': 1.94,
#   'Sector': 'Financial Services'},
#  {'ticker': 'DHI',
#   'Revenue': 16068000000.0,
#   'Revenue Growth': 0.1403,
#   'Gross Profit': 3669900000.0,
#   'Profit Margin': 0.091,
#   'grossProfitMargin': 0.22839805825243,
#   'netProfitMargin': 0.09088249937764503,
#   'Total assets': 14114600000.0,
#   'Total debt': 3203500000.0,
# ...
#   'Total debt': 0.0,
#   'Total liabilities': 799567000.0,
#   'EPS': 5.0,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CMG',
#   'Revenue': 4864985000.0,
#   'Revenue Growth': 0.0868,
#   'Gross Profit': 910992000.0,
#   'Profit Margin': 0.036000000000000004,
#   'grossProfitMargin': 0.18725484251236,
#   'netProfitMargin': 0.036290553824935,
#   'Total assets': 2265518000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 824179000.0,
#   'EPS': 6.35,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'REG',
#   'Revenue': 1120975000.0,
#   'Revenue Growth': 0.1388,
#   'Gross Profit': 815085000.0,
#   'Profit Margin': 0.222,
#   'grossProfitMargin': 0.72712147906956,
#   'netProfitMargin': 0.22224135239412,
#   'Total assets': 10944663000.0,
#   'Total debt': 3715212000.0,
#   'Total liabilities': 4494495000.0,
#   'EPS': 1.47,
#   'Dividend per Share': 2.22,
#   'Sector': 'Real Estate'},
#  {'ticker': 'PKG',
#   'Revenue': 7014600000.0,
#   'Revenue Growth': 0.0884,
#   'Gross Profit': 1645300000.0,
#   'Profit Margin': 0.105,
#   'grossProfitMargin': 0.23455364525418,
#   'netProfitMargin': 0.10520913523223,
#   'Total assets': 6569700000.0,
#   'Total debt': 2502700000.0,
#   'Total liabilities': 3897300000.0,
#   'EPS': 7.82,
#   'Dividend per Share': 3.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'CINF',
#   'Revenue': 5407000000.0,
#   'Revenue Growth': -0.0567,
#   'Gross Profit': 1917000000.0,
#   'Profit Margin': 0.053,
#   'grossProfitMargin': 0.35454041057888,
#   'netProfitMargin': 0.05307934159423,
#   'Total assets': 21935000000.0,
#   'Total debt': 866000000.0,
#   'Total liabilities': 14102000000.0,
#   'EPS': 1.76,
#   'Dividend per Share': 2.12,
#   'Sector': 'Financial Services'},
#  {'ticker': 'CLX',
#   'Revenue': 6124000000.0,
#   'Revenue Growth': 0.0253,
#   'Gross Profit': 2675000000.0,
#   'Profit Margin': 0.134,
#   'grossProfitMargin': 0.43680600914435,
#   'netProfitMargin': 0.13438928804703,
#   'Total assets': 5060000000.0,
#   'Total debt': 2483000000.0,
#   'Total liabilities': 4334000000.0,
#   'EPS': 6.37,
#   'Dividend per Share': 3.48,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'HII',
#   'Revenue': 8176000000.0,
#   'Revenue Growth': 0.0988,
#   'Gross Profit': 1791000000.0,
#   'Profit Margin': 0.102,
#   'grossProfitMargin': 0.21905577299413,
#   'netProfitMargin': 0.10225048923679,
#   'Total assets': 6383000000.0,
#   'Total debt': 1283000000.0,
#   'Total liabilities': 4867000000.0,
#   'EPS': 19.09,
#   'Dividend per Share': 3.02,
#   'Sector': 'Industrials'},
#  {'ticker': 'PRGO',
#   'Revenue': 4731700000.0,
#   'Revenue Growth': -0.0434,
#   'Gross Profit': 1831500000.0,
#   'Profit Margin': 0.028,
#   'grossProfitMargin': 0.38707018619101,
#   'netProfitMargin': 0.027685609823108,
#   'Total assets': 10983400000.0,
#   'Total debt': 3242400000.0,
#   'Total liabilities': 5315300000.0,
#   'EPS': 0.95,
#   'Dividend per Share': 0.76,
#   'Sector': 'Healthcare'},
#  {'ticker': 'IFF',
#   'Revenue': 3977539000.0,
#   'Revenue Growth': 0.1703,
#   'Gross Profit': 1682707000.0,
#   'Profit Margin': 0.085,
#   'grossProfitMargin': 0.42305229439611,
#   'netProfitMargin': 0.08480168264849201,
#   'Total assets': 12889395000.0,
#   'Total debt': 4553059000.0,
#   'Total liabilities': 6846021000.0,
#   'EPS': 3.81,
#   'Dividend per Share': 2.84,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'SRCL',
#   'Revenue': 3485900000.0,
#   'Revenue Growth': -0.0265,
#   'Gross Profit': 1376000000.0,
#   'Profit Margin': -0.073,
#   'grossProfitMargin': 0.3947330675005,
#   'netProfitMargin': -0.07019707966378799,
#   'Total assets': 6455500000.0,
#   'Total debt': 2783000000.0,
#   'Total liabilities': 3858400000.0,
#   'EPS': -2.91,
#   'Dividend per Share': 0.0,
#   'Sector': 'Industrials'},
#  {'ticker': 'MAC',
#   'Revenue': 960351000.0,
#   'Revenue Growth': -0.0335,
#   'Gross Profit': 579347000.0,
#   'Profit Margin': 0.062,
#   'grossProfitMargin': 0.60326588924258,
#   'netProfitMargin': 0.062497982508479,
#   'Total assets': 9026808000.0,
#   'Total debt': 5360945000.0,
#   'Total liabilities': 5838376000.0,
#   'EPS': 0.42,
#   'Dividend per Share': 2.97,
#   'Sector': 'Real Estate'},
#  {'ticker': 'IQV',
#   'Revenue': 10412000000.0,
#   'Revenue Growth': 0.0732,
#   'Gross Profit': 3666000000.0,
#   'Profit Margin': 0.025,
#   'grossProfitMargin': 0.35209373799462,
#   'netProfitMargin': 0.024875144064541,
#   'Total assets': 22549000000.0,
#   'Total debt': 11007000000.0,
#   'Total liabilities': 15595000000.0,
#   'EPS': 1.27,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AWK',
#   'Revenue': 3440000000.0,
#   'Revenue Growth': 0.0247,
#   'Gross Profit': 1961000000.0,
#   'Profit Margin': 0.165,
#   'grossProfitMargin': 0.57005813953488,
#   'netProfitMargin': 0.16482558139535,
#   'Total assets': 21223000000.0,
#   'Total debt': 8611000000.0,
#   'Total liabilities': 15359000000.0,
#   'EPS': 3.16,
#   'Dividend per Share': 1.78,
#   'Sector': 'Utilities'},
#  {'ticker': 'GPN',
#   'Revenue': 3366366000.0,
#   'Revenue Growth': -0.1532,
#   'Gross Profit': 2271352000.0,
#   'Profit Margin': 0.134,
#   'grossProfitMargin': 0.67471926700781,
#   'netProfitMargin': 0.13428516091238998,
#   'Total assets': 13230774000.0,
#   'Total debt': 5830729000.0,
#   'Total liabilities': 9044431000.0,
#   'EPS': 2.85,
#   'Dividend per Share': 0.04,
#   'Sector': 'Industrials'},
#  {'ticker': 'VAR',
#   'Revenue': 2919100000.0,
#   'Revenue Growth': 0.1145,
#   'Gross Profit': 1273600000.0,
#   'Profit Margin': 0.051,
#   'grossProfitMargin': 0.43629885923744,
#   'netProfitMargin': 0.0513514439382,
#   'Total assets': 3252700000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 1664000000.0,
#   'EPS': 1.64,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'WAT',
#   'Revenue': 2419929000.0,
#   'Revenue Growth': 0.048,
#   'Gross Profit': 1427365000.0,
#   'Profit Margin': 0.245,
#   'grossProfitMargin': 0.58983755308524,
#   'netProfitMargin': 0.24537662055374,
#   'Total assets': 3727426000.0,
#   'Total debt': 1148350000.0,
#   'Total liabilities': 2160168000.0,
#   'EPS': 7.71,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'MTB',
#   'Revenue': 5796302000.0,
#   'Revenue Growth': 0.0608,
#   'Gross Profit': 5796302000.0,
#   'Profit Margin': 0.317,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.31675851258268,
#   'Total assets': 120097403000.0,
#   'Total debt': 12843292000.0,
#   'Total liabilities': 104637212000.0,
#   'EPS': 12.75,
#   'Dividend per Share': 3.55,
#   'Sector': 'Financial Services'},
#  {'ticker': 'AVY',
#   'Revenue': 7159000000.0,
#   'Revenue Growth': 0.0824,
#   'Gross Profit': 1915500000.0,
#   'Profit Margin': 0.065,
#   'grossProfitMargin': 0.26756530241654003,
#   'netProfitMargin': 0.065288448107278,
#   'Total assets': 5177500000.0,
#   'Total debt': 1966200000.0,
#   'Total liabilities': 4222400000.0,
#   'EPS': 5.35,
#   'Dividend per Share': 2.01,
#   'Sector': 'Industrials'},
#  {'ticker': 'PSA',
#   'Revenue': 2754280000.0,
#   'Revenue Growth': 0.0321,
#   'Gross Profit': 2014558000.0,
#   'Profit Margin': 0.541,
#   'grossProfitMargin': 0.73142817723688,
#   'netProfitMargin': 0.62122623698389,
#   'Total assets': 10928270000.0,
#   'Total debt': 1412283000.0,
#   'Total liabilities': 1783542000.0,
#   'EPS': 8.56,
#   'Dividend per Share': 8.0,
#   'Sector': 'Real Estate'},
#  {'ticker': 'AIZ',
#   'Revenue': 8057600000.0,
#   'Revenue Growth': 0.2561,
#   'Gross Profit': 5715000000.0,
#   'Profit Margin': 0.029,
#   'grossProfitMargin': 0.70926826846704,
#   'netProfitMargin': 0.031150714853057995,
#   'Total assets': 41089300000.0,
#   'Total debt': 2006000000.0,
#   'Total liabilities': 35955400000.0,
#   'EPS': 4.0,
#   'Dividend per Share': 2.28,
#   'Sector': 'Financial Services'},
#  {'ticker': 'LEG',
#   'Revenue': 4269500000.0,
#   'Revenue Growth': 0.0826,
#   'Gross Profit': 888700000.0,
#   'Profit Margin': 0.07200000000000001,
#   'grossProfitMargin': 0.20815083733458,
#   'netProfitMargin': 0.07164773392668901,
#   'Total assets': 3382000000.0,
#   'Total debt': 1169000000.0,
#   'Total liabilities': 2224400000.0,
#   'EPS': 2.28,
#   'Dividend per Share': 1.5,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'FRT',
#   'Revenue': 915436000.0,
#   'Revenue Growth': 0.0678,
#   'Gross Profit': 627566000.0,
#   'Profit Margin': 0.255,
#   'grossProfitMargin': 0.68553782022992,
#   'netProfitMargin': 0.26425331754486,
#   'Total assets': 6289644000.0,
#   'Total debt': 3229204000.0,
#   'Total liabilities': 3686106000.0,
#   'EPS': 3.18,
#   'Dividend per Share': 4.04,
#   'Sector': 'Real Estate'},
#  {'ticker': 'PVH',
#   'Revenue': 8914800000.0,
#   'Revenue Growth': 0.0868,
#   'Gross Profit': 4894400000.0,
#   'Profit Margin': 0.06,
#   'grossProfitMargin': 0.54901960784314,
#   'netProfitMargin': 0.0603266478216,
#   'Total assets': 11885700000.0,
#   'Total debt': 3080800000.0,
#   'Total liabilities': 6349300000.0,
#   'EPS': 6.93,
#   'Dividend per Share': 0.152,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'MTD',
#   'Revenue': 2935586000.0,
#   'Revenue Growth': 0.0773,
#   'Gross Profit': 1684378000.0,
#   'Profit Margin': 0.175,
#   'grossProfitMargin': 0.57377913643136,
#   'netProfitMargin': 0.17461965004602,
#   'Total assets': 2618847000.0,
#   'Total debt': 1034691000.0,
#   'Total liabilities': 2028784000.0,
#   'EPS': 20.33,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ESS',
#   'Revenue': 1400053000.0,
#   'Revenue Growth': 0.0265,
#   'Gross Profit': 983657000.0,
#   'Profit Margin': 0.279,
#   'grossProfitMargin': 0.7025855449758001,
#   'netProfitMargin': 0.27867016462948,
#   'Total assets': 12383596000.0,
#   'Total debt': 5605942000.0,
#   'Total liabilities': 5954277000.0,
#   'EPS': 5.91,
#   'Dividend per Share': 7.44,
#   'Sector': 'Real Estate'},
#  {'ticker': 'VRSK',
#   'Revenue': 2395100000.0,
#   'Revenue Growth': 0.1165,
#   'Gross Profit': 1508900000.0,
#   'Profit Margin': 0.25,
#   'grossProfitMargin': 0.6299945722516801,
#   'netProfitMargin': 0.24996868606739006,
#   'Total assets': 5900300000.0,
#   'Total debt': 2723300000.0,
#   'Total liabilities': 3829700000.0,
#   'EPS': 3.63,
#   'Dividend per Share': 0.0,
#   'Sector': 'Industrials'},
#  {'ticker': 'APD',
#   'Revenue': 8930200000.0,
#   'Revenue Growth': 0.0907,
#   'Gross Profit': 2740700000.0,
#   'Profit Margin': 0.168,
#   'grossProfitMargin': 0.30690242099841,
#   'netProfitMargin': 0.16772300732346,
#   'Total assets': 19178300000.0,
#   'Total debt': 3812600000.0,
#   'Total liabilities': 8002000000.0,
#   'EPS': 6.83,
#   'Dividend per Share': 5.2,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'AJG',
#   'Revenue': 6934000000.0,
#   'Revenue Growth': 0.1096,
#   'Gross Profit': 4214300000.0,
#   'Profit Margin': 0.091,
#   'grossProfitMargin': 0.60777329102971,
#   'netProfitMargin': 0.091361407556966,
#   'Total assets': 16334000000.0,
#   'Total debt': 3610400000.0,
#   'Total liabilities': 11764300000.0,
#   'EPS': 3.47,
#   'Dividend per Share': 1.64,
#   'Sector': 'Financial Services'},
#  {'ticker': 'SNA',
#   'Revenue': 4070000000.0,
#   'Revenue Growth': -0.0001,
#   'Gross Profit': 2144000000.0,
#   'Profit Margin': 0.16699999999999998,
#   'grossProfitMargin': 0.52678132678133,
#   'netProfitMargin': 0.16705159705160005,
#   'Total assets': 5308000000.0,
#   'Total debt': 1132300000.0,
#   'Total liabilities': 2190000000.0,
#   'EPS': 12.15,
#   'Dividend per Share': 3.41,
#   'Sector': 'Industrials'},
#  {'ticker': 'WLTW',
#   'Revenue': 8513000000.0,
#   'Revenue Growth': 0.0379,
#   'Gross Profit': 8513000000.0,
#   'Profit Margin': 0.08199999999999999,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.081639844943028,
#   'Total assets': 32385000000.0,
#   'Total debt': 4575000000.0,
#   'Total liabilities': 22388000000.0,
#   'EPS': 5.29,
#   'Dividend per Share': 2.4,
#   'Sector': 'Financial Services'},
#  {'ticker': 'ROP',
#   'Revenue': 5191200000.0,
#   'Revenue Growth': 0.1267,
#   'Gross Profit': 3279500000.0,
#   'Profit Margin': 0.182,
#   'grossProfitMargin': 0.63174217907228,
#   'netProfitMargin': 0.18192325473879,
#   'Total assets': 15249500000.0,
#   'Total debt': 4941700000.0,
#   'Total liabilities': 7511000000.0,
#   'EPS': 9.15,
#   'Dividend per Share': 1.649,
#   'Sector': 'Industrials'},
#  {'ticker': 'GRMN',
#   'Revenue': 3347444000.0,
#   'Revenue Growth': 0.0724,
#   'Gross Profit': 1979719000.0,
#   'Profit Margin': 0.207,
#   'grossProfitMargin': 0.5914121341537,
#   'netProfitMargin': 0.20734626180453,
#   'Total assets': 5382858000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 1219884000.0,
#   'EPS': 3.68,
#   'Dividend per Share': 2.1,
#   'Sector': 'Technology'},
#  {'ticker': 'DTE',
#   'Revenue': 14212000000.0,
#   'Revenue Growth': 0.1273,
#   'Gross Profit': 3150000000.0,
#   'Profit Margin': 0.079,
#   'grossProfitMargin': 0.221643681396,
#   'netProfitMargin': 0.078806642274135,
#   'Total assets': 36288000000.0,
#   'Total debt': 14242000000.0,
#   'Total liabilities': 25571000000.0,
#   'EPS': 6.18,
#   'Dividend per Share': 3.592,
#   'Sector': 'Utilities'},
#  {'ticker': 'NDAQ',
#   'Revenue': 4277000000.0,
#   'Revenue Growth': 0.0833,
#   'Gross Profit': 2526000000.0,
#   'Profit Margin': 0.107,
#   'grossProfitMargin': 0.59060088847323,
#   'netProfitMargin': 0.10708440495675,
#   'Total assets': 15700000000.0,
#   'Total debt': 3831000000.0,
#   'Total liabilities': 10251000000.0,
#   'EPS': 2.77,
#   'Dividend per Share': 1.7,
#   'Sector': 'Financial Services'},
#  {'ticker': 'AME',
#   'Revenue': 4845872000.0,
#   'Revenue Growth': 0.1269,
#   'Gross Profit': 1659562000.0,
#   'Profit Margin': 0.161,
#   'grossProfitMargin': 0.34246921916221,
#   'netProfitMargin': 0.16053519366587,
#   'Total assets': 8662288000.0,
#   'Total debt': 2632713000.0,
#   'Total liabilities': 4420366000.0,
#   'EPS': 3.37,
#   'Dividend per Share': 0.56,
#   'Sector': 'Technology'},
#  {'ticker': 'BKNG',
#   'Revenue': 14527000000.0,
#   'Revenue Growth': 0.1456,
#   'Gross Profit': 14527000000.0,
#   'Profit Margin': 0.275,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.27521167481242,
#   'Total assets': 22687000000.0,
#   'Total debt': 8649000000.0,
#   'Total liabilities': 13902000000.0,
#   'EPS': 84.26,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'RE',
#   'Revenue': 7377206000.0,
#   'Revenue Growth': 0.1164,
#   'Gross Profit': 206773000.0,
#   'Profit Margin': 0.014,
#   'grossProfitMargin': 0.028028633062436,
#   'netProfitMargin': 0.014036750498766,
#   'Total assets': 24750992000.0,
#   'Total debt': 633613000.0,
#   'Total liabilities': 16890195000.0,
#   'EPS': 2.54,
#   'Dividend per Share': 5.3,
#   'Sector': 'Financial Services'},
#  {'ticker': 'AZO',
#   'Revenue': 11221077000.0,
#   'Revenue Growth': 0.0305,
#   'Gross Profit': 5973746000.0,
#   'Profit Margin': 0.119,
#   'grossProfitMargin': 0.53236832792432,
#   'netProfitMargin': 0.11919854038966,
#   'Total assets': 9346980000.0,
#   'Total debt': 5005930000.0,
#   'Total liabilities': 10867335000.0,
#   'EPS': 49.59,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'ANSS',
#   'Revenue': 1293636000.0,
#   'Revenue Growth': 0.1811,
#   'Gross Profit': 1137751000.0,
#   'Profit Margin': 0.324,
#   'grossProfitMargin': 0.87949856064612,
#   'netProfitMargin': 0.32418315507608,
#   'Total assets': 3265964000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 616417000.0,
#   'EPS': 4.99,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'AMG',
#   'Revenue': 2378400000.0,
#   'Revenue Growth': 0.0318,
#   'Gross Profit': 2378400000.0,
#   'Profit Margin': 0.102,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.10242179616549,
#   'Total assets': 8219100000.0,
#   'Total debt': 1829600000.0,
#   'Total liabilities': 3250500000.0,
#   'EPS': 4.55,
#   'Dividend per Share': 1.2,
#   'Sector': 'Financial Services'},
#  {'ticker': 'SNPS',
#   'Revenue': 3121058000.0,
#   'Revenue Growth': 0.1454,
#   'Gross Profit': 2385160000.0,
#   'Profit Margin': 0.139,
#   'grossProfitMargin': 0.7642152116365699,
#   'netProfitMargin': 0.13858057107558,
#   'Total assets': 6145974000.0,
#   'Total debt': 469304000.0,
#   'Total liabilities': 2660959000.0,
#   'EPS': 2.9,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'IPGP',
#   'Revenue': 1459874000.0,
#   'Revenue Growth': 0.0362,
#   'Gross Profit': 800268000.0,
#   'Profit Margin': 0.277,
#   'grossProfitMargin': 0.54817607546953,
#   'netProfitMargin': 0.27675470622807,
#   'Total assets': 2574450000.0,
#   'Total debt': 45378000.0,
#   'Total liabilities': 368215000.0,
#   'EPS': 7.55,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'}]

# %%
financial2017_dict=top500_2017.to_dict('records')
financial2017_dict
# Out:
# [{'ticker': 'PG',
#   'Revenue': 65058000000.0,
#   'Revenue Growth': -0.0037,
#   'Gross Profit': 32420000000.0,
#   'Profit Margin': 0.236,
#   'grossProfitMargin': 0.49832457192044,
#   'netProfitMargin': 0.23557441052599,
#   'Total assets': 120406000000.0,
#   'Total debt': 31592000000.0,
#   'Total liabilities': 64628000000.0,
#   'EPS': 5.8,
#   'Dividend per Share': 2.698,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KR',
#   'Revenue': 115337000000.0,
#   'Revenue Growth': 0.0501,
#   'Gross Profit': 25835000000.0,
#   'Profit Margin': 0.017,
#   'grossProfitMargin': 0.22399576892064,
#   'netProfitMargin': 0.017123733060510002,
#   'Total assets': 36505000000.0,
#   'Total debt': 14077000000.0,
#   'Total liabilities': 29795000000.0,
#   'EPS': 2.08,
#   'Dividend per Share': 0.45,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'GIS',
#   'Revenue': 15619800000.0,
#   'Revenue Growth': -0.057,
#   'Gross Profit': 5567800000.0,
#   'Profit Margin': 0.106,
#   'grossProfitMargin': 0.35645782916555,
#   'netProfitMargin': 0.10611531517689,
#   'Total assets': 21812600000.0,
#   'Total debt': 9481700000.0,
#   'Total liabilities': 16216200000.0,
#   'EPS': 2.82,
#   'Dividend per Share': 1.92,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'PM',
#   'Revenue': 78098000000.0,
#   'Revenue Growth': 0.042,
#   'Gross Profit': 18316000000.0,
#   'Profit Margin': 0.077,
#   'grossProfitMargin': 0.2345258521345,
#   'netProfitMargin': 0.077274706138441,
#   'Total assets': 42968000000.0,
#   'Total debt': 34339000000.0,
#   'Total liabilities': 53198000000.0,
#   'EPS': 3.88,
#   'Dividend per Share': 4.22,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KO',
#   'Revenue': 35410000000.0,
#   'Revenue Growth': -0.1541,
#   'Gross Profit': 22155000000.0,
#   'Profit Margin': 0.035,
#   'grossProfitMargin': 0.6256707144874301,
#   'netProfitMargin': 0.035244281276476,
#   'Total assets': 87896000000.0,
#   'Total debt': 47685000000.0,
#   'Total liabilities': 68919000000.0,
#   'EPS': 0.293,
#   'Dividend per Share': 1.48,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'WMT',
#   'Revenue': 485873000000.0,
#   'Revenue Growth': 0.0078,
#   'Gross Profit': 124617000000.0,
#   'Profit Margin': 0.028,
#   'grossProfitMargin': 0.25648060295592,
#   'netProfitMargin': 0.028079354069891004,
#   'Total assets': 198825000000.0,
#   'Total debt': 45938000000.0,
#   'Total liabilities': 118290000000.0,
#   'EPS': 4.4,
#   'Dividend per Share': 2.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MDLZ',
#   'Revenue': 25896000000.0,
#   'Revenue Growth': -0.001,
#   'Gross Profit': 10034000000.0,
#   'Profit Margin': 0.109,
#   'grossProfitMargin': 0.38747296879827,
#   'netProfitMargin': 0.10920605498919,
#   'Total assets': 62957000000.0,
#   'Total debt': 17652000000.0,
#   'Total liabilities': 36883000000.0,
#   'EPS': 1.87,
#   'Dividend per Share': 0.82,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MO',
#   'Revenue': 25576000000.0,
#   'Revenue Growth': -0.0065,
#   'Gross Profit': 11963000000.0,
#   'Profit Margin': 0.4,
#   'grossProfitMargin': 0.46774319674695,
#   'netProfitMargin': 0.39967156709415,
#   'Total assets': 43202000000.0,
#   'Total debt': 13894000000.0,
#   'Total liabilities': 27784000000.0,
#   'EPS': 5.31,
#   'Dividend per Share': 2.54,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KHC',
#   'Revenue': 26076000000.0,
#   'Revenue Growth': -0.0085,
#   'Gross Profit': 9033000000.0,
#   'Profit Margin': 0.42,
#   'grossProfitMargin': 0.34641049240681,
#   'netProfitMargin': 0.41958122411413,
#   'Total assets': 120092000000.0,
#   'Total debt': 31503000000.0,
#   'Total liabilities': 54016000000.0,
#   'EPS': 8.98,
#   'Dividend per Share': 2.45,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'NWL',
#   'Revenue': 9552000000.0,
#   'Revenue Growth': 0.0404,
#   'Gross Profit': 3263000000.0,
#   'Profit Margin': 0.28800000000000003,
#   'grossProfitMargin': 0.34160385259631,
#   'netProfitMargin': 0.28777219430485995,
#   'Total assets': 33135500000.0,
#   'Total debt': 10551000000.0,
#   'Total liabilities': 18954200000.0,
#   'EPS': 5.65,
#   'Dividend per Share': 0.88,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KMB',
#   'Revenue': 18348000000.0,
#   'Revenue Growth': 0.0033,
#   'Gross Profit': 6587000000.0,
#   'Profit Margin': 0.124,
#   'grossProfitMargin': 0.3590037061260101,
#   'netProfitMargin': 0.12415522127752,
#   'Total assets': 15151000000.0,
#   'Total debt': 7425000000.0,
#   'Total liabilities': 14269000000.0,
#   'EPS': 6.44,
#   'Dividend per Share': 3.88,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CPB',
#   'Revenue': 5837000000.0,
#   'Revenue Growth': -0.2668,
#   'Gross Profit': 2442000000.0,
#   'Profit Margin': 0.152,
#   'grossProfitMargin': 0.41836559876649,
#   'netProfitMargin': 0.15196162412198005,
#   'Total assets': 7726000000.0,
#   'Total debt': 3536000000.0,
#   'Total liabilities': 6081000000.0,
#   'EPS': 2.91,
#   'Dividend per Share': 1.4,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TGT',
#   'Revenue': 70271000000.0,
#   'Revenue Growth': -0.0476,
#   'Gross Profit': 21126000000.0,
#   'Profit Margin': 0.039,
#   'grossProfitMargin': 0.30063610877887,
#   'netProfitMargin': 0.038906519047687,
#   'Total assets': 37431000000.0,
#   'Total debt': 12749000000.0,
#   'Total liabilities': 26478000000.0,
#   'EPS': 4.73,
#   'Dividend per Share': 2.32,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'HRL',
#   'Revenue': 9167519000.0,
#   'Revenue Growth': -0.0374,
#   'Gross Profit': 2003163000.0,
#   'Profit Margin': 0.092,
#   'grossProfitMargin': 0.21850655559045,
#   'netProfitMargin': 0.092362502875642,
#   'Total assets': 6975908000.0,
#   'Total debt': 250000000.0,
#   'Total liabilities': 2036211000.0,
#   'EPS': 1.6,
#   'Dividend per Share': 0.68,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'K',
#   'Revenue': 12854000000.0,
#   'Revenue Growth': -0.0086,
#   'Gross Profit': 4699000000.0,
#   'Profit Margin': 0.098,
#   'grossProfitMargin': 0.36556713863389,
#   'netProfitMargin': 0.09755718064415697,
#   'Total assets': 16351000000.0,
#   'Total debt': 8615000000.0,
#   'Total liabilities': 14157000000.0,
#   'EPS': 3.61,
#   'Dividend per Share': 2.12,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CAG',
#   'Revenue': 7826900000.0,
#   'Revenue Growth': -0.0966,
#   'Gross Profit': 2343800000.0,
#   'Profit Margin': 0.08199999999999999,
#   'grossProfitMargin': 0.29945444556593,
#   'netProfitMargin': 0.081679847704711,
#   'Total assets': 10096300000.0,
#   'Total debt': 2996400000.0,
#   'Total liabilities': 6018500000.0,
#   'EPS': 1.48,
#   'Dividend per Share': 0.9,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'PEP',
#   'Revenue': 63525000000.0,
#   'Revenue Growth': 0.0116,
#   'Gross Profit': 34729000000.0,
#   'Profit Margin': 0.076,
#   'grossProfitMargin': 0.54669815033451,
#   'netProfitMargin': 0.07645808736717799,
#   'Total assets': 79804000000.0,
#   'Total debt': 39281000000.0,
#   'Total liabilities': 68823000000.0,
#   'EPS': 3.4,
#   'Dividend per Share': 3.167,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'COST',
#   'Revenue': 129025000000.0,
#   'Revenue Growth': 0.0868,
#   'Gross Profit': 17143000000.0,
#   'Profit Margin': 0.021,
#   'grossProfitMargin': 0.13286572369696,
#   'netProfitMargin': 0.020763417942259,
#   'Total assets': 36347000000.0,
#   'Total debt': 6573000000.0,
#   'Total liabilities': 25268000000.0,
#   'EPS': 6.11,
#   'Dividend per Share': 8.9,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'COTY',
#   'Revenue': 7650300000.0,
#   'Revenue Growth': 0.7591,
#   'Gross Profit': 4622000000.0,
#   'Profit Margin': -0.055,
#   'grossProfitMargin': 0.6041593140138299,
#   'netProfitMargin': -0.055187378272747015,
#   'Total assets': 22548200000.0,
#   'Total debt': 7137400000.0,
#   'Total liabilities': 12679400000.0,
#   'EPS': -0.66,
#   'Dividend per Share': 0.65,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MNST',
#   'Revenue': 3369045000.0,
#   'Revenue Growth': 0.1048,
#   'Gross Profit': 2137690000.0,
#   'Profit Margin': 0.244,
#   'grossProfitMargin': 0.63450918583753,
#   'netProfitMargin': 0.24359365933076,
#   'Total assets': 4791012000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 895800000.0,
#   'EPS': 1.45,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'SJM',
#   'Revenue': 7392300000.0,
#   'Revenue Growth': -0.0536,
#   'Gross Profit': 2835300000.0,
#   'Profit Margin': 0.08,
#   'grossProfitMargin': 0.38354774562721,
#   'netProfitMargin': 0.080123912719992,
#   'Total assets': 15639700000.0,
#   'Total debt': 5398500000.0,
#   'Total liabilities': 8789500000.0,
#   'EPS': 5.11,
#   'Dividend per Share': 2.92,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CL',
#   'Revenue': 15454000000.0,
#   'Revenue Growth': 0.017,
#   'Gross Profit': 9280000000.0,
#   'Profit Margin': 0.131,
#   'grossProfitMargin': 0.6004917820629,
#   'netProfitMargin': 0.13096932832924002,
#   'Total assets': 12676000000.0,
#   'Total debt': 6577000000.0,
#   'Total liabilities': 12433000000.0,
#   'EPS': 2.3,
#   'Dividend per Share': 1.59,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'ADM',
#   'Revenue': 60828000000.0,
#   'Revenue Growth': -0.0243,
#   'Gross Profit': 3518000000.0,
#   'Profit Margin': 0.026,
#   'grossProfitMargin': 0.057835207470244,
#   'netProfitMargin': 0.026221476951404,
#   'Total assets': 39963000000.0,
#   'Total debt': 7493000000.0,
#   'Total liabilities': 21641000000.0,
#   'EPS': 2.8,
#   'Dividend per Share': 1.28,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'DG',
#   'Revenue': 21986598000.0,
#   'Revenue Growth': 0.0794,
#   'Gross Profit': 6782638000.0,
#   'Profit Margin': 0.057,
#   'grossProfitMargin': 0.30848965356077,
#   'netProfitMargin': 0.056904346911696,
#   'Total assets': 11672298000.0,
#   'Total debt': 3211526000.0,
#   'Total liabilities': 6266004000.0,
#   'EPS': 4.45,
#   'Dividend per Share': 1.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TAP',
#   'Revenue': 11002800000.0,
#   'Revenue Growth': 1.2524,
#   'Gross Profit': 4766100000.0,
#   'Profit Margin': 0.142,
#   'grossProfitMargin': 0.43317155633112,
#   'netProfitMargin': 0.14229105318646,
#   'Total assets': 30246900000.0,
#   'Total debt': 11313500000.0,
#   'Total liabilities': 17059600000.0,
#   'EPS': 7.27,
#   'Dividend per Share': 1.64,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'SYY',
#   'Revenue': 55371139000.0,
#   'Revenue Growth': 0.0994,
#   'Gross Profit': 10557507000.0,
#   'Profit Margin': 0.021,
#   'grossProfitMargin': 0.19066804820468,
#   'netProfitMargin': 0.020633547018059,
#   'Total assets': 17756655000.0,
#   'Total debt': 8194890000.0,
#   'Total liabilities': 15375139000.0,
#   'EPS': 2.1,
#   'Dividend per Share': 0.97,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CHD',
#   'Revenue': 3776200000.0,
#   'Revenue Growth': 0.081,
#   'Gross Profit': 1729600000.0,
#   'Profit Margin': 0.197,
#   'grossProfitMargin': 0.45802658757481,
#   'netProfitMargin': 0.19686457285101,
#   'Total assets': 6014800000.0,
#   'Total debt': 2374300000.0,
#   'Total liabilities': 3796800000.0,
#   'EPS': 2.97,
#   'Dividend per Share': 0.76,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'STZ',
#   'Revenue': 7321100000.0,
#   'Revenue Growth': 0.118,
#   'Gross Profit': 3519000000.0,
#   'Profit Margin': 0.209,
#   'grossProfitMargin': 0.4806654737676,
#   'netProfitMargin': 0.20879376050047,
#   'Total assets': 18602400000.0,
#   'Total debt': 9238100000.0,
#   'Total liabilities': 11717600000.0,
#   'EPS': 7.76,
#   'Dividend per Share': 1.6,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'EL',
#   'Revenue': 11824000000.0,
#   'Revenue Growth': 0.0499,
#   'Gross Profit': 9390000000.0,
#   'Profit Margin': 0.106,
#   'grossProfitMargin': 0.79414749661705,
#   'netProfitMargin': 0.10563261163735,
#   'Total assets': 11568000000.0,
#   'Total debt': 3572000000.0,
#   'Total liabilities': 7166000000.0,
#   'EPS': 3.4,
#   'Dividend per Share': 1.32,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'DLTR',
#   'Revenue': 20719200000.0,
#   'Revenue Growth': 0.3369,
#   'Gross Profit': 6394700000.0,
#   'Profit Margin': 0.043,
#   'grossProfitMargin': 0.30863643383914,
#   'netProfitMargin': 0.04325456581335201,
#   'Total assets': 15701600000.0,
#   'Total debt': 6321800000.0,
#   'Total liabilities': 10312100000.0,
#   'EPS': 3.8,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TSN',
#   'Revenue': 38260000000.0,
#   'Revenue Growth': 0.0374,
#   'Gross Profit': 5062000000.0,
#   'Profit Margin': 0.046,
#   'grossProfitMargin': 0.13230527966545,
#   'netProfitMargin': 0.04636696288552,
#   'Total assets': 28066000000.0,
#   'Total debt': 10203000000.0,
#   'Total liabilities': 17507000000.0,
#   'EPS': 4.94,
#   'Dividend per Share': 0.825,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MKC',
#   'Revenue': 4834100000.0,
#   'Revenue Growth': 0.0958,
#   'Gross Profit': 2010200000.0,
#   'Profit Margin': 0.092,
#   'grossProfitMargin': 0.41583748784676,
#   'netProfitMargin': 0.09174406818228803,
#   'Total assets': 10385800000.0,
#   'Total debt': 5027100000.0,
#   'Total liabilities': 7814900000.0,
#   'EPS': 3.77,
#   'Dividend per Share': 1.88,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'HSY',
#   'Revenue': 7515426000.0,
#   'Revenue Growth': 0.0101,
#   'Gross Profit': 3455376000.0,
#   'Profit Margin': 0.104,
#   'grossProfitMargin': 0.45977114271367,
#   'netProfitMargin': 0.1041831826965,
#   'Total assets': 5553726000.0,
#   'Total debt': 2920480000.0,
#   'Total liabilities': 4622161000.0,
#   'EPS': 3.44,
#   'Dividend per Share': 2.548,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CLX',
#   'Revenue': 5973000000.0,
#   'Revenue Growth': 0.0368,
#   'Gross Profit': 2671000000.0,
#   'Profit Margin': 0.117,
#   'grossProfitMargin': 0.44717897204085,
#   'netProfitMargin': 0.1173614599029,
#   'Total assets': 4573000000.0,
#   'Total debt': 2195000000.0,
#   'Total liabilities': 4031000000.0,
#   'EPS': 5.43,
#   'Dividend per Share': 3.2,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'FCX',
#   'Revenue': 16403000000.0,
#   'Revenue Growth': 0.1061,
#   'Gross Profit': 4423000000.0,
#   'Profit Margin': 0.111,
#   'grossProfitMargin': 0.26964579650064,
#   'netProfitMargin': 0.11101627751021,
#   'Total assets': 37302000000.0,
#   'Total debt': 13229000000.0,
#   'Total liabilities': 26006000000.0,
#   'EPS': 1.25,
#   'Dividend per Share': 0.0,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'NUE',
#   'Revenue': 20252393000.0,
#   'Revenue Growth': 0.2495,
#   'Gross Profit': 2569407000.0,
#   'Profit Margin': 0.065,
#   'grossProfitMargin': 0.12686930379042,
#   'netProfitMargin': 0.06511270050902099,
#   'Total assets': 15841258000.0,
#   'Total debt': 3795075000.0,
#   'Total liabilities': 6756470000.0,
#   'EPS': 4.11,
#   'Dividend per Share': 1.511,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'JCI',
#   'Revenue': 22835000000.0,
#   'Revenue Growth': 0.0959,
#   'Gross Profit': 7530000000.0,
#   'Profit Margin': 0.071,
#   'grossProfitMargin': 0.3297569520473,
#   'netProfitMargin': 0.070549594920079,
#   'Total assets': 51884000000.0,
#   'Total debt': 13572000000.0,
#   'Total liabilities': 30517000000.0,
#   'EPS': 1.72,
#   'Dividend per Share': 1.0,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MAS',
#   'Revenue': 7642000000.0,
#   'Revenue Growth': 0.0382,
#   'Gross Profit': 2612000000.0,
#   'Profit Margin': 0.07,
#   'grossProfitMargin': 0.34179534153362995,
#   'netProfitMargin': 0.069746139753991,
#   'Total assets': 5534000000.0,
#   'Total debt': 3085000000.0,
#   'Total liabilities': 5351000000.0,
#   'EPS': 1.68,
#   'Dividend per Share': 0.405,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'WY',
#   'Revenue': 7196000000.0,
#   'Revenue Growth': 0.1306,
#   'Gross Profit': 2026000000.0,
#   'Profit Margin': 0.081,
#   'grossProfitMargin': 0.28154530294608,
#   'netProfitMargin': 0.080878265703168,
#   'Total assets': 18059000000.0,
#   'Total debt': 6503000000.0,
#   'Total liabilities': 9160000000.0,
#   'EPS': 0.77,
#   'Dividend per Share': 1.25,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'CF',
#   'Revenue': 4130000000.0,
#   'Revenue Growth': 0.1208,
#   'Gross Profit': 434000000.0,
#   'Profit Margin': 0.087,
#   'grossProfitMargin': 0.10508474576271,
#   'netProfitMargin': 0.086682808716707,
#   'Total assets': 13463000000.0,
#   'Total debt': 4692000000.0,
#   'Total liabilities': 6779000000.0,
#   'EPS': 1.53,
#   'Dividend per Share': 1.2,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'LYB',
#   'Revenue': 34484000000.0,
#   'Revenue Growth': 0.1816,
#   'Gross Profit': 6425000000.0,
#   'Profit Margin': 0.141,
#   'grossProfitMargin': 0.18631829254147,
#   'netProfitMargin': 0.14148590650736995,
#   'Total assets': 26206000000.0,
#   'Total debt': 8619000000.0,
#   'Total liabilities': 17256000000.0,
#   'EPS': 12.23,
#   'Dividend per Share': 3.55,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'VMC',
#   'Revenue': 3890296000.0,
#   'Revenue Growth': 0.0828,
#   'Gross Profit': 993513000.0,
#   'Profit Margin': 0.155,
#   'grossProfitMargin': 0.25538236679163,
#   'netProfitMargin': 0.15453451356915,
#   'Total assets': 9504891000.0,
#   'Total debt': 2854865000.0,
#   'Total liabilities': 4535998000.0,
#   'EPS': 4.54,
#   'Dividend per Share': 1.0,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'NEM',
#   'Revenue': 7379000000.0,
#   'Revenue Growth': 0.1046,
#   'Gross Profit': 3317000000.0,
#   'Profit Margin': -0.015,
#   'grossProfitMargin': 0.44951890500068,
#   'netProfitMargin': -0.015449247865563996,
#   'Total assets': 20646000000.0,
#   'Total debt': 4065000000.0,
#   'Total liabilities': 9127000000.0,
#   'EPS': -0.21,
#   'Dividend per Share': 0.25,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'EMN',
#   'Revenue': 9549000000.0,
#   'Revenue Growth': 0.0601,
#   'Gross Profit': 2363000000.0,
#   'Profit Margin': 0.145,
#   'grossProfitMargin': 0.24746046706461,
#   'netProfitMargin': 0.14493664258036998,
#   'Total assets': 15999000000.0,
#   'Total debt': 6540000000.0,
#   'Total liabilities': 10519000000.0,
#   'EPS': 9.56,
#   'Dividend per Share': 2.09,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MLM',
#   'Revenue': 3965594000.0,
#   'Revenue Growth': 0.0385,
#   'Gross Profit': 971940000.0,
#   'Profit Margin': 0.18,
#   'grossProfitMargin': 0.24509316889223,
#   'netProfitMargin': 0.17988276157368,
#   'Total assets': 8992511000.0,
#   'Total debt': 3027203000.0,
#   'Total liabilities': 4310034000.0,
#   'EPS': 11.3,
#   'Dividend per Share': 1.72,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MOS',
#   'Revenue': 7409400000.0,
#   'Revenue Growth': 0.0344,
#   'Gross Profit': 842800000.0,
#   'Profit Margin': -0.014,
#   'grossProfitMargin': 0.11374740194888,
#   'netProfitMargin': -0.014468108078927,
#   'Total assets': 18633400000.0,
#   'Total debt': 5227700000.0,
#   'Total liabilities': 8994300000.0,
#   'EPS': -0.31,
#   'Dividend per Share': 0.6,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'FMC',
#   'Revenue': 2878600000.0,
#   'Revenue Growth': 0.1338,
#   'Gross Profit': 1101300000.0,
#   'Profit Margin': 0.18600000000000005,
#   'grossProfitMargin': 0.3825818106023801,
#   'netProfitMargin': 0.18613214757174,
#   'Total assets': 9206300000.0,
#   'Total debt': 3237100000.0,
#   'Total liabilities': 6499200000.0,
#   'EPS': 3.99,
#   'Dividend per Share': 0.66,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'ALB',
#   'Revenue': 3071976000.0,
#   'Revenue Growth': 0.1475,
#   'Gross Profit': 1106276000.0,
#   'Profit Margin': 0.018000000000000002,
#   'grossProfitMargin': 0.36011869884400005,
#   'netProfitMargin': 0.017854957200186,
#   'Total assets': 7750772000.0,
#   'Total debt': 1837372000.0,
#   'Total liabilities': 3933076000.0,
#   'EPS': 0.49,
#   'Dividend per Share': 1.28,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'ECL',
#   'Revenue': 13835900000.0,
#   'Revenue Growth': 0.052000000000000005,
#   'Gross Profit': 5771700000.0,
#   'Profit Margin': 0.109,
#   'grossProfitMargin': 0.41715392565717,
#   'netProfitMargin': 0.10874608807522,
#   'Total assets': 19963500000.0,
#   'Total debt': 7322700000.0,
#   'Total liabilities': 12309700000.0,
#   'EPS': 5.2,
#   'Dividend per Share': 1.52,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'PPG',
#   'Revenue': 14748000000.0,
#   'Revenue Growth': 0.0335,
#   'Gross Profit': 6539000000.0,
#   'Profit Margin': 0.108,
#   'grossProfitMargin': 0.4433821535123401,
#   'netProfitMargin': 0.10808245185788,
#   'Total assets': 16538000000.0,
#   'Total debt': 4146000000.0,
#   'Total liabilities': 10866000000.0,
#   'EPS': 6.22,
#   'Dividend per Share': 1.7,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'SHW',
#   'Revenue': 14983788000.0,
#   'Revenue Growth': 0.2639,
#   'Gross Profit': 6718800000.0,
#   'Profit Margin': 0.115,
#   'grossProfitMargin': 0.4484046357303,
#   'netProfitMargin': 0.11532117245652003,
#   'Total assets': 19899517000.0,
#   'Total debt': 10520655000.0,
#   'Total liabilities': 16251643000.0,
#   'EPS': 18.6,
#   'Dividend per Share': 3.4,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'IFF',
#   'Revenue': 3398719000.0,
#   'Revenue Growth': 0.0906,
#   'Gross Profit': 1472463000.0,
#   'Profit Margin': 0.087,
#   'grossProfitMargin': 0.43324058270189,
#   'netProfitMargin': 0.086993070036093,
#   'Total assets': 4598926000.0,
#   'Total debt': 1639152000.0,
#   'Total liabilities': 2909632000.0,
#   'EPS': 3.73,
#   'Dividend per Share': 2.66,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'APD',
#   'Revenue': 8187600000.0,
#   'Revenue Growth': 0.0911,
#   'Gross Profit': 2436100000.0,
#   'Profit Margin': 0.366,
#   'grossProfitMargin': 0.29753529727881,
#   'netProfitMargin': 0.36645659289658,
#   'Total assets': 18467200000.0,
#   'Total debt': 3962800000.0,
#   'Total liabilities': 8281700000.0,
#   'EPS': 13.76,
#   'Dividend per Share': 3.62,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'PFE',
#   'Revenue': 52546000000.0,
#   'Revenue Growth': -0.0053,
#   'Gross Profit': 41318000000.0,
#   'Profit Margin': 0.406,
#   'grossProfitMargin': 0.7863205572260501,
#   'netProfitMargin': 0.40551136147376,
#   'Total assets': 171797000000.0,
#   'Total debt': 43491000000.0,
#   'Total liabilities': 100141000000.0,
#   'EPS': 3.57,
#   'Dividend per Share': 1.28,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BMY',
#   'Revenue': 20776000000.0,
#   'Revenue Growth': 0.0694,
#   'Gross Profit': 14682000000.0,
#   'Profit Margin': 0.048,
#   'grossProfitMargin': 0.70668078552176,
#   'netProfitMargin': 0.048469387755102,
#   'Total assets': 33551000000.0,
#   'Total debt': 7962000000.0,
#   'Total liabilities': 21704000000.0,
#   'EPS': 0.61,
#   'Dividend per Share': 1.56,
#   'Sector': 'Healthcare'},
#  {'ticker': 'GILD',
#   'Revenue': 26107000000.0,
#   'Revenue Growth': -0.1409,
#   'Gross Profit': 21736000000.0,
#   'Profit Margin': 0.177,
#   'grossProfitMargin': 0.83257363925384,
#   'netProfitMargin': 0.17727046386026998,
#   'Total assets': 70283000000.0,
#   'Total debt': 33542000000.0,
#   'Total liabilities': 49782000000.0,
#   'EPS': 3.54,
#   'Dividend per Share': 2.08,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABBV',
#   'Revenue': 28216000000.0,
#   'Revenue Growth': 0.1006,
#   'Gross Profit': 21174000000.0,
#   'Profit Margin': 0.188,
#   'grossProfitMargin': 0.75042529061525,
#   'netProfitMargin': 0.18815565636518,
#   'Total assets': 70786000000.0,
#   'Total debt': 37368000000.0,
#   'Total liabilities': 65689000000.0,
#   'EPS': 3.31,
#   'Dividend per Share': 2.56,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MRK',
#   'Revenue': 40122000000.0,
#   'Revenue Growth': 0.0079,
#   'Gross Profit': 27210000000.0,
#   'Profit Margin': 0.06,
#   'grossProfitMargin': 0.67818154628383,
#   'netProfitMargin': 0.059668012561687016,
#   'Total assets': 87872000000.0,
#   'Total debt': 24410000000.0,
#   'Total liabilities': 53303000000.0,
#   'EPS': 0.88,
#   'Dividend per Share': 1.89,
#   'Sector': 'Healthcare'},
#  {'ticker': 'JNJ',
#   'Revenue': 76450000000.0,
#   'Revenue Growth': 0.0634,
#   'Gross Profit': 51011000000.0,
#   'Profit Margin': 0.23,
#   'grossProfitMargin': 0.6672465663832601,
#   'netProfitMargin': 0.2163505559189,
#   'Total assets': 157303000000.0,
#   'Total debt': 27126000000.0,
#   'Total liabilities': 97143000000.0,
#   'EPS': 0.48,
#   'Dividend per Share': 3.15,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BSX',
#   'Revenue': 9048000000.0,
#   'Revenue Growth': 0.0789,
#   'Gross Profit': 6455000000.0,
#   'Profit Margin': 0.011,
#   'grossProfitMargin': 0.71341732979664,
#   'netProfitMargin': 0.011494252873563,
#   'Total assets': 19042000000.0,
#   'Total debt': 5616000000.0,
#   'Total liabilities': 12030000000.0,
#   'EPS': 0.08,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABT',
#   'Revenue': 27390000000.0,
#   'Revenue Growth': 0.3135,
#   'Gross Profit': 14981000000.0,
#   'Profit Margin': 0.017,
#   'grossProfitMargin': 0.54695144213217,
#   'netProfitMargin': 0.017415115005476003,
#   'Total assets': 76250000000.0,
#   'Total debt': 27924000000.0,
#   'Total liabilities': 45152000000.0,
#   'EPS': 0.27,
#   'Dividend per Share': 1.06,
#   'Sector': 'Healthcare'},
#  {'ticker': 'WBA',
#   'Revenue': 118214000000.0,
#   'Revenue Growth': 0.0074,
#   'Gross Profit': 29162000000.0,
#   'Profit Margin': 0.034,
#   'grossProfitMargin': 0.24668820951833,
#   'netProfitMargin': 0.034496760113014995,
#   'Total assets': 66009000000.0,
#   'Total debt': 12935000000.0,
#   'Total liabilities': 37735000000.0,
#   'EPS': 3.8,
#   'Dividend per Share': 1.525,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MDT',
#   'Revenue': 29710000000.0,
#   'Revenue Growth': 0.0304,
#   'Gross Profit': 20416000000.0,
#   'Profit Margin': 0.136,
#   'grossProfitMargin': 0.68717603500505,
#   'netProfitMargin': 0.13557724671828,
#   'Total assets': 99857000000.0,
#   'Total debt': 33441000000.0,
#   'Total liabilities': 49527000000.0,
#   'EPS': 2.92,
#   'Dividend per Share': 1.72,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CVS',
#   'Revenue': 184786000000.0,
#   'Revenue Growth': 0.0408,
#   'Gross Profit': 28528000000.0,
#   'Profit Margin': 0.036000000000000004,
#   'grossProfitMargin': 0.15438399012912,
#   'netProfitMargin': 0.035836048185469004,
#   'Total assets': 95131000000.0,
#   'Total debt': 27002000000.0,
#   'Total liabilities': 57436000000.0,
#   'EPS': 6.47,
#   'Dividend per Share': 2.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ESRX',
#   'Revenue': nan,
#   'Revenue Growth': nan,
#   'Gross Profit': nan,
#   'Profit Margin': nan,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 54256000000.0,
#   'Total debt': 14982000000.0,
#   'Total liabilities': 36130000000.0,
#   'EPS': 7.79,
#   'Dividend per Share': nan,
#   'Sector': 'Healthcare'},
#  {'ticker': 'UNH',
#   'Revenue': 201159000000.0,
#   'Revenue Growth': 0.0883,
#   'Gross Profit': 47011000000.0,
#   'Profit Margin': 0.052000000000000005,
#   'grossProfitMargin': 0.2337007044179,
#   'netProfitMargin': 0.052485844530943,
#   'Total assets': 139058000000.0,
#   'Total debt': 31692000000.0,
#   'Total liabilities': 87036000000.0,
#   'EPS': 10.95,
#   'Dividend per Share': 2.875,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CNC',
#   'Revenue': 48382000000.0,
#   'Revenue Growth': 0.1915,
#   'Gross Profit': 5801000000.0,
#   'Profit Margin': 0.017,
#   'grossProfitMargin': 0.11989996279608,
#   'netProfitMargin': 0.01711380265388,
#   'Total assets': 21855000000.0,
#   'Total debt': 4699000000.0,
#   'Total liabilities': 14979000000.0,
#   'EPS': 2.4,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CI',
#   'Revenue': 41806000000.0,
#   'Revenue Growth': 0.0494,
#   'Gross Profit': 14087000000.0,
#   'Profit Margin': 0.054000000000000006,
#   'grossProfitMargin': 0.33696120174138,
#   'netProfitMargin': 0.053509065684352014,
#   'Total assets': 61759000000.0,
#   'Total debt': 5439000000.0,
#   'Total liabilities': 47999000000.0,
#   'EPS': 8.92,
#   'Dividend per Share': 0.04,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CELG',
#   'Revenue': 13003000000.0,
#   'Revenue Growth': 0.158,
#   'Gross Profit': 12542000000.0,
#   'Profit Margin': 0.226,
#   'grossProfitMargin': 0.96454664308237,
#   'netProfitMargin': 0.22610166884565,
#   'Total assets': 30141000000.0,
#   'Total debt': 15838000000.0,
#   'Total liabilities': 23220000000.0,
#   'EPS': 3.77,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BIIB',
#   'Revenue': 12273900000.0,
#   'Revenue Growth': 0.0721,
#   'Gross Profit': 10643900000.0,
#   'Profit Margin': 0.207,
#   'grossProfitMargin': 0.867197875166,
#   'netProfitMargin': 0.20686986206503,
#   'Total assets': 23652600000.0,
#   'Total debt': 5938200000.0,
#   'Total liabilities': 11054500000.0,
#   'EPS': 11.94,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MYL',
#   'Revenue': 11907700000.0,
#   'Revenue Growth': 0.075,
#   'Gross Profit': 4783100000.0,
#   'Profit Margin': 0.058,
#   'grossProfitMargin': 0.4016812650637801,
#   'netProfitMargin': 0.058449574644978,
#   'Total assets': 35806300000.0,
#   'Total debt': 14720700000.0,
#   'Total liabilities': 22498700000.0,
#   'EPS': 1.3,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'XRAY',
#   'Revenue': 3993400000.0,
#   'Revenue Growth': 0.0662,
#   'Gross Profit': 2188500000.0,
#   'Profit Margin': -0.388,
#   'grossProfitMargin': 0.54802924825963,
#   'netProfitMargin': -0.38814043171233,
#   'Total assets': 10374500000.0,
#   'Total debt': 1641700000.0,
#   'Total liabilities': 3746600000.0,
#   'EPS': -6.76,
#   'Dividend per Share': 0.35,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ALXN',
#   'Revenue': 3551100000.0,
#   'Revenue Growth': 0.1514,
#   'Gross Profit': 3096900000.0,
#   'Profit Margin': 0.125,
#   'grossProfitMargin': 0.87209597026274,
#   'netProfitMargin': 0.12483455830588,
#   'Total assets': 13583300000.0,
#   'Total debt': 3231000000.0,
#   'Total liabilities': 4690200000.0,
#   'EPS': 1.98,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AMGN',
#   'Revenue': 22849000000.0,
#   'Revenue Growth': -0.0062,
#   'Gross Profit': 18780000000.0,
#   'Profit Margin': 0.087,
#   'grossProfitMargin': 0.8219178082191801,
#   'netProfitMargin': 0.086612105562607,
#   'Total assets': 79954000000.0,
#   'Total debt': 35342000000.0,
#   'Total liabilities': 54713000000.0,
#   'EPS': 2.71,
#   'Dividend per Share': 4.6,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BDX',
#   'Revenue': 12093000000.0,
#   'Revenue Growth': -0.0312,
#   'Gross Profit': 5942000000.0,
#   'Profit Margin': 0.085,
#   'grossProfitMargin': 0.49135863722815,
#   'netProfitMargin': 0.09096171338791,
#   'Total assets': 37734000000.0,
#   'Total debt': 18870000000.0,
#   'Total liabilities': 24786000000.0,
#   'EPS': 4.7,
#   'Dividend per Share': 2.92,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HOLX',
#   'Revenue': 3058800000.0,
#   'Revenue Growth': 0.0798,
#   'Gross Profit': 1621000000.0,
#   'Profit Margin': 0.247,
#   'grossProfitMargin': 0.52994638420296,
#   'netProfitMargin': 0.24699228455604005,
#   'Total assets': 7979600000.0,
#   'Total debt': 3347200000.0,
#   'Total liabilities': 5194900000.0,
#   'EPS': 2.7,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ANTM',
#   'Revenue': 90040000000.0,
#   'Revenue Growth': 0.061,
#   'Gross Profit': 17804000000.0,
#   'Profit Margin': 0.043,
#   'grossProfitMargin': 0.19773434029320006,
#   'netProfitMargin': 0.042681030653043,
#   'Total assets': 70540000000.0,
#   'Total debt': 19932000000.0,
#   'Total liabilities': 44037000000.0,
#   'EPS': 14.7,
#   'Dividend per Share': 2.7,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ZBH',
#   'Revenue': 7803300000.0,
#   'Revenue Growth': 0.0176,
#   'Gross Profit': 5670400000.0,
#   'Profit Margin': 0.232,
#   'grossProfitMargin': 0.72666692296849,
#   'netProfitMargin': 0.23244012148706,
#   'Total assets': 26014000000.0,
#   'Total debt': 10142500000.0,
#   'Total liabilities': 14278500000.0,
#   'EPS': 8.98,
#   'Dividend per Share': 0.96,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AET',
#   'Revenue': nan,
#   'Revenue Growth': nan,
#   'Gross Profit': nan,
#   'Profit Margin': nan,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 55151000000.0,
#   'Total debt': 8160000000.0,
#   'Total liabilities': 39314000000.0,
#   'EPS': 5.71,
#   'Dividend per Share': nan,
#   'Sector': 'Healthcare'},
#  {'ticker': 'LLY',
#   'Revenue': 22871300000.0,
#   'Revenue Growth': 0.0777,
#   'Gross Profit': 16720500000.0,
#   'Profit Margin': -0.009000000000000001,
#   'grossProfitMargin': 0.73106906909533,
#   'netProfitMargin': -0.008923847791774001,
#   'Total assets': 44981000000.0,
#   'Total debt': 13647100000.0,
#   'Total liabilities': 33313100000.0,
#   'EPS': -0.19,
#   'Dividend per Share': 2.08,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HSIC',
#   'Revenue': 12461543000.0,
#   'Revenue Growth': 0.0769,
#   'Gross Profit': 3399103000.0,
#   'Profit Margin': 0.033,
#   'grossProfitMargin': 0.27276742535014,
#   'netProfitMargin': 0.032604228866361,
#   'Total assets': 7863995000.0,
#   'Total debt': 1666068000.0,
#   'Total liabilities': 4207447000.0,
#   'EPS': 2.59,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BAX',
#   'Revenue': 10561000000.0,
#   'Revenue Growth': 0.0392,
#   'Gross Profit': 4470000000.0,
#   'Profit Margin': 0.068,
#   'grossProfitMargin': 0.42325537354417,
#   'netProfitMargin': 0.067891298172522,
#   'Total assets': 17111000000.0,
#   'Total debt': 3512000000.0,
#   'Total liabilities': 7995000000.0,
#   'EPS': 1.32,
#   'Dividend per Share': 0.61,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AGN',
#   'Revenue': 15940700000.0,
#   'Revenue Growth': 0.094,
#   'Gross Profit': 13772700000.0,
#   'Profit Margin': -0.276,
#   'grossProfitMargin': 0.8639959349338501,
#   'netProfitMargin': -0.25880293839041,
#   'Total assets': 118341900000.0,
#   'Total debt': 30075300000.0,
#   'Total liabilities': 44504800000.0,
#   'EPS': -13.19,
#   'Dividend per Share': 2.8,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HCA',
#   'Revenue': 43614000000.0,
#   'Revenue Growth': 0.0512,
#   'Gross Profit': 16239000000.0,
#   'Profit Margin': 0.051,
#   'grossProfitMargin': 0.37233457146788,
#   'netProfitMargin': 0.05080937313706599,
#   'Total assets': 36593000000.0,
#   'Total debt': 33058000000.0,
#   'Total liabilities': 41588000000.0,
#   'EPS': 6.12,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'VRTX',
#   'Revenue': 2488652000.0,
#   'Revenue Growth': 0.462,
#   'Gross Profit': 2213533000.0,
#   'Profit Margin': 0.106,
#   'grossProfitMargin': 0.88945059413691,
#   'netProfitMargin': 0.10587418409645,
#   'Total assets': 3546014000.0,
#   'Total debt': 606433000.0,
#   'Total liabilities': 1503708000.0,
#   'EPS': 1.06,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'NKTR',
#   'Revenue': 307711000.0,
#   'Revenue Growth': 0.86,
#   'Gross Profit': 277164000.0,
#   'Profit Margin': -0.314,
#   'grossProfitMargin': 0.90072828075694,
#   'netProfitMargin': -0.31422991053294,
#   'Total assets': 508866000.0,
#   'Total debt': 245207000.0,
#   'Total liabilities': 421038000.0,
#   'EPS': -0.62,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'A',
#   'Revenue': 4472000000.0,
#   'Revenue Growth': 0.0643,
#   'Gross Profit': 2409000000.0,
#   'Profit Margin': 0.153,
#   'grossProfitMargin': 0.53868515205725,
#   'netProfitMargin': 0.15295169946332998,
#   'Total assets': 8426000000.0,
#   'Total debt': 2011000000.0,
#   'Total liabilities': 3591000000.0,
#   'EPS': 2.12,
#   'Dividend per Share': 0.528,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DHR',
#   'Revenue': 18329700000.0,
#   'Revenue Growth': 0.0857,
#   'Gross Profit': 10192500000.0,
#   'Profit Margin': 0.136,
#   'grossProfitMargin': 0.55606474737721,
#   'netProfitMargin': 0.13595967200773,
#   'Total assets': 46648600000.0,
#   'Total debt': 10522100000.0,
#   'Total liabilities': 20280800000.0,
#   'EPS': 3.58,
#   'Dividend per Share': 0.56,
#   'Sector': 'Healthcare'},
#  {'ticker': 'EVHC',
#   'Revenue': nan,
#   'Revenue Growth': nan,
#   'Gross Profit': nan,
#   'Profit Margin': nan,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': nan,
#   'Total debt': nan,
#   'Total liabilities': nan,
#   'EPS': nan,
#   'Dividend per Share': nan,
#   'Sector': 'Healthcare'},
#  {'ticker': 'PKI',
#   'Revenue': 2256982000.0,
#   'Revenue Growth': 0.0669,
#   'Gross Profit': 1073754000.0,
#   'Profit Margin': 0.13,
#   'grossProfitMargin': 0.4757477020197801,
#   'netProfitMargin': 0.12965677174209,
#   'Total assets': 6091463000.0,
#   'Total debt': 2006109000.0,
#   'Total liabilities': 3588275000.0,
#   'EPS': 2.67,
#   'Dividend per Share': 0.35,
#   'Sector': 'Healthcare'},
#  {'ticker': 'UHS',
#   'Revenue': 10409865000.0,
#   'Revenue Growth': 0.0659,
#   'Gross Profit': 10409865000.0,
#   'Profit Margin': 0.07200000000000001,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.07226827629368901,
#   'Total assets': 10761828000.0,
#   'Total debt': 4040009000.0,
#   'Total liabilities': 5710392000.0,
#   'EPS': 7.86,
#   'Dividend per Share': 0.4,
#   'Sector': 'Healthcare'},
#  {'ticker': 'TMO',
#   'Revenue': 20918000000.0,
#   'Revenue Growth': 0.1447,
#   'Gross Profit': 9448000000.0,
#   'Profit Margin': 0.106,
#   'grossProfitMargin': 0.45166841954298,
#   'netProfitMargin': 0.1063677215795,
#   'Total assets': 56669000000.0,
#   'Total debt': 21008000000.0,
#   'Total liabilities': 31256000000.0,
#   'EPS': 5.64,
#   'Dividend per Share': 0.6,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DGX',
#   'Revenue': 7402000000.0,
#   'Revenue Growth': 0.0261,
#   'Gross Profit': 2683000000.0,
#   'Profit Margin': 0.104,
#   'grossProfitMargin': 0.36246960281005,
#   'netProfitMargin': 0.10429613617941,
#   'Total assets': 10503000000.0,
#   'Total debt': 3784000000.0,
#   'Total liabilities': 5548000000.0,
#   'EPS': 5.63,
#   'Dividend per Share': 1.8,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MCK',
#   'Revenue': 198533000000.0,
#   'Revenue Growth': 0.0401,
#   'Gross Profit': 11271000000.0,
#   'Profit Margin': 0.026,
#   'grossProfitMargin': 0.056771418353624,
#   'netProfitMargin': 0.025537316214433,
#   'Total assets': 60969000000.0,
#   'Total debt': 8545000000.0,
#   'Total liabilities': 49696000000.0,
#   'EPS': 22.95,
#   'Dividend per Share': 1.12,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABC',
#   'Revenue': 153143826000.0,
#   'Revenue Growth': 0.0429,
#   'Gross Profit': 4546002000.0,
#   'Profit Margin': 0.002,
#   'grossProfitMargin': 0.029684526753302007,
#   'netProfitMargin': 0.0023800110622808,
#   'Total assets': 35316470000.0,
#   'Total debt': 3793690000.0,
#   'Total liabilities': 33252009000.0,
#   'EPS': 1.67,
#   'Dividend per Share': 1.46,
#   'Sector': 'Healthcare'},
#  {'ticker': 'EW',
#   'Revenue': 3435300000.0,
#   'Revenue Growth': 0.1591,
#   'Gross Profit': 2560000000.0,
#   'Profit Margin': 0.17,
#   'grossProfitMargin': 0.7452042034174601,
#   'netProfitMargin': 0.16988327074782,
#   'Total assets': 5666400000.0,
#   'Total debt': 1036400000.0,
#   'Total liabilities': 2710200000.0,
#   'EPS': 2.77,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ZTS',
#   'Revenue': 5307000000.0,
#   'Revenue Growth': 0.0857,
#   'Gross Profit': 3532000000.0,
#   'Profit Margin': 0.163,
#   'grossProfitMargin': 0.66553608441681,
#   'netProfitMargin': 0.16280384397965,
#   'Total assets': 8586000000.0,
#   'Total debt': 4953000000.0,
#   'Total liabilities': 6800000000.0,
#   'EPS': 1.76,
#   'Dividend per Share': 0.42,
#   'Sector': 'Healthcare'},
#  {'ticker': 'SYK',
#   'Revenue': 12444000000.0,
#   'Revenue Growth': 0.0988,
#   'Gross Profit': 8180000000.0,
#   'Profit Margin': 0.08199999999999999,
#   'grossProfitMargin': 0.6573449051751801,
#   'netProfitMargin': 0.081967213114754,
#   'Total assets': 22197000000.0,
#   'Total debt': 7222000000.0,
#   'Total liabilities': 12217000000.0,
#   'EPS': 2.73,
#   'Dividend per Share': 1.745,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ILMN',
#   'Revenue': 2752000000.0,
#   'Revenue Growth': 0.1476,
#   'Gross Profit': 1826000000.0,
#   'Profit Margin': 0.263,
#   'grossProfitMargin': 0.6635174418604699,
#   'netProfitMargin': 0.26380813953488,
#   'Total assets': 5257000000.0,
#   'Total debt': 1192000000.0,
#   'Total liabilities': 2508000000.0,
#   'EPS': 4.96,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ISRG',
#   'Revenue': 3138200000.0,
#   'Revenue Growth': 0.1595,
#   'Gross Profit': 2202000000.0,
#   'Profit Margin': 0.214,
#   'grossProfitMargin': 0.70167612006883,
#   'netProfitMargin': 0.2137849722771,
#   'Total assets': 5776800000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 996400000.0,
#   'EPS': 6.01,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CAH',
#   'Revenue': 129976000000.0,
#   'Revenue Growth': 0.0694,
#   'Gross Profit': 6544000000.0,
#   'Profit Margin': 0.01,
#   'grossProfitMargin': 0.050347756508894,
#   'netProfitMargin': 0.009909521757863,
#   'Total assets': 40112000000.0,
#   'Total debt': 10395000000.0,
#   'Total liabilities': 33284000000.0,
#   'EPS': 4.06,
#   'Dividend per Share': 1.809,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DVA',
#   'Revenue': 10876634000.0,
#   'Revenue Growth': 0.0158,
#   'Gross Profit': 3236629000.0,
#   'Profit Margin': 0.061,
#   'grossProfitMargin': 0.29757634577021,
#   'netProfitMargin': 0.061013177422353,
#   'Total assets': 18974536000.0,
#   'Total debt': 9336231000.0,
#   'Total liabilities': 13077110000.0,
#   'EPS': 3.52,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'REGN',
#   'Revenue': 5872200000.0,
#   'Revenue Growth': 0.2082,
#   'Gross Profit': 5475100000.0,
#   'Profit Margin': 0.204,
#   'grossProfitMargin': 0.9323762814618,
#   'netProfitMargin': 0.20409727189128,
#   'Total assets': 8764300000.0,
#   'Total debt': 703500000.0,
#   'Total liabilities': 2620200000.0,
#   'EPS': 11.27,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HUM',
#   'Revenue': 53767000000.0,
#   'Revenue Growth': -0.0113,
#   'Gross Profit': 10271000000.0,
#   'Profit Margin': 0.046,
#   'grossProfitMargin': 0.19102795394945,
#   'netProfitMargin': 0.045529785928172,
#   'Total assets': 27178000000.0,
#   'Total debt': 5061000000.0,
#   'Total liabilities': 17336000000.0,
#   'EPS': 16.94,
#   'Dividend per Share': 1.89,
#   'Sector': 'Healthcare'},
#  {'ticker': 'RMD',
#   'Revenue': 2066737000.0,
#   'Revenue Growth': 0.124,
#   'Gross Profit': 1201745000.0,
#   'Profit Margin': 0.166,
#   'grossProfitMargin': 0.58146972740121,
#   'netProfitMargin': 0.1656156540479,
#   'Total assets': 3468487000.0,
#   'Total debt': 1078611000.0,
#   'Total liabilities': 1508221000.0,
#   'EPS': 2.42,
#   'Dividend per Share': 1.32,
#   'Sector': 'Healthcare'},
#  {'ticker': 'INCY',
#   'Revenue': 1536216000.0,
#   'Revenue Growth': 0.3893,
#   'Gross Profit': 1456737000.0,
#   'Profit Margin': -0.204,
#   'grossProfitMargin': 0.94826313487166,
#   'netProfitMargin': -0.203839824608,
#   'Total assets': 2302582000.0,
#   'Total debt': 24001000.0,
#   'Total liabilities': 671953000.0,
#   'EPS': -1.53,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'LH',
#   'Revenue': 10308000000.0,
#   'Revenue Growth': 0.079,
#   'Gross Profit': 3091800000.0,
#   'Profit Margin': 0.119,
#   'grossProfitMargin': 0.2999417927823,
#   'netProfitMargin': 0.11904346138921,
#   'Total assets': 16673000000.0,
#   'Total debt': 6762100000.0,
#   'Total liabilities': 9848100000.0,
#   'EPS': 11.99,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'COO',
#   'Revenue': 2139000000.0,
#   'Revenue Growth': 0.0876,
#   'Gross Profit': 1365800000.0,
#   'Profit Margin': 0.174,
#   'grossProfitMargin': 0.6385226741468001,
#   'netProfitMargin': 0.17433380084151,
#   'Total assets': 4858700000.0,
#   'Total debt': 1172700000.0,
#   'Total liabilities': 1682900000.0,
#   'EPS': 7.63,
#   'Dividend per Share': 0.06,
#   'Sector': 'Healthcare'},
#  {'ticker': 'IDXX',
#   'Revenue': 1969058000.0,
#   'Revenue Growth': 0.1091,
#   'Gross Profit': 1097382000.0,
#   'Profit Margin': 0.134,
#   'grossProfitMargin': 0.55731319239961,
#   'netProfitMargin': 0.13363953728128,
#   'Total assets': 1713416000.0,
#   'Total debt': 1261075000.0,
#   'Total liabilities': 1767258000.0,
#   'EPS': 3.0,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ALGN',
#   'Revenue': 1473413000.0,
#   'Revenue Growth': 0.3644,
#   'Gross Profit': 1116947000.0,
#   'Profit Margin': 0.157,
#   'grossProfitMargin': 0.7580678329836898,
#   'netProfitMargin': 0.15706254797535,
#   'Total assets': 1784009000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 629721000.0,
#   'EPS': 2.89,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'PRGO',
#   'Revenue': 4946200000.0,
#   'Revenue Growth': -0.0633,
#   'Gross Profit': 1979500000.0,
#   'Profit Margin': 0.024,
#   'grossProfitMargin': 0.40020621891553,
#   'netProfitMargin': 0.02418017872306,
#   'Total assets': 11628800000.0,
#   'Total debt': 3341200000.0,
#   'Total liabilities': 5458200000.0,
#   'EPS': 0.84,
#   'Dividend per Share': 0.64,
#   'Sector': 'Healthcare'},
#  {'ticker': 'IQV',
#   'Revenue': 9702000000.0,
#   'Revenue Growth': 0.4236,
#   'Gross Profit': 3401000000.0,
#   'Profit Margin': 0.132,
#   'grossProfitMargin': 0.35054627911771,
#   'netProfitMargin': 0.13162234590806,
#   'Total assets': 22857000000.0,
#   'Total debt': 10225000000.0,
#   'Total liabilities': 14613000000.0,
#   'EPS': 5.86,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'VAR',
#   'Revenue': 2619300000.0,
#   'Revenue Growth': 0.0099,
#   'Gross Profit': 1113900000.0,
#   'Profit Margin': 0.083,
#   'grossProfitMargin': 0.4252662925209,
#   'netProfitMargin': 0.083419234146528,
#   'Total assets': 3294400000.0,
#   'Total debt': 350000000.0,
#   'Total liabilities': 1772500000.0,
#   'EPS': 2.36,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MTD',
#   'Revenue': 2725053000.0,
#   'Revenue Growth': 0.0864,
#   'Gross Profit': 1575751000.0,
#   'Profit Margin': 0.138,
#   'grossProfitMargin': 0.5782460010869499,
#   'netProfitMargin': 0.137968692719,
#   'Total assets': 2549805000.0,
#   'Total debt': 979847000.0,
#   'Total liabilities': 2002525000.0,
#   'EPS': 14.62,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CMCSA',
#   'Revenue': 85029000000.0,
#   'Revenue Growth': 0.0532,
#   'Gross Profit': 85029000000.0,
#   'Profit Margin': 0.267,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.26737936468734,
#   'Total assets': 187462000000.0,
#   'Total debt': 64556000000.0,
#   'Total liabilities': 118003000000.0,
#   'EPS': 4.83,
#   'Dividend per Share': 0.473,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'F',
#   'Revenue': 156776000000.0,
#   'Revenue Growth': 0.0328,
#   'Gross Profit': 16408000000.0,
#   'Profit Margin': 0.049,
#   'grossProfitMargin': 0.10465887635863,
#   'netProfitMargin': 0.049312394754299,
#   'Total assets': 258496000000.0,
#   'Total debt': 154287000000.0,
#   'Total liabilities': 222792000000.0,
#   'EPS': 1.94,
#   'Dividend per Share': 0.65,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'NKE',
#   'Revenue': 34350000000.0,
#   'Revenue Growth': 0.061,
#   'Gross Profit': 15312000000.0,
#   'Profit Margin': 0.123,
#   'grossProfitMargin': 0.44576419213974,
#   'netProfitMargin': 0.12343522561863,
#   'Total assets': 23259000000.0,
#   'Total debt': 3802000000.0,
#   'Total liabilities': 10852000000.0,
#   'EPS': 2.56,
#   'Dividend per Share': 0.68,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'GM',
#   'Revenue': 145588000000.0,
#   'Revenue Growth': -0.0241,
#   'Gross Profit': 18231000000.0,
#   'Profit Margin': -0.027000000000000003,
#   'grossProfitMargin': 0.12522323268400998,
#   'netProfitMargin': -0.026540648954584,
#   'Total assets': 212482000000.0,
#   'Total debt': 94219000000.0,
#   'Total liabilities': 176282000000.0,
#   'EPS': -2.65,
#   'Dividend per Share': 1.52,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'TWX',
#   'Revenue': 31271000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 13624000000.0,
#   'Profit Margin': 0.16779124428384,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 69209000000.0,
#   'Total debt': 18294000000.0,
#   'Total liabilities': 40834000000.0,
#   'EPS': 6.73,
#   'Dividend per Share': nan,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'LOW',
#   'Revenue': 65017000000.0,
#   'Revenue Growth': 0.1006,
#   'Gross Profit': 21674000000.0,
#   'Profit Margin': 0.048,
#   'grossProfitMargin': 0.33335896765461,
#   'netProfitMargin': 0.047572173431564,
#   'Total assets': 34408000000.0,
#   'Total debt': 15699000000.0,
#   'Total liabilities': 27974000000.0,
#   'EPS': 3.48,
#   'Dividend per Share': 1.33,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'MAT',
#   'Revenue': 4881493000.0,
#   'Revenue Growth': -0.1048,
#   'Gross Profit': 1824571000.0,
#   'Profit Margin': -0.21600000000000005,
#   'grossProfitMargin': 0.37377314686306,
#   'netProfitMargin': -0.21603615942909,
#   'Total assets': 6228147000.0,
#   'Total debt': 3123119000.0,
#   'Total liabilities': 4981048000.0,
#   'EPS': -3.07,
#   'Dividend per Share': 0.91,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'DIS',
#   'Revenue': 55137000000.0,
#   'Revenue Growth': -0.0089,
#   'Gross Profit': 24831000000.0,
#   'Profit Margin': 0.163,
#   'grossProfitMargin': 0.45035094401219,
#   'netProfitMargin': 0.16286704028148002,
#   'Total assets': 95789000000.0,
#   'Total debt': 25291000000.0,
#   'Total liabilities': 50785000000.0,
#   'EPS': 5.73,
#   'Dividend per Share': 1.56,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'LEN',
#   'Revenue': 12646365000.0,
#   'Revenue Growth': 0.1549,
#   'Gross Profit': 1624884000.0,
#   'Profit Margin': 0.064,
#   'grossProfitMargin': 0.12848624881537,
#   'netProfitMargin': 0.064087981012726,
#   'Total assets': 18745034000.0,
#   'Total debt': 6410003000.0,
#   'Total liabilities': 10758902000.0,
#   'EPS': 3.38,
#   'Dividend per Share': 0.16,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'MGM',
# ...
#   'Total debt': 3278845000.0,
#   'Total liabilities': 6299708000.0,
#   'EPS': 0.04,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'GLW',
#   'Revenue': 10116000000.0,
#   'Revenue Growth': 0.0773,
#   'Gross Profit': 4020000000.0,
#   'Profit Margin': -0.049,
#   'grossProfitMargin': 0.39739027283511,
#   'netProfitMargin': -0.049130090945038,
#   'Total assets': 27494000000.0,
#   'Total debt': 5128000000.0,
#   'Total liabilities': 11724000000.0,
#   'EPS': -0.66,
#   'Dividend per Share': 0.62,
#   'Sector': 'Technology'},
#  {'ticker': 'STX',
#   'Revenue': 10771000000.0,
#   'Revenue Growth': -0.0349,
#   'Gross Profit': 3174000000.0,
#   'Profit Margin': 0.07200000000000001,
#   'grossProfitMargin': 0.29468015968805,
#   'netProfitMargin': 0.071673939281404,
#   'Total assets': 9268000000.0,
#   'Total debt': 5021000000.0,
#   'Total liabilities': 7904000000.0,
#   'EPS': 2.61,
#   'Dividend per Share': 2.52,
#   'Sector': 'Technology'},
#  {'ticker': 'ADBE',
#   'Revenue': 7301505000.0,
#   'Revenue Growth': 0.2472,
#   'Gross Profit': 6291014000.0,
#   'Profit Margin': 0.232,
#   'grossProfitMargin': 0.86160510744018,
#   'netProfitMargin': 0.23200066287704,
#   'Total assets': 14535556000.0,
#   'Total debt': 1881421000.0,
#   'Total liabilities': 6075687000.0,
#   'EPS': 3.43,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'LRCX',
#   'Revenue': 8013620000.0,
#   'Revenue Growth': 0.3615,
#   'Gross Profit': 3603359000.0,
#   'Profit Margin': 0.212,
#   'grossProfitMargin': 0.44965433848872,
#   'netProfitMargin': 0.21185968388818,
#   'Total assets': 12122765000.0,
#   'Total debt': 2693413000.0,
#   'Total liabilities': 5135453000.0,
#   'EPS': 10.47,
#   'Dividend per Share': 1.65,
#   'Sector': 'Technology'},
#  {'ticker': 'GOOGL',
#   'Revenue': 110855000000.0,
#   'Revenue Growth': 0.228,
#   'Gross Profit': 65272000000.0,
#   'Profit Margin': 0.114,
#   'grossProfitMargin': 0.58880519597673,
#   'netProfitMargin': 0.11422128005052,
#   'Total assets': 197295000000.0,
#   'Total debt': 3969000000.0,
#   'Total liabilities': 44793000000.0,
#   'EPS': 18.27,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'FTV',
#   'Revenue': 5756100000.0,
#   'Revenue Growth': 0.0703,
#   'Gross Profit': 2921400000.0,
#   'Profit Margin': 0.181,
#   'grossProfitMargin': 0.50753114087664,
#   'netProfitMargin': 0.18145966887302,
#   'Total assets': 10500600000.0,
#   'Total debt': 4056200000.0,
#   'Total liabilities': 6692400000.0,
#   'EPS': 3.01,
#   'Dividend per Share': 0.28,
#   'Sector': 'Technology'},
#  {'ticker': 'CTSH',
#   'Revenue': 14810000000.0,
#   'Revenue Growth': 0.0981,
#   'Gross Profit': 5658000000.0,
#   'Profit Margin': 0.102,
#   'grossProfitMargin': 0.38203916272789,
#   'netProfitMargin': 0.10155300472654,
#   'Total assets': 15221000000.0,
#   'Total debt': 873000000.0,
#   'Total liabilities': 4552000000.0,
#   'EPS': 2.54,
#   'Dividend per Share': 0.45,
#   'Sector': 'Technology'},
#  {'ticker': 'CTXS',
#   'Revenue': 2824686000.0,
#   'Revenue Growth': 0.0324,
#   'Gross Profit': 2385040000.0,
#   'Profit Margin': -0.006999999999999999,
#   'grossProfitMargin': 0.8443557974231501,
#   'netProfitMargin': -0.0073349745777053,
#   'Total assets': 5820176000.0,
#   'Total debt': 2127474000.0,
#   'Total liabilities': 4827715000.0,
#   'EPS': -0.13,
#   'Dividend per Share': 17.83,
#   'Sector': 'Technology'},
#  {'ticker': 'TTWO',
#   'Revenue': 1779748000.0,
#   'Revenue Growth': 0.2589,
#   'Gross Profit': 756789000.0,
#   'Profit Margin': 0.038,
#   'grossProfitMargin': 0.4252225595983301,
#   'netProfitMargin': 0.037816027887094,
#   'Total assets': 3149154000.0,
#   'Total debt': 251929000.0,
#   'Total liabilities': 2145426000.0,
#   'EPS': 0.73,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'KLAC',
#   'Revenue': 3480014000.0,
#   'Revenue Growth': 0.166,
#   'Gross Profit': 2193799000.0,
#   'Profit Margin': 0.266,
#   'grossProfitMargin': 0.6303994754044101,
#   'netProfitMargin': 0.26611272253502,
#   'Total assets': 5532173000.0,
#   'Total debt': 2930457000.0,
#   'Total liabilities': 4205756000.0,
#   'EPS': 5.92,
#   'Dividend per Share': 2.14,
#   'Sector': 'Technology'},
#  {'ticker': 'GOOG',
#   'Revenue': 110855000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 65272000000.0,
#   'Profit Margin': 0.11422128005052,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 197295000000.0,
#   'Total debt': 3943000000.0,
#   'Total liabilities': 44793000000.0,
#   'EPS': 18.27,
#   'Dividend per Share': nan,
#   'Sector': 'Technology'},
#  {'ticker': 'QRVO',
#   'Revenue': 3032574000.0,
#   'Revenue Growth': 0.1616,
#   'Gross Profit': 1135512000.0,
#   'Profit Margin': -0.005,
#   'grossProfitMargin': 0.37443834841293,
#   'netProfitMargin': -0.0054600481307299,
#   'Total assets': 6522323000.0,
#   'Total debt': 989154000.0,
#   'Total liabilities': 1625601000.0,
#   'EPS': -0.13,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'TEL',
#   'Revenue': 12185000000.0,
#   'Revenue Growth': 0.0734,
#   'Gross Profit': 4183000000.0,
#   'Profit Margin': 0.138,
#   'grossProfitMargin': 0.34329093147312,
#   'netProfitMargin': 0.13812064013131,
#   'Total assets': 19403000000.0,
#   'Total debt': 4344000000.0,
#   'Total liabilities': 9652000000.0,
#   'EPS': 4.74,
#   'Dividend per Share': 1.54,
#   'Sector': 'Technology'},
#  {'ticker': 'EA',
#   'Revenue': 4845000000.0,
#   'Revenue Growth': 0.1021,
#   'Gross Profit': 3547000000.0,
#   'Profit Margin': 0.2,
#   'grossProfitMargin': 0.73209494324045,
#   'netProfitMargin': 0.19958720330237,
#   'Total assets': 7718000000.0,
#   'Total debt': 990000000.0,
#   'Total liabilities': 3658000000.0,
#   'EPS': 3.19,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'INFO',
#   'Revenue': 3599700000.0,
#   'Revenue Growth': 0.3163,
#   'Gross Profit': 2251300000.0,
#   'Profit Margin': 0.116,
#   'grossProfitMargin': 0.62541322888018,
#   'netProfitMargin': 0.11581520682279,
#   'Total assets': 14554400000.0,
#   'Total debt': 4193300000.0,
#   'Total liabilities': 6550000000.0,
#   'EPS': 1.04,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CERN',
#   'Revenue': 5142272000.0,
#   'Revenue Growth': 0.0721,
#   'Gross Profit': 4288181000.0,
#   'Profit Margin': 0.16899999999999998,
#   'grossProfitMargin': 0.83390785240454,
#   'netProfitMargin': 0.16859823828845005,
#   'Total assets': 6469311000.0,
#   'Total debt': 526715000.0,
#   'Total liabilities': 1683963000.0,
#   'EPS': 2.62,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'AKAM',
#   'Revenue': 2489035000.0,
#   'Revenue Growth': 0.0601,
#   'Gross Profit': 1613198000.0,
#   'Profit Margin': 0.08900000000000001,
#   'grossProfitMargin': 0.64812186248888,
#   'netProfitMargin': 0.089498942361196,
#   'Total assets': 4648916000.0,
#   'Total debt': 662913000.0,
#   'Total liabilities': 1286447000.0,
#   'EPS': 1.3,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CDNS',
#   'Revenue': 1943032000.0,
#   'Revenue Growth': 0.0699,
#   'Gross Profit': 1705642000.0,
#   'Profit Margin': 0.105,
#   'grossProfitMargin': 0.8778249663412601,
#   'netProfitMargin': 0.10504253146629,
#   'Total assets': 2418714000.0,
#   'Total debt': 729369000.0,
#   'Total liabilities': 1429512000.0,
#   'EPS': 0.75,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'NTAP',
#   'Revenue': 5491000000.0,
#   'Revenue Growth': -0.0099,
#   'Gross Profit': 3364000000.0,
#   'Profit Margin': 0.08800000000000001,
#   'grossProfitMargin': 0.61263886359497,
#   'netProfitMargin': 0.087597887452195,
#   'Total assets': 9493000000.0,
#   'Total debt': 1993000000.0,
#   'Total liabilities': 6713000000.0,
#   'EPS': 1.75,
#   'Dividend per Share': 0.76,
#   'Sector': 'Technology'},
#  {'ticker': 'JNPR',
#   'Revenue': 5027200000.0,
#   'Revenue Growth': 0.0074,
#   'Gross Profit': 3072100000.0,
#   'Profit Margin': 0.061,
#   'grossProfitMargin': 0.61109563971992,
#   'netProfitMargin': 0.060908656906429,
#   'Total assets': 9833800000.0,
#   'Total debt': 2136300000.0,
#   'Total liabilities': 5152900000.0,
#   'EPS': 0.81,
#   'Dividend per Share': 0.4,
#   'Sector': 'Technology'},
#  {'ticker': 'MCHP',
#   'Revenue': 3407800000.0,
#   'Revenue Growth': 0.568,
#   'Gross Profit': 1757200000.0,
#   'Profit Margin': 0.048,
#   'grossProfitMargin': 0.5156405892364601,
#   'netProfitMargin': 0.048300956628910006,
#   'Total assets': 7686900000.0,
#   'Total debt': 2950500000.0,
#   'Total liabilities': 4416200000.0,
#   'EPS': 0.76,
#   'Dividend per Share': 1.4409999999999998,
#   'Sector': 'Technology'},
#  {'ticker': 'INTU',
#   'Revenue': 5196000000.0,
#   'Revenue Growth': 0.1069,
#   'Gross Profit': 4398000000.0,
#   'Profit Margin': 0.19,
#   'grossProfitMargin': 0.84642032332564,
#   'netProfitMargin': 0.18956889915319,
#   'Total assets': 4068000000.0,
#   'Total debt': 488000000.0,
#   'Total liabilities': 2714000000.0,
#   'EPS': 3.83,
#   'Dividend per Share': 1.36,
#   'Sector': 'Technology'},
#  {'ticker': 'XLNX',
#   'Revenue': 2356742000.0,
#   'Revenue Growth': 0.0645,
#   'Gross Profit': 1648110000.0,
#   'Profit Margin': 0.267,
#   'grossProfitMargin': 0.69931710810942,
#   'netProfitMargin': 0.26652599223844,
#   'Total assets': 4740532000.0,
#   'Total debt': 1451575000.0,
#   'Total liabilities': 2232899000.0,
#   'EPS': 2.49,
#   'Dividend per Share': 1.32,
#   'Sector': 'Technology'},
#  {'ticker': 'SWKS',
#   'Revenue': 3651400000.0,
#   'Revenue Growth': 0.1102,
#   'Gross Profit': 1841800000.0,
#   'Profit Margin': 0.277,
#   'grossProfitMargin': 0.50440926767815,
#   'netProfitMargin': 0.27666100673714,
#   'Total assets': 4573600000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 507900000.0,
#   'EPS': 5.48,
#   'Dividend per Share': 1.16,
#   'Sector': 'Technology'},
#  {'ticker': 'ADI',
#   'Revenue': 5107503000.0,
#   'Revenue Growth': 0.4928,
#   'Gross Profit': 3061596000.0,
#   'Profit Margin': 0.142,
#   'grossProfitMargin': 0.5994310722871801,
#   'netProfitMargin': 0.14239032262928,
#   'Total assets': 21141294000.0,
#   'Total debt': 7851084000.0,
#   'Total liabilities': 10979754000.0,
#   'EPS': 2.09,
#   'Dividend per Share': 1.77,
#   'Sector': 'Technology'},
#  {'ticker': 'VRSN',
#   'Revenue': 1165095000.0,
#   'Revenue Growth': 0.0201,
#   'Gross Profit': 971769000.0,
#   'Profit Margin': 0.392,
#   'grossProfitMargin': 0.8340684665199,
#   'netProfitMargin': 0.39245555083491,
#   'Total assets': 2941188000.0,
#   'Total debt': 2410145000.0,
#   'Total liabilities': 4201459000.0,
#   'EPS': 4.56,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'DXC',
#   'Revenue': 7607000000.0,
#   'Revenue Growth': -0.58,
#   'Gross Profit': 2058000000.0,
#   'Profit Margin': -0.016,
#   'grossProfitMargin': 0.27054029183647,
#   'netProfitMargin': -0.016169317733666002,
#   'Total assets': 8663000000.0,
#   'Total debt': 2963000000.0,
#   'Total liabilities': 6497000000.0,
#   'EPS': -0.88,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'EQIX',
#   'Revenue': 4368428000.0,
#   'Revenue Growth': 0.2094,
#   'Gross Profit': 2175279000.0,
#   'Profit Margin': 0.053,
#   'grossProfitMargin': 0.49795464180708,
#   'netProfitMargin': 0.053333144096685985,
#   'Total assets': 18691457000.0,
#   'Total debt': 10080419000.0,
#   'Total liabilities': 11841667000.0,
#   'EPS': 3.03,
#   'Dividend per Share': 8.0,
#   'Sector': 'Technology'},
#  {'ticker': 'FIS',
#   'Revenue': 8668000000.0,
#   'Revenue Growth': -0.0185,
#   'Gross Profit': 2874000000.0,
#   'Profit Margin': 0.145,
#   'grossProfitMargin': 0.33156437471158,
#   'netProfitMargin': 0.14547761882787,
#   'Total assets': 24526000000.0,
#   'Total debt': 8763000000.0,
#   'Total liabilities': 13706000000.0,
#   'EPS': 3.82,
#   'Dividend per Share': 1.16,
#   'Sector': 'Technology'},
#  {'ticker': 'AYI',
#   'Revenue': 3505100000.0,
#   'Revenue Growth': 0.065,
#   'Gross Profit': 1481100000.0,
#   'Profit Margin': 0.092,
#   'grossProfitMargin': 0.42255570454481,
#   'netProfitMargin': 0.091780548343842,
#   'Total assets': 2899600000.0,
#   'Total debt': 356900000.0,
#   'Total liabilities': 1234000000.0,
#   'EPS': 7.46,
#   'Dividend per Share': 0.52,
#   'Sector': 'Technology'},
#  {'ticker': 'MSI',
#   'Revenue': 6380000000.0,
#   'Revenue Growth': 0.0566,
#   'Gross Profit': 3024000000.0,
#   'Profit Margin': -0.024,
#   'grossProfitMargin': 0.4739811912225701,
#   'netProfitMargin': -0.024294670846395,
#   'Total assets': 8208000000.0,
#   'Total debt': 4471000000.0,
#   'Total liabilities': 9935000000.0,
#   'EPS': -0.95,
#   'Dividend per Share': 1.93,
#   'Sector': 'Technology'},
#  {'ticker': 'WHR',
#   'Revenue': 21253000000.0,
#   'Revenue Growth': 0.0258,
#   'Gross Profit': 3602000000.0,
#   'Profit Margin': 0.016,
#   'grossProfitMargin': 0.16948195548864006,
#   'netProfitMargin': 0.016468263304004,
#   'Total assets': 20038000000.0,
#   'Total debt': 5218000000.0,
#   'Total liabilities': 14910000000.0,
#   'EPS': 4.78,
#   'Dividend per Share': 4.3,
#   'Sector': 'Technology'},
#  {'ticker': 'FFIV',
#   'Revenue': 2090041000.0,
#   'Revenue Growth': 0.0476,
#   'Gross Profit': 1736556000.0,
#   'Profit Margin': 0.201,
#   'grossProfitMargin': 0.8308717388797601,
#   'netProfitMargin': 0.20131710334869,
#   'Total assets': 2476489000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 1247097000.0,
#   'EPS': 6.56,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'FLIR',
#   'Revenue': 1800434000.0,
#   'Revenue Growth': 0.0832,
#   'Gross Profit': 858776000.0,
#   'Profit Margin': 0.06,
#   'grossProfitMargin': 0.47698277193166,
#   'netProfitMargin': 0.059553974208441,
#   'Total assets': 2810026000.0,
#   'Total debt': 420684000.0,
#   'Total liabilities': 975468000.0,
#   'EPS': 0.78,
#   'Dividend per Share': 0.6,
#   'Sector': 'Technology'},
#  {'ticker': 'APH',
#   'Revenue': 7011300000.0,
#   'Revenue Growth': 0.1153,
#   'Gross Profit': 2309900000.0,
#   'Profit Margin': 0.093,
#   'grossProfitMargin': 0.32945388159115,
#   'netProfitMargin': 0.092778799937244,
#   'Total assets': 10003900000.0,
#   'Total debt': 3542600000.0,
#   'Total liabilities': 5960500000.0,
#   'EPS': 2.13,
#   'Dividend per Share': 0.7,
#   'Sector': 'Technology'},
#  {'ticker': 'WAT',
#   'Revenue': 2309078000.0,
#   'Revenue Growth': 0.0654,
#   'Gross Profit': 1362011000.0,
#   'Profit Margin': 0.009000000000000001,
#   'grossProfitMargin': 0.5898505810544301,
#   'netProfitMargin': 0.0087961515375401,
#   'Total assets': 5324354000.0,
#   'Total debt': 1997774000.0,
#   'Total liabilities': 3090566000.0,
#   'EPS': 0.25,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'GRMN',
#   'Revenue': 3121560000.0,
#   'Revenue Growth': 0.0249,
#   'Gross Profit': 1797941000.0,
#   'Profit Margin': 0.227,
#   'grossProfitMargin': 0.57597515344892,
#   'netProfitMargin': 0.22713226719973,
#   'Total assets': 4948289000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 1095870000.0,
#   'EPS': 3.77,
#   'Dividend per Share': 2.55,
#   'Sector': 'Technology'},
#  {'ticker': 'AME',
#   'Revenue': 4300170000.0,
#   'Revenue Growth': 0.1198,
#   'Gross Profit': 1438800000.0,
#   'Profit Margin': 0.158,
#   'grossProfitMargin': 0.33459142312978,
#   'netProfitMargin': 0.158475130053,
#   'Total assets': 7796064000.0,
#   'Total debt': 2174289000.0,
#   'Total liabilities': 3768431000.0,
#   'EPS': 2.96,
#   'Dividend per Share': 0.36,
#   'Sector': 'Technology'},
#  {'ticker': 'ANSS',
#   'Revenue': 1095250000.0,
#   'Revenue Growth': 0.108,
#   'Gross Profit': 945086000.0,
#   'Profit Margin': 0.237,
#   'grossProfitMargin': 0.86289522939968,
#   'netProfitMargin': 0.23670486190367,
#   'Total assets': 2941623000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 695792000.0,
#   'EPS': 3.05,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'SNPS',
#   'Revenue': 2724880000.0,
#   'Revenue Growth': 0.1248,
#   'Gross Profit': 2070696000.0,
#   'Profit Margin': 0.05,
#   'grossProfitMargin': 0.7599219048178301,
#   'netProfitMargin': 0.050117069375532015,
#   'Total assets': 5396414000.0,
#   'Total debt': 143987000.0,
#   'Total liabilities': 2116690000.0,
#   'EPS': 0.91,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'IPGP',
#   'Revenue': 1408889000.0,
#   'Revenue Growth': 0.4002,
#   'Gross Profit': 796911000.0,
#   'Profit Margin': 0.247,
#   'grossProfitMargin': 0.56563079135404,
#   'netProfitMargin': 0.24672916035259,
#   'Total assets': 2367255000.0,
#   'Total debt': 48982000.0,
#   'Total liabilities': 344933000.0,
#   'EPS': 6.5,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'}]

# %%
financial2016_dict=top500_2016.to_dict('records')
financial2016_dict
# Out:
# [{'ticker': 'PG',
#   'Revenue': 65299000000.0,
#   'Revenue Growth': -0.077,
#   'Gross Profit': 32390000000.0,
#   'Profit Margin': 0.161,
#   'grossProfitMargin': 0.49602597283266,
#   'netProfitMargin': 0.16092130047932998,
#   'Total assets': 127136000000.0,
#   'Total debt': 30598000000.0,
#   'Total liabilities': 69153000000.0,
#   'EPS': 3.8,
#   'Dividend per Share': 2.658,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KR',
#   'Revenue': 109830000000.0,
#   'Revenue Growth': 0.0126,
#   'Gross Profit': 24334000000.0,
#   'Profit Margin': 0.019,
#   'grossProfitMargin': 0.22156059364472006,
#   'netProfitMargin': 0.018565055085132003,
#   'Total assets': 33897000000.0,
#   'Total debt': 12079000000.0,
#   'Total liabilities': 27099000000.0,
#   'EPS': 2.09,
#   'Dividend per Share': 0.5,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'GIS',
#   'Revenue': 16563100000.0,
#   'Revenue Growth': -0.0605,
#   'Gross Profit': 5829500000.0,
#   'Profit Margin': 0.102,
#   'grossProfitMargin': 0.35195706117815995,
#   'netProfitMargin': 0.10248081578931,
#   'Total assets': 21712300000.0,
#   'Total debt': 8430900000.0,
#   'Total liabilities': 15559600000.0,
#   'EPS': 2.83,
#   'Dividend per Share': 1.78,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'PM',
#   'Revenue': 74953000000.0,
#   'Revenue Growth': 0.0141,
#   'Gross Profit': 17294000000.0,
#   'Profit Margin': 0.093,
#   'grossProfitMargin': 0.23073125825517,
#   'netProfitMargin': 0.092951582992008,
#   'Total assets': 36851000000.0,
#   'Total debt': 29067000000.0,
#   'Total liabilities': 47751000000.0,
#   'EPS': 4.48,
#   'Dividend per Share': 4.12,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KO',
#   'Revenue': 41863000000.0,
#   'Revenue Growth': -0.0549,
#   'Gross Profit': 25398000000.0,
#   'Profit Margin': 0.156,
#   'grossProfitMargin': 0.60669326135251,
#   'netProfitMargin': 0.15591333635907995,
#   'Total assets': 87270000000.0,
#   'Total debt': 45709000000.0,
#   'Total liabilities': 64050000000.0,
#   'EPS': 1.51,
#   'Dividend per Share': 1.4,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'WMT',
#   'Revenue': 482130000000.0,
#   'Revenue Growth': -0.0073,
#   'Gross Profit': 121146000000.0,
#   'Profit Margin': 0.03,
#   'grossProfitMargin': 0.2512724783772,
#   'netProfitMargin': 0.030477257171302,
#   'Total assets': 199581000000.0,
#   'Total debt': 50034000000.0,
#   'Total liabilities': 115970000000.0,
#   'EPS': 4.58,
#   'Dividend per Share': 1.96,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MDLZ',
#   'Revenue': 25923000000.0,
#   'Revenue Growth': -0.1253,
#   'Gross Profit': 10104000000.0,
#   'Profit Margin': 0.063,
#   'grossProfitMargin': 0.38976970258072,
#   'netProfitMargin': 0.063071403772711,
#   'Total assets': 61538000000.0,
#   'Total debt': 17199000000.0,
#   'Total liabilities': 36323000000.0,
#   'EPS': 1.05,
#   'Dividend per Share': 0.72,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MO',
#   'Revenue': 25744000000.0,
#   'Revenue Growth': 0.0122,
#   'Gross Profit': 11572000000.0,
#   'Profit Margin': 0.5529999999999999,
#   'grossProfitMargin': 0.44950279676818,
#   'netProfitMargin': 0.5530997513983801,
#   'Total assets': 45932000000.0,
#   'Total debt': 13881000000.0,
#   'Total liabilities': 33121000000.0,
#   'EPS': 7.28,
#   'Dividend per Share': 2.35,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KHC',
#   'Revenue': 26300000000.0,
#   'Revenue Growth': 0.4342,
#   'Gross Profit': 9146000000.0,
#   'Profit Margin': 0.13,
#   'grossProfitMargin': 0.3477566539924,
#   'netProfitMargin': 0.13673003802281,
#   'Total assets': 120480000000.0,
#   'Total debt': 32404000000.0,
#   'Total liabilities': 62906000000.0,
#   'EPS': 2.81,
#   'Dividend per Share': 2.35,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'NWL',
#   'Revenue': 9181100000.0,
#   'Revenue Growth': 0.552,
#   'Gross Profit': 2970900000.0,
#   'Profit Margin': 0.057,
#   'grossProfitMargin': 0.32358867673808,
#   'netProfitMargin': 0.057487664876758,
#   'Total assets': 33837500000.0,
#   'Total debt': 11892800000.0,
#   'Total liabilities': 22453100000.0,
#   'EPS': 1.25,
#   'Dividend per Share': 0.76,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KMB',
#   'Revenue': 18287000000.0,
#   'Revenue Growth': -0.0164,
#   'Gross Profit': 6691000000.0,
#   'Profit Margin': 0.118,
#   'grossProfitMargin': 0.36588833597638,
#   'netProfitMargin': 0.11844479685022,
#   'Total assets': 14602000000.0,
#   'Total debt': 7572000000.0,
#   'Total liabilities': 14485000000.0,
#   'EPS': 6.03,
#   'Dividend per Share': 3.68,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CPB',
#   'Revenue': 7961000000.0,
#   'Revenue Growth': -0.015,
#   'Gross Profit': 2928000000.0,
#   'Profit Margin': 0.071,
#   'grossProfitMargin': 0.3677929908303,
#   'netProfitMargin': 0.07071975882426801,
#   'Total assets': 7837000000.0,
#   'Total debt': 3533000000.0,
#   'Total liabilities': 6304000000.0,
#   'EPS': 1.82,
#   'Dividend per Share': 1.248,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TGT',
#   'Revenue': 73785000000.0,
#   'Revenue Growth': 0.0161,
#   'Gross Profit': 21544000000.0,
#   'Profit Margin': 0.046,
#   'grossProfitMargin': 0.29198346547401,
#   'netProfitMargin': 0.045578369587314,
#   'Total assets': 40262000000.0,
#   'Total debt': 12760000000.0,
#   'Total liabilities': 27305000000.0,
#   'EPS': 5.35,
#   'Dividend per Share': 2.16,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'HRL',
#   'Revenue': 9523224000.0,
#   'Revenue Growth': 0.028,
#   'Gross Profit': 2158175000.0,
#   'Profit Margin': 0.093,
#   'grossProfitMargin': 0.22662230773948006,
#   'netProfitMargin': 0.093461205994945,
#   'Total assets': 6370067000.0,
#   'Total debt': 250000000.0,
#   'Total liabilities': 1918661000.0,
#   'EPS': 1.68,
#   'Dividend per Share': 0.58,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'K',
#   'Revenue': 12965000000.0,
#   'Revenue Growth': -0.0414,
#   'Gross Profit': 4834000000.0,
#   'Profit Margin': 0.054000000000000006,
#   'grossProfitMargin': 0.37284998071732,
#   'netProfitMargin': 0.053914384882376,
#   'Total assets': 15111000000.0,
#   'Total debt': 7767000000.0,
#   'Total liabilities': 13185000000.0,
#   'EPS': 1.99,
#   'Dividend per Share': 2.04,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CAG',
#   'Revenue': 8664100000.0,
#   'Revenue Growth': -0.0409,
#   'Gross Profit': 2429200000.0,
#   'Profit Margin': -0.078,
#   'grossProfitMargin': 0.28037534192819,
#   'netProfitMargin': -0.07813852564028599,
#   'Total assets': 13390600000.0,
#   'Total debt': 5454700000.0,
#   'Total liabilities': 9595800000.0,
#   'EPS': -1.57,
#   'Dividend per Share': 1.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'PEP',
#   'Revenue': 62799000000.0,
#   'Revenue Growth': -0.0041,
#   'Gross Profit': 34577000000.0,
#   'Profit Margin': 0.101,
#   'grossProfitMargin': 0.55059793945763,
#   'netProfitMargin': 0.10078185958375,
#   'Total assets': 73490000000.0,
#   'Total debt': 36945000000.0,
#   'Total liabilities': 62291000000.0,
#   'EPS': 4.39,
#   'Dividend per Share': 2.96,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'COST',
#   'Revenue': 118719000000.0,
#   'Revenue Growth': 0.0217,
#   'Gross Profit': 15818000000.0,
#   'Profit Margin': 0.02,
#   'grossProfitMargin': 0.13323899291605,
#   'netProfitMargin': 0.019794641127368,
#   'Total assets': 33163000000.0,
#   'Total debt': 5161000000.0,
#   'Total liabilities': 20831000000.0,
#   'EPS': 5.36,
#   'Dividend per Share': 1.7,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'COTY',
#   'Revenue': 4349100000.0,
#   'Revenue Growth': -0.0105,
#   'Gross Profit': 2603100000.0,
#   'Profit Margin': 0.036000000000000004,
#   'grossProfitMargin': 0.5985376284748599,
#   'netProfitMargin': 0.036076429606125,
#   'Total assets': 7035600000.0,
#   'Total debt': 4098200000.0,
#   'Total liabilities': 6595200000.0,
#   'EPS': 0.45,
#   'Dividend per Share': 0.25,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MNST',
#   'Revenue': 3049393000.0,
#   'Revenue Growth': 0.12,
#   'Gross Profit': 1942000000.0,
#   'Profit Margin': 0.234,
#   'grossProfitMargin': 0.6368480546784201,
#   'netProfitMargin': 0.2337137259776,
#   'Total assets': 4153471000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 823762000.0,
#   'EPS': 1.21,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'SJM',
#   'Revenue': 7811200000.0,
#   'Revenue Growth': 0.3721,
#   'Gross Profit': 2967800000.0,
#   'Profit Margin': 0.08800000000000001,
#   'grossProfitMargin': 0.37994162228595,
#   'netProfitMargin': 0.088168271200328,
#   'Total assets': 15984100000.0,
#   'Total debt': 5430000000.0,
#   'Total liabilities': 8975600000.0,
#   'EPS': 5.77,
#   'Dividend per Share': 2.65,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CL',
#   'Revenue': 15195000000.0,
#   'Revenue Growth': -0.0523,
#   'Gross Profit': 9123000000.0,
#   'Profit Margin': 0.161,
#   'grossProfitMargin': 0.60039486673248,
#   'netProfitMargin': 0.16064494899638002,
#   'Total assets': 12123000000.0,
#   'Total debt': 6533000000.0,
#   'Total liabilities': 12106000000.0,
#   'EPS': 2.74,
#   'Dividend per Share': 1.55,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'ADM',
#   'Revenue': 62346000000.0,
#   'Revenue Growth': -0.0791,
#   'Gross Profit': 3618000000.0,
#   'Profit Margin': 0.021,
#   'grossProfitMargin': 0.05803098835530701,
#   'netProfitMargin': 0.020514547845892,
#   'Total assets': 39769000000.0,
#   'Total debt': 6931000000.0,
#   'Total liabilities': 22588000000.0,
#   'EPS': 2.18,
#   'Dividend per Share': 1.2,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'DG',
#   'Revenue': 20368562000.0,
#   'Revenue Growth': 0.0772,
#   'Gross Profit': 6306091000.0,
#   'Profit Margin': 0.057,
#   'grossProfitMargin': 0.30959922453043,
#   'netProfitMargin': 0.05719991426002501,
#   'Total assets': 11257885000.0,
#   'Total debt': 2970554000.0,
#   'Total liabilities': 5880009000.0,
#   'EPS': 3.96,
#   'Dividend per Share': 0.88,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TAP',
#   'Revenue': 4885000000.0,
#   'Revenue Growth': 0.3693,
#   'Gross Profit': 1886000000.0,
#   'Profit Margin': 0.326,
#   'grossProfitMargin': 0.38607983623337,
#   'netProfitMargin': 0.32628454452405,
#   'Total assets': 29341500000.0,
#   'Total debt': 12072500000.0,
#   'Total liabilities': 17719800000.0,
#   'EPS': 7.52,
#   'Dividend per Share': 1.64,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'SYY',
#   'Revenue': 50366919000.0,
#   'Revenue Growth': 0.0346,
#   'Gross Profit': 9040472000.0,
#   'Profit Margin': 0.019,
#   'grossProfitMargin': 0.17949225760662,
#   'netProfitMargin': 0.01885408158478,
#   'Total assets': 16721804000.0,
#   'Total debt': 7435402000.0,
#   'Total liabilities': 13242196000.0,
#   'EPS': 1.66,
#   'Dividend per Share': 1.53,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CHD',
#   'Revenue': 3493100000.0,
#   'Revenue Growth': 0.029,
#   'Gross Profit': 1590600000.0,
#   'Profit Margin': 0.131,
#   'grossProfitMargin': 0.4553548424036,
#   'netProfitMargin': 0.13140190661589998,
#   'Total assets': 4354100000.0,
#   'Total debt': 1120200000.0,
#   'Total liabilities': 2376200000.0,
#   'EPS': 1.78,
#   'Dividend per Share': 0.71,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'STZ',
#   'Revenue': 6548400000.0,
#   'Revenue Growth': 0.0863,
#   'Gross Profit': 2942300000.0,
#   'Profit Margin': 0.161,
#   'grossProfitMargin': 0.44931586341702,
#   'netProfitMargin': 0.16109278602407,
#   'Total assets': 16965000000.0,
#   'Total debt': 8081200000.0,
#   'Total liabilities': 10273200000.0,
#   'EPS': 5.42,
#   'Dividend per Share': 1.24,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'EL',
#   'Revenue': 11262000000.0,
#   'Revenue Growth': 0.0447,
#   'Gross Profit': 9081000000.0,
#   'Profit Margin': 0.099,
#   'grossProfitMargin': 0.80633990410229,
#   'netProfitMargin': 0.099005505238856,
#   'Total assets': 9223000000.0,
#   'Total debt': 2242000000.0,
#   'Total liabilities': 5636000000.0,
#   'EPS': 3.01,
#   'Dividend per Share': 1.14,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'DLTR',
#   'Revenue': 15498400000.0,
#   'Revenue Growth': 0.8017,
#   'Gross Profit': 4656700000.0,
#   'Profit Margin': 0.018000000000000002,
#   'grossProfitMargin': 0.30046327362825,
#   'netProfitMargin': 0.018221235740464,
#   'Total assets': 15901200000.0,
#   'Total debt': 7346400000.0,
#   'Total liabilities': 11494300000.0,
#   'EPS': 1.27,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TSN',
#   'Revenue': 36881000000.0,
#   'Revenue Growth': -0.1086,
#   'Gross Profit': 4697000000.0,
#   'Profit Margin': 0.048,
#   'grossProfitMargin': 0.12735554892763,
#   'netProfitMargin': 0.047937962636588,
#   'Total assets': 22373000000.0,
#   'Total debt': 6279000000.0,
#   'Total liabilities': 12749000000.0,
#   'EPS': 4.67,
#   'Dividend per Share': 0.6,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MKC',
#   'Revenue': 4411500000.0,
#   'Revenue Growth': 0.0268,
#   'Gross Profit': 1831700000.0,
#   'Profit Margin': 0.099,
#   'grossProfitMargin': 0.41521024594809,
#   'netProfitMargin': 0.098877932675961,
#   'Total assets': 4635900000.0,
#   'Total debt': 1447200000.0,
#   'Total liabilities': 2997800000.0,
#   'EPS': 3.73,
#   'Dividend per Share': 1.72,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'HSY',
#   'Revenue': 7440181000.0,
#   'Revenue Growth': 0.0073,
#   'Gross Profit': 3169539000.0,
#   'Profit Margin': 0.097,
#   'grossProfitMargin': 0.42600294267035,
#   'netProfitMargin': 0.096777753121866,
#   'Total assets': 5524333000.0,
#   'Total debt': 2980169000.0,
#   'Total liabilities': 4696646000.0,
#   'EPS': 3.15,
#   'Dividend per Share': 2.402,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CLX',
#   'Revenue': 5761000000.0,
#   'Revenue Growth': 0.0187,
#   'Gross Profit': 2598000000.0,
#   'Profit Margin': 0.112,
#   'grossProfitMargin': 0.45096337441416,
#   'netProfitMargin': 0.11248047214025,
#   'Total assets': 4510000000.0,
#   'Total debt': 2312000000.0,
#   'Total liabilities': 4213000000.0,
#   'EPS': 5.01,
#   'Dividend per Share': 3.08,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'FCX',
#   'Revenue': 14830000000.0,
#   'Revenue Growth': 0.0153,
#   'Gross Profit': -2704000000.0,
#   'Profit Margin': -0.28,
#   'grossProfitMargin': -0.18233310856372,
#   'netProfitMargin': -0.28671611598112,
#   'Total assets': 37317000000.0,
#   'Total debt': 16027000000.0,
#   'Total liabilities': 28060000000.0,
#   'EPS': -3.16,
#   'Dividend per Share': 0.0,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'NUE',
#   'Revenue': 16208122000.0,
#   'Revenue Growth': -0.0141,
#   'Gross Profit': 2025907000.0,
#   'Profit Margin': 0.049,
#   'grossProfitMargin': 0.12499332124968,
#   'netProfitMargin': 0.049127900197197,
#   'Total assets': 15223518000.0,
#   'Total debt': 4357100000.0,
#   'Total liabilities': 6968810000.0,
#   'EPS': 2.48,
#   'Dividend per Share': 1.5019999999999998,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'JCI',
#   'Revenue': 20837000000.0,
#   'Revenue Growth': 0.2185,
#   'Gross Profit': 5654000000.0,
#   'Profit Margin': -0.042,
#   'grossProfitMargin': 0.27134424341316,
#   'netProfitMargin': -0.041656668426357,
#   'Total assets': 63179000000.0,
#   'Total debt': 12759000000.0,
#   'Total liabilities': 38089000000.0,
#   'EPS': -1.3,
#   'Dividend per Share': 1.16,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MAS',
#   'Revenue': 7361000000.0,
#   'Revenue Growth': 0.0307,
#   'Gross Profit': 2462000000.0,
#   'Profit Margin': 0.067,
#   'grossProfitMargin': 0.33446542589322,
#   'netProfitMargin': 0.066974595842956,
#   'Total assets': 5137000000.0,
#   'Total debt': 2997000000.0,
#   'Total liabilities': 5240000000.0,
#   'EPS': 1.49,
#   'Dividend per Share': 0.385,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'WY',
#   'Revenue': 6365000000.0,
#   'Revenue Growth': 0.2133,
#   'Gross Profit': 1438000000.0,
#   'Profit Margin': 0.158,
#   'grossProfitMargin': 0.22592301649647,
#   'netProfitMargin': 0.16135113904163,
#   'Total assets': 19243000000.0,
#   'Total debt': 7121000000.0,
#   'Total liabilities': 10063000000.0,
#   'EPS': 1.4,
#   'Dividend per Share': 1.24,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'CF',
#   'Revenue': 3685000000.0,
#   'Revenue Growth': -0.1446,
#   'Gross Profit': 843000000.0,
#   'Profit Margin': -0.075,
#   'grossProfitMargin': 0.22876526458616,
#   'netProfitMargin': -0.07516960651289001,
#   'Total assets': 15131000000.0,
#   'Total debt': 5778000000.0,
#   'Total liabilities': 8639000000.0,
#   'EPS': -1.19,
#   'Dividend per Share': 1.2,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'LYB',
#   'Revenue': 29183000000.0,
#   'Revenue Growth': -0.1085,
#   'Gross Profit': 5992000000.0,
#   'Profit Margin': 0.131,
#   'grossProfitMargin': 0.20532501798993,
#   'netProfitMargin': 0.13144639002159,
#   'Total assets': 23442000000.0,
#   'Total debt': 8981000000.0,
#   'Total liabilities': 17369000000.0,
#   'EPS': 9.15,
#   'Dividend per Share': 3.33,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'VMC',
#   'Revenue': 3592667000.0,
#   'Revenue Growth': 0.0498,
#   'Gross Profit': 988885000.0,
#   'Profit Margin': 0.117,
#   'grossProfitMargin': 0.2752509486685,
#   'netProfitMargin': 0.11676311776182,
#   'Total assets': 8471475000.0,
#   'Total debt': 1982889000.0,
#   'Total liabilities': 3898999000.0,
#   'EPS': 3.15,
#   'Dividend per Share': 0.8,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'NEM',
#   'Revenue': 6680000000.0,
#   'Revenue Growth': 0.0978,
#   'Gross Profit': 2942000000.0,
#   'Profit Margin': -0.094,
#   'grossProfitMargin': 0.4404191616766501,
#   'netProfitMargin': -0.09416167664670698,
#   'Total assets': 21031000000.0,
#   'Total debt': 4615000000.0,
#   'Total liabilities': 9157000000.0,
#   'EPS': -1.19,
#   'Dividend per Share': 0.125,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'EMN',
#   'Revenue': 9008000000.0,
#   'Revenue Growth': -0.0663,
#   'Gross Profit': 2357000000.0,
#   'Profit Margin': 0.095,
#   'grossProfitMargin': 0.26165630550622,
#   'netProfitMargin': 0.094804618117229,
#   'Total assets': 15457000000.0,
#   'Total debt': 6594000000.0,
#   'Total liabilities': 10849000000.0,
#   'EPS': 5.8,
#   'Dividend per Share': 1.89,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MLM',
#   'Revenue': 3818749000.0,
#   'Revenue Growth': 0.0789,
#   'Gross Profit': 911738000.0,
#   'Profit Margin': 0.111,
#   'grossProfitMargin': 0.23875305761128,
#   'netProfitMargin': 0.11139407172349,
#   'Total assets': 7300905000.0,
#   'Total debt': 1686189000.0,
#   'Total liabilities': 3158315000.0,
#   'EPS': 6.66,
#   'Dividend per Share': 1.64,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MOS',
#   'Revenue': 7162800000.0,
#   'Revenue Growth': -0.1948,
#   'Gross Profit': 810000000.0,
#   'Profit Margin': 0.042,
#   'grossProfitMargin': 0.11308426872173,
#   'netProfitMargin': 0.041575920031273,
#   'Total assets': 16840700000.0,
#   'Total debt': 3818200000.0,
#   'Total liabilities': 7218200000.0,
#   'EPS': 0.85,
#   'Dividend per Share': 1.1,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'FMC',
#   'Revenue': 2538900000.0,
#   'Revenue Growth': 0.0192,
#   'Gross Profit': 931200000.0,
#   'Profit Margin': 0.08199999999999999,
#   'grossProfitMargin': 0.3667730119343,
#   'netProfitMargin': 0.08235850171334,
#   'Total assets': 6139300000.0,
#   'Total debt': 1997500000.0,
#   'Total liabilities': 4146300000.0,
#   'EPS': 1.56,
#   'Dividend per Share': 0.66,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'ALB',
#   'Revenue': 2677203000.0,
#   'Revenue Growth': -0.0528,
#   'Gross Profit': 970306000.0,
#   'Profit Margin': 0.24,
#   'grossProfitMargin': 0.36243273296795,
#   'netProfitMargin': 0.24042816327339,
#   'Total assets': 8161207000.0,
#   'Total debt': 2369262000.0,
#   'Total liabilities': 4218603000.0,
#   'EPS': 5.73,
#   'Dividend per Share': 1.22,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'ECL',
#   'Revenue': 13151800000.0,
#   'Revenue Growth': -0.029,
#   'Gross Profit': 5617900000.0,
#   'Profit Margin': 0.093,
#   'grossProfitMargin': 0.4271582597059001,
#   'netProfitMargin': 0.093447284782311,
#   'Total assets': 18330200000.0,
#   'Total debt': 6687000000.0,
#   'Total liabilities': 11359300000.0,
#   'EPS': 4.2,
#   'Dividend per Share': 1.42,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'PPG',
#   'Revenue': 14270000000.0,
#   'Revenue Growth': 0.002,
#   'Gross Profit': 6605000000.0,
#   'Profit Margin': 0.061,
#   'grossProfitMargin': 0.46285914505957,
#   'netProfitMargin': 0.06117729502452701,
#   'Total assets': 15771000000.0,
#   'Total debt': 4416000000.0,
#   'Total liabilities': 10856000000.0,
#   'EPS': 3.29,
#   'Dividend per Share': 1.56,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'SHW',
#   'Revenue': 11855602000.0,
#   'Revenue Growth': 0.0455,
#   'Gross Profit': 5921258000.0,
#   'Profit Margin': 0.096,
#   'grossProfitMargin': 0.49944810900366,
#   'netProfitMargin': 0.095541584476267,
#   'Total assets': 6752521000.0,
#   'Total debt': 1952540000.0,
#   'Total liabilities': 4874080000.0,
#   'EPS': 12.33,
#   'Dividend per Share': 3.36,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'IFF',
#   'Revenue': 3116350000.0,
#   'Revenue Growth': 0.0308,
#   'Gross Profit': 1395563000.0,
#   'Profit Margin': 0.13,
#   'grossProfitMargin': 0.4478197249988,
#   'netProfitMargin': 0.12996967606333998,
#   'Total assets': 4016984000.0,
#   'Total debt': 1325371000.0,
#   'Total liabilities': 2385850000.0,
#   'EPS': 5.07,
#   'Dividend per Share': 2.4,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'APD',
#   'Revenue': 7503700000.0,
#   'Revenue Growth': -0.041,
#   'Gross Profit': 2326400000.0,
#   'Profit Margin': 0.084,
#   'grossProfitMargin': 0.31003371669976,
#   'netProfitMargin': 0.08410517478044201,
#   'Total assets': 18028600000.0,
#   'Total debt': 5210900000.0,
#   'Total liabilities': 10815200000.0,
#   'EPS': 2.92,
#   'Dividend per Share': 3.39,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'PFE',
#   'Revenue': 52824000000.0,
#   'Revenue Growth': 0.0813,
#   'Gross Profit': 40502000000.0,
#   'Profit Margin': 0.13699999999999998,
#   'grossProfitMargin': 0.76673481750719,
#   'netProfitMargin': 0.1365856428896,
#   'Total assets': 171615000000.0,
#   'Total debt': 42086000000.0,
#   'Total liabilities': 111776000000.0,
#   'EPS': 1.18,
#   'Dividend per Share': 1.2,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BMY',
#   'Revenue': 19427000000.0,
#   'Revenue Growth': 0.1731,
#   'Gross Profit': 14458000000.0,
#   'Profit Margin': 0.229,
#   'grossProfitMargin': 0.7442219591290501,
#   'netProfitMargin': 0.22942296803418,
#   'Total assets': 33707000000.0,
#   'Total debt': 6708000000.0,
#   'Total liabilities': 17360000000.0,
#   'EPS': 2.67,
#   'Dividend per Share': 1.14,
#   'Sector': 'Healthcare'},
#  {'ticker': 'GILD',
#   'Revenue': 30390000000.0,
#   'Revenue Growth': -0.0689,
#   'Gross Profit': 26129000000.0,
#   'Profit Margin': 0.444,
#   'grossProfitMargin': 0.85978940440935,
#   'netProfitMargin': 0.44425797959855,
#   'Total assets': 56977000000.0,
#   'Total debt': 26346000000.0,
#   'Total liabilities': 37614000000.0,
#   'EPS': 10.08,
#   'Dividend per Share': 1.84,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABBV',
#   'Revenue': 25638000000.0,
#   'Revenue Growth': 0.1216,
#   'Gross Profit': 19806000000.0,
#   'Profit Margin': 0.232,
#   'grossProfitMargin': 0.7725251579686401,
#   'netProfitMargin': 0.23219439893907,
#   'Total assets': 66099000000.0,
#   'Total debt': 36842000000.0,
#   'Total liabilities': 61463000000.0,
#   'EPS': 3.65,
#   'Dividend per Share': 2.28,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MRK',
#   'Revenue': 39807000000.0,
#   'Revenue Growth': 0.0078,
#   'Gross Profit': 25777000000.0,
#   'Profit Margin': 0.098,
#   'grossProfitMargin': 0.64754942598036,
#   'netProfitMargin': 0.098475142562866,
#   'Total assets': 95377000000.0,
#   'Total debt': 24842000000.0,
#   'Total liabilities': 55069000000.0,
#   'EPS': 1.42,
#   'Dividend per Share': 1.85,
#   'Sector': 'Healthcare'},
#  {'ticker': 'JNJ',
#   'Revenue': 70074000000.0,
#   'Revenue Growth': -0.0573,
#   'Gross Profit': 48538000000.0,
#   'Profit Margin': 0.22,
#   'grossProfitMargin': 0.6926677512344102,
#   'netProfitMargin': 0.23293946399521,
#   'Total assets': 133411000000.0,
#   'Total debt': 18760000000.0,
#   'Total liabilities': 62261000000.0,
#   'EPS': 5.56,
#   'Dividend per Share': 2.76,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BSX',
#   'Revenue': 8386000000.0,
#   'Revenue Growth': 0.1216,
#   'Gross Profit': 5962000000.0,
#   'Profit Margin': 0.041,
#   'grossProfitMargin': 0.7109468161221101,
#   'netProfitMargin': 0.041378487956117004,
#   'Total assets': 18096000000.0,
#   'Total debt': 5484000000.0,
#   'Total liabilities': 11363000000.0,
#   'EPS': 0.26,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABT',
#   'Revenue': 20853000000.0,
#   'Revenue Growth': 0.022,
#   'Gross Profit': 11759000000.0,
#   'Profit Margin': 0.067,
#   'grossProfitMargin': 0.5638996787033,
#   'netProfitMargin': 0.067136623027862,
#   'Total assets': 52666000000.0,
#   'Total debt': 22006000000.0,
#   'Total liabilities': 31949000000.0,
#   'EPS': 0.94,
#   'Dividend per Share': 1.04,
#   'Sector': 'Healthcare'},
#  {'ticker': 'WBA',
#   'Revenue': 117351000000.0,
#   'Revenue Growth': 0.1344,
#   'Gross Profit': 29874000000.0,
#   'Profit Margin': 0.036000000000000004,
#   'grossProfitMargin': 0.25456962445995,
#   'netProfitMargin': 0.035559986706547,
#   'Total assets': 72688000000.0,
#   'Total debt': 19028000000.0,
#   'Total liabilities': 42407000000.0,
#   'EPS': 3.85,
#   'Dividend per Share': 1.455,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MDT',
#   'Revenue': 28833000000.0,
#   'Revenue Growth': 0.4231,
#   'Gross Profit': 19691000000.0,
#   'Profit Margin': 0.123,
#   'grossProfitMargin': 0.6829327506676399,
#   'netProfitMargin': 0.12270662088579,
#   'Total assets': 99644000000.0,
#   'Total debt': 31102000000.0,
#   'Total liabilities': 47581000000.0,
#   'EPS': 2.51,
#   'Dividend per Share': 1.52,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CVS',
#   'Revenue': 177546000000.0,
#   'Revenue Growth': 0.1582,
#   'Gross Profit': 28834000000.0,
#   'Profit Margin': 0.03,
#   'grossProfitMargin': 0.16240298288894,
#   'netProfitMargin': 0.02994716862109,
#   'Total assets': 94462000000.0,
#   'Total debt': 27531000000.0,
#   'Total liabilities': 57628000000.0,
#   'EPS': 4.93,
#   'Dividend per Share': 1.7,
#   'Sector': 'Healthcare'},
#  {'ticker': 'UNH',
#   'Revenue': 184840000000.0,
#   'Revenue Growth': 0.1765,
#   'Gross Profit': 43386000000.0,
#   'Profit Margin': 0.038,
#   'grossProfitMargin': 0.23472192166198,
#   'netProfitMargin': 0.037962562215971,
#   'Total assets': 122810000000.0,
#   'Total debt': 32970000000.0,
#   'Total liabilities': 82621000000.0,
#   'EPS': 7.37,
#   'Dividend per Share': 2.375,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CNC',
#   'Revenue': 40607000000.0,
#   'Revenue Growth': 0.7841,
#   'Gross Profit': 5544000000.0,
#   'Profit Margin': 0.014,
#   'grossProfitMargin': 0.13652818479572,
#   'netProfitMargin': 0.01383997832886,
#   'Total assets': 20197000000.0,
#   'Total debt': 4655000000.0,
#   'Total liabilities': 14143000000.0,
#   'EPS': 1.76,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CI',
#   'Revenue': 39838000000.0,
#   'Revenue Growth': 0.0518,
#   'Gross Profit': 13029000000.0,
#   'Profit Margin': 0.047,
#   'grossProfitMargin': 0.32704955068026004,
#   'netProfitMargin': 0.046864802449922,
#   'Total assets': 59360000000.0,
#   'Total debt': 5032000000.0,
#   'Total liabilities': 45575000000.0,
#   'EPS': 7.31,
#   'Dividend per Share': 0.04,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CELG',
#   'Revenue': 11229000000.0,
#   'Revenue Growth': 0.2132,
#   'Gross Profit': 10791000000.0,
#   'Profit Margin': 0.17800000000000002,
#   'grossProfitMargin': 0.96099385519637,
#   'netProfitMargin': 0.17802119511978,
#   'Total assets': 28086000000.0,
#   'Total debt': 14290000000.0,
#   'Total liabilities': 21486000000.0,
#   'EPS': 2.57,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BIIB',
#   'Revenue': 11448800000.0,
#   'Revenue Growth': 0.0636,
#   'Gross Profit': 9970100000.0,
#   'Profit Margin': 0.32299999999999995,
#   'grossProfitMargin': 0.87084235902453,
#   'netProfitMargin': 0.32342254210048,
#   'Total assets': 22876800000.0,
#   'Total debt': 6517400000.0,
#   'Total liabilities': 10748200000.0,
#   'EPS': 16.96,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MYL',
#   'Revenue': 11076900000.0,
#   'Revenue Growth': 0.1747,
#   'Gross Profit': 4697000000.0,
#   'Profit Margin': 0.043,
#   'grossProfitMargin': 0.42403560562973,
#   'netProfitMargin': 0.043333423611298987,
#   'Total assets': 34726200000.0,
#   'Total debt': 15539300000.0,
#   'Total liabilities': 23608600000.0,
#   'EPS': 0.94,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'XRAY',
#   'Revenue': 3745300000.0,
#   'Revenue Growth': 0.4005,
#   'Gross Profit': 2000900000.0,
#   'Profit Margin': 0.115,
#   'grossProfitMargin': 0.5342429177903,
#   'netProfitMargin': 0.11478386244093,
#   'Total assets': 11555800000.0,
#   'Total debt': 1532200000.0,
#   'Total liabilities': 3429900000.0,
#   'EPS': 1.97,
#   'Dividend per Share': 0.31,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ALXN',
#   'Revenue': 3084100000.0,
#   'Revenue Growth': 0.1844,
#   'Gross Profit': 2825800000.0,
#   'Profit Margin': 0.13,
#   'grossProfitMargin': 0.91624785188548,
#   'netProfitMargin': 0.12950293440549998,
#   'Total assets': 13253300000.0,
#   'Total debt': 3288500000.0,
#   'Total liabilities': 4559500000.0,
#   'EPS': 1.78,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AMGN',
#   'Revenue': 22991000000.0,
#   'Revenue Growth': 0.0614,
#   'Gross Profit': 18829000000.0,
#   'Profit Margin': 0.336,
#   'grossProfitMargin': 0.8189726414684001,
#   'netProfitMargin': 0.33587055804445,
#   'Total assets': 77626000000.0,
#   'Total debt': 34596000000.0,
#   'Total liabilities': 47751000000.0,
#   'EPS': 10.32,
#   'Dividend per Share': 4.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BDX',
#   'Revenue': 12483000000.0,
#   'Revenue Growth': 0.2141,
#   'Gross Profit': 5991000000.0,
#   'Profit Margin': 0.078,
#   'grossProfitMargin': 0.47993270848354,
#   'netProfitMargin': 0.078186333413442,
#   'Total assets': 25586000000.0,
#   'Total debt': 11551000000.0,
#   'Total liabilities': 17953000000.0,
#   'EPS': 4.59,
#   'Dividend per Share': 2.64,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HOLX',
#   'Revenue': 2832700000.0,
#   'Revenue Growth': 0.0472,
#   'Gross Profit': 1563300000.0,
#   'Profit Margin': 0.117,
#   'grossProfitMargin': 0.55187630176157,
#   'netProfitMargin': 0.11677904472764,
#   'Total assets': 7317000000.0,
#   'Total debt': 3345400000.0,
#   'Total liabilities': 5174300000.0,
#   'EPS': 1.18,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ANTM',
#   'Revenue': 84863000000.0,
#   'Revenue Growth': 0.0721,
#   'Gross Profit': 18029000000.0,
#   'Profit Margin': 0.029,
#   'grossProfitMargin': 0.21244829902313,
#   'netProfitMargin': 0.029105735126027,
#   'Total assets': 65083100000.0,
#   'Total debt': 15726900000.0,
#   'Total liabilities': 39982700000.0,
#   'EPS': 9.39,
#   'Dividend per Share': 2.6,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ZBH',
#   'Revenue': 7668400000.0,
#   'Revenue Growth': 0.2785,
#   'Gross Profit': 5286600000.0,
#   'Profit Margin': 0.04,
#   'grossProfitMargin': 0.68940065724271,
#   'netProfitMargin': 0.039890981169475,
#   'Total assets': 26684400000.0,
#   'Total debt': 11241400000.0,
#   'Total liabilities': 17014500000.0,
#   'EPS': 1.53,
#   'Dividend per Share': 0.96,
#   'Sector': 'Healthcare'},
#  {'ticker': 'LLY',
#   'Revenue': 21222100000.0,
#   'Revenue Growth': 0.0633,
#   'Gross Profit': 15512000000.0,
#   'Profit Margin': 0.129,
#   'grossProfitMargin': 0.73093614675268,
#   'netProfitMargin': 0.12899760155686998,
#   'Total assets': 38805900000.0,
#   'Total debt': 10305200000.0,
#   'Total liabilities': 24725400000.0,
#   'EPS': 2.59,
#   'Dividend per Share': 2.04,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HSIC',
#   'Revenue': 11571668000.0,
#   'Revenue Growth': 0.0886,
#   'Gross Profit': 3226473000.0,
#   'Profit Margin': 0.044,
#   'grossProfitMargin': 0.27882523072732,
#   'netProfitMargin': 0.043794723457327,
#   'Total assets': 6760396000.0,
#   'Total debt': 1218856000.0,
#   'Total liabilities': 3351956000.0,
#   'EPS': 3.14,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BAX',
#   'Revenue': 10163000000.0,
#   'Revenue Growth': 0.0196,
#   'Gross Profit': 4116000000.0,
#   'Profit Margin': 0.489,
#   'grossProfitMargin': 0.40499852405786,
#   'netProfitMargin': 0.48853684935551,
#   'Total assets': 15546000000.0,
#   'Total debt': 2782000000.0,
#   'Total liabilities': 7266000000.0,
#   'EPS': 9.09,
#   'Dividend per Share': 0.505,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AGN',
#   'Revenue': 14570600000.0,
#   'Revenue Growth': 0.1484,
#   'Gross Profit': 12709800000.0,
#   'Profit Margin': 1.009,
#   'grossProfitMargin': 0.87229077731871,
#   'netProfitMargin': 1.027644709209,
#   'Total assets': 128986300000.0,
#   'Total debt': 32768700000.0,
#   'Total liabilities': 52785800000.0,
#   'EPS': 38.18,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HCA',
#   'Revenue': 41490000000.0,
#   'Revenue Growth': 0.0457,
#   'Gross Profit': 15660000000.0,
#   'Profit Margin': 0.07,
#   'grossProfitMargin': 0.37744034707158,
#   'netProfitMargin': 0.069655338635816,
#   'Total assets': 33758000000.0,
#   'Total debt': 31376000000.0,
#   'Total liabilities': 39391000000.0,
#   'EPS': 7.53,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'VRTX',
#   'Revenue': 1702177000.0,
#   'Revenue Growth': 0.6489,
#   'Gross Profit': 1491717000.0,
#   'Profit Margin': -0.066,
#   'grossProfitMargin': 0.87635833406279,
#   'netProfitMargin': -0.065828641792246,
#   'Total assets': 2896787000.0,
#   'Total debt': 840761000.0,
#   'Total liabilities': 1558596000.0,
#   'EPS': -0.46,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'NKTR',
#   'Revenue': 165436000.0,
#   'Revenue Growth': -0.2832,
#   'Gross Profit': 135221000.0,
#   'Profit Margin': -0.928,
#   'grossProfitMargin': 0.81736139655214,
#   'netProfitMargin': -0.9279963248627902,
#   'Total assets': 568871000.0,
#   'Total debt': 243464000.0,
#   'Total liabilities': 480746000.0,
#   'EPS': -1.1,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'A',
#   'Revenue': 4202000000.0,
#   'Revenue Growth': 0.0406,
#   'Gross Profit': 2197000000.0,
#   'Profit Margin': 0.11,
#   'grossProfitMargin': 0.52284626368396,
#   'netProfitMargin': 0.10994764397906,
#   'Total assets': 7794000000.0,
#   'Total debt': 1904000000.0,
#   'Total liabilities': 3548000000.0,
#   'EPS': 1.42,
#   'Dividend per Share': 0.46,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DHR',
#   'Revenue': 16882400000.0,
#   'Revenue Growth': 0.1697,
#   'Gross Profit': 9334600000.0,
#   'Profit Margin': 0.151,
#   'grossProfitMargin': 0.55291901625361,
#   'netProfitMargin': 0.1512640382884,
#   'Total assets': 45295300000.0,
#   'Total debt': 12269000000.0,
#   'Total liabilities': 22218500000.0,
#   'EPS': 3.69,
#   'Dividend per Share': 26.221,
#   'Sector': 'Healthcare'},
#  {'ticker': 'EVHC',
#   'Revenue': nan,
#   'Revenue Growth': nan,
#   'Gross Profit': nan,
#   'Profit Margin': nan,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': nan,
#   'Total debt': nan,
#   'Total liabilities': nan,
#   'EPS': nan,
#   'Dividend per Share': nan,
#   'Sector': 'Healthcare'},
#  {'ticker': 'PKI',
#   'Revenue': 2104823000.0,
#   'Revenue Growth': 0.0169,
#   'Gross Profit': 964231000.0,
#   'Profit Margin': 0.101,
#   'grossProfitMargin': 0.4581055034081301,
#   'netProfitMargin': 0.1009229754711,
#   'Total assets': 4166295000.0,
#   'Total debt': 1012885000.0,
#   'Total liabilities': 2055854000.0,
#   'EPS': 1.89,
#   'Dividend per Share': 0.28,
#   'Sector': 'Healthcare'},
#  {'ticker': 'UHS',
#   'Revenue': 9766210000.0,
#   'Revenue Growth': 0.0799,
#   'Gross Profit': 9766210000.0,
#   'Profit Margin': 0.07200000000000001,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.07192237316215801,
#   'Total assets': 10317802000.0,
#   'Total debt': 4136125000.0,
#   'Total liabilities': 5720208000.0,
#   'EPS': 7.22,
#   'Dividend per Share': 0.4,
#   'Sector': 'Healthcare'},
#  {'ticker': 'TMO',
#   'Revenue': 18274000000.0,
#   'Revenue Growth': 0.0772,
#   'Gross Profit': 8372000000.0,
#   'Profit Margin': 0.111,
#   'grossProfitMargin': 0.45813724417205,
#   'netProfitMargin': 0.11064900952172,
#   'Total assets': 45908000000.0,
#   'Total debt': 16627000000.0,
#   'Total liabilities': 24368000000.0,
#   'EPS': 5.12,
#   'Dividend per Share': 0.6,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DGX',
#   'Revenue': 7214000000.0,
#   'Revenue Growth': -0.0372,
#   'Gross Profit': 2598000000.0,
#   'Profit Margin': 0.08900000000000001,
#   'grossProfitMargin': 0.36013307457721,
#   'netProfitMargin': 0.08940948156362599,
#   'Total assets': 10100000000.0,
#   'Total debt': 3734000000.0,
#   'Total liabilities': 5440000000.0,
#   'EPS': 4.58,
#   'Dividend per Share': 1.58,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MCK',
#   'Revenue': 190884000000.0,
#   'Revenue Growth': 0.0661,
#   'Gross Profit': 11416000000.0,
#   'Profit Margin': 0.012,
#   'grossProfitMargin': 0.059805955449383,
#   'netProfitMargin': 0.011829173739025,
#   'Total assets': 56523000000.0,
#   'Total debt': 8114000000.0,
#   'Total liabilities': 47515000000.0,
#   'EPS': 9.82,
#   'Dividend per Share': 1.08,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABC',
#   'Revenue': 146849686000.0,
#   'Revenue Growth': 0.0801,
#   'Gross Profit': 4272606000.0,
#   'Profit Margin': 0.01,
#   'grossProfitMargin': 0.029095097962961006,
#   'netProfitMargin': 0.0097237456810088,
#   'Total assets': 33637501000.0,
#   'Total debt': 4462694000.0,
#   'Total liabilities': 31508097000.0,
#   'EPS': 6.73,
#   'Dividend per Share': 1.36,
#   'Sector': 'Healthcare'},
#  {'ticker': 'EW',
#   'Revenue': 2963700000.0,
#   'Revenue Growth': 0.1885,
#   'Gross Profit': 2166300000.0,
#   'Profit Margin': 0.192,
#   'grossProfitMargin': 0.7309444275736401,
#   'netProfitMargin': 0.19215845058542005,
#   'Total assets': 4510000000.0,
#   'Total debt': 822300000.0,
#   'Total liabilities': 1891000000.0,
#   'EPS': 2.67,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ZTS',
#   'Revenue': 4888000000.0,
#   'Revenue Growth': 0.0258,
#   'Gross Profit': 3222000000.0,
#   'Profit Margin': 0.168,
#   'grossProfitMargin': 0.6591653027823199,
#   'netProfitMargin': 0.16796235679214,
#   'Total assets': 7649000000.0,
#   'Total debt': 4468000000.0,
#   'Total liabilities': 6150000000.0,
#   'EPS': 1.66,
#   'Dividend per Share': 0.38,
#   'Sector': 'Healthcare'},
#  {'ticker': 'SYK',
#   'Revenue': 11325000000.0,
#   'Revenue Growth': 0.1386,
#   'Gross Profit': 7504000000.0,
#   'Profit Margin': 0.145,
#   'grossProfitMargin': 0.6626048565121401,
#   'netProfitMargin': 0.14543046357616,
#   'Total assets': 20435000000.0,
#   'Total debt': 6914000000.0,
#   'Total liabilities': 10885000000.0,
#   'EPS': 4.4,
#   'Dividend per Share': 1.565,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ILMN',
#   'Revenue': 2220000000.0,
#   'Revenue Growth': 0.1927,
#   'Gross Profit': 1549000000.0,
#   'Profit Margin': 0.208,
#   'grossProfitMargin': 0.69774774774775,
#   'netProfitMargin': 0.20810810810811,
#   'Total assets': 3687747000.0,
#   'Total debt': 1090578000.0,
#   'Total liabilities': 1839194000.0,
#   'EPS': 3.19,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ISRG',
#   'Revenue': 2706500000.0,
#   'Revenue Growth': 0.1351,
#   'Gross Profit': 1892900000.0,
#   'Profit Margin': 0.273,
#   'grossProfitMargin': 0.69939035654905,
#   'netProfitMargin': 0.27278773323481004,
#   'Total assets': 6486900000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 709100000.0,
#   'EPS': 6.43,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CAH',
#   'Revenue': 121546000000.0,
#   'Revenue Growth': 0.1855,
#   'Gross Profit': 6543000000.0,
#   'Profit Margin': 0.012,
#   'grossProfitMargin': 0.053831471212545,
#   'netProfitMargin': 0.011740411037796002,
#   'Total assets': 34122000000.0,
#   'Total debt': 5539000000.0,
#   'Total liabilities': 27551000000.0,
#   'EPS': 4.36,
#   'Dividend per Share': 1.61,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DVA',
#   'Revenue': 10707467000.0,
#   'Revenue Growth': 0.0727,
#   'Gross Profit': 3275885000.0,
#   'Profit Margin': 0.08199999999999999,
#   'grossProfitMargin': 0.30594397349065,
#   'netProfitMargin': 0.082173869879776,
#   'Total assets': 18755776000.0,
#   'Total debt': 9104938000.0,
#   'Total liabilities': 12932777000.0,
#   'EPS': 4.36,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'REGN',
#   'Revenue': 4860400000.0,
#   'Revenue Growth': 0.1844,
#   'Gross Profit': 4560700000.0,
#   'Profit Margin': 0.184,
#   'grossProfitMargin': 0.93833840836145,
#   'netProfitMargin': 0.1842440951362,
#   'Total assets': 6973466000.0,
#   'Total debt': 481126000.0,
#   'Total liabilities': 2524221000.0,
#   'EPS': 8.55,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HUM',
#   'Revenue': 54379000000.0,
#   'Revenue Growth': 0.0017,
#   'Gross Profit': 9372000000.0,
#   'Profit Margin': 0.011,
#   'grossProfitMargin': 0.17234594236745998,
#   'netProfitMargin': 0.011291123411611,
#   'Total assets': 25396000000.0,
#   'Total debt': 4304000000.0,
#   'Total liabilities': 14711000000.0,
#   'EPS': 4.11,
#   'Dividend per Share': 0.87,
#   'Sector': 'Healthcare'},
#  {'ticker': 'RMD',
#   'Revenue': 1838713000.0,
#   'Revenue Growth': 0.0952,
#   'Gross Profit': 1066497000.0,
#   'Profit Margin': 0.192,
#   'grossProfitMargin': 0.5800236360976401,
#   'netProfitMargin': 0.19166068875349,
#   'Total assets': 3256705000.0,
#   'Total debt': 1172770000.0,
#   'Total liabilities': 1561874000.0,
#   'EPS': 2.51,
#   'Dividend per Share': 1.2,
#   'Sector': 'Healthcare'},
#  {'ticker': 'INCY',
#   'Revenue': 1105719000.0,
#   'Revenue Growth': 0.467,
#   'Gross Profit': 1047532000.0,
#   'Profit Margin': 0.094,
#   'grossProfitMargin': 0.94737632255573,
#   'netProfitMargin': 0.094257220867146,
#   'Total assets': 1638597000.0,
#   'Total debt': 651481000.0,
#   'Total liabilities': 1219130000.0,
#   'EPS': 0.55,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'LH',
#   'Revenue': 9552900000.0,
#   'Revenue Growth': 0.1006,
#   'Gross Profit': 2854000000.0,
#   'Profit Margin': 0.075,
#   'grossProfitMargin': 0.29875744538308,
#   'netProfitMargin': 0.07451140491369099,
#   'Total assets': 14247000000.0,
#   'Total debt': 5849500000.0,
#   'Total liabilities': 8726000000.0,
#   'EPS': 6.94,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'COO',
#   'Revenue': 1966800000.0,
#   'Revenue Growth': 0.0944,
#   'Gross Profit': 1173100000.0,
#   'Profit Margin': 0.139,
#   'grossProfitMargin': 0.59645108806183,
#   'netProfitMargin': 0.13926174496644,
#   'Total assets': 4478600000.0,
#   'Total debt': 1333700000.0,
#   'Total liabilities': 1782700000.0,
#   'EPS': 5.65,
#   'Dividend per Share': 0.06,
#   'Sector': 'Healthcare'},
#  {'ticker': 'IDXX',
#   'Revenue': 1775423000.0,
#   'Revenue Growth': 0.1083,
#   'Gross Profit': 975436000.0,
#   'Profit Margin': 0.125,
#   'grossProfitMargin': 0.54941047851695,
#   'netProfitMargin': 0.12506597019414994,
#   'Total assets': 1530704000.0,
#   'Total debt': 1204110000.0,
#   'Total liabilities': 1638917000.0,
#   'EPS': 2.47,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ALGN',
#   'Revenue': 1079874000.0,
#   'Revenue Growth': 0.2772,
#   'Gross Profit': 815294000.0,
#   'Profit Margin': 0.17600000000000002,
#   'grossProfitMargin': 0.7549899340108199,
#   'netProfitMargin': 0.17565197421181,
#   'Total assets': 1396151000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 400762000.0,
#   'EPS': 2.38,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'PRGO',
#   'Revenue': 5280600000.0,
#   'Revenue Growth': 0.2492,
#   'Gross Profit': 2051800000.0,
#   'Profit Margin': -0.76,
#   'grossProfitMargin': 0.38855433094724,
#   'netProfitMargin': -0.7599136461765699,
#   'Total assets': 13870100000.0,
#   'Total debt': 5797300000.0,
#   'Total liabilities': 7912500000.0,
#   'EPS': -28.01,
#   'Dividend per Share': 0.58,
#   'Sector': 'Healthcare'},
#  {'ticker': 'IQV',
#   'Revenue': 6815000000.0,
#   'Revenue Growth': 0.1879,
#   'Gross Profit': 2067000000.0,
#   'Profit Margin': 0.011,
#   'grossProfitMargin': 0.303301540719,
#   'netProfitMargin': 0.010564930300807,
#   'Total assets': 21208000000.0,
#   'Total debt': 7200000000.0,
#   'Total liabilities': 12348000000.0,
#   'EPS': 0.48,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'VAR',
#   'Revenue': 2593700000.0,
#   'Revenue Growth': 0.0414,
#   'Gross Profit': 1104700000.0,
#   'Profit Margin': 0.154,
#   'grossProfitMargin': 0.42591664417627,
#   'netProfitMargin': 0.15394995566179998,
#   'Total assets': 3814800000.0,
#   'Total debt': 665900000.0,
#   'Total liabilities': 2060300000.0,
#   'EPS': 4.19,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MTD',
#   'Revenue': 2508257000.0,
#   'Revenue Growth': 0.0471,
#   'Gross Profit': 1437732000.0,
#   'Profit Margin': 0.153,
#   'grossProfitMargin': 0.57319963624142,
#   'netProfitMargin': 0.15324187274270998,
#   'Total assets': 2166777000.0,
#   'Total debt': 894030000.0,
#   'Total liabilities': 1731834000.0,
#   'EPS': 14.49,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CMCSA',
#   'Revenue': 80736000000.0,
#   'Revenue Growth': 0.0836,
#   'Gross Profit': 80736000000.0,
#   'Profit Margin': 0.107,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.10748612762584,
#   'Total assets': 180500000000.0,
#   'Total debt': 61046000000.0,
#   'Total liabilities': 124326000000.0,
#   'EPS': 1.8,
#   'Dividend per Share': 0.675,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'F',
#   'Revenue': 151800000000.0,
#   'Revenue Growth': 0.015,
#   'Gross Profit': 16758000000.0,
#   'Profit Margin': 0.03,
#   'grossProfitMargin': 0.110395256917,
#   'netProfitMargin': 0.030230566534914,
#   'Total assets': 237951000000.0,
#   'Total debt': 142970000000.0,
#   'Total liabilities': 208668000000.0,
#   'EPS': 1.16,
#   'Dividend per Share': 0.85,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'NKE',
#   'Revenue': 32376000000.0,
#   'Revenue Growth': 0.058,
#   'Gross Profit': 14971000000.0,
#   'Profit Margin': 0.116,
#   'grossProfitMargin': 0.46241042747714,
#   'netProfitMargin': 0.1161354089449,
#   'Total assets': 21379000000.0,
#   'Total debt': 2038000000.0,
#   'Total liabilities': 9121000000.0,
#   'EPS': 2.21,
#   'Dividend per Share': 0.46,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'GM',
#   'Revenue': 149184000000.0,
#   'Revenue Growth': 0.0992,
#   'Gross Profit': 19031000000.0,
#   'Profit Margin': 0.063,
#   'grossProfitMargin': 0.1275672994423,
#   'netProfitMargin': 0.063190422565423,
#   'Total assets': 221690000000.0,
#   'Total debt': 75123000000.0,
#   'Total liabilities': 177615000000.0,
#   'EPS': 6.12,
#   'Dividend per Share': 1.52,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'TWX',
#   'Revenue': 29318000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 12942000000.0,
#   'Profit Margin': 0.13391090797462,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 65966000000.0,
#   'Total debt': 22392000000.0,
#   'Total liabilities': 41631000000.0,
#   'EPS': 5.01,
#   'Dividend per Share': nan,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'LOW',
#   'Revenue': 59074000000.0,
#   'Revenue Growth': 0.0507,
#   'Gross Profit': 20570000000.0,
#   'Profit Margin': 0.043,
#   'grossProfitMargin': 0.34820733317534,
#   'netProfitMargin': 0.04309848664387,
#   'Total assets': 31266000000.0,
#   'Total debt': 12649000000.0,
#   'Total liabilities': 23612000000.0,
#   'EPS': 2.73,
#   'Dividend per Share': 1.07,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'MAT',
#   'Revenue': 5453150000.0,
#   'Revenue Growth': -0.0437,
#   'Gross Profit': 2546691000.0,
#   'Profit Margin': 0.057,
#   'grossProfitMargin': 0.4670128274483599,
#   'netProfitMargin': 0.057381146676691,
#   'Total assets': 6493794000.0,
#   'Total debt': 2326439000.0,
#   'Total liabilities': 4086012000.0,
#   'EPS': 0.91,
#   'Dividend per Share': 1.52,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'DIS',
#   'Revenue': 55632000000.0,
#   'Revenue Growth': 0.0604,
#   'Gross Profit': 25639000000.0,
#   'Profit Margin': 0.16899999999999998,
#   'grossProfitMargin': 0.46086784584412,
#   'netProfitMargin': 0.16880572332470994,
#   'Total assets': 92033000000.0,
#   'Total debt': 20170000000.0,
#   'Total liabilities': 44710000000.0,
#   'EPS': 5.76,
#   'Dividend per Share': 1.42,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'LEN',
#   'Revenue': 10949999000.0,
#   'Revenue Growth': 0.1558,
#   'Gross Profit': 1494925000.0,
#   'Profit Margin': 0.083,
#   'grossProfitMargin': 0.13652284351807,
#   'netProfitMargin': 0.083273432262414,
#   'Total assets': 15361781000.0,
#   'Total debt': 4575977000.0,
#   'Total liabilities': 8150214000.0,
#   'EPS': 4.05,
#   'Dividend per Share': 0.16,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'MGM',
#   'Revenue': 9478269000.0,
#   'Revenue Growth': -0.0466,
#   'Gross Profit': 3957048000.0,
#   'Profit Margin': 0.116,
#   'grossProfitMargin': 0.4174863574773,
#   'netProfitMargin': 0.11609799215447,
#   'Total assets': 28173301000.0,
#   'Total debt': 13146623000.0,
#   'Total liabilities': 18203989000.0,
#   'EPS': 1.94,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'CCL',
#   'Revenue': 16389000000.0,
#   'Revenue Growth': 0.043,
#   'Gross Profit': 7006000000.0,
#   'Profit Margin': 0.17,
#   'grossProfitMargin': 0.42748184758069,
#   'netProfitMargin': 0.16956495210201994,
#   'Total assets': 38881000000.0,
#   'Total debt': 9399000000.0,
# ...
#   'Total assets': 2367335000.0,
#   'Total debt': 694391000.0,
#   'Total liabilities': 2306457000.0,
#   'EPS': 2.34,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'GLW',
#   'Revenue': 9390000000.0,
#   'Revenue Growth': 0.0306,
#   'Gross Profit': 3763000000.0,
#   'Profit Margin': 0.394,
#   'grossProfitMargin': 0.40074547390841,
#   'netProfitMargin': 0.39350372736954,
#   'Total assets': 27899000000.0,
#   'Total debt': 3902000000.0,
#   'Total liabilities': 9939000000.0,
#   'EPS': 3.53,
#   'Dividend per Share': 0.54,
#   'Sector': 'Technology'},
#  {'ticker': 'STX',
#   'Revenue': 11160000000.0,
#   'Revenue Growth': -0.1877,
#   'Gross Profit': 2615000000.0,
#   'Profit Margin': 0.022,
#   'grossProfitMargin': 0.23431899641577,
#   'netProfitMargin': 0.022222222222222,
#   'Total assets': 8213000000.0,
#   'Total debt': 4091000000.0,
#   'Total liabilities': 6620000000.0,
#   'EPS': 0.83,
#   'Dividend per Share': 2.43,
#   'Sector': 'Technology'},
#  {'ticker': 'ADBE',
#   'Revenue': 5854430000.0,
#   'Revenue Growth': 0.2208,
#   'Gross Profit': 5034522000.0,
#   'Profit Margin': 0.2,
#   'grossProfitMargin': 0.8599508406454599,
#   'netProfitMargin': 0.19964061403074,
#   'Total assets': 12697246000.0,
#   'Total debt': 1892200000.0,
#   'Total liabilities': 5272411000.0,
#   'EPS': 2.35,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'LRCX',
#   'Revenue': 5885893000.0,
#   'Revenue Growth': 0.1191,
#   'Gross Profit': 2618922000.0,
#   'Profit Margin': 0.155,
#   'grossProfitMargin': 0.4449489652632101,
#   'netProfitMargin': 0.15529487199309,
#   'Total assets': 12264315000.0,
#   'Total debt': 4325862000.0,
#   'Total liabilities': 6162246000.0,
#   'EPS': 5.75,
#   'Dividend per Share': 1.2,
#   'Sector': 'Technology'},
#  {'ticker': 'GOOGL',
#   'Revenue': 90272000000.0,
#   'Revenue Growth': 0.2038,
#   'Gross Profit': 55134000000.0,
#   'Profit Margin': 0.21600000000000005,
#   'grossProfitMargin': 0.6107541651896501,
#   'netProfitMargin': 0.21577011697979,
#   'Total assets': 167497000000.0,
#   'Total debt': 3935000000.0,
#   'Total liabilities': 28461000000.0,
#   'EPS': 28.32,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'FTV',
#   'Revenue': 5378200000.0,
#   'Revenue Growth': -0.1296,
#   'Gross Profit': 2685500000.0,
#   'Profit Margin': 0.162,
#   'grossProfitMargin': 0.49933063106616,
#   'netProfitMargin': 0.16219181138671,
#   'Total assets': 8189800000.0,
#   'Total debt': 3358000000.0,
#   'Total liabilities': 5498800000.0,
#   'EPS': 2.52,
#   'Dividend per Share': 0.14,
#   'Sector': 'Technology'},
#  {'ticker': 'CTSH',
#   'Revenue': 13487000000.0,
#   'Revenue Growth': 0.0863,
#   'Gross Profit': 5379000000.0,
#   'Profit Margin': 0.115,
#   'grossProfitMargin': 0.39882850151998,
#   'netProfitMargin': 0.11514792021947,
#   'Total assets': 14262000000.0,
#   'Total debt': 878000000.0,
#   'Total liabilities': 3534000000.0,
#   'EPS': 2.56,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CTXS',
#   'Revenue': 2736080000.0,
#   'Revenue Growth': 0.034,
#   'Gross Profit': 2331191000.0,
#   'Profit Margin': 0.196,
#   'grossProfitMargin': 0.8520185813280301,
#   'netProfitMargin': 0.19594163913336,
#   'Total assets': 6390227000.0,
#   'Total debt': 1348156000.0,
#   'Total liabilities': 3781500000.0,
#   'EPS': 3.46,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'TTWO',
#   'Revenue': 1413698000.0,
#   'Revenue Growth': 0.3054,
#   'Gross Profit': 599825000.0,
#   'Profit Margin': -0.006,
#   'grossProfitMargin': 0.42429500501522,
#   'netProfitMargin': -0.0058725413772956,
#   'Total assets': 2590277000.0,
#   'Total debt': 497935000.0,
#   'Total liabilities': 2008892000.0,
#   'EPS': -0.1,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'KLAC',
#   'Revenue': 2984493000.0,
#   'Revenue Growth': 0.0606,
#   'Gross Profit': 1821102000.0,
#   'Profit Margin': 0.236,
#   'grossProfitMargin': 0.61018806209296,
#   'netProfitMargin': 0.23602735875072,
#   'Total assets': 4962432000.0,
#   'Total debt': 3057936000.0,
#   'Total liabilities': 4273318000.0,
#   'EPS': 4.52,
#   'Dividend per Share': 2.08,
#   'Sector': 'Technology'},
#  {'ticker': 'GOOG',
#   'Revenue': 90272000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 55134000000.0,
#   'Profit Margin': 0.21577011697979,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 167497000000.0,
#   'Total debt': 3935000000.0,
#   'Total liabilities': 28461000000.0,
#   'EPS': 28.32,
#   'Dividend per Share': nan,
#   'Sector': 'Technology'},
#  {'ticker': 'QRVO',
#   'Revenue': 2610726000.0,
#   'Revenue Growth': 0.5259,
#   'Gross Profit': 1049553000.0,
#   'Profit Margin': -0.011,
#   'grossProfitMargin': 0.40201576113311,
#   'netProfitMargin': -0.011048650835055,
#   'Total assets': 6596819000.0,
#   'Total debt': 988130000.0,
#   'Total liabilities': 1597147000.0,
#   'EPS': -0.2,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'TEL',
#   'Revenue': 11352000000.0,
#   'Revenue Growth': -0.07200000000000001,
#   'Gross Profit': 3827000000.0,
#   'Profit Margin': 0.177,
#   'grossProfitMargin': 0.33712121212121005,
#   'netProfitMargin': 0.17697322057787002,
#   'Total assets': 17608000000.0,
#   'Total debt': 4070000000.0,
#   'Total liabilities': 9123000000.0,
#   'EPS': 5.49,
#   'Dividend per Share': 1.4,
#   'Sector': 'Technology'},
#  {'ticker': 'EA',
#   'Revenue': 4396000000.0,
#   'Revenue Growth': -0.0264,
#   'Gross Profit': 3042000000.0,
#   'Profit Margin': 0.263,
#   'grossProfitMargin': 0.69199272065514,
#   'netProfitMargin': 0.26296633303003,
#   'Total assets': 7050000000.0,
#   'Total debt': 1152000000.0,
#   'Total liabilities': 3652000000.0,
#   'EPS': 3.73,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'INFO',
#   'Revenue': 2734800000.0,
#   'Revenue Growth': 1.4563,
#   'Gross Profit': 1697100000.0,
#   'Profit Margin': 0.056,
#   'grossProfitMargin': 0.620557261957,
#   'netProfitMargin': 0.055872458680708,
#   'Total assets': 13936600000.0,
#   'Total debt': 3383900000.0,
#   'Total liabilities': 5852200000.0,
#   'EPS': 0.49,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CERN',
#   'Revenue': 4796473000.0,
#   'Revenue Growth': 0.0839,
#   'Gross Profit': 4017357000.0,
#   'Profit Margin': 0.133,
#   'grossProfitMargin': 0.83756481064315,
#   'netProfitMargin': 0.13269833896699,
#   'Total assets': 5629963000.0,
#   'Total debt': 563749000.0,
#   'Total liabilities': 1702016000.0,
#   'EPS': 1.88,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'AKAM',
#   'Revenue': 2347988000.0,
#   'Revenue Growth': 0.0685,
#   'Gross Profit': 1538882000.0,
#   'Profit Margin': 0.13699999999999998,
#   'grossProfitMargin': 0.65540454210158,
#   'netProfitMargin': 0.1365965243434,
#   'Total assets': 4373146000.0,
#   'Total debt': 640087000.0,
#   'Total liabilities': 1148776000.0,
#   'EPS': 1.83,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CDNS',
#   'Revenue': 1816083000.0,
#   'Revenue Growth': 0.067,
#   'Gross Profit': 1559591000.0,
#   'Profit Margin': 0.112,
#   'grossProfitMargin': 0.8587663669557,
#   'netProfitMargin': 0.11182638678959,
#   'Total assets': 2096908000.0,
#   'Total debt': 693493000.0,
#   'Total liabilities': 1355138000.0,
#   'EPS': 0.71,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'NTAP',
#   'Revenue': 5546000000.0,
#   'Revenue Growth': -0.0942,
#   'Gross Profit': 3373000000.0,
#   'Profit Margin': 0.041,
#   'grossProfitMargin': 0.6081860800577,
#   'netProfitMargin': 0.041291020555355,
#   'Total assets': 10037000000.0,
#   'Total debt': 2339000000.0,
#   'Total liabilities': 7156000000.0,
#   'EPS': 0.78,
#   'Dividend per Share': 0.72,
#   'Sector': 'Technology'},
#  {'ticker': 'JNPR',
#   'Revenue': 4990100000.0,
#   'Revenue Growth': 0.0272,
#   'Gross Profit': 3104500000.0,
#   'Profit Margin': 0.119,
#   'grossProfitMargin': 0.62213182100559,
#   'netProfitMargin': 0.1187751748462,
#   'Total assets': 9656500000.0,
#   'Total debt': 2133700000.0,
#   'Total liabilities': 4694000000.0,
#   'EPS': 1.55,
#   'Dividend per Share': 0.4,
#   'Sector': 'Technology'},
#  {'ticker': 'MCHP',
#   'Revenue': 2173300000.0,
#   'Revenue Growth': 0.0122,
#   'Gross Profit': 1205500000.0,
#   'Profit Margin': 0.149,
#   'grossProfitMargin': 0.55468642157088,
#   'netProfitMargin': 0.14912805411126,
#   'Total assets': 5537883000.0,
#   'Total debt': 2453405000.0,
#   'Total liabilities': 3386964000.0,
#   'EPS': 1.59,
#   'Dividend per Share': 1.433,
#   'Sector': 'Technology'},
#  {'ticker': 'INTU',
#   'Revenue': 4694000000.0,
#   'Revenue Growth': 0.1198,
#   'Gross Profit': 3964000000.0,
#   'Profit Margin': 0.209,
#   'grossProfitMargin': 0.84448231785258,
#   'netProfitMargin': 0.20856412441415,
#   'Total assets': 4250000000.0,
#   'Total debt': 1000000000.0,
#   'Total liabilities': 3089000000.0,
#   'EPS': 3.73,
#   'Dividend per Share': 1.2,
#   'Sector': 'Technology'},
#  {'ticker': 'XLNX',
#   'Revenue': 2213881000.0,
#   'Revenue Growth': -0.0688,
#   'Gross Profit': 1541974000.0,
#   'Profit Margin': 0.249,
#   'grossProfitMargin': 0.69650265755025,
#   'netProfitMargin': 0.24882412378985,
#   'Total assets': 4819269000.0,
#   'Total debt': 1579056000.0,
#   'Total liabilities': 2229376000.0,
#   'EPS': 2.14,
#   'Dividend per Share': 1.24,
#   'Sector': 'Technology'},
#  {'ticker': 'SWKS',
#   'Revenue': 3289000000.0,
#   'Revenue Growth': 0.0094,
#   'Gross Profit': 1665200000.0,
#   'Profit Margin': 0.303,
#   'grossProfitMargin': 0.5062937062937101,
#   'netProfitMargin': 0.30258437214959005,
#   'Total assets': 3855400000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 314000000.0,
#   'EPS': 5.27,
#   'Dividend per Share': 1.06,
#   'Sector': 'Technology'},
#  {'ticker': 'ADI',
#   'Revenue': 3421409000.0,
#   'Revenue Growth': -0.004,
#   'Gross Profit': 2227173000.0,
#   'Profit Margin': 0.252,
#   'grossProfitMargin': 0.65095199083185,
#   'netProfitMargin': 0.25184478090751,
#   'Total assets': 7970278000.0,
#   'Total debt': 1732177000.0,
#   'Total liabilities': 2804660000.0,
#   'EPS': 2.79,
#   'Dividend per Share': 1.66,
#   'Sector': 'Technology'},
#  {'ticker': 'VRSN',
#   'Revenue': 1142167000.0,
#   'Revenue Growth': 0.0782,
#   'Gross Profit': 943925000.0,
#   'Profit Margin': 0.386,
#   'grossProfitMargin': 0.8264334374920699,
#   'netProfitMargin': 0.38579734837375,
#   'Total assets': 2334572000.0,
#   'Total debt': 1866953000.0,
#   'Total liabilities': 3535167000.0,
#   'EPS': 4.12,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'DXC',
#   'Revenue': 18112000000.0,
#   'Revenue Growth': 1.5488,
#   'Gross Profit': 2564000000.0,
#   'Profit Margin': -0.037000000000000005,
#   'grossProfitMargin': 0.14156360424028,
#   'netProfitMargin': -0.037157685512367006,
#   'Total assets': 7391000000.0,
#   'Total debt': 2834000000.0,
#   'Total liabilities': 5359000000.0,
#   'EPS': 1.82,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'EQIX',
#   'Revenue': 3611989000.0,
#   'Revenue Growth': 0.3251,
#   'Gross Profit': 1791119000.0,
#   'Profit Margin': 0.035,
#   'grossProfitMargin': 0.49588163197618,
#   'netProfitMargin': 0.035105311782511,
#   'Total assets': 12608371000.0,
#   'Total debt': 6759573000.0,
#   'Total liabilities': 8242542000.0,
#   'EPS': 1.81,
#   'Dividend per Share': 7.0,
#   'Sector': 'Technology'},
#  {'ticker': 'FIS',
#   'Revenue': 8831000000.0,
#   'Revenue Growth': 0.3388,
#   'Gross Profit': 2936000000.0,
#   'Profit Margin': 0.059,
#   'grossProfitMargin': 0.33246517948137,
#   'netProfitMargin': 0.059449665949496,
#   'Total assets': 26031000000.0,
#   'Total debt': 10478000000.0,
#   'Total liabilities': 16186000000.0,
#   'EPS': 1.61,
#   'Dividend per Share': 1.04,
#   'Sector': 'Technology'},
#  {'ticker': 'AYI',
#   'Revenue': 3291300000.0,
#   'Revenue Growth': 0.21600000000000005,
#   'Gross Profit': 1436200000.0,
#   'Profit Margin': 0.08800000000000001,
#   'grossProfitMargin': 0.4363625315225,
#   'netProfitMargin': 0.08835414577826403,
#   'Total assets': 2948000000.0,
#   'Total debt': 355200000.0,
#   'Total liabilities': 1288200000.0,
#   'EPS': 6.67,
#   'Dividend per Share': 0.52,
#   'Sector': 'Technology'},
#  {'ticker': 'MSI',
#   'Revenue': 6038000000.0,
#   'Revenue Growth': 0.0602,
#   'Gross Profit': 2869000000.0,
#   'Profit Margin': 0.093,
#   'grossProfitMargin': 0.47515733686651,
#   'netProfitMargin': 0.09274594236502197,
#   'Total assets': 8463000000.0,
#   'Total debt': 4396000000.0,
#   'Total liabilities': 9415000000.0,
#   'EPS': 3.3,
#   'Dividend per Share': 1.7,
#   'Sector': 'Technology'},
#  {'ticker': 'WHR',
#   'Revenue': 20718000000.0,
#   'Revenue Growth': -0.0083,
#   'Gross Profit': 3692000000.0,
#   'Profit Margin': 0.043,
#   'grossProfitMargin': 0.17820252920166002,
#   'netProfitMargin': 0.042861280046337005,
#   'Total assets': 19153000000.0,
#   'Total debt': 4470000000.0,
#   'Total liabilities': 13425000000.0,
#   'EPS': 11.67,
#   'Dividend per Share': 3.9,
#   'Sector': 'Technology'},
#  {'ticker': 'FFIV',
#   'Revenue': 1995034000.0,
#   'Revenue Growth': 0.0392,
#   'Gross Profit': 1657829000.0,
#   'Profit Margin': 0.183,
#   'grossProfitMargin': 0.8309778179219,
#   'netProfitMargin': 0.1833828395907,
#   'Total assets': 2306323000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 1121061000.0,
#   'EPS': 5.43,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'FLIR',
#   'Revenue': 1662167000.0,
#   'Revenue Growth': 0.0675,
#   'Gross Profit': 767121000.0,
#   'Profit Margin': 0.1,
#   'grossProfitMargin': 0.46151860793771,
#   'netProfitMargin': 0.10024624481174002,
#   'Total assets': 2619706000.0,
#   'Total debt': 516921000.0,
#   'Total liabilities': 941380000.0,
#   'EPS': 1.22,
#   'Dividend per Share': 0.48,
#   'Sector': 'Technology'},
#  {'ticker': 'APH',
#   'Revenue': 6286400000.0,
#   'Revenue Growth': 0.1289,
#   'Gross Profit': 2040000000.0,
#   'Profit Margin': 0.131,
#   'grossProfitMargin': 0.32451005344871003,
#   'netProfitMargin': 0.13090162891321006,
#   'Total assets': 8498700000.0,
#   'Total debt': 3010700000.0,
#   'Total liabilities': 4775600000.0,
#   'EPS': 2.67,
#   'Dividend per Share': 0.58,
#   'Sector': 'Technology'},
#  {'ticker': 'WAT',
#   'Revenue': 2167423000.0,
#   'Revenue Growth': 0.0612,
#   'Gross Profit': 1275970000.0,
#   'Profit Margin': 0.241,
#   'grossProfitMargin': 0.5887037278833,
#   'netProfitMargin': 0.2406097010136,
#   'Total assets': 4662059000.0,
#   'Total debt': 1827263000.0,
#   'Total liabilities': 2360110000.0,
#   'EPS': 6.46,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'GRMN',
#   'Revenue': 3045797000.0,
#   'Revenue Growth': 0.08,
#   'Gross Profit': 1688525000.0,
#   'Profit Margin': 0.17,
#   'grossProfitMargin': 0.55437870613176,
#   'netProfitMargin': 0.16997981152388,
#   'Total assets': 4525133000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 1107130000.0,
#   'EPS': 2.74,
#   'Dividend per Share': 2.55,
#   'Sector': 'Technology'},
#  {'ticker': 'AME',
#   'Revenue': 3840087000.0,
#   'Revenue Growth': -0.0338,
#   'Gross Profit': 1254588000.0,
#   'Profit Margin': 0.133,
#   'grossProfitMargin': 0.32670822301682,
#   'netProfitMargin': 0.13337145746958,
#   'Total assets': 7100674000.0,
#   'Total debt': 2341565000.0,
#   'Total liabilities': 3844161000.0,
#   'EPS': 2.2,
#   'Dividend per Share': 0.36,
#   'Sector': 'Technology'},
#  {'ticker': 'ANSS',
#   'Revenue': 988465000.0,
#   'Revenue Growth': 0.0485,
#   'Gross Profit': 841605000.0,
#   'Profit Margin': 0.269,
#   'grossProfitMargin': 0.8514262012311999,
#   'netProfitMargin': 0.26873586824015,
#   'Total assets': 2800526000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 592121000.0,
#   'EPS': 3.05,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'SNPS',
#   'Revenue': 2422532000.0,
#   'Revenue Growth': 0.0804,
#   'Gross Profit': 1879570000.0,
#   'Profit Margin': 0.11,
#   'grossProfitMargin': 0.7758700401068,
#   'netProfitMargin': 0.11014343670176,
#   'Total assets': 5240365000.0,
#   'Total debt': 205000000.0,
#   'Total liabilities': 2045219000.0,
#   'EPS': 1.76,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'IPGP',
#   'Revenue': 1006173000.0,
#   'Revenue Growth': 0.1164,
#   'Gross Profit': 552240000.0,
#   'Profit Margin': 0.259,
#   'grossProfitMargin': 0.54885193699294,
#   'netProfitMargin': 0.25915225314136,
#   'Total assets': 1789999000.0,
#   'Total debt': 40823000.0,
#   'Total liabilities': 232275000.0,
#   'EPS': 4.91,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'}]

# %%
financial2015_dict=top500_2015.to_dict('records')
financial2015_dict
# Out:
# [{'ticker': 'PG',
#   'Revenue': 70749000000.0,
#   'Revenue Growth': -0.0491,
#   'Gross Profit': 33693000000.0,
#   'Profit Margin': 0.099,
#   'grossProfitMargin': 0.47623288,
#   'netProfitMargin': 0.099450169,
#   'Total assets': 129495000000.0,
#   'Total debt': 30345000000.0,
#   'Total liabilities': 66445000000.0,
#   'EPS': 2.5,
#   'Dividend per Share': 2.595,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KR',
#   'Revenue': 108465000000.0,
#   'Revenue Growth': 0.1026,
#   'Gross Profit': 22953000000.0,
#   'Profit Margin': 0.016,
#   'grossProfitMargin': 0.21161665100000002,
#   'netProfitMargin': 0.015931406000000002,
#   'Total assets': 30497000000.0,
#   'Total debt': 11597000000.0,
#   'Total liabilities': 25055000000.0,
#   'EPS': 1.74,
#   'Dividend per Share': 0.34,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'GIS',
#   'Revenue': 17630300000.0,
#   'Revenue Growth': -0.0156,
#   'Gross Profit': 5949200000.0,
#   'Profit Margin': 0.069,
#   'grossProfitMargin': 0.337441791,
#   'netProfitMargin': 0.069272786,
#   'Total assets': 21832000000.0,
#   'Total debt': 9191500000.0,
#   'Total liabilities': 15660400000.0,
#   'EPS': 2.02,
#   'Dividend per Share': 1.67,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'PM',
#   'Revenue': 73908000000.0,
#   'Revenue Growth': -0.0774,
#   'Gross Profit': 17429000000.0,
#   'Profit Margin': 0.09300000000000001,
#   'grossProfitMargin': 0.23582020899999998,
#   'netProfitMargin': 0.09299399300000001,
#   'Total assets': 33956000000.0,
#   'Total debt': 28480000000.0,
#   'Total liabilities': 45432000000.0,
#   'EPS': 4.42,
#   'Dividend per Share': 4.04,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KO',
#   'Revenue': 44294000000.0,
#   'Revenue Growth': -0.037000000000000005,
#   'Gross Profit': 26812000000.0,
#   'Profit Margin': 0.166,
#   'grossProfitMargin': 0.605319005,
#   'netProfitMargin': 0.165959272,
#   'Total assets': 89996000000.0,
#   'Total debt': 44116000000.0,
#   'Total liabilities': 64232000000.0,
#   'EPS': 1.69,
#   'Dividend per Share': 1.32,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'WMT',
#   'Revenue': 485651000000.0,
#   'Revenue Growth': 0.0196,
#   'Gross Profit': 120565000000.0,
#   'Profit Margin': 0.034,
#   'grossProfitMargin': 0.248254405,
#   'netProfitMargin': 0.033692919,
#   'Total assets': 203490000000.0,
#   'Total debt': 50165000000.0,
#   'Total liabilities': 117553000000.0,
#   'EPS': 5.07,
#   'Dividend per Share': 1.92,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MDLZ',
#   'Revenue': 29636000000.0,
#   'Revenue Growth': -0.1346,
#   'Gross Profit': 11512000000.0,
#   'Profit Margin': 0.245,
#   'grossProfitMargin': 0.388446484,
#   'netProfitMargin': 0.24520853,
#   'Total assets': 62843000000.0,
#   'Total debt': 15398000000.0,
#   'Total liabilities': 34743000000.0,
#   'EPS': 4.49,
#   'Dividend per Share': 0.64,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MO',
#   'Revenue': 25434000000.0,
#   'Revenue Growth': 0.0372,
#   'Gross Profit': 11114000000.0,
#   'Profit Margin': 0.20600000000000002,
#   'grossProfitMargin': 0.436974129,
#   'netProfitMargin': 0.20606275100000002,
#   'Total assets': 31459000000.0,
#   'Total debt': 12847000000.0,
#   'Total liabilities': 28549000000.0,
#   'EPS': 2.67,
#   'Dividend per Share': 2.17,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'NWL',
#   'Revenue': 5915700000.0,
#   'Revenue Growth': 0.0329,
#   'Gross Profit': 2304600000.0,
#   'Profit Margin': 0.059000000000000004,
#   'grossProfitMargin': 0.38957350799999996,
#   'netProfitMargin': 0.05916459599999999,
#   'Total assets': 7259500000.0,
#   'Total debt': 3057900000.0,
#   'Total liabilities': 5433100000.0,
#   'EPS': 1.3,
#   'Dividend per Share': 0.76,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KMB',
#   'Revenue': 18591000000.0,
#   'Revenue Growth': -0.0574,
#   'Gross Profit': 6624000000.0,
#   'Profit Margin': 0.054000000000000006,
#   'grossProfitMargin': 0.356301436,
#   'netProfitMargin': 0.054488731,
#   'Total assets': 14842000000.0,
#   'Total debt': 7775000000.0,
#   'Total liabilities': 14802000000.0,
#   'EPS': 2.78,
#   'Dividend per Share': 3.52,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CPB',
#   'Revenue': 8082000000.0,
#   'Revenue Growth': -0.0225,
#   'Gross Profit': 2782000000.0,
#   'Profit Margin': 0.08199999999999999,
#   'grossProfitMargin': 0.34422172700000003,
#   'netProfitMargin': 0.082405345,
#   'Total assets': 8077000000.0,
#   'Total debt': 4082000000.0,
#   'Total liabilities': 6700000000.0,
#   'EPS': 2.13,
#   'Dividend per Share': 1.248,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TGT',
#   'Revenue': 72618000000.0,
#   'Revenue Growth': 0.0188,
#   'Gross Profit': 21340000000.0,
#   'Profit Margin': -0.023,
#   'grossProfitMargin': 0.293866534,
#   'netProfitMargin': -0.02252885,
#   'Total assets': 41172000000.0,
#   'Total debt': 12725000000.0,
#   'Total liabilities': 27175000000.0,
#   'EPS': -2.58,
#   'Dividend per Share': 1.9,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'HRL',
#   'Revenue': 9263863000.0,
#   'Revenue Growth': -0.0056,
#   'Gross Profit': 1808581000.0,
#   'Profit Margin': 0.07400000000000001,
#   'grossProfitMargin': 0.195229679,
#   'netProfitMargin': 0.074060681,
#   'Total assets': 6139831000.0,
#   'Total debt': 435000000.0,
#   'Total liabilities': 2138438000.0,
#   'EPS': 1.3,
#   'Dividend per Share': 0.5,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'K',
#   'Revenue': 14580000000.0,
#   'Revenue Growth': -0.0143,
#   'Gross Profit': 5063000000.0,
#   'Profit Margin': 0.043,
#   'grossProfitMargin': 0.347256516,
#   'netProfitMargin': 0.043347051,
#   'Total assets': 15153000000.0,
#   'Total debt': 7370000000.0,
#   'Total liabilities': 12302000000.0,
#   'EPS': 1.76,
#   'Dividend per Share': 1.9,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CAG',
#   'Revenue': 9034000000.0,
#   'Revenue Growth': -0.2369,
#   'Gross Profit': 2296200000.0,
#   'Profit Margin': -0.027999999999999997,
#   'grossProfitMargin': 0.254173124,
#   'netProfitMargin': -0.027961036,
#   'Total assets': 17437800000.0,
#   'Total debt': 7904500000.0,
#   'Total liabilities': 12827800000.0,
#   'EPS': -0.6,
#   'Dividend per Share': 1.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'PEP',
#   'Revenue': 63056000000.0,
#   'Revenue Growth': -0.0544,
#   'Gross Profit': 34325000000.0,
#   'Profit Margin': 0.086,
#   'grossProfitMargin': 0.5443573970000001,
#   'netProfitMargin': 0.08646282699999999,
#   'Total assets': 69667000000.0,
#   'Total debt': 33284000000.0,
#   'Total liabilities': 57637000000.0,
#   'EPS': 3.71,
#   'Dividend per Share': 2.762,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'COST',
#   'Revenue': 116199000000.0,
#   'Revenue Growth': 0.0316,
#   'Gross Profit': 15134000000.0,
#   'Profit Margin': 0.02,
#   'grossProfitMargin': 0.130242085,
#   'netProfitMargin': 0.020456286,
#   'Total assets': 33017000000.0,
#   'Total debt': 6135000000.0,
#   'Total liabilities': 22174000000.0,
#   'EPS': 5.41,
#   'Dividend per Share': 6.51,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'COTY',
#   'Revenue': 4395200000.0,
#   'Revenue Growth': -0.0344,
#   'Gross Profit': 2638200000.0,
#   'Profit Margin': 0.053,
#   'grossProfitMargin': 0.600245723,
#   'netProfitMargin': 0.052898617,
#   'Total assets': 6018900000.0,
#   'Total debt': 2634700000.0,
#   'Total liabilities': 4947900000.0,
#   'EPS': 0.66,
#   'Dividend per Share': 0.2,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MNST',
#   'Revenue': 2722564000.0,
#   'Revenue Growth': 0.1045,
#   'Gross Profit': 1632301000.0,
#   'Profit Margin': 0.201,
#   'grossProfitMargin': 0.599545502,
#   'netProfitMargin': 0.20081548100000002,
#   'Total assets': 5571277000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 761867000.0,
#   'EPS': 0.97,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'SJM',
#   'Revenue': 5692700000.0,
#   'Revenue Growth': 0.0146,
#   'Gross Profit': 1968700000.0,
#   'Profit Margin': 0.061,
#   'grossProfitMargin': 0.345828869,
#   'netProfitMargin': 0.060586365,
#   'Total assets': 16806300000.0,
#   'Total debt': 6170900000.0,
#   'Total liabilities': 9719400000.0,
#   'EPS': 3.33,
#   'Dividend per Share': 2.5,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CL',
#   'Revenue': 16034000000.0,
#   'Revenue Growth': -0.0719,
#   'Gross Profit': 9399000000.0,
#   'Profit Margin': 0.086,
#   'grossProfitMargin': 0.5861918420000001,
#   'netProfitMargin': 0.08631657699999999,
#   'Total assets': 11935000000.0,
#   'Total debt': 6548000000.0,
#   'Total liabilities': 11979000000.0,
#   'EPS': 1.53,
#   'Dividend per Share': 1.5,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'ADM',
#   'Revenue': 67702000000.0,
#   'Revenue Growth': -0.1662,
#   'Gross Profit': 3966000000.0,
#   'Profit Margin': 0.027000000000000003,
#   'grossProfitMargin': 0.058580249,
#   'netProfitMargin': 0.027310862,
#   'Total assets': 40157000000.0,
#   'Total debt': 5877000000.0,
#   'Total liabilities': 22242000000.0,
#   'EPS': 2.99,
#   'Dividend per Share': 1.12,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'DG',
#   'Revenue': 18909588000.0,
#   'Revenue Growth': 0.0803,
#   'Gross Profit': 5802507000.0,
#   'Profit Margin': 0.055999999999999994,
#   'grossProfitMargin': 0.306855284,
#   'netProfitMargin': 0.05633888,
#   'Total assets': 11208642000.0,
#   'Total debt': 2725123000.0,
#   'Total liabilities': 5498604000.0,
#   'EPS': 3.5,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TAP',
#   'Revenue': 3567500000.0,
#   'Revenue Growth': -0.1396,
#   'Gross Profit': 1435900000.0,
#   'Profit Margin': 0.111,
#   'grossProfitMargin': 0.40249474399999996,
#   'netProfitMargin': 0.110777856,
#   'Total assets': 12276300000.0,
#   'Total debt': 2937400000.0,
#   'Total liabilities': 5213200000.0,
#   'EPS': 2.13,
#   'Dividend per Share': 1.64,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'SYY',
#   'Revenue': 48680752000.0,
#   'Revenue Growth': 0.0465,
#   'Gross Profit': 8551516000.0,
#   'Profit Margin': 0.013999999999999999,
#   'grossProfitMargin': 0.17566524,
#   'netProfitMargin': 0.014107691,
#   'Total assets': 17989281000.0,
#   'Total debt': 7321877000.0,
#   'Total liabilities': 12729057000.0,
#   'EPS': 1.16,
#   'Dividend per Share': 1.18,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CHD',
#   'Revenue': 3394800000.0,
#   'Revenue Growth': 0.0295,
#   'Gross Profit': 1511800000.0,
#   'Profit Margin': 0.121,
#   'grossProfitMargin': 0.445328149,
#   'netProfitMargin': 0.120890774,
#   'Total assets': 4256900000.0,
#   'Total debt': 1050000000.0,
#   'Total liabilities': 2233700000.0,
#   'EPS': 1.57,
#   'Dividend per Share': 0.67,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'STZ',
#   'Revenue': 6028000000.0,
#   'Revenue Growth': 0.2384,
#   'Gross Profit': 2578600000.0,
#   'Profit Margin': 0.139,
#   'grossProfitMargin': 0.427770405,
#   'netProfitMargin': 0.139233577,
#   'Total assets': 15093000000.0,
#   'Total debt': 7296500000.0,
#   'Total liabilities': 9211700000.0,
#   'EPS': 4.4,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'EL',
#   'Revenue': 10780000000.0,
#   'Revenue Growth': -0.0172,
#   'Gross Profit': 8680000000.0,
#   'Profit Margin': 0.10099999999999999,
#   'grossProfitMargin': 0.805194805,
#   'netProfitMargin': 0.101020408,
#   'Total assets': 8226900000.0,
#   'Total debt': 1624900000.0,
#   'Total liabilities': 4572600000.0,
#   'EPS': 2.87,
#   'Dividend per Share': 0.92,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'DLTR',
#   'Revenue': 8602200000.0,
#   'Revenue Growth': 0.0972,
#   'Gross Profit': 3034000000.0,
#   'Profit Margin': 0.07,
#   'grossProfitMargin': 0.35270047200000004,
#   'netProfitMargin': 0.069656599,
#   'Total assets': 3492700000.0,
#   'Total debt': 682700000.0,
#   'Total liabilities': 1707700000.0,
#   'EPS': 2.91,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TSN',
#   'Revenue': 41373000000.0,
#   'Revenue Growth': 0.1009,
#   'Gross Profit': 3917000000.0,
#   'Profit Margin': 0.028999999999999998,
#   'grossProfitMargin': 0.09467527099999999,
#   'netProfitMargin': 0.02948783,
#   'Total assets': 22969000000.0,
#   'Total debt': 6690000000.0,
#   'Total liabilities': 13263000000.0,
#   'EPS': 3.06,
#   'Dividend per Share': 0.375,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MKC',
#   'Revenue': 4296300000.0,
#   'Revenue Growth': 0.0125,
#   'Gross Profit': 1737300000.0,
#   'Profit Margin': 0.085,
#   'grossProfitMargin': 0.40437120299999996,
#   'netProfitMargin': 0.084933547,
#   'Total assets': 4472600000.0,
#   'Total debt': 1394400000.0,
#   'Total liabilities': 2785700000.0,
#   'EPS': 3.14,
#   'Dividend per Share': 1.6,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'HSY',
#   'Revenue': 7386626000.0,
#   'Revenue Growth': -0.0047,
#   'Gross Profit': 3382675000.0,
#   'Profit Margin': 0.069,
#   'grossProfitMargin': 0.45794588799999997,
#   'netProfitMargin': 0.069443207,
#   'Total assets': 5344371000.0,
#   'Total debt': 2420527000.0,
#   'Total liabilities': 4296909000.0,
#   'EPS': 2.19,
#   'Dividend per Share': 2.2359999999999998,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CLX',
#   'Revenue': 5655000000.0,
#   'Revenue Growth': 0.0256,
#   'Gross Profit': 2465000000.0,
#   'Profit Margin': 0.10300000000000001,
#   'grossProfitMargin': 0.435897436,
#   'netProfitMargin': 0.102564103,
#   'Total assets': 4164000000.0,
#   'Total debt': 2191000000.0,
#   'Total liabilities': 4046000000.0,
#   'EPS': 4.45,
#   'Dividend per Share': 2.96,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'FCX',
#   'Revenue': 14607000000.0,
#   'Revenue Growth': -0.2697,
#   'Gross Profit': -12808000000.0,
#   'Profit Margin': -0.838,
#   'grossProfitMargin': -0.8768398709999999,
#   'netProfitMargin': -0.829465325,
#   'Total assets': 46577000000.0,
#   'Total debt': 20324000000.0,
#   'Total liabilities': 33769000000.0,
#   'EPS': -11.31,
#   'Dividend per Share': 0.46299999999999997,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'NUE',
#   'Revenue': 16439276000.0,
#   'Revenue Growth': -0.2211,
#   'Gross Profit': 1113890000.0,
#   'Profit Margin': 0.005,
#   'grossProfitMargin': 0.06775785,
#   'netProfitMargin': 0.004910435,
#   'Total assets': 14326969000.0,
#   'Total debt': 4388460000.0,
#   'Total liabilities': 6477092000.0,
#   'EPS': 0.25,
#   'Dividend per Share': 1.494,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'JCI',
#   'Revenue': 17100000000.0,
#   'Revenue Growth': 0.7269,
#   'Gross Profit': 4531000000.0,
#   'Profit Margin': 0.091,
#   'grossProfitMargin': 0.26497076,
#   'netProfitMargin': 0.09140350900000001,
#   'Total assets': 29622000000.0,
#   'Total debt': 6610000000.0,
#   'Total liabilities': 19124000000.0,
#   'EPS': 2.39,
#   'Dividend per Share': 1.04,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MAS',
#   'Revenue': 7142000000.0,
#   'Revenue Growth': 0.0194,
#   'Gross Profit': 2253000000.0,
#   'Profit Margin': 0.05,
#   'grossProfitMargin': 0.315457855,
#   'netProfitMargin': 0.049705965,
#   'Total assets': 5664000000.0,
#   'Total debt': 3407000000.0,
#   'Total liabilities': 5606000000.0,
#   'EPS': 1.03,
#   'Dividend per Share': 3.585,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'WY',
#   'Revenue': 5246000000.0,
#   'Revenue Growth': -0.0443,
#   'Gross Profit': 1052000000.0,
#   'Profit Margin': 0.08800000000000001,
#   'grossProfitMargin': 0.20053374,
#   'netProfitMargin': 0.096454441,
#   'Total assets': 12720000000.0,
#   'Total debt': 5302000000.0,
#   'Total liabilities': 7851000000.0,
#   'EPS': 0.89,
#   'Dividend per Share': 1.2,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'CF',
#   'Revenue': 4308000000.0,
#   'Revenue Growth': -0.0917,
#   'Gross Profit': 1547000000.0,
#   'Profit Margin': 0.162,
#   'grossProfitMargin': 0.35909935,
#   'netProfitMargin': 0.162488394,
#   'Total assets': 12683000000.0,
#   'Total debt': 5537000000.0,
#   'Total liabilities': 8296000000.0,
#   'EPS': 2.97,
#   'Dividend per Share': 1.2,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'LYB',
#   'Revenue': 32735000000.0,
#   'Revenue Growth': -0.2823,
#   'Gross Profit': 7052000000.0,
#   'Profit Margin': 0.13699999999999998,
#   'grossProfitMargin': 0.215426913,
#   'netProfitMargin': 0.136734382,
#   'Total assets': 22757000000.0,
#   'Total debt': 8028000000.0,
#   'Total liabilities': 16183000000.0,
#   'EPS': 9.62,
#   'Dividend per Share': 3.04,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'VMC',
#   'Revenue': 3422181000.0,
#   'Revenue Growth': 0.1429,
#   'Gross Profit': 857533000.0,
#   'Profit Margin': 0.065,
#   'grossProfitMargin': 0.250580843,
#   'netProfitMargin': 0.064630421,
#   'Total assets': 8301632000.0,
#   'Total debt': 1980464000.0,
#   'Total liabilities': 3847444000.0,
#   'EPS': 1.66,
#   'Dividend per Share': 0.4,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'NEM',
#   'Revenue': 6085000000.0,
#   'Revenue Growth': -0.1076,
#   'Gross Profit': 2507000000.0,
#   'Profit Margin': 0.036000000000000004,
#   'grossProfitMargin': 0.41199671299999996,
#   'netProfitMargin': 0.036154478,
#   'Total assets': 25130000000.0,
#   'Total debt': 5863000000.0,
#   'Total liabilities': 10838000000.0,
#   'EPS': 0.43,
#   'Dividend per Share': 0.1,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'EMN',
#   'Revenue': 9648000000.0,
#   'Revenue Growth': 0.0127,
#   'Gross Profit': 2580000000.0,
#   'Profit Margin': 0.08800000000000001,
#   'grossProfitMargin': 0.267412935,
#   'netProfitMargin': 0.087893864,
#   'Total assets': 15580000000.0,
#   'Total debt': 7008000000.0,
#   'Total liabilities': 11559000000.0,
#   'EPS': 5.71,
#   'Dividend per Share': 1.66,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MLM',
#   'Revenue': 3539570000.0,
#   'Revenue Growth': 0.1966,
#   'Gross Profit': 726920000.0,
#   'Profit Margin': 0.08199999999999999,
#   'grossProfitMargin': 0.205369579,
#   'netProfitMargin': 0.081589572,
#   'Total assets': 6957611000.0,
#   'Total debt': 1579009000.0,
#   'Total liabilities': 2897434000.0,
#   'EPS': 4.31,
#   'Dividend per Share': 1.6,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MOS',
#   'Revenue': 8895300000.0,
#   'Revenue Growth': -0.0177,
#   'Gross Profit': 1717900000.0,
#   'Profit Margin': 0.11199999999999999,
#   'grossProfitMargin': 0.193124459,
#   'netProfitMargin': 0.112463885,
#   'Total assets': 17389500000.0,
#   'Total debt': 3836700000.0,
#   'Total liabilities': 7824500000.0,
#   'EPS': 2.79,
#   'Dividend per Share': 1.075,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'FMC',
#   'Revenue': 2491000000.0,
#   'Revenue Growth': -0.2356,
#   'Gross Profit': 800400000.0,
#   'Profit Margin': 0.196,
#   'grossProfitMargin': 0.32131674,
#   'netProfitMargin': 0.196306704,
#   'Total assets': 6325900000.0,
#   'Total debt': 2216100000.0,
#   'Total liabilities': 4417600000.0,
#   'EPS': 3.66,
#   'Dividend per Share': 0.66,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'ALB',
#   'Revenue': 2826429000.0,
#   'Revenue Growth': 0.1557,
#   'Gross Profit': 860233000.0,
#   'Profit Margin': 0.11800000000000001,
#   'grossProfitMargin': 0.304353302,
#   'netProfitMargin': 0.118490859,
#   'Total assets': 9597954000.0,
#   'Total debt': 3817157000.0,
#   'Total liabilities': 6196641000.0,
#   'EPS': 3.01,
#   'Dividend per Share': 1.16,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'ECL',
#   'Revenue': 13545100000.0,
#   'Revenue Growth': -0.0515,
#   'Gross Profit': 6321600000.0,
#   'Profit Margin': 0.07400000000000001,
#   'grossProfitMargin': 0.466707518,
#   'netProfitMargin': 0.07398247299999999,
#   'Total assets': 18641700000.0,
#   'Total debt': 6465500000.0,
#   'Total liabilities': 11661300000.0,
#   'EPS': 3.38,
#   'Dividend per Share': 1.34,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'PPG',
#   'Revenue': 14241000000.0,
#   'Revenue Growth': -0.0372,
#   'Gross Profit': 6455000000.0,
#   'Profit Margin': 0.099,
#   'grossProfitMargin': 0.45326873100000004,
#   'netProfitMargin': 0.09872902199999999,
#   'Total assets': 17076000000.0,
#   'Total debt': 4307000000.0,
#   'Total liabilities': 12007000000.0,
#   'EPS': 5.18,
#   'Dividend per Share': 1.415,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'SHW',
#   'Revenue': 11339304000.0,
#   'Revenue Growth': 0.0188,
#   'Gross Profit': 5559613000.0,
#   'Profit Margin': 0.09300000000000001,
#   'grossProfitMargin': 0.490295789,
#   'netProfitMargin': 0.092937715,
#   'Total assets': 5778937000.0,
#   'Total debt': 1949894000.0,
#   'Total liabilities': 4911027000.0,
#   'EPS': 11.43,
#   'Dividend per Share': 2.68,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'IFF',
#   'Revenue': 3023189000.0,
#   'Revenue Growth': -0.0212,
#   'Gross Profit': 1351599000.0,
#   'Profit Margin': 0.139,
#   'grossProfitMargin': 0.44707724200000004,
#   'netProfitMargin': 0.13867707199999998,
#   'Total assets': 3702010000.0,
#   'Total debt': 1067722000.0,
#   'Total liabilities': 2107021000.0,
#   'EPS': 5.19,
#   'Dividend per Share': 2.06,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'APD',
#   'Revenue': 7824300000.0,
#   'Revenue Growth': -0.2505,
#   'Gross Profit': 2226100000.0,
#   'Profit Margin': 0.163,
#   'grossProfitMargin': 0.284511074,
#   'netProfitMargin': 0.163324515,
#   'Total assets': 17334500000.0,
#   'Total debt': 5879000000.0,
#   'Total liabilities': 9953400000.0,
#   'EPS': 5.95,
#   'Dividend per Share': 3.2,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'PFE',
#   'Revenue': 48851000000.0,
#   'Revenue Growth': -0.0152,
#   'Gross Profit': 39203000000.0,
#   'Profit Margin': 0.142,
#   'grossProfitMargin': 0.8025014840000001,
#   'netProfitMargin': 0.14247405400000002,
#   'Total assets': 167381000000.0,
#   'Total debt': 38899000000.0,
#   'Total liabilities': 102384000000.0,
#   'EPS': 1.13,
#   'Dividend per Share': 1.12,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BMY',
#   'Revenue': 16560000000.0,
#   'Revenue Growth': 0.0429,
#   'Gross Profit': 12651000000.0,
#   'Profit Margin': 0.095,
#   'grossProfitMargin': 0.763949275,
#   'netProfitMargin': 0.094504831,
#   'Total assets': 31748000000.0,
#   'Total debt': 6689000000.0,
#   'Total liabilities': 17324000000.0,
#   'EPS': 0.94,
#   'Dividend per Share': 1.49,
#   'Sector': 'Healthcare'},
#  {'ticker': 'GILD',
#   'Revenue': 32639000000.0,
#   'Revenue Growth': 0.3113,
#   'Gross Profit': 28633000000.0,
#   'Profit Margin': 0.555,
#   'grossProfitMargin': 0.877263397,
#   'netProfitMargin': 0.5547964089999999,
#   'Total assets': 51716000000.0,
#   'Total debt': 22055000000.0,
#   'Total liabilities': 32603000000.0,
#   'EPS': 12.37,
#   'Dividend per Share': 1.29,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABBV',
#   'Revenue': 22859000000.0,
#   'Revenue Growth': 0.1452,
#   'Gross Profit': 18359000000.0,
#   'Profit Margin': 0.225,
#   'grossProfitMargin': 0.803140995,
#   'netProfitMargin': 0.22503171600000002,
#   'Total assets': 53050000000.0,
#   'Total debt': 31671000000.0,
#   'Total liabilities': 49105000000.0,
#   'EPS': 3.15,
#   'Dividend per Share': 2.02,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MRK',
#   'Revenue': 39498000000.0,
#   'Revenue Growth': -0.0648,
#   'Gross Profit': 24564000000.0,
#   'Profit Margin': 0.11199999999999999,
#   'grossProfitMargin': 0.621904907,
#   'netProfitMargin': 0.11246139,
#   'Total assets': 101677000000.0,
#   'Total debt': 26412000000.0,
#   'Total liabilities': 56910000000.0,
#   'EPS': 1.58,
#   'Dividend per Share': 1.81,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BSX',
#   'Revenue': 7477000000.0,
#   'Revenue Growth': 0.0131,
#   'Gross Profit': 5304000000.0,
#   'Profit Margin': -0.032,
#   'grossProfitMargin': 0.7093754179999999,
#   'netProfitMargin': -0.031964692,
#   'Total assets': 18133000000.0,
#   'Total debt': 5677000000.0,
#   'Total liabilities': 11813000000.0,
#   'EPS': -0.18,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABT',
#   'Revenue': 20405000000.0,
#   'Revenue Growth': 0.0078,
#   'Gross Profit': 11658000000.0,
#   'Profit Margin': 0.217,
#   'grossProfitMargin': 0.571330556,
#   'netProfitMargin': 0.216760598,
#   'Total assets': 41247000000.0,
#   'Total debt': 9001000000.0,
#   'Total liabilities': 19921000000.0,
#   'EPS': 2.94,
#   'Dividend per Share': 0.96,
#   'Sector': 'Healthcare'},
#  {'ticker': 'WBA',
#   'Revenue': 103444000000.0,
#   'Revenue Growth': 0.3541,
#   'Gross Profit': 26753000000.0,
#   'Profit Margin': 0.040999999999999995,
#   'grossProfitMargin': 0.258623023,
#   'netProfitMargin': 0.04079502,
#   'Total assets': 68782000000.0,
#   'Total debt': 14383000000.0,
#   'Total liabilities': 37482000000.0,
#   'EPS': 4.05,
#   'Dividend per Share': 1.3730000000000002,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MDT',
#   'Revenue': 20261000000.0,
#   'Revenue Growth': 0.1915,
#   'Gross Profit': 13952000000.0,
#   'Profit Margin': 0.132,
#   'grossProfitMargin': 0.688613593,
#   'netProfitMargin': 0.13202704699999998,
#   'Total assets': 106685000000.0,
#   'Total debt': 36186000000.0,
#   'Total liabilities': 53455000000.0,
#   'EPS': 2.44,
#   'Dividend per Share': 1.22,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CVS',
#   'Revenue': 153290000000.0,
#   'Revenue Growth': 0.0999,
#   'Gross Profit': 26528000000.0,
#   'Profit Margin': 0.034,
#   'grossProfitMargin': 0.173057603,
#   'netProfitMargin': 0.034164003,
#   'Total assets': 92437000000.0,
#   'Total debt': 27464000000.0,
#   'Total liabilities': 55234000000.0,
#   'EPS': 4.66,
#   'Dividend per Share': 1.4,
#   'Sector': 'Healthcare'},
#  {'ticker': 'UNH',
#   'Revenue': 157107000000.0,
#   'Revenue Growth': 0.2041,
#   'Gross Profit': 37026000000.0,
#   'Profit Margin': 0.037000000000000005,
#   'grossProfitMargin': 0.235673776,
#   'netProfitMargin': 0.037000261,
#   'Total assets': 111254000000.0,
#   'Total debt': 31965000000.0,
#   'Total liabilities': 75793000000.0,
#   'EPS': 6.1,
#   'Dividend per Share': 1.875,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CNC',
#   'Revenue': 22760000000.0,
#   'Revenue Growth': 0.3744,
#   'Gross Profit': 2746000000.0,
#   'Profit Margin': 0.016,
#   'grossProfitMargin': 0.12065026400000001,
#   'netProfitMargin': 0.01559754,
#   'Total assets': 7339000000.0,
#   'Total debt': 1221000000.0,
#   'Total liabilities': 5015000000.0,
#   'EPS': 1.49,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CI',
#   'Revenue': 37876000000.0,
#   'Revenue Growth': 0.0848,
#   'Gross Profit': 12452000000.0,
#   'Profit Margin': 0.055,
#   'grossProfitMargin': 0.328756997,
#   'netProfitMargin': 0.055285669,
#   'Total assets': 57088000000.0,
#   'Total debt': 5169000000.0,
#   'Total liabilities': 44975000000.0,
#   'EPS': 8.17,
#   'Dividend per Share': 0.04,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CELG',
#   'Revenue': 9256000000.0,
#   'Revenue Growth': 0.2067,
#   'Gross Profit': 8836000000.0,
#   'Profit Margin': 0.17300000000000001,
#   'grossProfitMargin': 0.954624028,
#   'netProfitMargin': 0.173076923,
#   'Total assets': 26964400000.0,
#   'Total debt': 14161400000.0,
#   'Total liabilities': 21045400000.0,
#   'EPS': 2.02,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BIIB',
#   'Revenue': 10763800000.0,
#   'Revenue Growth': 0.1093,
#   'Gross Profit': 9523400000.0,
#   'Profit Margin': 0.33,
#   'grossProfitMargin': 0.884761887,
#   'netProfitMargin': 0.329530463,
#   'Total assets': 19504800000.0,
#   'Total debt': 6526300000.0,
#   'Total liabilities': 10129900000.0,
#   'EPS': 15.38,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MYL',
#   'Revenue': 9429300000.0,
#   'Revenue Growth': 0.2215,
#   'Gross Profit': 4216100000.0,
#   'Profit Margin': 0.09,
#   'grossProfitMargin': 0.44712757,
#   'netProfitMargin': 0.089890024,
#   'Total assets': 22267700000.0,
#   'Total debt': 7373900000.0,
#   'Total liabilities': 12501900000.0,
#   'EPS': 1.8,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'XRAY',
#   'Revenue': 2674300000.0,
#   'Revenue Growth': -0.085,
#   'Gross Profit': 1517200000.0,
#   'Profit Margin': 0.094,
#   'grossProfitMargin': 0.567326029,
#   'netProfitMargin': 0.09393112199999999,
#   'Total assets': 4402900000.0,
#   'Total debt': 1153100000.0,
#   'Total liabilities': 2063500000.0,
#   'EPS': 1.79,
#   'Dividend per Share': 0.289,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ALXN',
#   'Revenue': 2604000000.0,
#   'Revenue Growth': 0.1656,
#   'Gross Profit': 2370900000.0,
#   'Profit Margin': 0.055,
#   'grossProfitMargin': 0.910483871,
#   'netProfitMargin': 0.05545314900000001,
#   'Total assets': 13097000000.0,
#   'Total debt': 3571000000.0,
#   'Total liabilities': 4838000000.0,
#   'EPS': 0.68,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AMGN',
#   'Revenue': 21662000000.0,
#   'Revenue Growth': 0.0797,
#   'Gross Profit': 17435000000.0,
#   'Profit Margin': 0.32,
#   'grossProfitMargin': 0.804865663,
#   'netProfitMargin': 0.32033053300000003,
#   'Total assets': 71449000000.0,
#   'Total debt': 31429000000.0,
#   'Total liabilities': 43366000000.0,
#   'EPS': 9.15,
#   'Dividend per Share': 3.16,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BDX',
#   'Revenue': 10282000000.0,
#   'Revenue Growth': 0.2174,
#   'Gross Profit': 4695000000.0,
#   'Profit Margin': 0.068,
#   'grossProfitMargin': 0.456623225,
#   'netProfitMargin': 0.067593853,
#   'Total assets': 26478000000.0,
#   'Total debt': 12822000000.0,
#   'Total liabilities': 19314000000.0,
#   'EPS': 3.43,
#   'Dividend per Share': 2.4,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HOLX',
#   'Revenue': 2705000000.0,
#   'Revenue Growth': 0.0689,
#   'Gross Profit': 1432700000.0,
#   'Profit Margin': 0.049,
#   'grossProfitMargin': 0.529648799,
#   'netProfitMargin': 0.048650647000000005,
#   'Total assets': 7642500000.0,
#   'Total debt': 3612200000.0,
#   'Total liabilities': 5563300000.0,
#   'EPS': 0.47,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ANTM',
#   'Revenue': 79156500000.0,
#   'Revenue Growth': 0.0715,
#   'Gross Profit': 18039600000.0,
#   'Profit Margin': 0.032,
#   'grossProfitMargin': 0.22789789800000002,
#   'netProfitMargin': 0.032340995,
#   'Total assets': 61717800000.0,
#   'Total debt': 15864500000.0,
#   'Total liabilities': 38673700000.0,
#   'EPS': 9.73,
#   'Dividend per Share': 2.5,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ZBH',
#   'Revenue': 5997800000.0,
#   'Revenue Growth': 0.2834,
#   'Gross Profit': 4197200000.0,
#   'Profit Margin': 0.025,
#   'grossProfitMargin': 0.699789923,
#   'netProfitMargin': 0.024508987000000003,
#   'Total assets': 27160600000.0,
#   'Total debt': 11497400000.0,
#   'Total liabilities': 17271200000.0,
#   'EPS': 0.78,
#   'Dividend per Share': 0.88,
#   'Sector': 'Healthcare'},
#  {'ticker': 'LLY',
#   'Revenue': 19958700000.0,
#   'Revenue Growth': 0.0175,
#   'Gross Profit': 14921500000.0,
#   'Profit Margin': 0.121,
#   'grossProfitMargin': 0.747618833,
#   'netProfitMargin': 0.12066918199999999,
#   'Total assets': 35568900000.0,
#   'Total debt': 7978500000.0,
#   'Total liabilities': 20978600000.0,
#   'EPS': 2.27,
#   'Dividend per Share': 2.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HSIC',
#   'Revenue': 10629719000.0,
#   'Revenue Growth': 0.0249,
#   'Gross Profit': 3006954000.0,
#   'Profit Margin': 0.045,
#   'grossProfitMargin': 0.282881796,
#   'netProfitMargin': 0.045067795,
#   'Total assets': 6504740000.0,
#   'Total debt': 809714000.0,
#   'Total liabilities': 3075732000.0,
#   'EPS': 2.89,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BAX',
#   'Revenue': 9968000000.0,
#   'Revenue Growth': -0.0701,
#   'Gross Profit': 4146000000.0,
#   'Profit Margin': 0.09699999999999999,
#   'grossProfitMargin': 0.415930979,
#   'netProfitMargin': 0.09711075400000001,
#   'Total assets': 20962000000.0,
#   'Total debt': 6507000000.0,
#   'Total liabilities': 12097000000.0,
#   'EPS': 1.78,
#   'Dividend per Share': 34.283,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AGN',
#   'Revenue': 12688100000.0,
#   'Revenue Growth': 1.7132,
#   'Gross Profit': 9936300000.0,
#   'Profit Margin': 0.29,
#   'grossProfitMargin': 0.7831196159999999,
#   'netProfitMargin': 0.3085726,
#   'Total assets': 135583000000.0,
#   'Total debt': 42530400000.0,
#   'Total liabilities': 58994000000.0,
#   'EPS': 10.01,
#   'Dividend per Share': 0.1,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HCA',
#   'Revenue': 39678000000.0,
#   'Revenue Growth': 0.0748,
#   'Gross Profit': 14925000000.0,
#   'Profit Margin': 0.054000000000000006,
#   'grossProfitMargin': 0.37615303200000005,
#   'netProfitMargin': 0.053656938,
#   'Total assets': 32744000000.0,
#   'Total debt': 30488000000.0,
#   'Total liabilities': 38790000000.0,
#   'EPS': 5.14,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'VRTX',
#   'Revenue': 1032336000.0,
#   'Revenue Growth': 0.7786,
#   'Gross Profit': 907824000.0,
#   'Profit Margin': -0.539,
#   'grossProfitMargin': 0.879388106,
#   'netProfitMargin': -0.538907875,
#   'Total assets': 2498587000.0,
#   'Total debt': 826238000.0,
#   'Total liabilities': 1404959000.0,
#   'EPS': -2.31,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'NKTR',
#   'Revenue': 230784000.0,
#   'Revenue Growth': 0.1499,
#   'Gross Profit': 196682000.0,
#   'Profit Margin': -0.35200000000000004,
#   'grossProfitMargin': 0.8522341240000001,
#   'netProfitMargin': -0.35174448799999997,
#   'Total assets': 498642000.0,
#   'Total debt': 247528000.0,
#   'Total liabilities': 492213000.0,
#   'EPS': -0.61,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'A',
#   'Revenue': 4038000000.0,
#   'Revenue Growth': -0.0025,
#   'Gross Profit': 2041000000.0,
#   'Profit Margin': 0.099,
#   'grossProfitMargin': 0.505448242,
#   'netProfitMargin': 0.09930658699999999,
#   'Total assets': 7479000000.0,
#   'Total debt': 1655000000.0,
#   'Total liabilities': 3309000000.0,
#   'EPS': 1.2,
#   'Dividend per Share': 16.066,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DHR',
#   'Revenue': 14433700000.0,
#   'Revenue Growth': 0.1218,
#   'Gross Profit': 7771100000.0,
#   'Profit Margin': 0.233,
#   'grossProfitMargin': 0.538399717,
#   'netProfitMargin': 0.232608409,
#   'Total assets': 48222200000.0,
#   'Total debt': 12870400000.0,
#   'Total liabilities': 24458200000.0,
#   'EPS': 4.81,
#   'Dividend per Share': 0.675,
#   'Sector': 'Healthcare'},
#  {'ticker': 'UHS',
#   'Revenue': 9043451000.0,
#   'Revenue Growth': 0.1022,
#   'Gross Profit': 9043451000.0,
#   'Profit Margin': 0.075,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.075250919,
#   'Total assets': 9615444000.0,
#   'Total debt': 3431356000.0,
#   'Total liabilities': 5306283000.0,
#   'EPS': 6.89,
#   'Dividend per Share': 0.4,
#   'Sector': 'Healthcare'},
#  {'ticker': 'TMO',
#   'Revenue': 16965000000.0,
#   'Revenue Growth': 0.0045,
#   'Gross Profit': 7756000000.0,
#   'Profit Margin': 0.11599999999999999,
#   'grossProfitMargin': 0.45717654,
#   'netProfitMargin': 0.116416151,
#   'Total assets': 40834300000.0,
#   'Total debt': 12472000000.0,
#   'Total liabilities': 19484100000.0,
#   'EPS': 4.96,
#   'Dividend per Share': 0.6,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DGX',
#   'Revenue': 7493000000.0,
#   'Revenue Growth': 0.0078,
#   'Gross Profit': 2836000000.0,
#   'Profit Margin': 0.095,
#   'grossProfitMargin': 0.37848658700000004,
#   'netProfitMargin': 0.09462164699999999,
#   'Total assets': 9962000000.0,
#   'Total debt': 3651000000.0,
#   'Total liabilities': 5249000000.0,
#   'EPS': 4.92,
#   'Dividend per Share': 1.47,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MCK',
#   'Revenue': 179045000000.0,
#   'Revenue Growth': 0.3032,
#   'Gross Profit': 11411000000.0,
#   'Profit Margin': 0.008,
#   'grossProfitMargin': 0.063732581,
#   'netProfitMargin': 0.008243738,
#   'Total assets': 53870000000.0,
#   'Total debt': 9844000000.0,
#   'Total liabilities': 45785000000.0,
#   'EPS': 6.37,
#   'Dividend per Share': 0.96,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABC',
#   'Revenue': 135962000000.0,
#   'Revenue Growth': 0.1371,
#   'Gross Profit': 3529313000.0,
#   'Profit Margin': -0.001,
#   'grossProfitMargin': 0.025958121,
#   'netProfitMargin': -0.001016205,
#   'Total assets': 27962982000.0,
#   'Total debt': 3739225000.0,
#   'Total liabilities': 27346596000.0,
#   'EPS': -0.63,
#   'Dividend per Share': 1.16,
#   'Sector': 'Healthcare'},
#  {'ticker': 'EW',
#   'Revenue': 2493700000.0,
#   'Revenue Growth': 0.0735,
#   'Gross Profit': 1876500000.0,
#   'Profit Margin': 0.198,
#   'grossProfitMargin': 0.7524962909999999,
#   'netProfitMargin': 0.19846012,
#   'Total assets': 4056300000.0,
#   'Total debt': 596900000.0,
#   'Total liabilities': 1553200000.0,
#   'EPS': 2.3,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ZTS',
#   'Revenue': 4765000000.0,
#   'Revenue Growth': -0.0042,
#   'Gross Profit': 3027000000.0,
#   'Profit Margin': 0.071,
#   'grossProfitMargin': 0.635257083,
#   'netProfitMargin': 0.071143757,
#   'Total assets': 7913000000.0,
#   'Total debt': 4868000000.0,
#   'Total liabilities': 6822000000.0,
#   'EPS': 0.68,
#   'Dividend per Share': 0.332,
#   'Sector': 'Healthcare'},
#  {'ticker': 'SYK',
#   'Revenue': 9946000000.0,
#   'Revenue Growth': 0.027999999999999997,
#   'Gross Profit': 6602000000.0,
#   'Profit Margin': 0.145,
#   'grossProfitMargin': 0.663784436,
#   'netProfitMargin': 0.144681279,
#   'Total assets': 16223000000.0,
#   'Total debt': 3998000000.0,
#   'Total liabilities': 7712000000.0,
#   'EPS': 3.82,
#   'Dividend per Share': 1.415,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ISRG',
#   'Revenue': 2384400000.0,
#   'Revenue Growth': 0.1185,
#   'Gross Profit': 1577900000.0,
#   'Profit Margin': 0.247,
#   'grossProfitMargin': 0.661759772,
#   'netProfitMargin': 0.246938433,
#   'Total assets': 4907300000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 587800000.0,
#   'EPS': 5.29,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CAH',
#   'Revenue': 102531000000.0,
#   'Revenue Growth': 0.1257,
#   'Gross Profit': 5712000000.0,
#   'Profit Margin': 0.012,
#   'grossProfitMargin': 0.05570998,
#   'netProfitMargin': 0.011850075,
#   'Total assets': 30142000000.0,
#   'Total debt': 5492000000.0,
#   'Total liabilities': 23886000000.0,
#   'EPS': 3.66,
#   'Dividend per Share': 1.415,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DVA',
#   'Revenue': 9982245000.0,
#   'Revenue Growth': -0.2198,
#   'Gross Profit': 3126183000.0,
#   'Profit Margin': 0.027000000000000003,
#   'grossProfitMargin': 0.313174341,
#   'netProfitMargin': 0.027021176,
#   'Total assets': 18514875000.0,
#   'Total debt': 9130345000.0,
#   'Total liabilities': 12566637000.0,
#   'EPS': 1.27,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'REGN',
#   'Revenue': 4103728000.0,
#   'Revenue Growth': 0.4555,
#   'Gross Profit': 3711019000.0,
#   'Profit Margin': 0.155,
#   'grossProfitMargin': 0.90430433,
#   'netProfitMargin': 0.154994678,
#   'Total assets': 5609132000.0,
#   'Total debt': 362919000.0,
#   'Total liabilities': 1954295000.0,
#   'EPS': 6.17,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HUM',
#   'Revenue': 54289000000.0,
#   'Revenue Growth': 0.1194,
#   'Gross Profit': 10020000000.0,
#   'Profit Margin': 0.024,
#   'grossProfitMargin': 0.18456777600000002,
#   'netProfitMargin': 0.023503841,
#   'Total assets': 24678000000.0,
#   'Total debt': 4394000000.0,
#   'Total liabilities': 14332000000.0,
#   'EPS': 8.54,
#   'Dividend per Share': 1.15,
#   'Sector': 'Healthcare'},
#  {'ticker': 'RMD',
#   'Revenue': 1678912000.0,
#   'Revenue Growth': 0.0797,
#   'Gross Profit': 1011396000.0,
#   'Profit Margin': 0.21,
#   'grossProfitMargin': 0.602411562,
#   'netProfitMargin': 0.210187312,
#   'Total assets': 2181774000.0,
#   'Total debt': 300594000.0,
#   'Total liabilities': 594467000.0,
#   'EPS': 2.51,
#   'Dividend per Share': 1.12,
#   'Sector': 'Healthcare'},
#  {'ticker': 'INCY',
#   'Revenue': 753751000.0,
#   'Revenue Growth': 0.4736,
#   'Gross Profit': 726779000.0,
#   'Profit Margin': 0.009000000000000001,
#   'grossProfitMargin': 0.9642163,
#   'netProfitMargin': 0.008664665,
#   'Total assets': 1007440000.0,
#   'Total debt': 619893000.0,
#   'Total liabilities': 836285000.0,
#   'EPS': 0.04,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'LH',
#   'Revenue': 8680100000.0,
#   'Revenue Growth': 0.4439,
#   'Gross Profit': 2903300000.0,
#   'Profit Margin': 0.05,
#   'grossProfitMargin': 0.334477713,
#   'netProfitMargin': 0.050414165999999996,
#   'Total assets': 14104700000.0,
#   'Total debt': 6364200000.0,
#   'Total liabilities': 9144700000.0,
#   'EPS': 4.43,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'COO',
#   'Revenue': 1797100000.0,
#   'Revenue Growth': 0.0462,
#   'Gross Profit': 1070300000.0,
#   'Profit Margin': 0.113,
#   'grossProfitMargin': 0.595570642,
#   'netProfitMargin': 0.113237995,
#   'Total assets': 4459864000.0,
#   'Total debt': 1349211000.0,
#   'Total liabilities': 1785960000.0,
#   'EPS': 4.2,
#   'Dividend per Share': 0.06,
#   'Sector': 'Healthcare'},
#  {'ticker': 'IDXX',
#   'Revenue': 1601892000.0,
#   'Revenue Growth': 0.0781,
#   'Gross Profit': 890270000.0,
#   'Profit Margin': 0.12,
#   'grossProfitMargin': 0.555761562,
#   'netProfitMargin': 0.11990696,
#   'Total assets': 1474993000.0,
#   'Total debt': 1170085000.0,
#   'Total liabilities': 1558988000.0,
#   'EPS': 2.07,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ALGN',
#   'Revenue': 845486000.0,
#   'Revenue Growth': 0.1101,
#   'Gross Profit': 640110000.0,
#   'Profit Margin': 0.17,
#   'grossProfitMargin': 0.757091188,
#   'netProfitMargin': 0.170339899,
#   'Total assets': 1158633000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 310707000.0,
#   'EPS': 1.8,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'PRGO',
#   'Revenue': nan,
#   'Revenue Growth': nan,
#   'Gross Profit': 746233000.0,
#   'Profit Margin': nan,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 19349600000.0,
#   'Total debt': 5400200000.0,
#   'Total liabilities': 9242800000.0,
#   'EPS': nan,
#   'Dividend per Share': nan,
#   'Sector': 'Healthcare'},
#  {'ticker': 'IQV',
#   'Revenue': 5737000000.0,
#   'Revenue Growth': 0.0507,
#   'Gross Profit': 1621000000.0,
#   'Profit Margin': 0.067,
#   'grossProfitMargin': 0.282551856,
#   'netProfitMargin': 0.06745685900000001,
#   'Total assets': 3926000000.0,
#   'Total debt': 2468000000.0,
#   'Total liabilities': 4262000000.0,
#   'EPS': 3.15,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'VAR',
#   'Revenue': 2490700000.0,
#   'Revenue Growth': -0.1833,
#   'Gross Profit': 1032100000.0,
#   'Profit Margin': 0.165,
#   'grossProfitMargin': 0.414381499,
#   'netProfitMargin': 0.16521459800000002,
#   'Total assets': 3578700000.0,
#   'Total debt': 495900000.0,
#   'Total liabilities': 1852400000.0,
#   'EPS': 4.13,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MTD',
#   'Revenue': 2395447000.0,
#   'Revenue Growth': -0.0364,
#   'Gross Profit': 1351993000.0,
#   'Profit Margin': 0.147,
#   'grossProfitMargin': 0.5644011329999999,
#   'netProfitMargin': 0.14728775,
#   'Total assets': 1959335000.0,
#   'Total debt': 589626000.0,
#   'Total liabilities': 1378878000.0,
#   'EPS': 12.75,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CMCSA',
#   'Revenue': 74510000000.0,
#   'Revenue Growth': 0.0834,
#   'Gross Profit': 74510000000.0,
#   'Profit Margin': 0.11,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.109555764,
#   'Total assets': 166574000000.0,
#   'Total debt': 52621000000.0,
#   'Total liabilities': 112596000000.0,
#   'EPS': 1.64,
#   'Dividend per Share': 0.48700000000000004,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'F',
#   'Revenue': 149558000000.0,
#   'Revenue Growth': 0.038,
#   'Gross Profit': 17744000000.0,
#   'Profit Margin': 0.049,
#   'grossProfitMargin': 0.118642935,
#   'netProfitMargin': 0.0492986,
#   'Total assets': 224925000000.0,
#   'Total debt': 132854000000.0,
#   'Total liabilities': 196174000000.0,
#   'EPS': 1.86,
#   'Dividend per Share': 0.6,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'NKE',
#   'Revenue': 30601000000.0,
#   'Revenue Growth': 0.1008,
#   'Gross Profit': 14067000000.0,
#   'Profit Margin': 0.107,
#   'grossProfitMargin': 0.45969086,
#   'netProfitMargin': 0.106957289,
#   'Total assets': 21597000000.0,
#   'Total debt': 1260000000.0,
#   'Total liabilities': 8890000000.0,
#   'EPS': 1.9,
#   'Dividend per Share': 0.54,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'GM',
#   'Revenue': 135725000000.0,
#   'Revenue Growth': -0.1296,
#   'Gross Profit': 17426000000.0,
#   'Profit Margin': 0.071,
#   'grossProfitMargin': 0.128391969,
#   'netProfitMargin': 0.07137226,
#   'Total assets': 194338000000.0,
#   'Total debt': 63111000000.0,
#   'Total liabilities': 154015000000.0,
#   'EPS': 6.11,
#   'Dividend per Share': 1.38,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'TWX',
#   'Revenue': 28118000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 11964000000.0,
#   'Profit Margin': 0.13631837300000002,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 63848000000.0,
#   'Total debt': 23594000000.0,
#   'Total liabilities': 40229000000.0,
#   'EPS': 4.69,
#   'Dividend per Share': nan,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'LOW',
#   'Revenue': 56223000000.0,
#   'Revenue Growth': 0.0525,
#   'Gross Profit': 19558000000.0,
#   'Profit Margin': 0.048,
#   'grossProfitMargin': 0.34786475299999997,
#   'netProfitMargin': 0.047987478,
#   'Total assets': 31721000000.0,
#   'Total debt': 11358000000.0,
#   'Total liabilities': 21753000000.0,
#   'EPS': 2.71,
#   'Dividend per Share': 0.87,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'MAT',
#   'Revenue': 5702613000.0,
#   'Revenue Growth': -0.0533,
#   'Gross Profit': 2806358000.0,
#   'Profit Margin': 0.065,
#   'grossProfitMargin': 0.49211791200000005,
#   'netProfitMargin': 0.06478012799999999,
#   'Total assets': 6535143000.0,
#   'Total debt': 2101635000.0,
#   'Total liabilities': 3901889000.0,
#   'EPS': 1.08,
#   'Dividend per Share': 1.52,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'DIS',
#   'Revenue': 52465000000.0,
#   'Revenue Growth': 0.0748,
#   'Gross Profit': 24101000000.0,
#   'Profit Margin': 0.16,
#   'grossProfitMargin': 0.459372915,
#   'netProfitMargin': 0.159763652,
#   'Total assets': 88182000000.0,
#   'Total debt': 17336000000.0,
#   'Total liabilities': 39527000000.0,
#   'EPS': 4.95,
#   'Dividend per Share': 1.81,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'LEN',
#   'Revenue': 9474008000.0,
#   'Revenue Growth': 0.2178,
#   'Gross Profit': 1302260000.0,
#   'Profit Margin': 0.085,
#   'grossProfitMargin': 0.13745608,
#   'netProfitMargin': 0.084747026,
#   'Total assets': 14419509000.0,
#   'Total debt': 5025130000.0,
#   'Total liabilities': 8469437000.0,
#   'EPS': 3.78,
#   'Dividend per Share': 0.16,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'MGM',
#   'Revenue': 9941841000.0,
#   'Revenue Growth': -0.0836,
#   'Gross Profit': 4316465000.0,
#   'Profit Margin': -0.045,
#   'grossProfitMargin': 0.43417159899999996,
#   'netProfitMargin': -0.045033912999999995,
#   'Total assets': 25215178000.0,
#   'Total debt': 12862667000.0,
#   'Total liabilities': 17450751000.0,
#   'EPS': -0.82,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'CCL',
#   'Revenue': 15714000000.0,
#   'Revenue Growth': -0.0107,
#   'Gross Profit': 6267000000.0,
#   'Profit Margin': 0.11199999999999999,
#   'grossProfitMargin': 0.39881634200000005,
#   'netProfitMargin': 0.111811124,
#   'Total assets': 39237000000.0,
#   'Total debt': 8787000000.0,
#   'Total liabilities': 15466000000.0,
#   'EPS': 2.26,
#   'Dividend per Share': 1.1,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'DISCA',
#   'Revenue': 6394000000.0,
#   'Revenue Growth': 0.0206,
#   'Gross Profit': 4051000000.0,
#   'Profit Margin': 0.162,
#   'grossProfitMargin': 0.633562715,
#   'netProfitMargin': 0.161714107,
#   'Total assets': 15864000000.0,
#   'Total debt': 7735000000.0,
#   'Total liabilities': 10172000000.0,
#   'EPS': 1.59,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'EBAY',
#   'Revenue': 8592000000.0,
#   'Revenue Growth': -0.0225,
#   'Gross Profit': 6821000000.0,
#   'Profit Margin': 0.201,
#   'grossProfitMargin': 0.7938780259999999,
#   'netProfitMargin': 0.200768156,
#   'Total assets': 17755000000.0,
#   'Total debt': 6749000000.0,
#   'Total liabilities': 11179000000.0,
#   'EPS': 1.43,
#   'Dividend per Share': 38.39,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'DISCK',
#   'Revenue': 6394000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 4051000000.0,
#   'Profit Margin': 0.163747263,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 15864000000.0,
#   'Total debt': 7616000000.0,
#   'Total liabilities': 10413000000.0,
#   'EPS': 1.59,
#   'Dividend per Share': nan,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'WYNN',
#   'Revenue': 4075883000.0,
#   'Revenue Growth': -0.2499,
#   'Gross Profit': 1545509000.0,
#   'Profit Margin': 0.048,
#   'grossProfitMargin': 0.379183848,
#   'netProfitMargin': 0.047913544,
#   'Total assets': 10459159000.0,
#   'Total debt': 9149665000.0,
#   'Total liabilities': 10437314000.0,
#   'EPS': 1.93,
#   'Dividend per Share': 3.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'HBI',
#   'Revenue': 5324746000.0,
#   'Revenue Growth': 0.1506,
#   'Gross Profit': 1904407000.0,
#   'Profit Margin': 0.076,
#   'grossProfitMargin': 0.357652177,
#   'netProfitMargin': 0.075969633,
#   'Total assets': 5208193000.0,
#   'Total debt': 1983752000.0,
#   'Total liabilities': 3821421000.0,
#   'EPS': 1.01,
#   'Dividend per Share': 0.3,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'SBUX',
#   'Revenue': 19162700000.0,
#   'Revenue Growth': 0.1651,
#   'Gross Profit': 11375200000.0,
#   'Profit Margin': 0.14400000000000002,
#   'grossProfitMargin': 0.5936115470000001,
#   'netProfitMargin': 0.143894128,
#   'Total assets': 12416300000.0,
#   'Total debt': 2347500000.0,
#   'Total liabilities': 6596500000.0,
#   'EPS': 1.84,
#   'Dividend per Share': 0.64,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'HD',
# ...
#   'Dividend per Share': 5.0,
#   'Sector': 'Technology'},
#  {'ticker': 'IT',
#   'Revenue': 2163056000.0,
#   'Revenue Growth': 0.0701,
#   'Gross Profit': 1323980000.0,
#   'Profit Margin': 0.081,
#   'grossProfitMargin': 0.612087713,
#   'netProfitMargin': 0.08119762,
#   'Total assets': 2168517000.0,
#   'Total debt': 818831000.0,
#   'Total liabilities': 2300917000.0,
#   'EPS': 2.09,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'GLW',
#   'Revenue': 9111000000.0,
#   'Revenue Growth': -0.0622,
#   'Gross Profit': 3653000000.0,
#   'Profit Margin': 0.147,
#   'grossProfitMargin': 0.400943914,
#   'netProfitMargin': 0.146965207,
#   'Total assets': 28527000000.0,
#   'Total debt': 4462000000.0,
#   'Total liabilities': 9664000000.0,
#   'EPS': 1.02,
#   'Dividend per Share': 0.48,
#   'Sector': 'Technology'},
#  {'ticker': 'STX',
#   'Revenue': 13739000000.0,
#   'Revenue Growth': 0.0011,
#   'Gross Profit': 3809000000.0,
#   'Profit Margin': 0.127,
#   'grossProfitMargin': 0.277239974,
#   'netProfitMargin': 0.126792343,
#   'Total assets': 9845000000.0,
#   'Total debt': 4155000000.0,
#   'Total liabilities': 6827000000.0,
#   'EPS': 5.38,
#   'Dividend per Share': 2.05,
#   'Sector': 'Technology'},
#  {'ticker': 'ADBE',
#   'Revenue': 4795511000.0,
#   'Revenue Growth': 0.1564,
#   'Gross Profit': 4051194000.0,
#   'Profit Margin': 0.131,
#   'grossProfitMargin': 0.844788804,
#   'netProfitMargin': 0.131279232,
#   'Total assets': 11726472000.0,
#   'Total debt': 1907231000.0,
#   'Total liabilities': 4724892000.0,
#   'EPS': 1.26,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'LRCX',
#   'Revenue': 5259312000.0,
#   'Revenue Growth': 0.1415,
#   'Gross Profit': 2284336000.0,
#   'Profit Margin': 0.125,
#   'grossProfitMargin': 0.434341222,
#   'netProfitMargin': 0.124650715,
#   'Total assets': 9364648000.0,
#   'Total debt': 2361032000.0,
#   'Total liabilities': 4019696000.0,
#   'EPS': 4.11,
#   'Dividend per Share': 0.84,
#   'Sector': 'Technology'},
#  {'ticker': 'GOOGL',
#   'Revenue': 74989000000.0,
#   'Revenue Growth': 0.1362,
#   'Gross Profit': 46825000000.0,
#   'Profit Margin': 0.21100000000000002,
#   'grossProfitMargin': 0.624424916,
#   'netProfitMargin': 0.21800530699999998,
#   'Total assets': 147461000000.0,
#   'Total debt': 5220000000.0,
#   'Total liabilities': 27130000000.0,
#   'EPS': 23.11,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'FTV',
#   'Revenue': 6178800000.0,
#   'Revenue Growth': -0.025,
#   'Gross Profit': 3000000000.0,
#   'Profit Margin': 0.14,
#   'grossProfitMargin': 0.48553117100000004,
#   'netProfitMargin': 0.139800609,
#   'Total assets': 7210600000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 2028100000.0,
#   'EPS': 2.5,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CTSH',
#   'Revenue': 12416000000.0,
#   'Revenue Growth': 0.2098,
#   'Gross Profit': 4976000000.0,
#   'Profit Margin': 0.131,
#   'grossProfitMargin': 0.400773196,
#   'netProfitMargin': 0.13079896900000001,
#   'Total assets': 13061000000.0,
#   'Total debt': 1283000000.0,
#   'Total liabilities': 3783000000.0,
#   'EPS': 2.67,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CTXS',
#   'Revenue': 2646154000.0,
#   'Revenue Growth': -0.158,
#   'Gross Profit': 2172114000.0,
#   'Profit Margin': 0.121,
#   'grossProfitMargin': 0.820856987,
#   'netProfitMargin': 0.120688743,
#   'Total assets': 5467517000.0,
#   'Total debt': 1311071000.0,
#   'Total liabilities': 3494071000.0,
#   'EPS': 2.01,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'TTWO',
#   'Revenue': 1082938000.0,
#   'Revenue Growth': -0.5393,
#   'Gross Profit': 288071000.0,
#   'Profit Margin': -0.258,
#   'grossProfitMargin': 0.266008765,
#   'netProfitMargin': -0.258066482,
#   'Total assets': 2228073000.0,
#   'Total debt': 473030000.0,
#   'Total liabilities': 1664985000.0,
#   'EPS': -3.48,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'KLAC',
#   'Revenue': 2814049000.0,
#   'Revenue Growth': -0.0394,
#   'Gross Profit': 1598820000.0,
#   'Profit Margin': 0.13,
#   'grossProfitMargin': 0.5681564179999999,
#   'netProfitMargin': 0.130117848,
#   'Total assets': 4826012000.0,
#   'Total debt': 3190416000.0,
#   'Total liabilities': 4404573000.0,
#   'EPS': 2.26,
#   'Dividend per Share': 18.5,
#   'Sector': 'Technology'},
#  {'ticker': 'GOOG',
#   'Revenue': 74989000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 46825000000.0,
#   'Profit Margin': 0.21800530699999998,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 147461000000.0,
#   'Total debt': 1995000000.0,
#   'Total liabilities': 27130000000.0,
#   'EPS': 23.11,
#   'Dividend per Share': nan,
#   'Sector': 'Technology'},
#  {'ticker': 'QRVO',
#   'Revenue': 1710966000.0,
#   'Revenue Growth': 0.4901,
#   'Gross Profit': 689308000.0,
#   'Profit Margin': 0.115,
#   'grossProfitMargin': 0.40287650399999997,
#   'netProfitMargin': 0.11473226199999999,
#   'Total assets': 6892379000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 719219000.0,
#   'EPS': 2.17,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'TEL',
#   'Revenue': 12233000000.0,
#   'Revenue Growth': 0.0217,
#   'Gross Profit': 4087000000.0,
#   'Profit Margin': 0.198,
#   'grossProfitMargin': 0.334096297,
#   'netProfitMargin': 0.197825554,
#   'Total assets': 20589000000.0,
#   'Total debt': 3884000000.0,
#   'Total liabilities': 11004000000.0,
#   'EPS': 5.98,
#   'Dividend per Share': 1.24,
#   'Sector': 'Technology'},
#  {'ticker': 'EA',
#   'Revenue': 4515000000.0,
#   'Revenue Growth': 0.2629,
#   'Gross Profit': 3086000000.0,
#   'Profit Margin': 0.19399999999999998,
#   'grossProfitMargin': 0.6834994459999999,
#   'netProfitMargin': 0.19379845,
#   'Total assets': 6147000000.0,
#   'Total debt': 633000000.0,
#   'Total liabilities': 3080000000.0,
#   'EPS': 2.81,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'INFO',
#   'Revenue': 1113400000.0,
#   'Revenue Growth': 0.0453,
#   'Gross Profit': 1113400000.0,
#   'Profit Margin': 0.13699999999999998,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.136967846,
#   'Total assets': 5571000000.0,
#   'Total debt': 435600000.0,
#   'Total liabilities': 3370000000.0,
#   'EPS': 0.85,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CERN',
#   'Revenue': 3402703000.0,
#   'Revenue Growth': 0.16899999999999998,
#   'Gross Profit': 2798326000.0,
#   'Profit Margin': 0.154,
#   'grossProfitMargin': 0.8223832640000001,
#   'netProfitMargin': 0.154416357,
#   'Total assets': 4530565000.0,
#   'Total debt': 130328000.0,
#   'Total liabilities': 964597000.0,
#   'EPS': 1.54,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'AKAM',
#   'Revenue': 2197448000.0,
#   'Revenue Growth': 0.1189,
#   'Gross Profit': 1471828000.0,
#   'Profit Margin': 0.146,
#   'grossProfitMargin': 0.669789683,
#   'netProfitMargin': 0.14626330199999998,
#   'Total assets': 4181684000.0,
#   'Total debt': 618047000.0,
#   'Total liabilities': 1060806000.0,
#   'EPS': 1.8,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CDNS',
#   'Revenue': 1580932000.0,
#   'Revenue Growth': 0.0827,
#   'Gross Profit': 1357226000.0,
#   'Profit Margin': 0.10099999999999999,
#   'grossProfitMargin': 0.8584973929999999,
#   'netProfitMargin': 0.100509067,
#   'Total assets': 3209556000.0,
#   'Total debt': 691175000.0,
#   'Total liabilities': 1875982000.0,
#   'EPS': 0.56,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'NTAP',
#   'Revenue': 6123000000.0,
#   'Revenue Growth': -0.0319,
#   'Gross Profit': 3833000000.0,
#   'Profit Margin': 0.091,
#   'grossProfitMargin': 0.6260003270000001,
#   'netProfitMargin': 0.091458435,
#   'Total assets': 9401000000.0,
#   'Total debt': 1487000000.0,
#   'Total liabilities': 5987000000.0,
#   'EPS': 1.77,
#   'Dividend per Share': 0.66,
#   'Sector': 'Technology'},
#  {'ticker': 'JNPR',
#   'Revenue': 4857800000.0,
#   'Revenue Growth': 0.0499,
#   'Gross Profit': 3078600000.0,
#   'Profit Margin': 0.13,
#   'grossProfitMargin': 0.63374367,
#   'netProfitMargin': 0.130449998,
#   'Total assets': 8607900000.0,
#   'Total debt': 1937400000.0,
#   'Total liabilities': 4033500000.0,
#   'EPS': 1.62,
#   'Dividend per Share': 0.4,
#   'Sector': 'Technology'},
#  {'ticker': 'MCHP',
#   'Revenue': 2147036000.0,
#   'Revenue Growth': 0.1118,
#   'Gross Profit': 1229564000.0,
#   'Profit Margin': 0.172,
#   'grossProfitMargin': 0.572679731,
#   'netProfitMargin': 0.171869032,
#   'Total assets': 4780713000.0,
#   'Total debt': 1826858000.0,
#   'Total liabilities': 2719687000.0,
#   'EPS': 1.84,
#   'Dividend per Share': 1.425,
#   'Sector': 'Technology'},
#  {'ticker': 'INTU',
#   'Revenue': 4192000000.0,
#   'Revenue Growth': -0.012,
#   'Gross Profit': 3497000000.0,
#   'Profit Margin': 0.087,
#   'grossProfitMargin': 0.834208015,
#   'netProfitMargin': 0.08707061099999999,
#   'Total assets': 4968000000.0,
#   'Total debt': 500000000.0,
#   'Total liabilities': 2636000000.0,
#   'EPS': 1.3,
#   'Dividend per Share': 1.0,
#   'Sector': 'Technology'},
#  {'ticker': 'XLNX',
#   'Revenue': 2377344000.0,
#   'Revenue Growth': -0.0022,
#   'Gross Profit': 1668521000.0,
#   'Profit Margin': 0.273,
#   'grossProfitMargin': 0.7018424759999999,
#   'netProfitMargin': 0.272663948,
#   'Total assets': 4898065000.0,
#   'Total debt': 1570892000.0,
#   'Total liabilities': 2286471000.0,
#   'EPS': 2.44,
#   'Dividend per Share': 1.16,
#   'Sector': 'Technology'},
#  {'ticker': 'SWKS',
#   'Revenue': 3258400000.0,
#   'Revenue Growth': 0.42200000000000004,
#   'Gross Profit': 1554500000.0,
#   'Profit Margin': 0.245,
#   'grossProfitMargin': 0.477074638,
#   'netProfitMargin': 0.244997545,
#   'Total assets': 3719400000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 560200000.0,
#   'EPS': 4.21,
#   'Dividend per Share': 0.65,
#   'Sector': 'Technology'},
#  {'ticker': 'ADI',
#   'Revenue': 3435092000.0,
#   'Revenue Growth': 0.1991,
#   'Gross Profit': 2259262000.0,
#   'Profit Margin': 0.203,
#   'grossProfitMargin': 0.65770058,
#   'netProfitMargin': 0.202870258,
#   'Total assets': 7058777000.0,
#   'Total debt': 869935000.0,
#   'Total liabilities': 1985818000.0,
#   'EPS': 2.23,
#   'Dividend per Share': 1.57,
#   'Sector': 'Technology'},
#  {'ticker': 'VRSN',
#   'Revenue': 1059366000.0,
#   'Revenue Growth': 0.0488,
#   'Gross Profit': 866578000.0,
#   'Profit Margin': 0.354,
#   'grossProfitMargin': 0.818015681,
#   'netProfitMargin': 0.35420808299999995,
#   'Total assets': 2357737000.0,
#   'Total debt': 1869680000.0,
#   'Total liabilities': 3428184000.0,
#   'EPS': 3.29,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'DXC',
#   'Revenue': 7106000000.0,
#   'Revenue Growth': -0.6266,
#   'Gross Profit': 1244000000.0,
#   'Profit Margin': -0.099,
#   'grossProfitMargin': 0.175063327,
#   'netProfitMargin': -0.265268787,
#   'Total assets': 10221000000.0,
#   'Total debt': nan,
#   'Total liabilities': 7256000000.0,
#   'EPS': nan,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'EQIX',
#   'Revenue': 2725867000.0,
#   'Revenue Growth': 0.1154,
#   'Gross Profit': 1434361000.0,
#   'Profit Margin': 0.069,
#   'grossProfitMargin': 0.52620359,
#   'netProfitMargin': 0.068885973,
#   'Total assets': 10356695000.0,
#   'Total debt': 6521020000.0,
#   'Total liabilities': 7611309000.0,
#   'EPS': 3.25,
#   'Dividend per Share': 17.71,
#   'Sector': 'Technology'},
#  {'ticker': 'FIS',
#   'Revenue': 6596000000.0,
#   'Revenue Growth': 0.0285,
#   'Gross Profit': 2201000000.0,
#   'Profit Margin': 0.096,
#   'grossProfitMargin': 0.333687083,
#   'netProfitMargin': 0.09581564599999999,
#   'Total assets': 26200000000.0,
#   'Total debt': 11444000000.0,
#   'Total liabilities': 16793000000.0,
#   'EPS': 2.22,
#   'Dividend per Share': 1.04,
#   'Sector': 'Technology'},
#  {'ticker': 'AYI',
#   'Revenue': 2706700000.0,
#   'Revenue Growth': 0.1309,
#   'Gross Profit': 1145600000.0,
#   'Profit Margin': 0.08199999999999999,
#   'grossProfitMargin': 0.423246019,
#   'netProfitMargin': 0.08205564,
#   'Total assets': 2407000000.0,
#   'Total debt': 352400000.0,
#   'Total liabilities': 1047000000.0,
#   'EPS': 5.13,
#   'Dividend per Share': 0.52,
#   'Sector': 'Technology'},
#  {'ticker': 'MSI',
#   'Revenue': 5695000000.0,
#   'Revenue Growth': -0.0316,
#   'Gross Profit': 2719000000.0,
#   'Profit Margin': 0.107,
#   'grossProfitMargin': 0.47743634799999995,
#   'netProfitMargin': 0.107111501,
#   'Total assets': 8346000000.0,
#   'Total debt': 4349000000.0,
#   'Total liabilities': 8442000000.0,
#   'EPS': 3.06,
#   'Dividend per Share': 1.43,
#   'Sector': 'Technology'},
#  {'ticker': 'WHR',
#   'Revenue': 20891000000.0,
#   'Revenue Growth': 0.0513,
#   'Gross Profit': 3660000000.0,
#   'Profit Margin': 0.037000000000000005,
#   'grossProfitMargin': 0.17519506,
#   'netProfitMargin': 0.037480255,
#   'Total assets': 19010000000.0,
#   'Total debt': 3998000000.0,
#   'Total liabilities': 13336000000.0,
#   'EPS': 9.95,
#   'Dividend per Share': 3.45,
#   'Sector': 'Technology'},
#  {'ticker': 'FFIV',
#   'Revenue': 1919823000.0,
#   'Revenue Growth': 0.1084,
#   'Gross Profit': 1587562000.0,
#   'Profit Margin': 0.19,
#   'grossProfitMargin': 0.8269314409999999,
#   'netProfitMargin': 0.19012898600000003,
#   'Total assets': 2312290000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 995562000.0,
#   'EPS': 5.07,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'FLIR',
#   'Revenue': 1557067000.0,
#   'Revenue Growth': 0.0173,
#   'Gross Profit': 753561000.0,
#   'Profit Margin': 0.155,
#   'grossProfitMargin': 0.48396183299999995,
#   'netProfitMargin': 0.15521875400000001,
#   'Total assets': 2406400000.0,
#   'Total debt': 358444000.0,
#   'Total liabilities': 756885000.0,
#   'EPS': 1.73,
#   'Dividend per Share': 0.44,
#   'Sector': 'Technology'},
#  {'ticker': 'APH',
#   'Revenue': 5568700000.0,
#   'Revenue Growth': 0.0418,
#   'Gross Profit': 1779500000.0,
#   'Profit Margin': 0.13699999999999998,
#   'grossProfitMargin': 0.319553935,
#   'netProfitMargin': 0.13710560800000002,
#   'Total assets': 7458400000.0,
#   'Total debt': 2813500000.0,
#   'Total liabilities': 4180000000.0,
#   'EPS': 2.47,
#   'Dividend per Share': 0.53,
#   'Sector': 'Technology'},
#  {'ticker': 'WAT',
#   'Revenue': 2042332000.0,
#   'Revenue Growth': 0.0266,
#   'Gross Profit': 1199660000.0,
#   'Profit Margin': 0.23,
#   'grossProfitMargin': 0.587397152,
#   'netProfitMargin': 0.229665402,
#   'Total assets': 4268677000.0,
#   'Total debt': 1668336000.0,
#   'Total liabilities': 2209826000.0,
#   'EPS': 5.7,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'GRMN',
#   'Revenue': 2820270000.0,
#   'Revenue Growth': -0.0176,
#   'Gross Profit': 1538704000.0,
#   'Profit Margin': 0.162,
#   'grossProfitMargin': 0.5455874789999999,
#   'netProfitMargin': 0.161767136,
#   'Total assets': 4499391000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 1154265000.0,
#   'EPS': 2.39,
#   'Dividend per Share': 2.01,
#   'Sector': 'Technology'},
#  {'ticker': 'AME',
#   'Revenue': 3974295000.0,
#   'Revenue Growth': -0.0119,
#   'Gross Profit': 1356308000.0,
#   'Profit Margin': 0.149,
#   'grossProfitMargin': 0.34127008700000006,
#   'netProfitMargin': 0.148670141,
#   'Total assets': 6660450000.0,
#   'Total debt': 1938040000.0,
#   'Total liabilities': 3405824000.0,
#   'EPS': 2.46,
#   'Dividend per Share': 0.36,
#   'Sector': 'Technology'},
#  {'ticker': 'ANSS',
#   'Revenue': 942753000.0,
#   'Revenue Growth': 0.0072,
#   'Gross Profit': 795507000.0,
#   'Profit Margin': 0.268,
#   'grossProfitMargin': 0.843812748,
#   'netProfitMargin': 0.267854889,
#   'Total assets': 2729904000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 535477000.0,
#   'EPS': 2.82,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'SNPS',
#   'Revenue': 2242211000.0,
#   'Revenue Growth': 0.0898,
#   'Gross Profit': 1723291000.0,
#   'Profit Margin': 0.10099999999999999,
#   'grossProfitMargin': 0.768567722,
#   'netProfitMargin': 0.10076393300000001,
#   'Total assets': 5045739000.0,
#   'Total debt': 205000000.0,
#   'Total liabilities': 1911750000.0,
#   'EPS': 1.46,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'IPGP',
#   'Revenue': 901265000.0,
#   'Revenue Growth': 0.1707,
#   'Gross Profit': 491877000.0,
#   'Profit Margin': 0.26899999999999996,
#   'grossProfitMargin': 0.5457628999999999,
#   'netProfitMargin': 0.268682352,
#   'Total assets': 1453429000.0,
#   'Total debt': 19667000.0,
#   'Total liabilities': 192764000.0,
#   'EPS': 4.6,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'}]

# %%
financial2014_dict=top500_2014.to_dict('records')
financial2014_dict
# Out:
# [{'ticker': 'PG',
#   'Revenue': 74401000000.0,
#   'Revenue Growth': -0.0713,
#   'Gross Profit': 35371000000.0,
#   'Profit Margin': 0.156,
#   'grossProfitMargin': 0.47541027674359,
#   'netProfitMargin': 0.15648983212591,
#   'Total assets': 144266000000.0,
#   'Total debt': 35417000000.0,
#   'Total liabilities': 74290000000.0,
#   'EPS': 4.19,
#   'Dividend per Share': 2.448,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KR',
#   'Revenue': 98375000000.0,
#   'Revenue Growth': 0.0182,
#   'Gross Profit': 20237000000.0,
#   'Profit Margin': 0.015,
#   'grossProfitMargin': 0.20571283354511,
#   'netProfitMargin': 0.015440914866582,
#   'Total assets': 29281000000.0,
#   'Total debt': 11310000000.0,
#   'Total liabilities': 23886000000.0,
#   'EPS': 1.47,
#   'Dividend per Share': 0.307,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'GIS',
#   'Revenue': 17909600000.0,
#   'Revenue Growth': 0.0076,
#   'Gross Profit': 6369800000.0,
#   'Profit Margin': 0.102,
#   'grossProfitMargin': 0.3556640014294,
#   'netProfitMargin': 0.10186715504534,
#   'Total assets': 23145700000.0,
#   'Total debt': 8785800000.0,
#   'Total liabilities': 15156200000.0,
#   'EPS': 2.9,
#   'Dividend per Share': 1.55,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'PM',
#   'Revenue': 80106000000.0,
#   'Revenue Growth': 0.001,
#   'Gross Profit': 19331000000.0,
#   'Profit Margin': 0.094,
#   'grossProfitMargin': 0.24131775397598,
#   'netProfitMargin': 0.093538561406137,
#   'Total assets': 35187000000.0,
#   'Total debt': 29455000000.0,
#   'Total liabilities': 46390000000.0,
#   'EPS': 4.76,
#   'Dividend per Share': 3.88,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KO',
#   'Revenue': 45998000000.0,
#   'Revenue Growth': -0.0183,
#   'Gross Profit': 28109000000.0,
#   'Profit Margin': 0.154,
#   'grossProfitMargin': 0.61109178659942,
#   'netProfitMargin': 0.15431105700248002,
#   'Total assets': 92023000000.0,
#   'Total debt': 41745000000.0,
#   'Total liabilities': 61462000000.0,
#   'EPS': 1.62,
#   'Dividend per Share': 1.22,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'WMT',
#   'Revenue': 476294000000.0,
#   'Revenue Growth': 0.0163,
#   'Gross Profit': 118225000000.0,
#   'Profit Margin': 0.034,
#   'grossProfitMargin': 0.24821853728999,
#   'netProfitMargin': 0.033638886905987,
#   'Total assets': 204751000000.0,
#   'Total debt': 56641000000.0,
#   'Total liabilities': 123412000000.0,
#   'EPS': 4.9,
#   'Dividend per Share': 1.88,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MDLZ',
#   'Revenue': 34244000000.0,
#   'Revenue Growth': -0.0299,
#   'Gross Profit': 12597000000.0,
#   'Profit Margin': 0.064,
#   'grossProfitMargin': 0.36786006307674,
#   'netProfitMargin': 0.063777596075225,
#   'Total assets': 66771000000.0,
#   'Total debt': 16656000000.0,
#   'Total liabilities': 38918000000.0,
#   'EPS': 1.29,
#   'Dividend per Share': 0.58,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MO',
#   'Revenue': 24522000000.0,
#   'Revenue Growth': 0.0023,
#   'Gross Profit': 10160000000.0,
#   'Profit Margin': 0.207,
#   'grossProfitMargin': 0.41432183345567,
#   'netProfitMargin': 0.20675311964766,
#   'Total assets': 34475000000.0,
#   'Total debt': 14693000000.0,
#   'Total liabilities': 31430000000.0,
#   'EPS': 2.56,
#   'Dividend per Share': 2.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KHC',
#   'Revenue': 10922000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 3277000000.0,
#   'Profit Margin': -0.006,
#   'grossProfitMargin': 0.30003662332906,
#   'netProfitMargin': 0.06015381798205501,
#   'Total assets': 36571000000.0,
#   'Total debt': 13358000000.0,
#   'Total liabilities': 20886000000.0,
#   'EPS': -0.17,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'NWL',
#   'Revenue': 5727000000.0,
#   'Revenue Growth': 0.0214,
#   'Gross Profit': 2203400000.0,
#   'Profit Margin': 0.066,
#   'grossProfitMargin': 0.38473895582329,
#   'netProfitMargin': 0.065968220708923,
#   'Total assets': 6564300000.0,
#   'Total debt': 2481900000.0,
#   'Total liabilities': 4709400000.0,
#   'EPS': 1.37,
#   'Dividend per Share': 0.66,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'KMB',
#   'Revenue': 19724000000.0,
#   'Revenue Growth': 0.0083,
#   'Gross Profit': 6683000000.0,
#   'Profit Margin': 0.077,
#   'grossProfitMargin': 0.3388257959845901,
#   'netProfitMargin': 0.077367673899817,
#   'Total assets': 15526000000.0,
#   'Total debt': 6956000000.0,
#   'Total liabilities': 14527000000.0,
#   'EPS': 4.07,
#   'Dividend per Share': 8.132,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CPB',
#   'Revenue': 8268000000.0,
#   'Revenue Growth': 0.0268,
#   'Gross Profit': 2971000000.0,
#   'Profit Margin': 0.105,
#   'grossProfitMargin': 0.35933720367683003,
#   'netProfitMargin': 0.10474117077891,
#   'Total assets': 8113000000.0,
#   'Total debt': 4015000000.0,
#   'Total liabilities': 6510000000.0,
#   'EPS': 2.76,
#   'Dividend per Share': 1.248,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TGT',
#   'Revenue': 71279000000.0,
#   'Revenue Growth': -0.0276,
#   'Gross Profit': 21240000000.0,
#   'Profit Margin': 0.028,
#   'grossProfitMargin': 0.29798397845088004,
#   'netProfitMargin': 0.027651903085060003,
#   'Total assets': 44553000000.0,
#   'Total debt': 12572000000.0,
#   'Total liabilities': 28322000000.0,
#   'EPS': 3.1,
#   'Dividend per Share': 1.58,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'HRL',
#   'Revenue': 9316256000.0,
#   'Revenue Growth': 0.0645,
#   'Gross Profit': 1564983000.0,
#   'Profit Margin': 0.065,
#   'grossProfitMargin': 0.1679841129312,
#   'netProfitMargin': 0.06469090158106401,
#   'Total assets': 5455619000.0,
#   'Total debt': 250000000.0,
#   'Total liabilities': 1843563000.0,
#   'EPS': 1.14,
#   'Dividend per Share': 0.4,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CAG',
#   'Revenue': 11838200000.0,
#   'Revenue Growth': -0.1211,
#   'Gross Profit': 2927400000.0,
#   'Profit Margin': 0.026,
#   'grossProfitMargin': 0.24728421550574,
#   'netProfitMargin': 0.025603554594448,
#   'Total assets': 19319500000.0,
#   'Total debt': 8946400000.0,
#   'Total liabilities': 13964300000.0,
#   'EPS': 0.72,
#   'Dividend per Share': 1.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'PEP',
#   'Revenue': 66683000000.0,
#   'Revenue Growth': 0.004,
#   'Gross Profit': 35445000000.0,
#   'Profit Margin': 0.098,
#   'grossProfitMargin': 0.53154477153097,
#   'netProfitMargin': 0.097671070587706,
#   'Total assets': 70509000000.0,
#   'Total debt': 28897000000.0,
#   'Total liabilities': 52961000000.0,
#   'EPS': 4.31,
#   'Dividend per Share': 2.533,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'COST',
#   'Revenue': 112640000000.0,
#   'Revenue Growth': 0.0712,
#   'Gross Profit': 14182000000.0,
#   'Profit Margin': 0.018000000000000002,
#   'grossProfitMargin': 0.12590553977273,
#   'netProfitMargin': 0.018270596590909,
#   'Total assets': 33024000000.0,
#   'Total debt': 5093000000.0,
#   'Total liabilities': 20509000000.0,
#   'EPS': 4.69,
#   'Dividend per Share': 1.33,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'COTY',
#   'Revenue': 4551600000.0,
#   'Revenue Growth': -0.021,
#   'Gross Profit': 2685900000.0,
#   'Profit Margin': -0.021,
#   'grossProfitMargin': 0.59010018455049,
#   'netProfitMargin': -0.021399068459443,
#   'Total assets': 6592500000.0,
#   'Total debt': 3293500000.0,
#   'Total liabilities': 5631900000.0,
#   'EPS': -0.26,
#   'Dividend per Share': 0.2,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MNST',
#   'Revenue': 2464867000.0,
#   'Revenue Growth': 0.0972,
#   'Gross Profit': 1339810000.0,
#   'Profit Margin': 0.196,
#   'grossProfitMargin': 0.54356279669451,
#   'netProfitMargin': 0.19602883238731,
#   'Total assets': 1938875000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 423725000.0,
#   'EPS': 0.96,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'SJM',
#   'Revenue': 5610600000.0,
#   'Revenue Growth': -0.0487,
#   'Gross Profit': 2031000000.0,
#   'Profit Margin': 0.101,
#   'grossProfitMargin': 0.3619933696930801,
#   'netProfitMargin': 0.10073788899583,
#   'Total assets': 9060200000.0,
#   'Total debt': 2216300000.0,
#   'Total liabilities': 4030600000.0,
#   'EPS': 5.42,
#   'Dividend per Share': 2.26,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CL',
#   'Revenue': 17277000000.0,
#   'Revenue Growth': -0.0082,
#   'Gross Profit': 10109000000.0,
#   'Profit Margin': 0.126,
#   'grossProfitMargin': 0.58511315621925,
#   'netProfitMargin': 0.12617931353822998,
#   'Total assets': 13459000000.0,
#   'Total debt': 6148000000.0,
#   'Total liabilities': 12074000000.0,
#   'EPS': 2.38,
#   'Dividend per Share': 1.42,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'ADM',
#   'Revenue': 81201000000.0,
#   'Revenue Growth': -0.0958,
#   'Gross Profit': 4768000000.0,
#   'Profit Margin': 0.028,
#   'grossProfitMargin': 0.058718488688563,
#   'netProfitMargin': 0.027684388123299,
#   'Total assets': 43997000000.0,
#   'Total debt': 5660000000.0,
#   'Total liabilities': 24367000000.0,
#   'EPS': 3.44,
#   'Dividend per Share': 0.96,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'DG',
#   'Revenue': 17504167000.0,
#   'Revenue Growth': 0.0925,
#   'Gross Profit': 5435742000.0,
#   'Profit Margin': 0.059,
#   'grossProfitMargin': 0.31053988458862,
#   'netProfitMargin': 0.058564112191114015,
#   'Total assets': 10867524000.0,
#   'Total debt': 2818754000.0,
#   'Total liabilities': 5465331000.0,
#   'EPS': 3.17,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TAP',
#   'Revenue': 4146300000.0,
#   'Revenue Growth': -0.0142,
#   'Gross Profit': 1653000000.0,
#   'Profit Margin': 0.124,
#   'grossProfitMargin': 0.3986686925692801,
#   'netProfitMargin': 0.12396594554181,
#   'Total assets': 13980100000.0,
#   'Total debt': 3170300000.0,
#   'Total liabilities': 6094000000.0,
#   'EPS': 2.78,
#   'Dividend per Share': 1.48,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'SYY',
#   'Revenue': 46516712000.0,
#   'Revenue Growth': 0.0474,
#   'Gross Profit': 8181035000.0,
#   'Profit Margin': 0.02,
#   'grossProfitMargin': 0.17587302817104,
#   'netProfitMargin': 0.020025770523076,
#   'Total assets': 13141113000.0,
#   'Total debt': 2733082000.0,
#   'Total liabilities': 7874418000.0,
#   'EPS': 1.59,
#   'Dividend per Share': 1.14,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CHD',
#   'Revenue': 3297600000.0,
#   'Revenue Growth': 0.0323,
#   'Gross Profit': 1452900000.0,
#   'Profit Margin': 0.126,
#   'grossProfitMargin': 0.44059315866084,
#   'netProfitMargin': 0.12551552644347,
#   'Total assets': 4359200000.0,
#   'Total debt': 1086600000.0,
#   'Total liabilities': 2257300000.0,
#   'EPS': 1.53,
#   'Dividend per Share': 0.62,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'STZ',
#   'Revenue': 4867700000.0,
#   'Revenue Growth': 0.7409,
#   'Gross Profit': 1991700000.0,
#   'Profit Margin': 0.399,
#   'grossProfitMargin': 0.4091665468291,
#   'netProfitMargin': 0.39918236538817,
#   'Total assets': 14302100000.0,
#   'Total debt': 7020500000.0,
#   'Total liabilities': 9320800000.0,
#   'EPS': 10.45,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'EL',
#   'Revenue': 10968800000.0,
#   'Revenue Growth': 0.0773,
#   'Gross Profit': 8810600000.0,
#   'Profit Margin': 0.11,
#   'grossProfitMargin': 0.80324192254394,
#   'netProfitMargin': 0.10977499817665,
#   'Total assets': 7868800000.0,
#   'Total debt': 1343100000.0,
#   'Total liabilities': 3999400000.0,
#   'EPS': 3.12,
#   'Dividend per Share': 0.78,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'DLTR',
#   'Revenue': 7840300000.0,
#   'Revenue Growth': 0.0603,
#   'Gross Profit': 2789800000.0,
#   'Profit Margin': 0.076,
#   'grossProfitMargin': 0.35582822085890004,
#   'netProfitMargin': 0.076106781628254,
#   'Total assets': 2771900000.0,
#   'Total debt': 769800000.0,
#   'Total liabilities': 1601200000.0,
#   'EPS': 2.74,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'TSN',
#   'Revenue': 37580000000.0,
#   'Revenue Growth': 0.0933,
#   'Gross Profit': 2685000000.0,
#   'Profit Margin': 0.023,
#   'grossProfitMargin': 0.071447578499202,
#   'netProfitMargin': 0.02299095263438,
#   'Total assets': 23956000000.0,
#   'Total debt': 8178000000.0,
#   'Total liabilities': 15052000000.0,
#   'EPS': 2.48,
#   'Dividend per Share': 0.3,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'MKC',
#   'Revenue': 4243200000.0,
#   'Revenue Growth': 0.0291,
#   'Gross Profit': 1730200000.0,
#   'Profit Margin': 0.096,
#   'grossProfitMargin': 0.40775829562594,
#   'netProfitMargin': 0.096271681749623,
#   'Total assets': 4414300000.0,
#   'Total debt': 1284900000.0,
#   'Total liabilities': 2604900000.0,
#   'EPS': 3.37,
#   'Dividend per Share': 1.48,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'HSY',
#   'Revenue': 7421768000.0,
#   'Revenue Growth': 0.0386,
#   'Gross Profit': 3336166000.0,
#   'Profit Margin': 0.114,
#   'grossProfitMargin': 0.44951095210737,
#   'netProfitMargin': 0.11411189355419997,
#   'Total assets': 5622870000.0,
#   'Total debt': 2177818000.0,
#   'Total liabilities': 4103340000.0,
#   'EPS': 3.54,
#   'Dividend per Share': 2.04,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'CLX',
#   'Revenue': 5514000000.0,
#   'Revenue Growth': -0.0034,
#   'Gross Profit': 2356000000.0,
#   'Profit Margin': 0.101,
#   'grossProfitMargin': 0.42727602466449,
#   'netProfitMargin': 0.10119695321001,
#   'Total assets': 4258000000.0,
#   'Total debt': 2313000000.0,
#   'Total liabilities': 4104000000.0,
#   'EPS': 4.31,
#   'Dividend per Share': 2.84,
#   'Sector': 'Consumer Defensive'},
#  {'ticker': 'FCX',
#   'Revenue': 20001000000.0,
#   'Revenue Growth': -0.044,
#   'Gross Profit': 1507000000.0,
#   'Profit Margin': -0.065,
#   'grossProfitMargin': 0.075346232688366,
#   'netProfitMargin': -0.055147242637868,
#   'Total assets': 58674000000.0,
#   'Total debt': 18849000000.0,
#   'Total liabilities': 35449000000.0,
#   'EPS': -1.26,
#   'Dividend per Share': 1.25,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'NUE',
#   'Revenue': 21105141000.0,
#   'Revenue Growth': 0.1078,
#   'Gross Profit': 1849237000.0,
#   'Profit Margin': 0.032,
#   'grossProfitMargin': 0.087620215377855,
#   'netProfitMargin': 0.032188223712886,
#   'Total assets': 15615927000.0,
#   'Total debt': 4584411000.0,
#   'Total liabilities': 7540809000.0,
#   'EPS': 2.12,
#   'Dividend per Share': 1.483,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'JCI',
#   'Revenue': 38749000000.0,
#   'Revenue Growth': 0.0432,
#   'Gross Profit': 6305000000.0,
#   'Profit Margin': 0.032,
#   'grossProfitMargin': 0.16271387648714006,
#   'netProfitMargin': 0.030400784536375,
#   'Total assets': 32804000000.0,
#   'Total debt': 5498000000.0,
#   'Total liabilities': 21242000000.0,
#   'EPS': 1.82,
#   'Dividend per Share': 0.76,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MAS',
#   'Revenue': 7006000000.0,
#   'Revenue Growth': 0.0362,
#   'Gross Profit': 2060000000.0,
#   'Profit Margin': 0.122,
#   'grossProfitMargin': 0.2940336854125,
#   'netProfitMargin': 0.12218098772481,
#   'Total assets': 7208000000.0,
#   'Total debt': 3424000000.0,
#   'Total liabilities': 6080000000.0,
#   'EPS': 2.4,
#   'Dividend per Share': 0.33,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'WY',
#   'Revenue': 5489000000.0,
#   'Revenue Growth': -0.2433,
#   'Gross Profit': 1454000000.0,
#   'Profit Margin': 0.325,
#   'grossProfitMargin': 0.26489342321006,
#   'netProfitMargin': 0.33266533066132004,
#   'Total assets': 13265000000.0,
#   'Total debt': 5402000000.0,
#   'Total liabilities': 7961000000.0,
#   'EPS': 3.2,
#   'Dividend per Share': 1.02,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'CF',
#   'Revenue': 4743000000.0,
#   'Revenue Growth': -0.1337,
#   'Gross Profit': 1778000000.0,
#   'Profit Margin': 0.293,
#   'grossProfitMargin': 0.37486822686064,
#   'netProfitMargin': 0.29306346194392,
#   'Total assets': 11254200000.0,
#   'Total debt': 4592500000.0,
#   'Total liabilities': 6681700000.0,
#   'EPS': 5.43,
#   'Dividend per Share': 1.0,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'LYB',
#   'Revenue': 45608000000.0,
#   'Revenue Growth': 0.0351,
#   'Gross Profit': 6669000000.0,
#   'Profit Margin': 0.092,
#   'grossProfitMargin': 0.14622434660585998,
#   'netProfitMargin': 0.091519031748816,
#   'Total assets': 24221000000.0,
#   'Total debt': 7045000000.0,
#   'Total liabilities': 15877000000.0,
#   'EPS': 8.03,
#   'Dividend per Share': 2.7,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'VMC',
#   'Revenue': 2994169000.0,
#   'Revenue Growth': 0.0807,
#   'Gross Profit': 587582000.0,
#   'Profit Margin': 0.068,
#   'grossProfitMargin': 0.19624209588704,
#   'netProfitMargin': 0.068440692559438,
#   'Total assets': 8041097000.0,
#   'Total debt': 1984779000.0,
#   'Total liabilities': 3864398000.0,
#   'EPS': 1.56,
#   'Dividend per Share': 0.22,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'NEM',
#   'Revenue': 6819000000.0,
#   'Revenue Growth': -0.1896,
#   'Gross Profit': 2900000000.0,
#   'Profit Margin': 0.07400000000000001,
#   'grossProfitMargin': 0.4252822994574,
#   'netProfitMargin': 0.074497726939434,
#   'Total assets': 24916000000.0,
#   'Total debt': 6646000000.0,
#   'Total liabilities': 11827000000.0,
#   'EPS': 1.02,
#   'Dividend per Share': 0.225,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'EMN',
#   'Revenue': 9527000000.0,
#   'Revenue Growth': 0.0189,
#   'Gross Profit': 2221000000.0,
#   'Profit Margin': 0.079,
#   'grossProfitMargin': 0.23312690248767,
#   'netProfitMargin': 0.078828592421539,
#   'Total assets': 16072000000.0,
#   'Total debt': 7549000000.0,
#   'Total liabilities': 12482000000.0,
#   'EPS': 5.03,
#   'Dividend per Share': 1.45,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MLM',
#   'Revenue': 2957951000.0,
#   'Revenue Growth': 0.3722,
#   'Gross Profit': 522360000.0,
#   'Profit Margin': 0.053,
#   'grossProfitMargin': 0.17659521743260995,
#   'netProfitMargin': 0.0526043196794,
#   'Total assets': 7219754000.0,
#   'Total debt': 1585578000.0,
#   'Total liabilities': 2867006000.0,
#   'EPS': 2.73,
#   'Dividend per Share': 1.6,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'MOS',
#   'Revenue': 9055800000.0,
#   'Revenue Growth': -0.0921,
#   'Gross Profit': 1926600000.0,
#   'Profit Margin': 0.114,
#   'grossProfitMargin': 0.21274763135228,
#   'netProfitMargin': 0.11358466397226,
#   'Total assets': 18283000000.0,
#   'Total debt': 3832500000.0,
#   'Total liabilities': 7562400000.0,
#   'EPS': 2.69,
#   'Dividend per Share': 1.0,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'FMC',
#   'Revenue': 3258700000.0,
#   'Revenue Growth': 0.0409,
#   'Gross Profit': 1210900000.0,
#   'Profit Margin': 0.094,
#   'grossProfitMargin': 0.37158989781201,
#   'netProfitMargin': 0.09436278270475998,
#   'Total assets': 5326000000.0,
#   'Total debt': 1714300000.0,
#   'Total liabilities': 3762000000.0,
#   'EPS': 2.3,
#   'Dividend per Share': 0.6,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'ALB',
#   'Revenue': 2445548000.0,
#   'Revenue Growth': 0.0214,
#   'Gross Profit': 770848000.0,
#   'Profit Margin': 0.055,
#   'grossProfitMargin': 0.31520460853764,
#   'netProfitMargin': 0.054513753154712005,
#   'Total assets': 5223103000.0,
#   'Total debt': 2934131000.0,
#   'Total liabilities': 3734468000.0,
#   'EPS': 1.69,
#   'Dividend per Share': 1.1,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'ECL',
#   'Revenue': 14280500000.0,
#   'Revenue Growth': 0.0775,
#   'Gross Profit': 6601400000.0,
#   'Profit Margin': 0.084,
#   'grossProfitMargin': 0.46226672735548,
#   'netProfitMargin': 0.084226742761108,
#   'Total assets': 19427400000.0,
#   'Total debt': 6548200000.0,
#   'Total liabilities': 12045300000.0,
#   'EPS': 4.01,
#   'Dividend per Share': 1.155,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'PPG',
#   'Revenue': 14791000000.0,
#   'Revenue Growth': 0.0369,
#   'Gross Profit': 6443000000.0,
#   'Profit Margin': 0.142,
#   'grossProfitMargin': 0.4356027313907101,
#   'netProfitMargin': 0.14211344736664,
#   'Total assets': 17535000000.0,
#   'Total debt': 4014000000.0,
#   'Total liabilities': 12270000000.0,
#   'EPS': 7.6,
#   'Dividend per Share': 1.31,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'SHW',
#   'Revenue': 11129533000.0,
#   'Revenue Growth': 0.0927,
#   'Gross Profit': 5164484000.0,
#   'Profit Margin': 0.078,
#   'grossProfitMargin': 0.46403420520879,
#   'netProfitMargin': 0.07780083854372,
#   'Total assets': 5699333000.0,
#   'Total debt': 1798697000.0,
#   'Total liabilities': 4702863000.0,
#   'EPS': 9.0,
#   'Dividend per Share': 2.2,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'IFF',
#   'Revenue': 3088533000.0,
#   'Revenue Growth': 0.0459,
#   'Gross Profit': 1362150000.0,
#   'Profit Margin': 0.134,
#   'grossProfitMargin': 0.44103462711909,
#   'netProfitMargin': 0.13422003261743,
#   'Total assets': 3494621000.0,
#   'Total debt': 942322000.0,
#   'Total liabilities': 1971932000.0,
#   'EPS': 5.09,
#   'Dividend per Share': 1.72,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'APD',
#   'Revenue': 10439000000.0,
#   'Revenue Growth': 0.0254,
#   'Gross Profit': 2809100000.0,
#   'Profit Margin': 0.095,
#   'grossProfitMargin': 0.26909665676789,
#   'netProfitMargin': 0.094999521026918,
#   'Total assets': 17779100000.0,
#   'Total debt': 6118500000.0,
#   'Total liabilities': 9970500000.0,
#   'EPS': 4.66,
#   'Dividend per Share': 3.02,
#   'Sector': 'Basic Materials'},
#  {'ticker': 'PFE',
#   'Revenue': 49605000000.0,
#   'Revenue Growth': -0.0384,
#   'Gross Profit': 40028000000.0,
#   'Profit Margin': 0.184,
#   'grossProfitMargin': 0.80693478479992,
#   'netProfitMargin': 0.18415482310251,
#   'Total assets': 167566000000.0,
#   'Total debt': 36682000000.0,
#   'Total liabilities': 95944000000.0,
#   'EPS': 1.44,
#   'Dividend per Share': 1.04,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BMY',
#   'Revenue': 15879000000.0,
#   'Revenue Growth': -0.0309,
#   'Gross Profit': 11947000000.0,
#   'Profit Margin': 0.126,
#   'grossProfitMargin': 0.75237735373764,
#   'netProfitMargin': 0.12620442093331,
#   'Total assets': 33749000000.0,
#   'Total debt': 7832000000.0,
#   'Total liabilities': 18766000000.0,
#   'EPS': 1.21,
#   'Dividend per Share': 1.45,
#   'Sector': 'Healthcare'},
#  {'ticker': 'GILD',
#   'Revenue': 24890000000.0,
#   'Revenue Growth': 1.2219,
#   'Gross Profit': 21102000000.0,
#   'Profit Margin': 0.486,
#   'grossProfitMargin': 0.8478103656086801,
#   'netProfitMargin': 0.48617918842909,
#   'Total assets': 34664000000.0,
#   'Total debt': 12404000000.0,
#   'Total liabilities': 18845000000.0,
#   'EPS': 7.95,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABBV',
#   'Revenue': 19960000000.0,
#   'Revenue Growth': 0.0623,
#   'Gross Profit': 15534000000.0,
#   'Profit Margin': 0.08900000000000001,
#   'grossProfitMargin': 0.77825651302605,
#   'netProfitMargin': 0.08887775551102199,
#   'Total assets': 27513000000.0,
#   'Total debt': 14977000000.0,
#   'Total liabilities': 25771000000.0,
#   'EPS': 1.11,
#   'Dividend per Share': 1.66,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MRK',
#   'Revenue': 42237000000.0,
#   'Revenue Growth': -0.0408,
#   'Gross Profit': 25469000000.0,
#   'Profit Margin': 0.282,
#   'grossProfitMargin': 0.60300210715723,
#   'netProfitMargin': 0.28221701351895,
#   'Total assets': 98167000000.0,
#   'Total debt': 21403000000.0,
#   'Total liabilities': 49376000000.0,
#   'EPS': 4.12,
#   'Dividend per Share': 1.77,
#   'Sector': 'Healthcare'},
#  {'ticker': 'JNJ',
#   'Revenue': 74331000000.0,
#   'Revenue Growth': 0.0423,
#   'Gross Profit': 51585000000.0,
#   'Profit Margin': 0.194,
#   'grossProfitMargin': 0.69399039431731,
#   'netProfitMargin': 0.1860731054338,
#   'Total assets': 130358000000.0,
#   'Total debt': 18180000000.0,
#   'Total liabilities': 60606000000.0,
#   'EPS': 5.8,
#   'Dividend per Share': 2.59,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BSX',
#   'Revenue': 7380000000.0,
#   'Revenue Growth': 0.0332,
#   'Gross Profit': 5170000000.0,
#   'Profit Margin': -0.016,
#   'grossProfitMargin': 0.7005420054200501,
#   'netProfitMargin': -0.016124661246612,
#   'Total assets': 17024000000.0,
#   'Total debt': 4244000000.0,
#   'Total liabilities': 10567000000.0,
#   'EPS': -0.09,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABT',
#   'Revenue': 20247000000.0,
#   'Revenue Growth': 0.03,
#   'Gross Profit': 11029000000.0,
#   'Profit Margin': 0.113,
#   'grossProfitMargin': 0.54472267496419,
#   'netProfitMargin': 0.11280683558058,
#   'Total assets': 41207000000.0,
#   'Total debt': 7830000000.0,
#   'Total liabilities': 19568000000.0,
#   'EPS': 1.5,
#   'Dividend per Share': 0.88,
#   'Sector': 'Healthcare'},
#  {'ticker': 'WBA',
#   'Revenue': 76392000000.0,
#   'Revenue Growth': 0.0578,
#   'Gross Profit': 21569000000.0,
#   'Profit Margin': 0.025,
#   'grossProfitMargin': 0.28234631898628004,
#   'netProfitMargin': 0.025290606346214,
#   'Total assets': 37250000000.0,
#   'Total debt': 4490000000.0,
#   'Total liabilities': 16633000000.0,
#   'EPS': 2.03,
#   'Dividend per Share': 1.2819999999999998,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MDT',
#   'Revenue': 17005000000.0,
#   'Revenue Growth': 0.025,
#   'Gross Profit': 12672000000.0,
#   'Profit Margin': 0.18,
#   'grossProfitMargin': 0.74519259041458,
#   'netProfitMargin': 0.18024110555719,
#   'Total assets': 37943000000.0,
#   'Total debt': 11928000000.0,
#   'Total liabilities': 18500000000.0,
#   'EPS': 3.06,
#   'Dividend per Share': 1.12,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CVS',
#   'Revenue': 139367000000.0,
#   'Revenue Growth': 0.0994,
#   'Gross Profit': 25367000000.0,
#   'Profit Margin': 0.033,
#   'grossProfitMargin': 0.18201582871124,
#   'netProfitMargin': 0.033322092030395,
#   'Total assets': 74187000000.0,
#   'Total debt': 12890000000.0,
#   'Total liabilities': 36224000000.0,
#   'EPS': 3.98,
#   'Dividend per Share': 1.1,
#   'Sector': 'Healthcare'},
#  {'ticker': 'UNH',
#   'Revenue': 130474000000.0,
#   'Revenue Growth': 0.0652,
#   'Gross Profit': 33015000000.0,
#   'Profit Margin': 0.043,
#   'grossProfitMargin': 0.2530389196315,
#   'netProfitMargin': 0.043066051473857,
#   'Total assets': 86382000000.0,
#   'Total debt': 17406000000.0,
#   'Total liabilities': 52540000000.0,
#   'EPS': 5.78,
#   'Dividend per Share': 1.405,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CNC',
#   'Revenue': 16560000000.0,
#   'Revenue Growth': 0.5244,
#   'Gross Profit': 1904000000.0,
#   'Profit Margin': 0.016,
#   'grossProfitMargin': 0.11497584541063,
#   'netProfitMargin': 0.016364734299517,
#   'Total assets': 5824000000.0,
#   'Total debt': 879000000.0,
#   'Total liabilities': 3933000000.0,
#   'EPS': 1.165,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CI',
#   'Revenue': 34914000000.0,
#   'Revenue Growth': 0.0783,
#   'Gross Profit': 11673000000.0,
#   'Profit Margin': 0.06,
#   'grossProfitMargin': 0.33433579652861,
#   'netProfitMargin': 0.06020507532794901,
#   'Total assets': 55870000000.0,
#   'Total debt': 5126000000.0,
#   'Total liabilities': 44991000000.0,
#   'EPS': 7.97,
#   'Dividend per Share': 0.04,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CELG',
#   'Revenue': 7670400000.0,
#   'Revenue Growth': 0.1812,
#   'Gross Profit': 7284500000.0,
#   'Profit Margin': 0.261,
#   'grossProfitMargin': 0.94968971631206,
#   'netProfitMargin': 0.26072955778056,
#   'Total assets': 17340100000.0,
#   'Total debt': 6871600000.0,
#   'Total liabilities': 10815300000.0,
#   'EPS': 2.49,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BIIB',
#   'Revenue': 9703300000.0,
#   'Revenue Growth': 0.3997,
#   'Gross Profit': 8532300000.0,
#   'Profit Margin': 0.302,
#   'grossProfitMargin': 0.8793194067997501,
#   'netProfitMargin': 0.30245380437583,
#   'Total assets': 14314700000.0,
#   'Total debt': 583400000.0,
#   'Total liabilities': 3500700000.0,
#   'EPS': 12.42,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MYL',
#   'Revenue': 7719600000.0,
#   'Revenue Growth': 0.1173,
#   'Gross Profit': 3528000000.0,
#   'Profit Margin': 0.12,
#   'grossProfitMargin': 0.45701849836779,
#   'netProfitMargin': 0.12039483911083,
#   'Total assets': 15820500000.0,
#   'Total debt': 8503500000.0,
#   'Total liabilities': 12544500000.0,
#   'EPS': 2.49,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'XRAY',
#   'Revenue': 2922600000.0,
#   'Revenue Growth': -0.0096,
#   'Gross Profit': 1599800000.0,
#   'Profit Margin': 0.11,
#   'grossProfitMargin': 0.54738931088757,
#   'netProfitMargin': 0.11048381578047,
#   'Total assets': 4646500000.0,
#   'Total debt': 1261900000.0,
#   'Total liabilities': 2324300000.0,
#   'EPS': 2.28,
#   'Dividend per Share': 0.265,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ALXN',
#   'Revenue': 2234000000.0,
#   'Revenue Growth': 0.44,
#   'Gross Profit': 2060000000.0,
#   'Profit Margin': 0.294,
#   'grossProfitMargin': 0.92211280214861,
#   'netProfitMargin': 0.29409131602507,
#   'Total assets': 4201962000.0,
#   'Total debt': 164599000.0,
#   'Total liabilities': 899944000.0,
#   'EPS': 3.32,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AMGN',
#   'Revenue': 20063000000.0,
#   'Revenue Growth': 0.0743,
#   'Gross Profit': 15641000000.0,
#   'Profit Margin': 0.257,
#   'grossProfitMargin': 0.77959427802422,
#   'netProfitMargin': 0.25709016597717,
#   'Total assets': 69009000000.0,
#   'Total debt': 30715000000.0,
#   'Total liabilities': 43231000000.0,
#   'EPS': 6.8,
#   'Dividend per Share': 2.44,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BDX',
#   'Revenue': 8446000000.0,
#   'Revenue Growth': 0.0487,
#   'Gross Profit': 4301000000.0,
#   'Profit Margin': 0.14,
#   'grossProfitMargin': 0.5092351408951,
#   'netProfitMargin': 0.14030310206015,
#   'Total assets': 12447000000.0,
#   'Total debt': 3971000000.0,
#   'Total liabilities': 7394000000.0,
#   'EPS': 6.13,
#   'Dividend per Share': 2.18,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HOLX',
#   'Revenue': 2530700000.0,
#   'Revenue Growth': 0.0154,
#   'Gross Profit': 1245500000.0,
#   'Profit Margin': 0.006999999999999999,
#   'grossProfitMargin': 0.49215632038566,
#   'netProfitMargin': 0.0068360532658948,
#   'Total assets': 8414700000.0,
#   'Total debt': 4267700000.0,
#   'Total liabilities': 6351700000.0,
#   'EPS': 0.06,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ANTM',
#   'Revenue': 73874100000.0,
#   'Revenue Growth': 0.0401,
#   'Gross Profit': 17019200000.0,
#   'Profit Margin': 0.035,
#   'grossProfitMargin': 0.23038114846746,
#   'netProfitMargin': 0.034784856939035005,
#   'Total assets': 61676300000.0,
#   'Total debt': 15043900000.0,
#   'Total liabilities': 37425000000.0,
#   'EPS': 9.31,
#   'Dividend per Share': 1.7519999999999998,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ZBH',
#   'Revenue': 4673300000.0,
#   'Revenue Growth': 0.0108,
#   'Gross Profit': 3430500000.0,
#   'Profit Margin': 0.154,
#   'grossProfitMargin': 0.73406372370702,
#   'netProfitMargin': 0.15413091391522,
#   'Total assets': 9658000000.0,
#   'Total debt': 1425500000.0,
#   'Total liabilities': 3106300000.0,
#   'EPS': 4.26,
#   'Dividend per Share': 0.88,
#   'Sector': 'Healthcare'},
#  {'ticker': 'LLY',
#   'Revenue': 19615600000.0,
#   'Revenue Growth': -0.1513,
#   'Gross Profit': 14683100000.0,
#   'Profit Margin': 0.122,
#   'grossProfitMargin': 0.74854197679398,
#   'netProfitMargin': 0.12186728930035,
#   'Total assets': 36307600000.0,
#   'Total debt': 8021500000.0,
#   'Total liabilities': 20919500000.0,
#   'EPS': 2.23,
#   'Dividend per Share': 1.96,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HSIC',
#   'Revenue': 10371390000.0,
#   'Revenue Growth': 0.0848,
#   'Gross Profit': 2911315000.0,
#   'Profit Margin': 0.045,
#   'grossProfitMargin': 0.2807063469795301,
#   'netProfitMargin': 0.044938720846482,
#   'Total assets': 6138807000.0,
#   'Total debt': 731490000.0,
#   'Total liabilities': 2757835000.0,
#   'EPS': 2.765,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'BAX',
#   'Revenue': 10719000000.0,
#   'Revenue Growth': 0.1387,
#   'Gross Profit': 4581000000.0,
#   'Profit Margin': 0.233,
#   'grossProfitMargin': 0.4273719563392101,
#   'netProfitMargin': 0.23295083496595004,
#   'Total assets': 26138000000.0,
#   'Total debt': 9029000000.0,
#   'Total liabilities': 17982000000.0,
#   'EPS': 4.61,
#   'Dividend per Share': 2.05,
#   'Sector': 'Healthcare'},
#  {'ticker': 'AGN',
#   'Revenue': 4676500000.0,
#   'Revenue Growth': 0.7969,
#   'Gross Profit': 2971700000.0,
#   'Profit Margin': -0.349,
#   'grossProfitMargin': 0.63545386507003,
#   'netProfitMargin': -0.34865818453972,
#   'Total assets': 52758000000.0,
#   'Total debt': 15531100000.0,
#   'Total liabilities': 24422500000.0,
#   'EPS': -7.42,
#   'Dividend per Share': 0.2,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HCA',
#   'Revenue': 36918000000.0,
#   'Revenue Growth': 0.08,
#   'Gross Profit': 14015000000.0,
#   'Profit Margin': 0.051,
#   'grossProfitMargin': 0.37962511512,
#   'netProfitMargin': 0.05078823338209,
#   'Total assets': 30980000000.0,
#   'Total debt': 29426000000.0,
#   'Total liabilities': 37478000000.0,
#   'EPS': 4.3,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'VRTX',
#   'Revenue': 580415000.0,
#   'Revenue Growth': -0.5211,
#   'Gross Profit': 519428000.0,
#   'Profit Margin': -1.272,
#   'grossProfitMargin': 0.8949251828433101,
#   'netProfitMargin': -1.2724602224271,
#   'Total assets': 2334679000.0,
#   'Total debt': 824947000.0,
#   'Total liabilities': 1238496000.0,
#   'EPS': -3.14,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'NKTR',
#   'Revenue': 200707000.0,
#   'Revenue Growth': 0.3477,
#   'Gross Profit': 172174000.0,
#   'Profit Margin': -0.269,
#   'grossProfitMargin': 0.8578375442809699,
#   'netProfitMargin': -0.26863039156581,
#   'Total assets': 441621000.0,
#   'Total debt': 133651000.0,
#   'Total liabilities': 405289000.0,
#   'EPS': -0.42,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'A',
#   'Revenue': 4048000000.0,
#   'Revenue Growth': 0.0395,
#   'Gross Profit': 1976000000.0,
#   'Profit Margin': 0.136,
#   'grossProfitMargin': 0.48814229249012,
#   'netProfitMargin': 0.13562252964427,
#   'Total assets': 10815000000.0,
#   'Total debt': 1663000000.0,
#   'Total liabilities': 5511000000.0,
#   'EPS': 1.65,
#   'Dividend per Share': 0.528,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DHR',
#   'Revenue': 12866900000.0,
#   'Revenue Growth': -0.2962,
#   'Gross Profit': 6849500000.0,
#   'Profit Margin': 0.202,
#   'grossProfitMargin': 0.5323349058436799,
#   'netProfitMargin': 0.20194452432210006,
#   'Total assets': 36991700000.0,
#   'Total debt': 3473400000.0,
#   'Total liabilities': 13541900000.0,
#   'EPS': 3.7,
#   'Dividend per Share': 0.4,
#   'Sector': 'Healthcare'},
#  {'ticker': 'PKI',
#   'Revenue': 2069880000.0,
#   'Revenue Growth': -0.0407,
#   'Gross Profit': 934598000.0,
#   'Profit Margin': 0.076,
#   'grossProfitMargin': 0.4515227935919,
#   'netProfitMargin': 0.076225674918353,
#   'Total assets': 4127576000.0,
#   'Total debt': 1046468000.0,
#   'Total liabilities': 2085474000.0,
#   'EPS': 1.4,
#   'Dividend per Share': 0.28,
#   'Sector': 'Healthcare'},
#  {'ticker': 'UHS',
#   'Revenue': 8205088000.0,
#   'Revenue Growth': 0.1136,
#   'Gross Profit': 8205088000.0,
#   'Profit Margin': 0.066,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.06646400379861901,
#   'Total assets': 8974443000.0,
#   'Total debt': 3278534000.0,
#   'Total liabilities': 5183363000.0,
#   'EPS': 5.52,
#   'Dividend per Share': 0.3,
#   'Sector': 'Healthcare'},
#  {'ticker': 'TMO',
#   'Revenue': 16889600000.0,
#   'Revenue Growth': 0.2902,
#   'Gross Profit': 7492000000.0,
#   'Profit Margin': 0.112,
#   'grossProfitMargin': 0.44358658582797,
#   'netProfitMargin': 0.11216369837059,
#   'Total assets': 42852100000.0,
#   'Total debt': 14564000000.0,
#   'Total liabilities': 22304000000.0,
#   'EPS': 4.76,
#   'Dividend per Share': 0.6,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DGX',
#   'Revenue': 7435000000.0,
#   'Revenue Growth': 0.0404,
#   'Gross Profit': 2798000000.0,
#   'Profit Margin': 0.075,
#   'grossProfitMargin': 0.37632817753867,
#   'netProfitMargin': 0.07478143913920599,
#   'Total assets': 9857000000.0,
#   'Total debt': 3742000000.0,
#   'Total liabilities': 5527000000.0,
#   'EPS': 3.83,
#   'Dividend per Share': 1.29,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MCK',
#   'Revenue': 137392000000.0,
#   'Revenue Growth': 0.1244,
#   'Gross Profit': 8352000000.0,
#   'Profit Margin': 0.009000000000000001,
#   'grossProfitMargin': 0.06078956562245299,
#   'netProfitMargin': 0.0091926749737976,
#   'Total assets': 51759000000.0,
#   'Total debt': 10594000000.0,
#   'Total liabilities': 41441000000.0,
#   'EPS': 5.51,
#   'Dividend per Share': 0.92,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ABC',
#   'Revenue': 119569127000.0,
#   'Revenue Growth': 0.3594,
#   'Gross Profit': 2982366000.0,
#   'Profit Margin': 0.002,
#   'grossProfitMargin': 0.024942609140234,
#   'netProfitMargin': 0.0022934850063763,
#   'Total assets': 21532183000.0,
#   'Total debt': 1995632000.0,
#   'Total liabilities': 19575284000.0,
#   'EPS': 1.21,
#   'Dividend per Share': 0.94,
#   'Sector': 'Healthcare'},
#  {'ticker': 'EW',
#   'Revenue': 2322900000.0,
#   'Revenue Growth': 0.1356,
#   'Gross Profit': 1697300000.0,
#   'Profit Margin': 0.349,
#   'grossProfitMargin': 0.7306814757415301,
#   'netProfitMargin': 0.34917559946618,
#   'Total assets': 3523000000.0,
#   'Total debt': 598100000.0,
#   'Total liabilities': 1331600000.0,
#   'EPS': 3.81,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ZTS',
#   'Revenue': 4785000000.0,
#   'Revenue Growth': 0.0491,
#   'Gross Profit': 3068000000.0,
#   'Profit Margin': 0.122,
#   'grossProfitMargin': 0.6411703239289399,
#   'netProfitMargin': 0.12183908045977,
#   'Total assets': 6588000000.0,
#   'Total debt': 3631000000.0,
#   'Total liabilities': 5251000000.0,
#   'EPS': 1.16,
#   'Dividend per Share': 0.28800000000000003,
#   'Sector': 'Healthcare'},
#  {'ticker': 'SYK',
#   'Revenue': 9675000000.0,
#   'Revenue Growth': 0.0725,
#   'Gross Profit': 6356000000.0,
#   'Profit Margin': 0.053,
#   'grossProfitMargin': 0.65695090439276,
#   'netProfitMargin': 0.053229974160207,
#   'Total assets': 17279000000.0,
#   'Total debt': 3973000000.0,
#   'Total liabilities': 8684000000.0,
#   'EPS': 1.36,
#   'Dividend per Share': 1.26,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ILMN',
#   'Revenue': 1861358000.0,
#   'Revenue Growth': 0.3097,
#   'Gross Profit': 1297710000.0,
#   'Profit Margin': 0.19,
#   'grossProfitMargin': 0.6971845287150601,
#   'netProfitMargin': 0.18983505591079,
#   'Total assets': 3339640000.0,
#   'Total debt': 1291036000.0,
#   'Total liabilities': 1876842000.0,
#   'EPS': 2.61,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ISRG',
#   'Revenue': 2131700000.0,
#   'Revenue Growth': -0.0589,
#   'Gross Profit': 1413800000.0,
#   'Profit Margin': 0.196,
#   'grossProfitMargin': 0.66322653281419,
#   'netProfitMargin': 0.19646291692077,
#   'Total assets': 3959400000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 580000000.0,
#   'EPS': 3.783,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CAH',
#   'Revenue': 91084000000.0,
#   'Revenue Growth': -0.099,
#   'Gross Profit': 5161000000.0,
#   'Profit Margin': 0.013,
#   'grossProfitMargin': 0.056661982345966,
#   'netProfitMargin': 0.012801370163805,
#   'Total assets': 26033000000.0,
#   'Total debt': 3972000000.0,
#   'Total liabilities': 19632000000.0,
#   'EPS': 3.42,
#   'Dividend per Share': 1.25,
#   'Sector': 'Healthcare'},
#  {'ticker': 'DVA',
#   'Revenue': 12795106000.0,
#   'Revenue Growth': 0.0876,
#   'Gross Profit': 3675801000.0,
#   'Profit Margin': 0.057,
#   'grossProfitMargin': 0.28728179352324,
#   'netProfitMargin': 0.05651488936473099,
#   'Total assets': 17617432000.0,
#   'Total debt': 8418778000.0,
#   'Total liabilities': 11427156000.0,
#   'EPS': 3.41,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'REGN',
#   'Revenue': 2819557000.0,
#   'Revenue Growth': 0.3396,
#   'Gross Profit': 2614539000.0,
#   'Profit Margin': 0.12,
#   'grossProfitMargin': 0.92728715894022,
#   'netProfitMargin': 0.11992167563911997,
#   'Total assets': 3837672000.0,
#   'Total debt': 457711000.0,
#   'Total liabilities': 1287421000.0,
#   'EPS': 3.36,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'HUM',
#   'Revenue': 48500000000.0,
#   'Revenue Growth': 0.174,
#   'Gross Profit': 10334000000.0,
#   'Profit Margin': 0.024,
#   'grossProfitMargin': 0.21307216494845,
#   'netProfitMargin': 0.023649484536082,
#   'Total assets': 23527000000.0,
#   'Total debt': 4159000000.0,
#   'Total liabilities': 13881000000.0,
#   'EPS': 7.44,
#   'Dividend per Share': 1.11,
#   'Sector': 'Healthcare'},
#  {'ticker': 'RMD',
#   'Revenue': 1554973000.0,
#   'Revenue Growth': 0.0268,
#   'Gross Profit': 989786000.0,
#   'Profit Margin': 0.222,
#   'grossProfitMargin': 0.6365293802529001,
#   'netProfitMargin': 0.22204436990224,
#   'Total assets': 2360962000.0,
#   'Total debt': 300788000.0,
#   'Total liabilities': 602714000.0,
#   'EPS': 2.44,
#   'Dividend per Share': 1.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'INCY',
#   'Revenue': 511495000.0,
#   'Revenue Growth': 0.441,
#   'Gross Profit': 508491000.0,
#   'Profit Margin': -0.095,
#   'grossProfitMargin': 0.99412701981447,
#   'netProfitMargin': -0.094782940204694,
#   'Total assets': 796477000.0,
#   'Total debt': 675167000.0,
#   'Total liabilities': 878105000.0,
#   'EPS': -0.29,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'LH',
#   'Revenue': 6011600000.0,
#   'Revenue Growth': 0.035,
#   'Gross Profit': 2203100000.0,
#   'Profit Margin': 0.085,
#   'grossProfitMargin': 0.36647481535698,
#   'netProfitMargin': 0.085035597844168,
#   'Total assets': 7301800000.0,
#   'Total debt': 3029800000.0,
#   'Total liabilities': 4463600000.0,
#   'EPS': 6.03,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'COO',
#   'Revenue': 1717776000.0,
#   'Revenue Growth': 0.0819,
#   'Gross Profit': 1091570000.0,
#   'Profit Margin': 0.157,
#   'grossProfitMargin': 0.63545537951398,
#   'netProfitMargin': 0.15709615223405,
#   'Total assets': 4458340000.0,
#   'Total debt': 1382351000.0,
#   'Total liabilities': 1869900000.0,
#   'EPS': 5.61,
#   'Dividend per Share': 0.06,
#   'Sector': 'Healthcare'},
#  {'ticker': 'IDXX',
#   'Revenue': 1485807000.0,
#   'Revenue Growth': 0.079,
#   'Gross Profit': 816116000.0,
#   'Profit Margin': 0.122,
#   'grossProfitMargin': 0.54927456930813,
#   'netProfitMargin': 0.12242909072309,
#   'Total assets': 1384211000.0,
#   'Total debt': 899000000.0,
#   'Total liabilities': 1266622000.0,
#   'EPS': 1.82,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'ALGN',
#   'Revenue': 761653000.0,
#   'Revenue Growth': 0.1537,
#   'Gross Profit': 578443000.0,
#   'Profit Margin': 0.191,
#   'grossProfitMargin': 0.7594573907015401,
#   'netProfitMargin': 0.19146776813063,
#   'Total assets': 987997000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 235226000.0,
#   'EPS': 1.81,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'PRGO',
#   'Revenue': 3914100000.0,
#   'Revenue Growth': 0.1057,
#   'Gross Profit': 1644200000.0,
#   'Profit Margin': 0.059,
#   'grossProfitMargin': 0.42007102526762,
#   'netProfitMargin': 0.059477274469227015,
#   'Total assets': 13852800000.0,
#   'Total debt': 1974000000.0,
#   'Total liabilities': 5159100000.0,
#   'EPS': 2.02,
#   'Dividend per Share': 0.39,
#   'Sector': 'Healthcare'},
#  {'ticker': 'IQV',
#   'Revenue': 5460000000.0,
#   'Revenue Growth': 0.0707,
#   'Gross Profit': 1501000000.0,
#   'Profit Margin': 0.065,
#   'grossProfitMargin': 0.27490842490842,
#   'netProfitMargin': 0.065384615384615,
#   'Total assets': 3295953000.0,
#   'Total debt': 2283438000.0,
#   'Total liabilities': 3999965000.0,
#   'EPS': 2.78,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'VAR',
#   'Revenue': 3049800000.0,
#   'Revenue Growth': 0.0363,
#   'Gross Profit': 1301700000.0,
#   'Profit Margin': 0.132,
#   'grossProfitMargin': 0.42681487310643,
#   'netProfitMargin': 0.13236933569414,
#   'Total assets': 3357290000.0,
#   'Total debt': 437500000.0,
#   'Total liabilities': 1740870000.0,
#   'EPS': 3.88,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'MTD',
#   'Revenue': 2485983000.0,
#   'Revenue Growth': 0.045,
#   'Gross Profit': 1358750000.0,
#   'Profit Margin': 0.136,
#   'grossProfitMargin': 0.54656447771364,
#   'netProfitMargin': 0.13605925704239,
#   'Total assets': 2009110000.0,
#   'Total debt': 451954000.0,
#   'Total liabilities': 1289515000.0,
#   'EPS': 11.71,
#   'Dividend per Share': 0.0,
#   'Sector': 'Healthcare'},
#  {'ticker': 'CMCSA',
#   'Revenue': 68775000000.0,
#   'Revenue Growth': 0.0637,
#   'Gross Profit': 68775000000.0,
#   'Profit Margin': 0.122,
#   'grossProfitMargin': 1.0,
#   'netProfitMargin': 0.12184660123591,
#   'Total assets': 159186000000.0,
#   'Total debt': 48081000000.0,
#   'Total liabilities': 106118000000.0,
#   'EPS': 1.62,
#   'Dividend per Share': 0.338,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'F',
#   'Revenue': 144077000000.0,
#   'Revenue Growth': -0.0193,
#   'Gross Profit': 12174000000.0,
#   'Profit Margin': 0.009000000000000001,
#   'grossProfitMargin': 0.08449648451869501,
#   'netProfitMargin': 0.0085440424217606,
#   'Total assets': 208615000000.0,
#   'Total debt': 119171000000.0,
#   'Total liabilities': 183808000000.0,
#   'EPS': 0.31,
#   'Dividend per Share': 0.5,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'NKE',
#   'Revenue': 27799000000.0,
#   'Revenue Growth': 0.0982,
#   'Gross Profit': 12446000000.0,
#   'Profit Margin': 0.097,
#   'grossProfitMargin': 0.44771394654484,
#   'netProfitMargin': 0.096873988272959,
#   'Total assets': 18594000000.0,
#   'Total debt': 1373000000.0,
#   'Total liabilities': 7770000000.0,
#   'EPS': 1.52,
#   'Dividend per Share': 0.465,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'GM',
#   'Revenue': 155929000000.0,
#   'Revenue Growth': 0.0032,
#   'Gross Profit': 13808000000.0,
#   'Profit Margin': 0.018000000000000002,
#   'grossProfitMargin': 0.08855312353699403,
#   'netProfitMargin': 0.02532562897216,
#   'Total assets': 177501000000.0,
#   'Total debt': 46665000000.0,
#   'Total liabilities': 141477000000.0,
#   'EPS': 1.75,
#   'Dividend per Share': 1.2,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'LOW',
#   'Revenue': 53417000000.0,
#   'Revenue Growth': 0.0573,
#   'Gross Profit': 18476000000.0,
#   'Profit Margin': 0.043,
#   'grossProfitMargin': 0.34588239698971995,
#   'netProfitMargin': 0.042795364771515,
#   'Total assets': 32732000000.0,
#   'Total debt': 10521000000.0,
#   'Total liabilities': 20879000000.0,
#   'EPS': 2.14,
#   'Dividend per Share': 0.7,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'MAT',
#   'Revenue': 6023819000.0,
#   'Revenue Growth': -0.0711,
#   'Gross Profit': 3001022000.0,
#   'Profit Margin': 0.083,
#   'grossProfitMargin': 0.49819259177608,
#   'netProfitMargin': 0.08281689738685699,
#   'Total assets': 6721983000.0,
#   'Total debt': 2100000000.0,
#   'Total liabilities': 3772912000.0,
#   'EPS': 1.46,
#   'Dividend per Share': 1.52,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'DIS',
#   'Revenue': 48813000000.0,
#   'Revenue Growth': 0.0837,
#   'Gross Profit': 22393000000.0,
#   'Profit Margin': 0.154,
#   'grossProfitMargin': 0.45875074263004,
#   'netProfitMargin': 0.15366808022453002,
#   'Total assets': 84141000000.0,
#   'Total debt': 14795000000.0,
#   'Total liabilities': 35963000000.0,
#   'EPS': 4.31,
#   'Dividend per Share': 0.86,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'LEN',
#   'Revenue': 7779812000.0,
#   'Revenue Growth': 0.3108,
#   'Gross Profit': 1099199000.0,
#   'Profit Margin': 0.08199999999999999,
#   'grossProfitMargin': 0.14128863268161,
#   'netProfitMargin': 0.08212486368565201,
#   'Total assets': 12923151000.0,
#   'Total debt': 4661266000.0,
#   'Total liabilities': 7671849000.0,
#   'EPS': 3.12,
#   'Dividend per Share': 0.16,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'MGM',
#   'Revenue': 10848264000.0,
#   'Revenue Growth': 0.0269,
#   'Gross Profit': 4479566000.0,
#   'Profit Margin': -0.014,
#   'grossProfitMargin': 0.41292929449357,
#   'netProfitMargin': -0.013815390185932,
#   'Total assets': 26593914000.0,
#   'Total debt': 14241760000.0,
#   'Total liabilities': 18965640000.0,
#   'EPS': -0.31,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'CCL',
#   'Revenue': 15884000000.0,
#   'Revenue Growth': 0.0277,
#   'Gross Profit': 5463000000.0,
#   'Profit Margin': 0.077,
#   'grossProfitMargin': 0.34393099974817,
#   'netProfitMargin': 0.07655502392344501,
#   'Total assets': 39448000000.0,
#   'Total debt': 9088000000.0,
#   'Total liabilities': 15244000000.0,
#   'EPS': 1.57,
#   'Dividend per Share': 1.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'DISCA',
#   'Revenue': 6265000000.0,
#   'Revenue Growth': 0.1319,
#   'Gross Profit': 4141000000.0,
#   'Profit Margin': 0.182,
#   'grossProfitMargin': 0.6609736632083,
#   'netProfitMargin': 0.18180367118915,
#   'Total assets': 15970000000.0,
#   'Total debt': 7109000000.0,
#   'Total liabilities': 9619000000.0,
#   'EPS': 1.67,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'EBAY',
#   'Revenue': 8790000000.0,
#   'Revenue Growth': 0.0646,
#   'Gross Profit': 7127000000.0,
#   'Profit Margin': 0.005,
#   'grossProfitMargin': 0.81080773606371,
#   'netProfitMargin': 0.0052332195676906,
#   'Total assets': 45132000000.0,
#   'Total debt': 7627000000.0,
#   'Total liabilities': 25226000000.0,
#   'EPS': 0.04,
#   'Dividend per Share': 0.0,
#   'Sector': 'Consumer Cyclical'},
#  {'ticker': 'DISCK',
#   'Revenue': 6265000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 4141000000.0,
#   'Profit Margin': 0.18116520351157006,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 16014000000.0,
#   'Total debt': 6046000000.0,
#   'Total liabilities': 10412000000.0,
# ...
#   'Profit Margin': 0.092,
#   'grossProfitMargin': 0.30382945358695,
#   'netProfitMargin': 0.09228322243757303,
#   'Total assets': 17930452000.0,
#   'Total debt': 26733000.0,
#   'Total liabilities': 11645115000.0,
#   'EPS': 4.64,
#   'Dividend per Share': 1.86,
#   'Sector': 'Technology'},
#  {'ticker': 'ADSK',
#   'Revenue': 2273900000.0,
#   'Revenue Growth': -0.0166,
#   'Gross Profit': 1999600000.0,
#   'Profit Margin': 0.101,
#   'grossProfitMargin': 0.8793702449536,
#   'netProfitMargin': 0.1006200800387,
#   'Total assets': 4595000000.0,
#   'Total debt': 746400000.0,
#   'Total liabilities': 2333500000.0,
#   'EPS': 1.02,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'IBM',
#   'Revenue': 92793000000.0,
#   'Revenue Growth': -0.0567,
#   'Gross Profit': 46407000000.0,
#   'Profit Margin': 0.13,
#   'grossProfitMargin': 0.50011315508713,
#   'netProfitMargin': 0.1295571864257,
#   'Total assets': 117271000000.0,
#   'Total debt': 40722000000.0,
#   'Total liabilities': 105257000000.0,
#   'EPS': 11.97,
#   'Dividend per Share': 4.25,
#   'Sector': 'Technology'},
#  {'ticker': 'IT',
#   'Revenue': 2021441000.0,
#   'Revenue Growth': 0.133,
#   'Gross Profit': 1223508000.0,
#   'Profit Margin': 0.091,
#   'grossProfitMargin': 0.6052652538461399,
#   'netProfitMargin': 0.090908416322811,
#   'Total assets': 1904351000.0,
#   'Total debt': 405000000.0,
#   'Total liabilities': 1743180000.0,
#   'EPS': 2.06,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'GLW',
#   'Revenue': 9715000000.0,
#   'Revenue Growth': 0.2425,
#   'Gross Profit': 4052000000.0,
#   'Profit Margin': 0.254,
#   'grossProfitMargin': 0.41708697889861,
#   'netProfitMargin': 0.25445187853834,
#   'Total assets': 30063000000.0,
#   'Total debt': 3263000000.0,
#   'Total liabilities': 8411000000.0,
#   'EPS': 1.82,
#   'Dividend per Share': 0.4,
#   'Sector': 'Technology'},
#  {'ticker': 'STX',
#   'Revenue': 13724000000.0,
#   'Revenue Growth': -0.0437,
#   'Gross Profit': 3846000000.0,
#   'Profit Margin': 0.114,
#   'grossProfitMargin': 0.28023899737686,
#   'netProfitMargin': 0.11439813465462,
#   'Total assets': 9492000000.0,
#   'Total debt': 3920000000.0,
#   'Total liabilities': 6660000000.0,
#   'EPS': 4.66,
#   'Dividend per Share': 1.67,
#   'Sector': 'Technology'},
#  {'ticker': 'ADBE',
#   'Revenue': 4147065000.0,
#   'Revenue Growth': 0.0226,
#   'Gross Profit': 3524985000.0,
#   'Profit Margin': 0.065,
#   'grossProfitMargin': 0.84999511702855,
#   'netProfitMargin': 0.064719265311733,
#   'Total assets': 10785829000.0,
#   'Total debt': 1514315000.0,
#   'Total liabilities': 4009924000.0,
#   'EPS': 0.54,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'LRCX',
#   'Revenue': 4607309000.0,
#   'Revenue Growth': 0.2802,
#   'Gross Profit': 2007481000.0,
#   'Profit Margin': 0.13699999999999998,
#   'grossProfitMargin': 0.43571659725883,
#   'netProfitMargin': 0.13723607424638,
#   'Total assets': 7993306000.0,
#   'Total debt': 1335469000.0,
#   'Total liabilities': 2780222000.0,
#   'EPS': 3.84,
#   'Dividend per Share': 0.18,
#   'Sector': 'Technology'},
#  {'ticker': 'GOOGL',
#   'Revenue': 66001000000.0,
#   'Revenue Growth': 0.1888,
#   'Gross Profit': 40310000000.0,
#   'Profit Margin': 0.214,
#   'grossProfitMargin': 0.61074832199512,
#   'netProfitMargin': 0.21417857305192,
#   'Total assets': 129187000000.0,
#   'Total debt': 5237000000.0,
#   'Total liabilities': 25327000000.0,
#   'EPS': 20.91,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CTSH',
#   'Revenue': 10263000000.0,
#   'Revenue Growth': 0.1606,
#   'Gross Profit': 4122000000.0,
#   'Profit Margin': 0.14,
#   'grossProfitMargin': 0.40163694826074,
#   'netProfitMargin': 0.14021241352431,
#   'Total assets': 11479000000.0,
#   'Total debt': 1637500000.0,
#   'Total liabilities': 3738800000.0,
#   'EPS': 2.37,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'CTXS',
#   'Revenue': 3142856000.0,
#   'Revenue Growth': 0.0769,
#   'Gross Profit': 2522637000.0,
#   'Profit Margin': 0.08,
#   'grossProfitMargin': 0.8026575191481898,
#   'netProfitMargin': 0.080093710943168,
#   'Total assets': 5512007000.0,
#   'Total debt': 1292953000.0,
#   'Total liabilities': 3338362000.0,
#   'EPS': 1.48,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'TTWO',
#   'Revenue': 2350568000.0,
#   'Revenue Growth': 0.9354,
#   'Gross Profit': 936241000.0,
#   'Profit Margin': 0.154,
#   'grossProfitMargin': 0.3983041545703,
#   'netProfitMargin': 0.15383728528594,
#   'Total assets': 1799630000.0,
#   'Total debt': 454031000.0,
#   'Total liabilities': 997824000.0,
#   'EPS': 3.79,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'KLAC',
#   'Revenue': 2929408000.0,
#   'Revenue Growth': 0.0305,
#   'Gross Profit': 1696446000.0,
#   'Profit Margin': 0.199,
#   'grossProfitMargin': 0.57910881652539,
#   'netProfitMargin': 0.19893268537534,
#   'Total assets': 5535846000.0,
#   'Total debt': 745101000.0,
#   'Total liabilities': 1866500000.0,
#   'EPS': 3.51,
#   'Dividend per Share': 1.8,
#   'Sector': 'Technology'},
#  {'ticker': 'GOOG',
#   'Revenue': 66001000000.0,
#   'Revenue Growth': nan,
#   'Gross Profit': 40310000000.0,
#   'Profit Margin': 0.21884516901259,
#   'grossProfitMargin': nan,
#   'netProfitMargin': nan,
#   'Total assets': 131133000000.0,
#   'Total debt': 2992000000.0,
#   'Total liabilities': 26633000000.0,
#   'EPS': 21.37,
#   'Dividend per Share': nan,
#   'Sector': 'Technology'},
#  {'ticker': 'QRVO',
#   'Revenue': 1148231000.0,
#   'Revenue Growth': 0.1909,
#   'Gross Profit': 404927000.0,
#   'Profit Margin': 0.011,
#   'grossProfitMargin': 0.35265290694991,
#   'netProfitMargin': 0.011009979699207,
#   'Total assets': 920312000.0,
#   'Total debt': 87263000.0,
#   'Total liabilities': 243961000.0,
#   'EPS': 0.18,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'TEL',
#   'Revenue': 11973000000.0,
#   'Revenue Growth': 0.0512,
#   'Gross Profit': 3972000000.0,
#   'Profit Margin': 0.149,
#   'grossProfitMargin': 0.33174642946629995,
#   'netProfitMargin': 0.14875135722041,
#   'Total assets': 20152000000.0,
#   'Total debt': 3858000000.0,
#   'Total liabilities': 11139000000.0,
#   'EPS': 4.34,
#   'Dividend per Share': 8.08,
#   'Sector': 'Technology'},
#  {'ticker': 'EA',
#   'Revenue': 3575000000.0,
#   'Revenue Growth': -0.0585,
#   'Gross Profit': 2228000000.0,
#   'Profit Margin': 0.002,
#   'grossProfitMargin': 0.6232167832167801,
#   'netProfitMargin': 0.0022377622377622,
#   'Total assets': 5716000000.0,
#   'Total debt': 580000000.0,
#   'Total liabilities': 3294000000.0,
#   'EPS': 0.03,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'INFO',
#   'Revenue': 1065100000.0,
#   'Revenue Growth': 0.1236,
#   'Gross Profit': 1360600000.0,
#   'Profit Margin': 0.155,
#   'grossProfitMargin': 1.2774387381467,
#   'netProfitMargin': 0.15510280724815,
#   'Total assets': 3300000000.0,
#   'Total debt': nan,
#   'Total liabilities': 1029400000.0,
#   'EPS': 0.92,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'AKAM',
#   'Revenue': 1963874000.0,
#   'Revenue Growth': 0.2446,
#   'Gross Profit': 1352931000.0,
#   'Profit Margin': 0.17,
#   'grossProfitMargin': 0.68890926810987,
#   'netProfitMargin': 0.17004553245269,
#   'Total assets': 4001546000.0,
#   'Total debt': 604851000.0,
#   'Total liabilities': 1056211000.0,
#   'EPS': 1.87,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'NTAP',
#   'Revenue': 6325000000.0,
#   'Revenue Growth': -0.0012,
#   'Gross Profit': 3919000000.0,
#   'Profit Margin': 0.101,
#   'grossProfitMargin': 0.6196047430830001,
#   'netProfitMargin': 0.10086956521739,
#   'Total assets': 9213800000.0,
#   'Total debt': 990100000.0,
#   'Total liabilities': 5427300000.0,
#   'EPS': 1.87,
#   'Dividend per Share': 0.6,
#   'Sector': 'Technology'},
#  {'ticker': 'JNPR',
#   'Revenue': 4627100000.0,
#   'Revenue Growth': -0.009000000000000001,
#   'Gross Profit': 2858200000.0,
#   'Profit Margin': -0.07200000000000001,
#   'grossProfitMargin': 0.6177087160424499,
#   'netProfitMargin': -0.072248276458257,
#   'Total assets': 8281400000.0,
#   'Total debt': 1349000000.0,
#   'Total liabilities': 3362300000.0,
#   'EPS': -0.73,
#   'Dividend per Share': 0.2,
#   'Sector': 'Technology'},
#  {'ticker': 'MCHP',
#   'Revenue': 1931217000.0,
#   'Revenue Growth': 0.221,
#   'Gross Profit': 1128743000.0,
#   'Profit Margin': 0.205,
#   'grossProfitMargin': 0.5844723819229,
#   'netProfitMargin': 0.20467974339497,
#   'Total assets': 4067630000.0,
#   'Total debt': 1020758000.0,
#   'Total liabilities': 1932169000.0,
#   'EPS': 1.99,
#   'Dividend per Share': 1.4169999999999998,
#   'Sector': 'Technology'},
#  {'ticker': 'INTU',
#   'Revenue': 4243000000.0,
#   'Revenue Growth': 0.0753,
#   'Gross Profit': 3640000000.0,
#   'Profit Margin': 0.214,
#   'grossProfitMargin': 0.85788357294367,
#   'netProfitMargin': 0.21376384633514,
#   'Total assets': 5201000000.0,
#   'Total debt': 499000000.0,
#   'Total liabilities': 2123000000.0,
#   'EPS': 3.18,
#   'Dividend per Share': 0.76,
#   'Sector': 'Technology'},
#  {'ticker': 'XLNX',
#   'Revenue': 2382531000.0,
#   'Revenue Growth': 0.0986,
#   'Gross Profit': 1639278000.0,
#   'Profit Margin': 0.265,
#   'grossProfitMargin': 0.68804057533774,
#   'netProfitMargin': 0.26458753317376005,
#   'Total assets': 5037349000.0,
#   'Total debt': 1558871000.0,
#   'Total liabilities': 2284667000.0,
#   'EPS': 2.37,
#   'Dividend per Share': 1.0,
#   'Sector': 'Technology'},
#  {'ticker': 'SWKS',
#   'Revenue': 2291500000.0,
#   'Revenue Growth': 0.2787,
#   'Gross Profit': 1022700000.0,
#   'Profit Margin': 0.2,
#   'grossProfitMargin': 0.44630154920358,
#   'netProfitMargin': 0.19973816277547,
#   'Total assets': 2973800000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 441400000.0,
#   'EPS': 2.44,
#   'Dividend per Share': 0.22,
#   'Sector': 'Technology'},
#  {'ticker': 'ADI',
#   'Revenue': 2864773000.0,
#   'Revenue Growth': 0.0877,
#   'Gross Profit': 1830188000.0,
#   'Profit Margin': 0.22,
#   'grossProfitMargin': 0.6388596932462,
#   'netProfitMargin': 0.21967534600473,
#   'Total assets': 6859690000.0,
#   'Total debt': 872789000.0,
#   'Total liabilities': 2101793000.0,
#   'EPS': 2.01,
#   'Dividend per Share': 1.45,
#   'Sector': 'Technology'},
#  {'ticker': 'VRSN',
#   'Revenue': 1010117000.0,
#   'Revenue Growth': 0.0467,
#   'Gross Profit': 821692000.0,
#   'Profit Margin': 0.35200000000000004,
#   'grossProfitMargin': 0.81346220289333,
#   'netProfitMargin': 0.35170183255999,
#   'Total assets': 1901150000.0,
#   'Total debt': 1360795000.0,
#   'Total liabilities': 2784616000.0,
#   'EPS': 2.8,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'DXC',
#   'Revenue': 19032000000.0,
#   'Revenue Growth': -0.1294,
#   'Gross Profit': 2188000000.0,
#   'Profit Margin': -0.064,
#   'grossProfitMargin': 0.24122212640138,
#   'netProfitMargin': 0.00024639645189109,
#   'Total assets': nan,
#   'Total debt': nan,
#   'Total liabilities': nan,
#   'EPS': nan,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'EQIX',
#   'Revenue': 2443776000.0,
#   'Revenue Growth': 0.1352,
#   'Gross Profit': 1245891000.0,
#   'Profit Margin': -0.106,
#   'grossProfitMargin': 0.50982209498743,
#   'netProfitMargin': -0.10620736106746,
#   'Total assets': 7781978000.0,
#   'Total debt': 4643954000.0,
#   'Total liabilities': 5511847000.0,
#   'EPS': -4.96,
#   'Dividend per Share': 7.57,
#   'Sector': 'Technology'},
#  {'ticker': 'FIS',
#   'Revenue': 6413000000.0,
#   'Revenue Growth': 0.0577,
#   'Gross Profit': 2086000000.0,
#   'Profit Margin': 0.106,
#   'grossProfitMargin': 0.3252767815375,
#   'netProfitMargin': 0.10587868392328,
#   'Total assets': 14520500000.0,
#   'Total debt': 5067700000.0,
#   'Total liabilities': 7829000000.0,
#   'EPS': 2.38,
#   'Dividend per Share': 0.96,
#   'Sector': 'Technology'},
#  {'ticker': 'AYI',
#   'Revenue': 2393500000.0,
#   'Revenue Growth': 0.1457,
#   'Gross Profit': 979200000.0,
#   'Profit Margin': 0.073,
#   'grossProfitMargin': 0.4091080008356,
#   'netProfitMargin': 0.07344892416962599,
#   'Total assets': 2166400000.0,
#   'Total debt': 351900000.0,
#   'Total liabilities': 1002900000.0,
#   'EPS': 4.07,
#   'Dividend per Share': 0.52,
#   'Sector': 'Technology'},
#  {'ticker': 'MSI',
#   'Revenue': 5881000000.0,
#   'Revenue Growth': -0.0556,
#   'Gross Profit': 2831000000.0,
#   'Profit Margin': 0.221,
#   'grossProfitMargin': 0.48138071756504,
#   'netProfitMargin': 0.22088080258459,
#   'Total assets': 10423000000.0,
#   'Total debt': 3400000000.0,
#   'Total liabilities': 7657000000.0,
#   'EPS': 5.29,
#   'Dividend per Share': 1.3,
#   'Sector': 'Technology'},
#  {'ticker': 'WHR',
#   'Revenue': 19872000000.0,
#   'Revenue Growth': 0.0588,
#   'Gross Profit': 3395000000.0,
#   'Profit Margin': 0.033,
#   'grossProfitMargin': 0.17084339774557006,
#   'netProfitMargin': 0.032709339774557006,
#   'Total assets': 20002000000.0,
#   'Total debt': 4347000000.0,
#   'Total liabilities': 14206000000.0,
#   'EPS': 8.3,
#   'Dividend per Share': 2.875,
#   'Sector': 'Technology'},
#  {'ticker': 'FFIV',
#   'Revenue': 1732046000.0,
#   'Revenue Growth': 0.1693,
#   'Gross Profit': 1422087000.0,
#   'Profit Margin': 0.18,
#   'grossProfitMargin': 0.8210445911944599,
#   'netProfitMargin': 0.17966208749652,
#   'Total assets': 2184950000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 815640000.0,
#   'EPS': 4.13,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'FLIR',
#   'Revenue': 1530654000.0,
#   'Revenue Growth': 0.0229,
#   'Gross Profit': 750373000.0,
#   'Profit Margin': 0.131,
#   'grossProfitMargin': 0.4902303198502101,
#   'netProfitMargin': 0.13083361752558,
#   'Total assets': 2349311000.0,
#   'Total debt': 372986000.0,
#   'Total liabilities': 739538000.0,
#   'EPS': 1.42,
#   'Dividend per Share': 0.4,
#   'Sector': 'Technology'},
#  {'ticker': 'APH',
#   'Revenue': 5345500000.0,
#   'Revenue Growth': 0.1584,
#   'Gross Profit': 1693800000.0,
#   'Profit Margin': 0.133,
#   'grossProfitMargin': 0.31686465251146,
#   'netProfitMargin': 0.13265363389767,
#   'Total assets': 6985900000.0,
#   'Total debt': 2656200000.0,
#   'Total liabilities': 4048000000.0,
#   'EPS': 2.26,
#   'Dividend per Share': 0.45,
#   'Sector': 'Technology'},
#  {'ticker': 'WAT',
#   'Revenue': 1989344000.0,
#   'Revenue Growth': 0.0447,
#   'Gross Profit': 1164431000.0,
#   'Profit Margin': 0.217,
#   'grossProfitMargin': 0.58533416040665,
#   'netProfitMargin': 0.2169659948204,
#   'Total assets': 3874690000.0,
#   'Total debt': 1462693000.0,
#   'Total liabilities': 1980024000.0,
#   'EPS': 5.12,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'GRMN',
#   'Revenue': 2870658000.0,
#   'Revenue Growth': 0.0907,
#   'Gross Profit': 1604412000.0,
#   'Profit Margin': 0.127,
#   'grossProfitMargin': 0.5589004332804499,
#   'netProfitMargin': 0.12687369934001,
#   'Total assets': 4693303000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 1289936000.0,
#   'EPS': 1.89,
#   'Dividend per Share': 1.89,
#   'Sector': 'Technology'},
#  {'ticker': 'AME',
#   'Revenue': 4021964000.0,
#   'Revenue Growth': 0.119,
#   'Gross Profit': 1361223000.0,
#   'Profit Margin': 0.145,
#   'grossProfitMargin': 0.33844733567978,
#   'netProfitMargin': 0.14531706400157002,
#   'Total assets': 6420963000.0,
#   'Total debt': 1714026000.0,
#   'Total liabilities': 3181402000.0,
#   'EPS': 2.39,
#   'Dividend per Share': 0.33,
#   'Sector': 'Technology'},
#  {'ticker': 'ANSS',
#   'Revenue': 936021000.0,
#   'Revenue Growth': 0.0868,
#   'Gross Profit': 782635000.0,
#   'Profit Margin': 0.272,
#   'grossProfitMargin': 0.8361297449523001,
#   'netProfitMargin': 0.27209859607851,
#   'Total assets': 2752879000.0,
#   'Total debt': 0.0,
#   'Total liabilities': 535378000.0,
#   'EPS': 2.77,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'SNPS',
#   'Revenue': 2057472000.0,
#   'Revenue Growth': 0.0485,
#   'Gross Profit': 1600587000.0,
#   'Profit Margin': 0.126,
#   'grossProfitMargin': 0.77793865481523,
#   'netProfitMargin': 0.12594290469081,
#   'Total assets': 4775499000.0,
#   'Total debt': 75000000.0,
#   'Total liabilities': 1719329000.0,
#   'EPS': 1.67,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'},
#  {'ticker': 'IPGP',
#   'Revenue': 769832000.0,
#   'Revenue Growth': 0.188,
#   'Gross Profit': 416518000.0,
#   'Profit Margin': 0.26,
#   'grossProfitMargin': 0.54105051491754,
#   'netProfitMargin': 0.26037499090711,
#   'Total assets': 1210887000.0,
#   'Total debt': 35631000.0,
#   'Total liabilities': 164326000.0,
#   'EPS': 3.85,
#   'Dividend per Share': 0.0,
#   'Sector': 'Technology'}]

# %%
top500_df
top500_dict=top500_df.to_dict('records')
top500_dict
# Out:
# [{'Symbol': 'MMM', 'Name': '3M Company', 'Sector': 'Industrials'},
#  {'Symbol': 'AOS', 'Name': 'A.O. Smith Corp', 'Sector': 'Industrials'},
#  {'Symbol': 'ABT', 'Name': 'Abbott Laboratories', 'Sector': 'Health Care'},
#  {'Symbol': 'ABBV', 'Name': 'AbbVie Inc.', 'Sector': 'Health Care'},
#  {'Symbol': 'ACN',
#   'Name': 'Accenture plc',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'ATVI',
#   'Name': 'Activision Blizzard',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'AYI', 'Name': 'Acuity Brands Inc', 'Sector': 'Industrials'},
#  {'Symbol': 'ADBE',
#   'Name': 'Adobe Systems Inc',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'AAP',
#   'Name': 'Advance Auto Parts',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'AMD',
#   'Name': 'Advanced Micro Devices Inc',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'AES', 'Name': 'AES Corp', 'Sector': 'Utilities'},
#  {'Symbol': 'AET', 'Name': 'Aetna Inc', 'Sector': 'Health Care'},
#  {'Symbol': 'AMG',
#   'Name': 'Affiliated Managers Group Inc',
#   'Sector': 'Financials'},
#  {'Symbol': 'AFL', 'Name': 'AFLAC Inc', 'Sector': 'Financials'},
#  {'Symbol': 'A', 'Name': 'Agilent Technologies Inc', 'Sector': 'Health Care'},
#  {'Symbol': 'APD',
#   'Name': 'Air Products & Chemicals Inc',
#   'Sector': 'Materials'},
#  {'Symbol': 'AKAM',
#   'Name': 'Akamai Technologies Inc',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'ALK', 'Name': 'Alaska Air Group Inc', 'Sector': 'Industrials'},
#  {'Symbol': 'ALB', 'Name': 'Albemarle Corp', 'Sector': 'Materials'},
#  {'Symbol': 'ARE',
#   'Name': 'Alexandria Real Estate Equities Inc',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'ALXN',
#   'Name': 'Alexion Pharmaceuticals',
#   'Sector': 'Health Care'},
#  {'Symbol': 'ALGN', 'Name': 'Align Technology', 'Sector': 'Health Care'},
#  {'Symbol': 'ALLE', 'Name': 'Allegion', 'Sector': 'Industrials'},
#  {'Symbol': 'AGN', 'Name': 'Allergan, Plc', 'Sector': 'Health Care'},
#  {'Symbol': 'ADS',
#   'Name': 'Alliance Data Systems',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'LNT', 'Name': 'Alliant Energy Corp', 'Sector': 'Utilities'},
#  {'Symbol': 'ALL', 'Name': 'Allstate Corp', 'Sector': 'Financials'},
#  {'Symbol': 'GOOGL',
#   'Name': 'Alphabet Inc Class A',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'GOOG',
#   'Name': 'Alphabet Inc Class C',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'MO', 'Name': 'Altria Group Inc', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'AMZN',
#   'Name': 'Amazon.com Inc.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'AEE', 'Name': 'Ameren Corp', 'Sector': 'Utilities'},
#  {'Symbol': 'AAL', 'Name': 'American Airlines Group', 'Sector': 'Industrials'},
#  {'Symbol': 'AEP', 'Name': 'American Electric Power', 'Sector': 'Utilities'},
#  {'Symbol': 'AXP', 'Name': 'American Express Co', 'Sector': 'Financials'},
#  {'Symbol': 'AIG',
#   'Name': 'American International Group, Inc.',
#   'Sector': 'Financials'},
#  {'Symbol': 'AMT', 'Name': 'American Tower Corp A', 'Sector': 'Real Estate'},
#  {'Symbol': 'AWK',
#   'Name': 'American Water Works Company Inc',
#   'Sector': 'Utilities'},
#  {'Symbol': 'AMP', 'Name': 'Ameriprise Financial', 'Sector': 'Financials'},
#  {'Symbol': 'ABC', 'Name': 'AmerisourceBergen Corp', 'Sector': 'Health Care'},
#  {'Symbol': 'AME', 'Name': 'AMETEK Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'AMGN', 'Name': 'Amgen Inc.', 'Sector': 'Health Care'},
#  {'Symbol': 'APH',
#   'Name': 'Amphenol Corp',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'APC', 'Name': 'Anadarko Petroleum Corp', 'Sector': 'Energy'},
#  {'Symbol': 'ADI',
#   'Name': 'Analog Devices, Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'ANDV', 'Name': 'Andeavor', 'Sector': 'Energy'},
#  {'Symbol': 'ANSS', 'Name': 'ANSYS', 'Sector': 'Information Technology'},
#  {'Symbol': 'ANTM', 'Name': 'Anthem Inc.', 'Sector': 'Health Care'},
#  {'Symbol': 'AON', 'Name': 'Aon plc', 'Sector': 'Financials'},
#  {'Symbol': 'APA', 'Name': 'Apache Corporation', 'Sector': 'Energy'},
#  {'Symbol': 'AIV',
#   'Name': 'Apartment Investment & Management',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'AAPL', 'Name': 'Apple Inc.', 'Sector': 'Information Technology'},
#  {'Symbol': 'AMAT',
#   'Name': 'Applied Materials Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'APTV', 'Name': 'Aptiv Plc', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'ADM',
#   'Name': 'Archer-Daniels-Midland Co',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'ARNC', 'Name': 'Arconic Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'AJG',
#   'Name': 'Arthur J. Gallagher & Co.',
#   'Sector': 'Financials'},
#  {'Symbol': 'AIZ', 'Name': 'Assurant Inc.', 'Sector': 'Financials'},
#  {'Symbol': 'T', 'Name': 'AT&T Inc.', 'Sector': 'Telecommunication Services'},
#  {'Symbol': 'ADSK',
#   'Name': 'Autodesk Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'ADP',
#   'Name': 'Automatic Data Processing',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'AZO', 'Name': 'AutoZone Inc', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'AVB',
#   'Name': 'AvalonBay Communities, Inc.',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'AVY', 'Name': 'Avery Dennison Corp', 'Sector': 'Materials'},
#  {'Symbol': 'BHGE', 'Name': 'Baker Hughes, a GE Company', 'Sector': 'Energy'},
#  {'Symbol': 'BLL', 'Name': 'Ball Corp', 'Sector': 'Materials'},
#  {'Symbol': 'BAC', 'Name': 'Bank of America Corp', 'Sector': 'Financials'},
#  {'Symbol': 'BAX',
#   'Name': 'Baxter International Inc.',
#   'Sector': 'Health Care'},
#  {'Symbol': 'BBT', 'Name': 'BB&T Corporation', 'Sector': 'Financials'},
#  {'Symbol': 'BDX', 'Name': 'Becton Dickinson', 'Sector': 'Health Care'},
#  {'Symbol': 'BRK.B', 'Name': 'Berkshire Hathaway', 'Sector': 'Financials'},
#  {'Symbol': 'BBY',
#   'Name': 'Best Buy Co. Inc.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'BIIB', 'Name': 'Biogen Inc.', 'Sector': 'Health Care'},
#  {'Symbol': 'BLK', 'Name': 'BlackRock', 'Sector': 'Financials'},
#  {'Symbol': 'HRB', 'Name': 'Block H&R', 'Sector': 'Financials'},
#  {'Symbol': 'BA', 'Name': 'Boeing Company', 'Sector': 'Industrials'},
#  {'Symbol': 'BKNG',
#   'Name': 'Booking Holdings Inc',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'BWA', 'Name': 'BorgWarner', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'BXP', 'Name': 'Boston Properties', 'Sector': 'Real Estate'},
#  {'Symbol': 'BSX', 'Name': 'Boston Scientific', 'Sector': 'Health Care'},
#  {'Symbol': 'BHF',
#   'Name': 'Brighthouse Financial Inc',
#   'Sector': 'Financials'},
#  {'Symbol': 'BMY', 'Name': 'Bristol-Myers Squibb', 'Sector': 'Health Care'},
#  {'Symbol': 'AVGO', 'Name': 'Broadcom', 'Sector': 'Information Technology'},
#  {'Symbol': 'BF.B',
#   'Name': 'Brown-Forman Corp.',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'CHRW',
#   'Name': 'C. H. Robinson Worldwide',
#   'Sector': 'Industrials'},
#  {'Symbol': 'CA', 'Name': 'CA, Inc.', 'Sector': 'Information Technology'},
#  {'Symbol': 'COG', 'Name': 'Cabot Oil & Gas', 'Sector': 'Energy'},
#  {'Symbol': 'CDNS',
#   'Name': 'Cadence Design Systems',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'CPB', 'Name': 'Campbell Soup', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'COF', 'Name': 'Capital One Financial', 'Sector': 'Financials'},
#  {'Symbol': 'CAH', 'Name': 'Cardinal Health Inc.', 'Sector': 'Health Care'},
#  {'Symbol': 'KMX', 'Name': 'Carmax Inc', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'CCL',
#   'Name': 'Carnival Corp.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'CAT', 'Name': 'Caterpillar Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'CBOE', 'Name': 'Cboe Global Markets', 'Sector': 'Financials'},
#  {'Symbol': 'CBRE', 'Name': 'CBRE Group', 'Sector': 'Real Estate'},
#  {'Symbol': 'CBS', 'Name': 'CBS Corp.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'CELG', 'Name': 'Celgene Corp.', 'Sector': 'Health Care'},
#  {'Symbol': 'CNC', 'Name': 'Centene Corporation', 'Sector': 'Health Care'},
#  {'Symbol': 'CNP', 'Name': 'CenterPoint Energy', 'Sector': 'Utilities'},
#  {'Symbol': 'CTL',
#   'Name': 'CenturyLink Inc',
#   'Sector': 'Telecommunication Services'},
#  {'Symbol': 'CERN', 'Name': 'Cerner', 'Sector': 'Health Care'},
#  {'Symbol': 'CF', 'Name': 'CF Industries Holdings Inc', 'Sector': 'Materials'},
#  {'Symbol': 'SCHW',
#   'Name': 'Charles Schwab Corporation',
#   'Sector': 'Financials'},
#  {'Symbol': 'CHTR',
#   'Name': 'Charter Communications',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'CVX', 'Name': 'Chevron Corp.', 'Sector': 'Energy'},
#  {'Symbol': 'CMG',
#   'Name': 'Chipotle Mexican Grill',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'CB', 'Name': 'Chubb Limited', 'Sector': 'Financials'},
#  {'Symbol': 'CHD', 'Name': 'Church & Dwight', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'CI', 'Name': 'CIGNA Corp.', 'Sector': 'Health Care'},
#  {'Symbol': 'XEC', 'Name': 'Cimarex Energy', 'Sector': 'Energy'},
#  {'Symbol': 'CINF', 'Name': 'Cincinnati Financial', 'Sector': 'Financials'},
#  {'Symbol': 'CTAS', 'Name': 'Cintas Corporation', 'Sector': 'Industrials'},
#  {'Symbol': 'CSCO',
#   'Name': 'Cisco Systems',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'C', 'Name': 'Citigroup Inc.', 'Sector': 'Financials'},
#  {'Symbol': 'CFG', 'Name': 'Citizens Financial Group', 'Sector': 'Financials'},
#  {'Symbol': 'CTXS',
#   'Name': 'Citrix Systems',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'CME', 'Name': 'CME Group Inc.', 'Sector': 'Financials'},
#  {'Symbol': 'CMS', 'Name': 'CMS Energy', 'Sector': 'Utilities'},
#  {'Symbol': 'KO',
#   'Name': 'Coca-Cola Company (The)',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'CTSH',
#   'Name': 'Cognizant Technology Solutions',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'CL', 'Name': 'Colgate-Palmolive', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'CMCSA',
#   'Name': 'Comcast Corp.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'CMA', 'Name': 'Comerica Inc.', 'Sector': 'Financials'},
#  {'Symbol': 'CAG', 'Name': 'Conagra Brands', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'CXO', 'Name': 'Concho Resources', 'Sector': 'Energy'},
#  {'Symbol': 'COP', 'Name': 'ConocoPhillips', 'Sector': 'Energy'},
#  {'Symbol': 'ED', 'Name': 'Consolidated Edison', 'Sector': 'Utilities'},
#  {'Symbol': 'STZ',
#   'Name': 'Constellation Brands',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'GLW', 'Name': 'Corning Inc.', 'Sector': 'Information Technology'},
#  {'Symbol': 'COST',
#   'Name': 'Costco Wholesale Corp.',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'COTY', 'Name': 'Coty, Inc', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'CCI',
#   'Name': 'Crown Castle International Corp.',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'CSRA', 'Name': 'CSRA Inc.', 'Sector': 'Information Technology'},
#  {'Symbol': 'CSX', 'Name': 'CSX Corp.', 'Sector': 'Industrials'},
#  {'Symbol': 'CMI', 'Name': 'Cummins Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'CVS', 'Name': 'CVS Health', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'DHI', 'Name': 'D. R. Horton', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'DHR', 'Name': 'Danaher Corp.', 'Sector': 'Health Care'},
#  {'Symbol': 'DRI',
#   'Name': 'Darden Restaurants',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'DVA', 'Name': 'DaVita Inc.', 'Sector': 'Health Care'},
#  {'Symbol': 'DE', 'Name': 'Deere & Co.', 'Sector': 'Industrials'},
#  {'Symbol': 'DAL', 'Name': 'Delta Air Lines Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'XRAY', 'Name': 'Dentsply Sirona', 'Sector': 'Health Care'},
#  {'Symbol': 'DVN', 'Name': 'Devon Energy Corp.', 'Sector': 'Energy'},
#  {'Symbol': 'DLR',
#   'Name': 'Digital Realty Trust Inc',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'DFS',
#   'Name': 'Discover Financial Services',
#   'Sector': 'Financials'},
#  {'Symbol': 'DISCA',
#   'Name': 'Discovery Inc. Class A',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'DISCK',
#   'Name': 'Discovery Inc. Class C',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'DISH',
#   'Name': 'Dish Network',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'DG',
#   'Name': 'Dollar General',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'DLTR', 'Name': 'Dollar Tree', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'D', 'Name': 'Dominion Energy', 'Sector': 'Utilities'},
#  {'Symbol': 'DOV', 'Name': 'Dover Corp.', 'Sector': 'Industrials'},
#  {'Symbol': 'DWDP', 'Name': 'DowDuPont', 'Sector': 'Materials'},
#  {'Symbol': 'DPS',
#   'Name': 'Dr Pepper Snapple Group',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'DTE', 'Name': 'DTE Energy Co.', 'Sector': 'Utilities'},
#  {'Symbol': 'DUK', 'Name': 'Duke Energy', 'Sector': 'Utilities'},
#  {'Symbol': 'DRE', 'Name': 'Duke Realty Corp', 'Sector': 'Real Estate'},
#  {'Symbol': 'DXC',
#   'Name': 'DXC Technology',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'ETFC', 'Name': 'E*Trade', 'Sector': 'Financials'},
#  {'Symbol': 'EMN', 'Name': 'Eastman Chemical', 'Sector': 'Materials'},
#  {'Symbol': 'ETN', 'Name': 'Eaton Corporation', 'Sector': 'Industrials'},
#  {'Symbol': 'EBAY', 'Name': 'eBay Inc.', 'Sector': 'Information Technology'},
#  {'Symbol': 'ECL', 'Name': 'Ecolab Inc.', 'Sector': 'Materials'},
#  {'Symbol': 'EIX', 'Name': "Edison Int'l", 'Sector': 'Utilities'},
#  {'Symbol': 'EW', 'Name': 'Edwards Lifesciences', 'Sector': 'Health Care'},
#  {'Symbol': 'EA',
#   'Name': 'Electronic Arts',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'EMR',
#   'Name': 'Emerson Electric Company',
#   'Sector': 'Industrials'},
#  {'Symbol': 'ETR', 'Name': 'Entergy Corp.', 'Sector': 'Utilities'},
#  {'Symbol': 'EVHC', 'Name': 'Envision Healthcare', 'Sector': 'Health Care'},
#  {'Symbol': 'EOG', 'Name': 'EOG Resources', 'Sector': 'Energy'},
#  {'Symbol': 'EQT', 'Name': 'EQT Corporation', 'Sector': 'Energy'},
#  {'Symbol': 'EFX', 'Name': 'Equifax Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'EQIX', 'Name': 'Equinix', 'Sector': 'Real Estate'},
#  {'Symbol': 'EQR', 'Name': 'Equity Residential', 'Sector': 'Real Estate'},
#  {'Symbol': 'ESS',
#   'Name': 'Essex Property Trust, Inc.',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'EL', 'Name': 'Estee Lauder Cos.', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'RE', 'Name': 'Everest Re Group Ltd.', 'Sector': 'Financials'},
#  {'Symbol': 'ES', 'Name': 'Eversource Energy', 'Sector': 'Utilities'},
#  {'Symbol': 'EXC', 'Name': 'Exelon Corp.', 'Sector': 'Utilities'},
#  {'Symbol': 'EXPE',
#   'Name': 'Expedia Inc.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'EXPD',
#   'Name': 'Expeditors International',
#   'Sector': 'Industrials'},
#  {'Symbol': 'ESRX', 'Name': 'Express Scripts', 'Sector': 'Health Care'},
#  {'Symbol': 'EXR', 'Name': 'Extra Space Storage', 'Sector': 'Real Estate'},
#  {'Symbol': 'XOM', 'Name': 'Exxon Mobil Corp.', 'Sector': 'Energy'},
#  {'Symbol': 'FFIV', 'Name': 'F5 Networks', 'Sector': 'Information Technology'},
#  {'Symbol': 'FB',
#   'Name': 'Facebook, Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'FAST', 'Name': 'Fastenal Co', 'Sector': 'Industrials'},
#  {'Symbol': 'FRT',
#   'Name': 'Federal Realty Investment Trust',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'FDX', 'Name': 'FedEx Corporation', 'Sector': 'Industrials'},
#  {'Symbol': 'FIS',
#   'Name': 'Fidelity National Information Services',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'FITB', 'Name': 'Fifth Third Bancorp', 'Sector': 'Financials'},
#  {'Symbol': 'FE', 'Name': 'FirstEnergy Corp', 'Sector': 'Utilities'},
#  {'Symbol': 'FISV', 'Name': 'Fiserv Inc', 'Sector': 'Information Technology'},
#  {'Symbol': 'FLIR',
#   'Name': 'FLIR Systems',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'FLS', 'Name': 'Flowserve Corporation', 'Sector': 'Industrials'},
#  {'Symbol': 'FLR', 'Name': 'Fluor Corp.', 'Sector': 'Industrials'},
#  {'Symbol': 'FMC', 'Name': 'FMC Corporation', 'Sector': 'Materials'},
#  {'Symbol': 'FL',
#   'Name': 'Foot Locker Inc',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'F', 'Name': 'Ford Motor', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'FTV', 'Name': 'Fortive Corp', 'Sector': 'Industrials'},
#  {'Symbol': 'FBHS',
#   'Name': 'Fortune Brands Home & Security',
#   'Sector': 'Industrials'},
#  {'Symbol': 'BEN', 'Name': 'Franklin Resources', 'Sector': 'Financials'},
#  {'Symbol': 'FCX', 'Name': 'Freeport-McMoRan Inc.', 'Sector': 'Materials'},
#  {'Symbol': 'GPS', 'Name': 'Gap Inc.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'GRMN', 'Name': 'Garmin Ltd.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'IT', 'Name': 'Gartner Inc', 'Sector': 'Information Technology'},
#  {'Symbol': 'GD', 'Name': 'General Dynamics', 'Sector': 'Industrials'},
#  {'Symbol': 'GE', 'Name': 'General Electric', 'Sector': 'Industrials'},
#  {'Symbol': 'GGP',
#   'Name': 'General Growth Properties Inc.',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'GIS', 'Name': 'General Mills', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'GM',
#   'Name': 'General Motors',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'GPC',
#   'Name': 'Genuine Parts',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'GILD', 'Name': 'Gilead Sciences', 'Sector': 'Health Care'},
#  {'Symbol': 'GPN',
#   'Name': 'Global Payments Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'GS', 'Name': 'Goldman Sachs Group', 'Sector': 'Financials'},
#  {'Symbol': 'GT',
#   'Name': 'Goodyear Tire & Rubber',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'GWW', 'Name': 'Grainger (W.W.) Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'HAL', 'Name': 'Halliburton Co.', 'Sector': 'Energy'},
#  {'Symbol': 'HBI',
#   'Name': 'Hanesbrands Inc',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'HOG',
#   'Name': 'Harley-Davidson',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'HRS',
#   'Name': 'Harris Corporation',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'HIG',
#   'Name': 'Hartford Financial Svc.Gp.',
#   'Sector': 'Financials'},
#  {'Symbol': 'HAS', 'Name': 'Hasbro Inc.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'HCA', 'Name': 'HCA Holdings', 'Sector': 'Health Care'},
#  {'Symbol': 'HCP', 'Name': 'HCP Inc.', 'Sector': 'Real Estate'},
#  {'Symbol': 'HP', 'Name': 'Helmerich & Payne', 'Sector': 'Energy'},
#  {'Symbol': 'HSIC', 'Name': 'Henry Schein', 'Sector': 'Health Care'},
#  {'Symbol': 'HES', 'Name': 'Hess Corporation', 'Sector': 'Energy'},
#  {'Symbol': 'HPE',
#   'Name': 'Hewlett Packard Enterprise',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'HLT',
#   'Name': 'Hilton Worldwide Holdings Inc',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'HOLX', 'Name': 'Hologic', 'Sector': 'Health Care'},
#  {'Symbol': 'HD', 'Name': 'Home Depot', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'HON', 'Name': "Honeywell Int'l Inc.", 'Sector': 'Industrials'},
#  {'Symbol': 'HRL', 'Name': 'Hormel Foods Corp.', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'HST', 'Name': 'Host Hotels & Resorts', 'Sector': 'Real Estate'},
#  {'Symbol': 'HPQ', 'Name': 'HP Inc.', 'Sector': 'Information Technology'},
#  {'Symbol': 'HUM', 'Name': 'Humana Inc.', 'Sector': 'Health Care'},
#  {'Symbol': 'HBAN', 'Name': 'Huntington Bancshares', 'Sector': 'Financials'},
#  {'Symbol': 'HII',
#   'Name': 'Huntington Ingalls Industries',
#   'Sector': 'Industrials'},
#  {'Symbol': 'IDXX', 'Name': 'IDEXX Laboratories', 'Sector': 'Health Care'},
#  {'Symbol': 'INFO', 'Name': 'IHS Markit Ltd.', 'Sector': 'Industrials'},
#  {'Symbol': 'ITW', 'Name': 'Illinois Tool Works', 'Sector': 'Industrials'},
#  {'Symbol': 'ILMN', 'Name': 'Illumina Inc', 'Sector': 'Health Care'},
#  {'Symbol': 'INCY', 'Name': 'Incyte', 'Sector': 'Health Care'},
#  {'Symbol': 'IR', 'Name': 'Ingersoll-Rand PLC', 'Sector': 'Industrials'},
#  {'Symbol': 'INTC', 'Name': 'Intel Corp.', 'Sector': 'Information Technology'},
#  {'Symbol': 'ICE',
#   'Name': 'Intercontinental Exchange',
#   'Sector': 'Financials'},
#  {'Symbol': 'IBM',
#   'Name': 'International Business Machines',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'IP', 'Name': 'International Paper', 'Sector': 'Materials'},
#  {'Symbol': 'IPG',
#   'Name': 'Interpublic Group',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'IFF', 'Name': 'Intl Flavors & Fragrances', 'Sector': 'Materials'},
#  {'Symbol': 'INTU', 'Name': 'Intuit Inc.', 'Sector': 'Information Technology'},
#  {'Symbol': 'ISRG',
#   'Name': 'Intuitive Surgical Inc.',
#   'Sector': 'Health Care'},
#  {'Symbol': 'IVZ', 'Name': 'Invesco Ltd.', 'Sector': 'Financials'},
#  {'Symbol': 'IPGP',
#   'Name': 'IPG Photonics Corp.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'IQV', 'Name': 'IQVIA Holdings Inc.', 'Sector': 'Health Care'},
#  {'Symbol': 'IRM',
#   'Name': 'Iron Mountain Incorporated',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'JBHT',
#   'Name': 'J. B. Hunt Transport Services',
#   'Sector': 'Industrials'},
#  {'Symbol': 'JEC',
#   'Name': 'Jacobs Engineering Group',
#   'Sector': 'Industrials'},
#  {'Symbol': 'SJM', 'Name': 'JM Smucker', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'JNJ', 'Name': 'Johnson & Johnson', 'Sector': 'Health Care'},
#  {'Symbol': 'JCI',
#   'Name': 'Johnson Controls International',
#   'Sector': 'Industrials'},
#  {'Symbol': 'JPM', 'Name': 'JPMorgan Chase & Co.', 'Sector': 'Financials'},
#  {'Symbol': 'JNPR',
#   'Name': 'Juniper Networks',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'KSU', 'Name': 'Kansas City Southern', 'Sector': 'Industrials'},
#  {'Symbol': 'K', 'Name': 'Kellogg Co.', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'KEY', 'Name': 'KeyCorp', 'Sector': 'Financials'},
#  {'Symbol': 'KMB', 'Name': 'Kimberly-Clark', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'KIM', 'Name': 'Kimco Realty', 'Sector': 'Real Estate'},
#  {'Symbol': 'KMI', 'Name': 'Kinder Morgan', 'Sector': 'Energy'},
#  {'Symbol': 'KLAC',
#   'Name': 'KLA-Tencor Corp.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'KSS', 'Name': "Kohl's Corp.", 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'KHC', 'Name': 'Kraft Heinz Co', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'KR', 'Name': 'Kroger Co.', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'LB', 'Name': 'L Brands Inc.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'LLL',
#   'Name': 'L-3 Communications Holdings',
#   'Sector': 'Industrials'},
#  {'Symbol': 'LH',
#   'Name': 'Laboratory Corp. of America Holding',
#   'Sector': 'Health Care'},
#  {'Symbol': 'LRCX',
#   'Name': 'Lam Research',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'LEG',
#   'Name': 'Leggett & Platt',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'LEN', 'Name': 'Lennar Corp.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'LUK', 'Name': 'Leucadia National Corp.', 'Sector': 'Financials'},
#  {'Symbol': 'LLY', 'Name': 'Lilly (Eli) & Co.', 'Sector': 'Health Care'},
#  {'Symbol': 'LNC', 'Name': 'Lincoln National', 'Sector': 'Financials'},
#  {'Symbol': 'LKQ',
#   'Name': 'LKQ Corporation',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'LMT', 'Name': 'Lockheed Martin Corp.', 'Sector': 'Industrials'},
#  {'Symbol': 'L', 'Name': 'Loews Corp.', 'Sector': 'Financials'},
#  {'Symbol': 'LOW', 'Name': "Lowe's Cos.", 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'LYB', 'Name': 'LyondellBasell', 'Sector': 'Materials'},
#  {'Symbol': 'MTB', 'Name': 'M&T Bank Corp.', 'Sector': 'Financials'},
#  {'Symbol': 'MAC', 'Name': 'Macerich', 'Sector': 'Real Estate'},
#  {'Symbol': 'M', 'Name': "Macy's Inc.", 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'MRO', 'Name': 'Marathon Oil Corp.', 'Sector': 'Energy'},
#  {'Symbol': 'MPC', 'Name': 'Marathon Petroleum', 'Sector': 'Energy'},
#  {'Symbol': 'MAR',
#   'Name': "Marriott Int'l.",
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'MMC', 'Name': 'Marsh & McLennan', 'Sector': 'Financials'},
#  {'Symbol': 'MLM', 'Name': 'Martin Marietta Materials', 'Sector': 'Materials'},
#  {'Symbol': 'MAS', 'Name': 'Masco Corp.', 'Sector': 'Industrials'},
#  {'Symbol': 'MA',
#   'Name': 'Mastercard Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'MAT', 'Name': 'Mattel Inc.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'MKC', 'Name': 'McCormick & Co.', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'MCD',
#   'Name': "McDonald's Corp.",
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'MCK', 'Name': 'McKesson Corp.', 'Sector': 'Health Care'},
#  {'Symbol': 'MDT', 'Name': 'Medtronic plc', 'Sector': 'Health Care'},
#  {'Symbol': 'MRK', 'Name': 'Merck & Co.', 'Sector': 'Health Care'},
#  {'Symbol': 'MET', 'Name': 'MetLife Inc.', 'Sector': 'Financials'},
#  {'Symbol': 'MTD', 'Name': 'Mettler Toledo', 'Sector': 'Health Care'},
#  {'Symbol': 'MGM',
#   'Name': 'MGM Resorts International',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'KORS',
#   'Name': 'Michael Kors Holdings',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'MCHP',
#   'Name': 'Microchip Technology',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'MU',
#   'Name': 'Micron Technology',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'MSFT',
#   'Name': 'Microsoft Corp.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'MAA', 'Name': 'Mid-America Apartments', 'Sector': 'Real Estate'},
#  {'Symbol': 'MHK',
#   'Name': 'Mohawk Industries',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'TAP',
#   'Name': 'Molson Coors Brewing Company',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'MDLZ',
#   'Name': 'Mondelez International',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'MON', 'Name': 'Monsanto Co.', 'Sector': 'Materials'},
#  {'Symbol': 'MNST', 'Name': 'Monster Beverage', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'MCO', 'Name': "Moody's Corp", 'Sector': 'Financials'},
#  {'Symbol': 'MS', 'Name': 'Morgan Stanley', 'Sector': 'Financials'},
#  {'Symbol': 'MSI',
#   'Name': 'Motorola Solutions Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'MYL', 'Name': 'Mylan N.V.', 'Sector': 'Health Care'},
#  {'Symbol': 'NDAQ', 'Name': 'Nasdaq, Inc.', 'Sector': 'Financials'},
#  {'Symbol': 'NOV', 'Name': 'National Oilwell Varco Inc.', 'Sector': 'Energy'},
#  {'Symbol': 'NAVI', 'Name': 'Navient', 'Sector': 'Financials'},
#  {'Symbol': 'NKTR', 'Name': 'Nektar Therapeutics', 'Sector': 'Health Care'},
#  {'Symbol': 'NTAP', 'Name': 'NetApp', 'Sector': 'Information Technology'},
#  {'Symbol': 'NFLX',
#   'Name': 'Netflix Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'NWL',
#   'Name': 'Newell Brands',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'NFX', 'Name': 'Newfield Exploration Co', 'Sector': 'Energy'},
#  {'Symbol': 'NEM',
#   'Name': 'Newmont Mining Corporation',
#   'Sector': 'Materials'},
#  {'Symbol': 'NWSA',
#   'Name': 'News Corp. Class A',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'NWS',
#   'Name': 'News Corp. Class B',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'NEE', 'Name': 'NextEra Energy', 'Sector': 'Utilities'},
#  {'Symbol': 'NLSN', 'Name': 'Nielsen Holdings', 'Sector': 'Industrials'},
#  {'Symbol': 'NKE', 'Name': 'Nike', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'NI', 'Name': 'NiSource Inc.', 'Sector': 'Utilities'},
#  {'Symbol': 'NBL', 'Name': 'Noble Energy Inc', 'Sector': 'Energy'},
#  {'Symbol': 'JWN', 'Name': 'Nordstrom', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'NSC', 'Name': 'Norfolk Southern Corp.', 'Sector': 'Industrials'},
#  {'Symbol': 'NTRS', 'Name': 'Northern Trust Corp.', 'Sector': 'Financials'},
#  {'Symbol': 'NOC', 'Name': 'Northrop Grumman Corp.', 'Sector': 'Industrials'},
#  {'Symbol': 'NCLH',
#   'Name': 'Norwegian Cruise Line',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'NRG', 'Name': 'NRG Energy', 'Sector': 'Utilities'},
#  {'Symbol': 'NUE', 'Name': 'Nucor Corp.', 'Sector': 'Materials'},
#  {'Symbol': 'NVDA',
#   'Name': 'Nvidia Corporation',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'ORLY',
#   'Name': "O'Reilly Automotive",
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'OXY', 'Name': 'Occidental Petroleum', 'Sector': 'Energy'},
#  {'Symbol': 'OMC',
#   'Name': 'Omnicom Group',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'OKE', 'Name': 'ONEOK', 'Sector': 'Energy'},
#  {'Symbol': 'ORCL',
#   'Name': 'Oracle Corp.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'PCAR', 'Name': 'PACCAR Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'PKG',
#   'Name': 'Packaging Corporation of America',
#   'Sector': 'Materials'},
#  {'Symbol': 'PH', 'Name': 'Parker-Hannifin', 'Sector': 'Industrials'},
#  {'Symbol': 'PAYX',
#   'Name': 'Paychex Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'PYPL', 'Name': 'PayPal', 'Sector': 'Information Technology'},
#  {'Symbol': 'PNR', 'Name': 'Pentair Ltd.', 'Sector': 'Industrials'},
#  {'Symbol': 'PBCT',
#   'Name': "People's United Financial",
#   'Sector': 'Financials'},
#  {'Symbol': 'PEP', 'Name': 'PepsiCo Inc.', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'PKI', 'Name': 'PerkinElmer', 'Sector': 'Health Care'},
#  {'Symbol': 'PRGO', 'Name': 'Perrigo', 'Sector': 'Health Care'},
#  {'Symbol': 'PFE', 'Name': 'Pfizer Inc.', 'Sector': 'Health Care'},
#  {'Symbol': 'PCG', 'Name': 'PG&E Corp.', 'Sector': 'Utilities'},
#  {'Symbol': 'PM',
#   'Name': 'Philip Morris International',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'PSX', 'Name': 'Phillips 66', 'Sector': 'Energy'},
#  {'Symbol': 'PNW', 'Name': 'Pinnacle West Capital', 'Sector': 'Utilities'},
#  {'Symbol': 'PXD', 'Name': 'Pioneer Natural Resources', 'Sector': 'Energy'},
#  {'Symbol': 'PNC', 'Name': 'PNC Financial Services', 'Sector': 'Financials'},
#  {'Symbol': 'RL',
#   'Name': 'Polo Ralph Lauren Corp.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'PPG', 'Name': 'PPG Industries', 'Sector': 'Materials'},
#  {'Symbol': 'PPL', 'Name': 'PPL Corp.', 'Sector': 'Utilities'},
#  {'Symbol': 'PX', 'Name': 'Praxair Inc.', 'Sector': 'Materials'},
#  {'Symbol': 'PFG',
#   'Name': 'Principal Financial Group',
#   'Sector': 'Financials'},
#  {'Symbol': 'PG', 'Name': 'Procter & Gamble', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'PGR', 'Name': 'Progressive Corp.', 'Sector': 'Financials'},
#  {'Symbol': 'PLD', 'Name': 'Prologis', 'Sector': 'Real Estate'},
#  {'Symbol': 'PRU', 'Name': 'Prudential Financial', 'Sector': 'Financials'},
#  {'Symbol': 'PEG',
#   'Name': 'Public Serv. Enterprise Inc.',
#   'Sector': 'Utilities'},
#  {'Symbol': 'PSA', 'Name': 'Public Storage', 'Sector': 'Real Estate'},
#  {'Symbol': 'PHM',
#   'Name': 'Pulte Homes Inc.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'PVH', 'Name': 'PVH Corp.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'QRVO', 'Name': 'Qorvo', 'Sector': 'Information Technology'},
#  {'Symbol': 'QCOM',
#   'Name': 'QUALCOMM Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'PWR', 'Name': 'Quanta Services Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'DGX', 'Name': 'Quest Diagnostics', 'Sector': 'Health Care'},
#  {'Symbol': 'RRC', 'Name': 'Range Resources Corp.', 'Sector': 'Energy'},
#  {'Symbol': 'RJF',
#   'Name': 'Raymond James Financial Inc.',
#   'Sector': 'Financials'},
#  {'Symbol': 'RTN', 'Name': 'Raytheon Co.', 'Sector': 'Industrials'},
#  {'Symbol': 'O', 'Name': 'Realty Income Corporation', 'Sector': 'Real Estate'},
#  {'Symbol': 'RHT', 'Name': 'Red Hat Inc.', 'Sector': 'Information Technology'},
#  {'Symbol': 'REG',
#   'Name': 'Regency Centers Corporation',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'REGN', 'Name': 'Regeneron', 'Sector': 'Health Care'},
#  {'Symbol': 'RF', 'Name': 'Regions Financial Corp.', 'Sector': 'Financials'},
#  {'Symbol': 'RSG', 'Name': 'Republic Services Inc', 'Sector': 'Industrials'},
#  {'Symbol': 'RMD', 'Name': 'ResMed', 'Sector': 'Health Care'},
#  {'Symbol': 'RHI',
#   'Name': 'Robert Half International',
#   'Sector': 'Industrials'},
#  {'Symbol': 'ROK',
#   'Name': 'Rockwell Automation Inc.',
#   'Sector': 'Industrials'},
#  {'Symbol': 'COL', 'Name': 'Rockwell Collins', 'Sector': 'Industrials'},
#  {'Symbol': 'ROP', 'Name': 'Roper Technologies', 'Sector': 'Industrials'},
#  {'Symbol': 'ROST', 'Name': 'Ross Stores', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'RCL',
#   'Name': 'Royal Caribbean Cruises Ltd',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'SPGI', 'Name': 'S&P Global, Inc.', 'Sector': 'Financials'},
#  {'Symbol': 'CRM',
#   'Name': 'Salesforce.com',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'SBAC', 'Name': 'SBA Communications', 'Sector': 'Real Estate'},
#  {'Symbol': 'SCG', 'Name': 'SCANA Corp', 'Sector': 'Utilities'},
#  {'Symbol': 'SLB', 'Name': 'Schlumberger Ltd.', 'Sector': 'Energy'},
#  {'Symbol': 'STX',
#   'Name': 'Seagate Technology',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'SEE', 'Name': 'Sealed Air', 'Sector': 'Materials'},
#  {'Symbol': 'SRE', 'Name': 'Sempra Energy', 'Sector': 'Utilities'},
#  {'Symbol': 'SHW', 'Name': 'Sherwin-Williams', 'Sector': 'Materials'},
#  {'Symbol': 'SPG',
#   'Name': 'Simon Property Group Inc',
#   'Sector': 'Real Estate'},
#  {'Symbol': 'SWKS',
#   'Name': 'Skyworks Solutions',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'SLG', 'Name': 'SL Green Realty', 'Sector': 'Real Estate'},
#  {'Symbol': 'SNA', 'Name': 'Snap-On Inc.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'SO', 'Name': 'Southern Co.', 'Sector': 'Utilities'},
#  {'Symbol': 'LUV', 'Name': 'Southwest Airlines', 'Sector': 'Industrials'},
#  {'Symbol': 'SWK',
#   'Name': 'Stanley Black & Decker',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'SBUX',
#   'Name': 'Starbucks Corp.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'STT', 'Name': 'State Street Corp.', 'Sector': 'Financials'},
#  {'Symbol': 'SRCL', 'Name': 'Stericycle Inc', 'Sector': 'Industrials'},
#  {'Symbol': 'SYK', 'Name': 'Stryker Corp.', 'Sector': 'Health Care'},
#  {'Symbol': 'STI', 'Name': 'SunTrust Banks', 'Sector': 'Financials'},
#  {'Symbol': 'SIVB', 'Name': 'SVB Financial', 'Sector': 'Financials'},
#  {'Symbol': 'SYMC',
#   'Name': 'Symantec Corp.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'SYF', 'Name': 'Synchrony Financial', 'Sector': 'Financials'},
#  {'Symbol': 'SNPS',
#   'Name': 'Synopsys Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'SYY', 'Name': 'Sysco Corp.', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'TROW', 'Name': 'T. Rowe Price Group', 'Sector': 'Financials'},
#  {'Symbol': 'TTWO',
#   'Name': 'Take-Two Interactive',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'TPR',
#   'Name': 'Tapestry, Inc.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'TGT', 'Name': 'Target Corp.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'TEL',
#   'Name': 'TE Connectivity Ltd.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'FTI', 'Name': 'TechnipFMC', 'Sector': 'Energy'},
#  {'Symbol': 'TXN',
#   'Name': 'Texas Instruments',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'TXT', 'Name': 'Textron Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'BK',
#   'Name': 'The Bank of New York Mellon Corp.',
#   'Sector': 'Financials'},
#  {'Symbol': 'CLX', 'Name': 'The Clorox Company', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'COO', 'Name': 'The Cooper Companies', 'Sector': 'Health Care'},
#  {'Symbol': 'HSY',
#   'Name': 'The Hershey Company',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'MOS', 'Name': 'The Mosaic Company', 'Sector': 'Materials'},
#  {'Symbol': 'TRV',
#   'Name': 'The Travelers Companies Inc.',
#   'Sector': 'Financials'},
#  {'Symbol': 'DIS',
#   'Name': 'The Walt Disney Company',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'TMO',
#   'Name': 'Thermo Fisher Scientific',
#   'Sector': 'Health Care'},
#  {'Symbol': 'TIF',
#   'Name': 'Tiffany & Co.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'TWX',
#   'Name': 'Time Warner Inc.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'TJX',
#   'Name': 'TJX Companies Inc.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'TMK', 'Name': 'Torchmark Corp.', 'Sector': 'Financials'},
#  {'Symbol': 'TSS',
#   'Name': 'Total System Services',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'TSCO',
#   'Name': 'Tractor Supply Company',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'TDG', 'Name': 'TransDigm Group', 'Sector': 'Industrials'},
#  {'Symbol': 'TRIP', 'Name': 'TripAdvisor', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'FOXA',
#   'Name': 'Twenty-First Century Fox Class A',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'FOX',
#   'Name': 'Twenty-First Century Fox Class B',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'TSN', 'Name': 'Tyson Foods', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'USB', 'Name': 'U.S. Bancorp', 'Sector': 'Financials'},
#  {'Symbol': 'UDR', 'Name': 'UDR Inc', 'Sector': 'Real Estate'},
#  {'Symbol': 'ULTA', 'Name': 'Ulta Beauty', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'UAA',
#   'Name': 'Under Armour Class A',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'UA',
#   'Name': 'Under Armour Class C',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'UNP', 'Name': 'Union Pacific', 'Sector': 'Industrials'},
#  {'Symbol': 'UAL',
#   'Name': 'United Continental Holdings',
#   'Sector': 'Industrials'},
#  {'Symbol': 'UNH',
#   'Name': 'United Health Group Inc.',
#   'Sector': 'Health Care'},
#  {'Symbol': 'UPS', 'Name': 'United Parcel Service', 'Sector': 'Industrials'},
#  {'Symbol': 'URI', 'Name': 'United Rentals, Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'UTX', 'Name': 'United Technologies', 'Sector': 'Industrials'},
#  {'Symbol': 'UHS',
#   'Name': 'Universal Health Services, Inc.',
#   'Sector': 'Health Care'},
#  {'Symbol': 'UNM', 'Name': 'Unum Group', 'Sector': 'Financials'},
#  {'Symbol': 'VFC', 'Name': 'V.F. Corp.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'VLO', 'Name': 'Valero Energy', 'Sector': 'Energy'},
#  {'Symbol': 'VAR', 'Name': 'Varian Medical Systems', 'Sector': 'Health Care'},
#  {'Symbol': 'VTR', 'Name': 'Ventas Inc', 'Sector': 'Real Estate'},
#  {'Symbol': 'VRSN',
#   'Name': 'Verisign Inc.',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'VRSK', 'Name': 'Verisk Analytics', 'Sector': 'Industrials'},
#  {'Symbol': 'VZ',
#   'Name': 'Verizon Communications',
#   'Sector': 'Telecommunication Services'},
#  {'Symbol': 'VRTX',
#   'Name': 'Vertex Pharmaceuticals Inc',
#   'Sector': 'Health Care'},
#  {'Symbol': 'VIAB', 'Name': 'Viacom Inc.', 'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'V', 'Name': 'Visa Inc.', 'Sector': 'Information Technology'},
#  {'Symbol': 'VNO', 'Name': 'Vornado Realty Trust', 'Sector': 'Real Estate'},
#  {'Symbol': 'VMC', 'Name': 'Vulcan Materials', 'Sector': 'Materials'},
#  {'Symbol': 'WMT', 'Name': 'Wal-Mart Stores', 'Sector': 'Consumer Staples'},
#  {'Symbol': 'WBA',
#   'Name': 'Walgreens Boots Alliance',
#   'Sector': 'Consumer Staples'},
#  {'Symbol': 'WM', 'Name': 'Waste Management Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'WAT', 'Name': 'Waters Corporation', 'Sector': 'Health Care'},
#  {'Symbol': 'WEC', 'Name': 'Wec Energy Group Inc', 'Sector': 'Utilities'},
#  {'Symbol': 'WFC', 'Name': 'Wells Fargo', 'Sector': 'Financials'},
#  {'Symbol': 'WELL', 'Name': 'Welltower Inc.', 'Sector': 'Real Estate'},
#  {'Symbol': 'WDC',
#   'Name': 'Western Digital',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'WU',
#   'Name': 'Western Union Co',
#   'Sector': 'Information Technology'},
#  {'Symbol': 'WRK', 'Name': 'WestRock Company', 'Sector': 'Materials'},
#  {'Symbol': 'WY', 'Name': 'Weyerhaeuser Corp.', 'Sector': 'Real Estate'},
#  {'Symbol': 'WHR',
#   'Name': 'Whirlpool Corp.',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'WMB', 'Name': 'Williams Cos.', 'Sector': 'Energy'},
#  {'Symbol': 'WLTW', 'Name': 'Willis Towers Watson', 'Sector': 'Financials'},
#  {'Symbol': 'WYN',
#   'Name': 'Wyndham Worldwide',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'WYNN',
#   'Name': 'Wynn Resorts Ltd',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'XEL', 'Name': 'Xcel Energy Inc', 'Sector': 'Utilities'},
#  {'Symbol': 'XRX', 'Name': 'Xerox Corp.', 'Sector': 'Information Technology'},
#  {'Symbol': 'XLNX', 'Name': 'Xilinx Inc', 'Sector': 'Information Technology'},
#  {'Symbol': 'XL', 'Name': 'XL Capital', 'Sector': 'Financials'},
#  {'Symbol': 'XYL', 'Name': 'Xylem Inc.', 'Sector': 'Industrials'},
#  {'Symbol': 'YUM',
#   'Name': 'Yum! Brands Inc',
#   'Sector': 'Consumer Discretionary'},
#  {'Symbol': 'ZBH', 'Name': 'Zimmer Biomet Holdings', 'Sector': 'Health Care'},
#  {'Symbol': 'ZION', 'Name': 'Zions Bancorp', 'Sector': 'Financials'},
#  {'Symbol': 'ZTS', 'Name': 'Zoetis', 'Sector': 'Health Care'}]

# %%
# path2= os.path.join('Data', 'output', 'financial_ind2018.csv')
# top500_2018.to_csv(path2)

# %% [markdown]
# ## Connect to Mongo DB and pushing the data to database

# %%
conn = 'mongodb+srv://stockUser:stockUser2020@cluster0-h88wh.mongodb.net/test?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)
db = client.stockDB

# %% [markdown]
# Pushing S&P 500 company details to Mongo Collection name:all_company

# %%
db.all_company.insert_many(top500_dict)

# %% [markdown]
# Pushing Financial metadata for each year

# %%
db.top500_2014.insert_many(financial2014_dict)

# %%
db.top500_2015.insert_many(financial2015_dict)

# %%
db.top500_2016.insert_many(financial2016_dict)

# %%
db.top500_2017.insert_many(financial2017_dict)

# %%
db.top500_2018.insert_many(financial2018_dict)

# %% [markdown]
# Data Base name: stockDB. Collection : all_stocks

# %%
db.all_stock.insert_many(stock_dict)
